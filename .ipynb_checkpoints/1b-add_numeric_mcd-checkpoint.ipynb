# %%
import fasttext
model = fasttext.load_model('./util/cc.en.300.bin')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import json
import re

from tqdm import tqdm

# %%
import util.normalization as norm
import util.model as models
import util.utility as util

# %% [markdown]
# # Import Data

# %%
# Opening JSON file
with open("./mcd_result/map_second_mcd.json") as json_file:
    map_second_keys = json.load(json_file)

with open("./mcd_result/map_category_mcd.json") as json_file:
    map_category = json.load(json_file)

with open("./mcd_result/list_first_cycle_mcd.json") as json_file:
    list_first_cycle = json.load(json_file)

# %%
# # Open residu

# df_residu = pd.read_csv("./mcd_result/residu_mcd.csv").fillna("")
# print(df_residu.info())
# df_residu['residu'] = df_residu['residu'].apply(lambda x: str(x).split(', '))

# %%
df_base = pd.read_csv("./mcd_result/base_mcd_v1.csv")

df_base['aspect'] = df_base['aspect'].apply(lambda x: x.split(", "))
df_base['token_sentence'] = df_base['token_sentence'].apply(lambda x: x.split(".\n"))
df_base['token_lemma'] = df_base['token_lemma'].apply(lambda x: x.split(".\n"))

df_base['residu'] = df_base['residu'].apply(lambda x: str(x).split(', '))

print(df_base.info())
df_base.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   reviewer_id     100 non-null    int64
#  1   review          100 non-null    object
#  2   summarize       100 non-null    object
#  3   aspect          100 non-null    object
#  4   token_sentence  100 non-null    object
#  5   token_lemma     100 non-null    object
#  6   rating          100 non-null    int64
#  7   residu          100 non-null    object
# dtypes: int64(2), object(6)
# memory usage: 6.4+ KB
# None
#    reviewer_id                                             review  \
# 0            1  Why does it look like someone spit on my food?...
# 1            2  It'd McDonalds. It is what it is as far as the...
# 2            3  Made a mobile order got to the speaker and che...
# 3            4  My mc. Crispy chicken sandwich was ÃÂ¯ÃÂ¿ÃÂ...
# 4            5  I repeat my order 3 times in the drive thru, a...
#
#                                            summarize  \
# 0   Why does it look like someone spit on my food...
# 1   The staff at McDonalds are always friendly an...
# 2   Never got the refund in the app. Made a mobil...
# 3   My mc. Crispy chicken sandwich was  customer ...
# 4   I repeat my order 3 times in the drive thru, ...
#
#                                               aspect  \
# 0  [clear substance, someone spit, everyone, norm...
# 1               [mcdonalds, atmosphere, staff, food]
# 2                [line, mobile order, money, refund]
# 3  [service, crispy chicken, customer service, ch...
# 4  [order, large fry, large meal, close attention...
#
#                                       token_sentence  \
# 0  [Why does it look like someone spit on my food...
# 1  [The staff at McDonalds are always friendly an...
# 2  [Never got the refund in the app., Made a mobi...
# 3  [Crispy chicken sandwich was  customer service...
# 4  [I repeat my order 3 times in the drive thru, ...
#
#                                          token_lemma  rating  \
# 0  [why do it look like someone spit on my food, ...       1
# 1  [the staff at mcdonalds be always friendly and...       4
# 2  [never get the refund in the app ., make a mob...       1
# 3  [crispy chicken sandwich be customer service b...       5
# 4  [i repeat my order 3 time in the drive thru, i...       1
#
#                                               residu
# 0  [normal transaction, clear substance, everyone...
# 1                                       [atmosphere]
# 2                      [refund, mobile order, money]
# 3                                   [crispy chicken]
# 4           [double filet, english, close attention]

# %%
df_nodes = pd.read_csv("./mcd_result/nodes_mcd.csv")
print(df_nodes.info())
df_nodes.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   node_id       500 non-null    int64
#  1   reviewer_id   500 non-null    int64
#  2   first_cycle   500 non-null    object
#  3   second_cycle  500 non-null    object
#  4   category      500 non-null    object
# dtypes: int64(2), object(3)
# memory usage: 19.7+ KB
# None
#    node_id  reviewer_id first_cycle second_cycle           category
# 0        0            1      normal    situation  place and service
# 1        1            1       other        drink     food and drink
# 2        2            2   mcdonalds        place  place and service
# 3        3            2       other        place  place and service
# 4        4            2        food         food     food and drink

# %% [markdown]
# # Sentiment Analysis

# %% [markdown]
# ## A. Sentiment Sentence

# %%
df_sentiment = df_base[['reviewer_id', 'token_lemma']].copy().explode('token_lemma')

tqdm.pandas()
df_sentiment['pattern_prediction'] = df_sentiment['token_lemma']\
                                    .progress_apply(models.pattern_lexicon_model)\
                                    .map({'positive': 1,'negative': -1})

df_sentiment = df_sentiment.groupby('reviewer_id')['pattern_prediction'].apply(list).reset_index()
print(df_sentiment.info())
df_sentiment
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 297/297 [00:00<00:00, 1648.95it/s]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 2 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   reviewer_id         100 non-null    int64
#  1   pattern_prediction  100 non-null    object
# dtypes: int64(1), object(1)
# memory usage: 1.7+ KB
# None
#     reviewer_id    pattern_prediction
# 0             1       [-1, 1, -1, -1]
# 1             2                [1, 1]
# 2             3  [-1, -1, -1, -1, -1]
# 3             4               [-1, 1]
# 4             5       [-1, 1, -1, -1]
# ..          ...                   ...
# 95           96          [-1, -1, -1]
# 96           97                  [-1]
# 97           98          [-1, -1, -1]
# 98           99                [1, 1]
# 99          100        [1, -1, 1, -1]
#
# [100 rows x 2 columns]

# %% [markdown]
# ## B. Inverse Coding Process

# %%
# Inverse coding process

df_1 = df_base[['reviewer_id', 'aspect', 'token_lemma', 'residu']].copy()
df_2 = df_nodes[['reviewer_id', 'node_id', 'first_cycle', 'second_cycle', 'category']].copy()

df_temp = df_1.merge(df_2, on='reviewer_id', how='inner')
df_temp = df_temp.merge(df_sentiment, on='reviewer_id', how='left')
print(df_temp.info())
df_temp.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   reviewer_id         500 non-null    int64
#  1   aspect              500 non-null    object
#  2   token_lemma         500 non-null    object
#  3   residu              500 non-null    object
#  4   node_id             500 non-null    int64
#  5   first_cycle         500 non-null    object
#  6   second_cycle        500 non-null    object
#  7   category            500 non-null    object
#  8   pattern_prediction  500 non-null    object
# dtypes: int64(2), object(7)
# memory usage: 35.3+ KB
# None
#    reviewer_id                                             aspect  \
# 0            1  [clear substance, someone spit, everyone, norm...
# 1            1  [clear substance, someone spit, everyone, norm...
# 2            2               [mcdonalds, atmosphere, staff, food]
# 3            2               [mcdonalds, atmosphere, staff, food]
# 4            2               [mcdonalds, atmosphere, staff, food]
#
#                                          token_lemma  \
# 0  [why do it look like someone spit on my food, ...
# 1  [why do it look like someone spit on my food, ...
# 2  [the staff at mcdonalds be always friendly and...
# 3  [the staff at mcdonalds be always friendly and...
# 4  [the staff at mcdonalds be always friendly and...
#
#                                               residu  node_id first_cycle  \
# 0  [normal transaction, clear substance, everyone...        0      normal
# 1  [normal transaction, clear substance, everyone...        1       other
# 2                                       [atmosphere]        2   mcdonalds
# 3                                       [atmosphere]        3       other
# 4                                       [atmosphere]        4        food
#
#   second_cycle           category pattern_prediction
# 0    situation  place and service    [-1, 1, -1, -1]
# 1        drink     food and drink    [-1, 1, -1, -1]
# 2        place  place and service             [1, 1]
# 3        place  place and service             [1, 1]
# 4         food     food and drink             [1, 1]

# %%
def inverse_score(x):
    # Define storage

    keywords = [] # Keywords for pattern search
    keys = [] # Key value for storing
    scoring =  {}
    
    
    # Extract all values
    first = x['first_cycle']
    second = x['second_cycle']
    residu = x['residu']
    aspect = x['aspect']
    tokens = x['token_lemma']
    scores = x['pattern_prediction']
    category = x['category']
    
    
    
    ################### INVERSING PROCESS ##########################################
    # Get the aspect of each code
    if first == 'other':
        for res in residu:
            nearest = util.get_nearest_word(res, [second], model, threshold=.35)
            if nearest:
                keywords.append(res)
                keys.append(second)
                break
    
    else:
        pattern = re.compile(rf"{first}")
        for element in aspect:
            if pattern.search(element):
                keywords.append(element)
                keys.append(first)
                

    # If keys and keywords empty, return None
    if (len(keys) == 0) and (len(keywords) == 0):
        return
    
    ################################# SCORING ##################################################
    # Get the index sentence
    for keyword in keywords:
        pattern = re.compile(rf"{keyword}")
        
        for idx, element in enumerate(tokens):
            if pattern.search(element):
                if keyword not in scoring:
                    scoring[keyword] = scores[idx]
                else:
                    scoring[keyword] = scoring[keyword] + scores[idx]

        if keyword not in scoring:
            # If it's not detected we have to split it and choose the token that contains all element.
            temp_split_result = {}
            for e in keyword.split(' '):
                pattern = re.compile(rf"{e}")
                
                for idx, element in enumerate(tokens):
                    if pattern.search(element):
                        if keyword not in scoring:
                            scoring[keyword] = scores[idx]
                        else:
                            scoring[keyword] = scoring[keyword] + scores[idx]

    # Scoring    
    total_scores = sum(list(scoring.values()))
    tags = '/'.join(keywords)
    
    if total_scores < 0:
        return (second, tags, 'negative')
    else:
        return (second, tags, 'positive')
#     return (second, tags, total_scores)

df_temp['key_score_aspect'] = [inverse_score(x[-1]) for x in df_temp.iterrows()]
# If positive => sentiment 1, if negative => sentiment 0, if empty => sentiment 1 
df_temp['sentiment'] = df_temp['key_score_aspect'].apply(lambda x: 1 if not x else 1 if x[-1] == 'positive' else 0)

# print(inverse_score(df_temp.iloc[495]))
# print(inverse_score(df_temp.iloc[497]))

df_temp
# Out:
#      reviewer_id                                             aspect  \
# 0              1  [clear substance, someone spit, everyone, norm...
# 1              1  [clear substance, someone spit, everyone, norm...
# 2              2               [mcdonalds, atmosphere, staff, food]
# 3              2               [mcdonalds, atmosphere, staff, food]
# 4              2               [mcdonalds, atmosphere, staff, food]
# ..           ...                                                ...
# 495           99                     [ice cream, best fry, allways]
# 496          100                [mcdonalds, people, order, english]
# 497          100                [mcdonalds, people, order, english]
# 498          100                [mcdonalds, people, order, english]
# 499          100                [mcdonalds, people, order, english]
#
#                                            token_lemma  \
# 0    [why do it look like someone spit on my food, ...
# 1    [why do it look like someone spit on my food, ...
# 2    [the staff at mcdonalds be always friendly and...
# 3    [the staff at mcdonalds be always friendly and...
# 4    [the staff at mcdonalds be always friendly and...
# ..                                                 ...
# 495  [allways have the best fry and ice cream in th...
# 496  [mcdonalds be great, they really need to hire ...
# 497  [mcdonalds be great, they really need to hire ...
# 498  [mcdonalds be great, they really need to hire ...
# 499  [mcdonalds be great, they really need to hire ...
#
#                                                 residu  node_id first_cycle  \
# 0    [normal transaction, clear substance, everyone...        0      normal
# 1    [normal transaction, clear substance, everyone...        1       other
# 2                                         [atmosphere]        2   mcdonalds
# 3                                         [atmosphere]        3       other
# 4                                         [atmosphere]        4        food
# ..                                                 ...      ...         ...
# 495                                          [allways]      495       cream
# 496                                          [english]      496   mcdonalds
# 497                                          [english]      497      people
# 498                                          [english]      498       other
# 499                                          [english]      499       order
#
#     second_cycle           category pattern_prediction  \
# 0      situation  place and service    [-1, 1, -1, -1]
# 1          drink     food and drink    [-1, 1, -1, -1]
# 2          place  place and service             [1, 1]
# 3          place  place and service             [1, 1]
# 4           food     food and drink             [1, 1]
# ..           ...                ...                ...
# 495         food     food and drink             [1, 1]
# 496        place  place and service     [1, -1, 1, -1]
# 497    situation  place and service     [1, -1, 1, -1]
# 498        other              other     [1, -1, 1, -1]
# 499         food     food and drink     [1, -1, 1, -1]
#
#                               key_score_aspect  sentiment
# 0    (situation, normal transaction, positive)          1
# 1              (drink, someone spit, negative)          0
# 2                 (place, mcdonalds, positive)          1
# 3                (place, atmosphere, positive)          1
# 4                       (food, food, positive)          1
# ..                                         ...        ...
# 495                (food, ice cream, positive)          1
# 496               (place, mcdonalds, positive)          1
# 497              (situation, people, positive)          1
# 498                                       None          1
# 499                    (food, order, negative)          0
#
# [500 rows x 11 columns]

# %% [markdown]
# # Sentiment Scoring

# %%
result = df_temp[['node_id', 'reviewer_id', 
                  'first_cycle', 'second_cycle', 
                  'category', 'sentiment']].copy()

result
# Out:
#      node_id  reviewer_id first_cycle second_cycle           category  \
# 0          0            1      normal    situation  place and service
# 1          1            1       other        drink     food and drink
# 2          2            2   mcdonalds        place  place and service
# 3          3            2       other        place  place and service
# 4          4            2        food         food     food and drink
# ..       ...          ...         ...          ...                ...
# 495      495           99       cream         food     food and drink
# 496      496          100   mcdonalds        place  place and service
# 497      497          100      people    situation  place and service
# 498      498          100       other        other              other
# 499      499          100       order         food     food and drink
#
#      sentiment
# 0            1
# 1            0
# 2            1
# 3            1
# 4            1
# ..         ...
# 495          1
# 496          1
# 497          1
# 498          1
# 499          0
#
# [500 rows x 6 columns]

# %%
first_sentiment = result.groupby('first_cycle')\
                    .agg({'sentiment': lambda x: round(np.sum(x) / len(x), 3)})\
                    .reset_index()\
                    .rename(columns={'sentiment': 'first_cycle_sentiment_positive_rate'})

second_sentiment = result.groupby('second_cycle')\
                    .agg({'sentiment': lambda x: round(np.sum(x) / len(x), 3)})\
                    .reset_index()\
                    .rename(columns={'sentiment': 'second_cycle_sentiment_positive_rate'})

category_sentiment = result.groupby('category')\
                    .agg({'sentiment': lambda x: round(np.sum(x) / len(x), 3)})\
                    .reset_index()\
                    .rename(columns={'sentiment': 'category_sentiment_positive_rate'})


result = result.merge(first_sentiment, on='first_cycle', how='left')
result = result.merge(second_sentiment, on='second_cycle', how='left')
result = result.merge(category_sentiment, on='category', how='left')
result['overall_sentiment_positive_rate'] = round(np.sum(result['sentiment']) / result.shape[0], 3) * np.ones(result.shape[0])


result = result.drop('sentiment', axis=1)

result
# Out:
#      node_id  reviewer_id first_cycle second_cycle           category  \
# 0          0            1      normal    situation  place and service
# 1          1            1       other        drink     food and drink
# 2          2            2   mcdonalds        place  place and service
# 3          3            2       other        place  place and service
# 4          4            2        food         food     food and drink
# ..       ...          ...         ...          ...                ...
# 495      495           99       cream         food     food and drink
# 496      496          100   mcdonalds        place  place and service
# 497      497          100      people    situation  place and service
# 498      498          100       other        other              other
# 499      499          100       order         food     food and drink
#
#      sentiment  first_cycle_sentiment_positive_rate  \
# 0            1                                1.000
# 1            0                                0.583
# 2            1                                0.500
# 3            1                                0.583
# 4            1                                0.500
# ..         ...                                  ...
# 495          1                                0.500
# 496          1                                0.500
# 497          1                                0.400
# 498          1                                0.583
# 499          0                                0.200
#
#      second_cycle_sentiment_positive_rate  category_sentiment_positive_rate  \
# 0                                   0.348                             0.385
# 1                                   0.389                             0.336
# 2                                   0.408                             0.385
# 3                                   0.408                             0.385
# 4                                   0.319                             0.336
# ..                                    ...                               ...
# 495                                 0.319                             0.336
# 496                                 0.408                             0.385
# 497                                 0.348                             0.385
# 498                                 0.653                             0.653
# 499                                 0.319                             0.336
#
#      overall_sentiment_positive_rate
# 0                              0.424
# 1                              0.424
# 2                              0.424
# 3                              0.424
# 4                              0.424
# ..                               ...
# 495                            0.424
# 496                            0.424
# 497                            0.424
# 498                            0.424
# 499                            0.424
#
# [500 rows x 10 columns]

# %% [markdown]
# # Add Review Value

# %%
df_rating = df_base[['reviewer_id', 'rating']]

result = result.merge(df_rating, on='reviewer_id', how='left')

first_rating = result.groupby('first_cycle')\
                .agg({'rating': 'mean'})\
                .apply(lambda x: round(x, 3))\
                .reset_index()\
                .rename(columns={'rating': 'first_cycle_rating'})
second_rating = result.groupby('second_cycle')\
                .agg({'rating': 'mean'})\
                .apply(lambda x: round(x, 3))\
                .reset_index()\
                .rename(columns={'rating': 'second_cycle_rating'})
category_rating = result.groupby('category')\
                .agg({'rating': 'mean'})\
                .apply(lambda x: round(x, 3))\
                .reset_index()\
                .rename(columns={'rating': 'category_rating'})

result = result.merge(first_rating, on='first_cycle', how='left')
result = result.merge(second_rating, on='second_cycle', how='left')
result = result.merge(overall_rating, on='category', how='left')
result['overall_rating'] = round(np.sum(result['rating']) / result.shape[0], 3) * np.ones(result.shape[0])

result = result.drop('rating', axis=1)

result
# Out:
#      node_id  reviewer_id first_cycle second_cycle           category  \
# 0          0            1      normal    situation  place and service
# 1          1            1       other        drink     food and drink
# 2          2            2   mcdonalds        place  place and service
# 3          3            2       other        place  place and service
# 4          4            2        food         food     food and drink
# ..       ...          ...         ...          ...                ...
# 495      495           99       cream         food     food and drink
# 496      496          100   mcdonalds        place  place and service
# 497      497          100      people    situation  place and service
# 498      498          100       other        other              other
# 499      499          100       order         food     food and drink
#
#      sentiment  first_cycle_sentiment_positive_rate  \
# 0            1                                1.000
# 1            0                                0.583
# 2            1                                0.500
# 3            1                                0.583
# 4            1                                0.500
# ..         ...                                  ...
# 495          1                                0.500
# 496          1                                0.500
# 497          1                                0.400
# 498          1                                0.583
# 499          0                                0.200
#
#      second_cycle_sentiment_positive_rate  category_sentiment_positive_rate  \
# 0                                   0.348                             0.385
# 1                                   0.389                             0.336
# 2                                   0.408                             0.385
# 3                                   0.408                             0.385
# 4                                   0.319                             0.336
# ..                                    ...                               ...
# 495                                 0.319                             0.336
# 496                                 0.408                             0.385
# 497                                 0.348                             0.385
# 498                                 0.653                             0.653
# 499                                 0.319                             0.336
#
#      overall_sentiment_positive_rate  first_cycle_rating  secpnd_cycle_rating  \
# 0                              0.424               1.667                1.565
# 1                              0.424               2.139                1.833
# 2                              0.424               1.750                2.014
# 3                              0.424               2.139                2.014
# 4                              0.424               2.700                2.062
# ..                               ...                 ...                  ...
# 495                            0.424               2.750                2.062
# 496                            0.424               1.750                2.014
# 497                            0.424               3.000                1.565
# 498                            0.424               2.139                1.944
# 499                            0.424               1.900                2.062
#
#      overall_rating
# 0             1.940
# 1             2.007
# 2             1.940
# 3             1.940
# 4             2.007
# ..              ...
# 495           2.007
# 496           1.940
# 497           1.940
# 498           1.944
# 499           2.007
#
# [500 rows x 13 columns]

# %%
# Update base

df_temp['key_score_aspect'] = df_temp['key_score_aspect'].apply(lambda x: ", ".join(list(x)) if x else '')
df_int = df_temp[['reviewer_id', 'key_score_aspect']]\
            .groupby('reviewer_id')\
            .agg({'key_score_aspect': lambda x: "; ".join(x)})\
            .reset_index()
df_base = df_base.merge(df_int, on='reviewer_id', how='left')

df_base['aspect'] = df_base['aspect'].apply(lambda x: ", ".join(x))
df_base['token_sentence'] = df_base['token_sentence'].apply(lambda x: ", ".join(x))
df_base['token_lemma'] = df_base['token_lemma'].apply(lambda x: ", ".join(x))
df_base['residu'] = df_base['residu'].apply(lambda x: ", ".join(x))

df_base.head()
# Out:
#    reviewer_id                                             review  \
# 0            1  Why does it look like someone spit on my food?...
# 1            2  It'd McDonalds. It is what it is as far as the...
# 2            3  Made a mobile order got to the speaker and che...
# 3            4  My mc. Crispy chicken sandwich was ÃÂ¯ÃÂ¿ÃÂ...
# 4            5  I repeat my order 3 times in the drive thru, a...
#
#                                            summarize  \
# 0   Why does it look like someone spit on my food...
# 1   The staff at McDonalds are always friendly an...
# 2   Never got the refund in the app. Made a mobil...
# 3   My mc. Crispy chicken sandwich was  customer ...
# 4   I repeat my order 3 times in the drive thru, ...
#
#                                               aspect  \
# 0  clear substance, someone spit, everyone, norma...
# 1                 mcdonalds, atmosphere, staff, food
# 2                  line, mobile order, money, refund
# 3  service, crispy chicken, customer service, chi...
# 4  order, large fry, large meal, close attention,...
#
#                                       token_sentence  \
# 0  Why does it look like someone spit on my food,...
# 1  The staff at McDonalds are always friendly and...
# 2  Never got the refund in the app., Made a mobil...
# 3  Crispy chicken sandwich was  customer service ...
# 4  I repeat my order 3 times in the drive thru, i...
#
#                                          token_lemma  rating  \
# 0  why do it look like someone spit on my food, i...       1
# 1  the staff at mcdonalds be always friendly and ...       4
# 2  never get the refund in the app ., make a mobi...       1
# 3  crispy chicken sandwich be customer service be...       5
# 4  i repeat my order 3 time in the drive thru, it...       1
#
#                                               residu  \
# 0  normal transaction, clear substance, everyone,...
# 1                                         atmosphere
# 2                        refund, mobile order, money
# 3                                     crispy chicken
# 4             double filet, english, close attention
#
#                                     key_score_aspect
# 0  situation, normal transaction, positive; drink...
# 1  place, mcdonalds, positive; place, atmosphere,...
# 2  situation, line, negative; service, mobile ord...
# 3  service, service/customer service, positive; ;...
# 4  place, close attention, negative; food, order,...

# %%
df_int
# Out:
#     reviewer_id                                   key_score_aspect
# 0             1  situation, normal transaction, positive; drink...
# 1             2  place, mcdonalds, positive; place, atmosphere,...
# 2             3  situation, line, negative; service, mobile ord...
# 3             4  service, service/customer service, positive; ;...
# 4             5  place, close attention, negative; food, order,...
# ..          ...                                                ...
# 95           96  service, time management, negative; service, s...
# 96           97  situation, mess, negative; ; food, order food,...
# 97           98  service, rude service, negative; food, order w...
# 98           99  drink, ice cream, positive; ; food, best fry, ...
# 99          100  place, mcdonalds, positive; situation, people,...
#
# [100 rows x 2 columns]

# %%
result.to_csv("./mcd_result/final_nodes.csv", index=False)
df_base.to_csv("./mcd_result/base_mcd_v2.csv", index=False)
