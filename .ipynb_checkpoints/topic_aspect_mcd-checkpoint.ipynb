# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from tqdm import tqdm

# %%
import util.normalization as norm
import util.model as models
import util.utility as util

# %%
df = pd.read_csv("./sample-mcd.csv", encoding='latin1')
df = df[['reviewer_id', 'review_time', 'review', 'rating']]
print(df.info())
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   reviewer_id  100 non-null    int64
#  1   review_time  100 non-null    object
#  2   review       100 non-null    object
#  3   rating       100 non-null    object
# dtypes: int64(1), object(3)
# memory usage: 3.3+ KB
# None
#    reviewer_id   review_time  \
# 0            1  3 months ago
# 1            2    5 days ago
# 2            3    5 days ago
# 3            4   a month ago
# 4            5  2 months ago
#
#                                               review   rating
# 0  Why does it look like someone spit on my food?...   1 star
# 1  It'd McDonalds. It is what it is as far as the...  4 stars
# 2  Made a mobile order got to the speaker and che...   1 star
# 3  My mc. Crispy chicken sandwich was ÃÂ¯ÃÂ¿ÃÂ...  5 stars
# 4  I repeat my order 3 times in the drive thru, a...   1 star

# %% [markdown]
# # Normalization

# %%
# df_prc = df[['reviewer_id', 'review']].copy()

# # Remove non-ASCII
# df_prc['token_sentence'] = df_prc['review'].apply(norm.remove_non_ascii)

# # Expand contractions
# df_prc['token_sentence'] = df_prc['token_sentence'].apply(norm.expand_contractions)

# # Remove characters
# df_prc['token_sentence'] = df_prc['token_sentence'].apply(norm.remove_characters, args=(True,))

# # Remove enter tab
# df_prc['token_clean'] = df_prc['token_sentence'].apply(norm.remove_enter_tab)

# # Lemmatization
# df_prc['token_clean'] = df_prc['token_clean'].apply(norm.lemmatize_text)

# %%
# Tokenization into sentence

df_st = df[['reviewer_id', 'review']].copy()

# Remove non-ASCII
df_st['token_sentence'] = df_st['review'].apply(norm.remove_non_ascii)

# Sentence Tokenization
df_st['token_sentence'] = df_st['token_sentence'].apply(norm.sentence_tokenize)
df_st = df_st.explode('token_sentence')
df_st['token_sentence'] = df_st['token_sentence'].str.strip()

# Expand contractions
df_st['token_sentence'] = df_st['token_sentence'].apply(norm.expand_contractions)

# Remove characters
df_st['token_sentence'] = df_st['token_sentence'].apply(norm.remove_characters, args=(True,))

# Remove enter tab
df_st['token_clean'] = df_st['token_sentence'].apply(norm.remove_enter_tab)

# Lemmatization
df_st['token_clean'] = df_st['token_clean'].apply(norm.lemmatize_text)

# %% [markdown]
# # Get Aspect (Rules Based)

# %%
# Get aspect from rules
tqdm.pandas()
df_st['sub_aspect'] = df_st['token_clean']\
                        .progress_apply(util.get_aspect_rules)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 545/545 [00:24<00:00, 22.55it/s]

# %%
df_st.head()
# Out:
#    reviewer_id                                             review  \
# 0            1  Why does it look like someone spit on my food?...
# 0            1  Why does it look like someone spit on my food?...
# 0            1  Why does it look like someone spit on my food?...
# 0            1  Why does it look like someone spit on my food?...
# 0            1  Why does it look like someone spit on my food?...
#
#                                       token_sentence  \
# 0      Why does it look like someone spit on my food
# 0                         I had a normal transaction
# 0                      everyone was chill and polite
# 0                   but now i dont want to eat this.
# 0  Im trying not to think about what this milky w...
#
#                                          token_clean            sub_aspect
# 0        why do it look like someone spit on my food        {someone spit}
# 0                        i have a normal transaction  {normal transaction}
# 0                       everyone be chill and polite            {everyone}
# 0                  but now i dont want to eat this .                    {}
# 0  im try not to think about what this milky whit...     {clear substance}

# %%
# Create summary
mask = df_st['sub_aspect'].apply(lambda x: False if len(x) == 0 else True).values

df_summary = df_st[mask].groupby(['reviewer_id'])['token_sentence']\
                .apply(lambda x: '. '.join(x))\
                .reset_index()\
                .rename(columns={'token_sentence': 'summary'})

df_prc = df_st.groupby(['reviewer_id'])\
                .agg({'sub_aspect': lambda x: set().union(*x),
                      'token_clean': lambda x: '. '.join(x),
                     })\
                .reset_index()

df_prc = df_prc.merge(df_summary, on='reviewer_id', how='left').fillna("")
print(df_prc.info())
df_prc.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   reviewer_id  100 non-null    int64
#  1   sub_aspect   100 non-null    object
#  2   token_clean  100 non-null    object
#  3   summary      100 non-null    object
# dtypes: int64(1), object(3)
# memory usage: 3.3+ KB
# None
#    reviewer_id                                         sub_aspect  \
# 0            1  {clear substance, normal transaction, someone ...
# 1            2  {atmosphere, food place, staff, pleasant exper...
# 2            3  {line, next day, mobile order, manager, refund...
# 3            4  {customer service, crispy chicken, chicken san...
# 4            5  {close attention, order, large fry, english, l...
#
#                                          token_clean  \
# 0  why do it look like someone spit on my food. i...
# 1  it would mcdonalds .. it be what it be as far ...
# 2  make a mobile order get to the speaker and che...
# 3  my mc .. crispy chicken sandwich be customer s...
# 4  i repeat my order 3 time in the drive thru. an...
#
#                                              summary
# 0  Why does it look like someone spit on my food....
# 1  It is what it is as far as the food and atmosp...
# 2  Made a mobile order got to the speaker and che...
# 3  Crispy chicken sandwich was  customer service ...
# 4  I repeat my order 3 times in the drive thru. i...

# %%
# # Get aspect from rules
# tqdm.pandas()
# df_prc['sub_aspect'] = df_prc['token_clean']\
#                         .progress_apply(util.get_aspect_rules)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:20<00:00,  4.78it/s]

# %%
# print(df_prc.info())
# df_prc.head()

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

text = ""
sub_aspect = df_prc['sub_aspect'].values
for i in range(df_prc.shape[0]):
    text = text + " " + " ".join(list(sub_aspect[i]))
    

text = text.strip()

wordcloud = WordCloud(background_color='white').generate(text)
plt.style.use('classic')
plt.figure(figsize=(12,10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
# df['sub_aspect'] = df_prc['sub_aspect'].apply(lambda x: ", ".join(list(x)))

# %% [markdown]
# # Get Topic

# %%
def get_optimum_lda(dictionary, corpus, texts, limit,
                    start=2, step=1, get_result=False,
                    iterations=20, passes=1):
    coherence_values = []
    
    for n in range(start, limit, step):
        lda = gensim.models.LdaMulticore(corpus=corpus,
                                         num_topics=n,
                                         id2word=dictionary,
                                         iterations=iterations,
                                         passes=passes)
        
        # Create coherence
        coherence_model = CoherenceModel(model=lda, 
                                         texts=texts,
                                         dictionary=dictionary, 
                                         coherence='c_v')
        coherence_values.append(coherence_model.get_coherence())
    
    
    opt_num_topics = start + coherence_values.index(max(coherence_values))
    
    lda_opt = gensim.models.LdaMulticore(corpus=corpus,
                                         num_topics=opt_num_topics,
                                         id2word=dictionary)
    
    if get_result:
        print(coherence_values)
    
    return lda_opt

# %%
import gensim
from gensim.models import CoherenceModel


texts = df_prc['token_clean'].apply(util.preprocess_lda)

dictionary = gensim.corpora.Dictionary(texts)

dictionary.filter_extremes(no_below=15, no_above=0.5, keep_n=100_000)
bow_corpus = [dictionary.doc2bow(doc) for doc in texts]

lda_opt = get_optimum_lda(dictionary, bow_corpus,
                          texts, 10, get_result=True,
                          passes=50, iterations=100)
# Out:
# WARNING:gensim.models.ldamulticore:too few updates, training might not converge; consider increasing the number of passes or iterations to improve accuracy
# [0.5094352004632003, 0.5094352004632003, 0.5094352004632003, 0.5094352004632003, 0.5094352004632005, 0.5094352004632005, 0.5094352004632003, 0.5094352004632003]

# %%
# Print topic
for idx, topic in lda_opt.print_topics(-1):
    print('Topic: {} \nWords: {}'.format(idx, topic))
# Out:
# Topic: 0
# Words: 0.469*"order" + 0.173*"food" + 0.093*"drive" + 0.087*"time" + 0.063*"service" + 0.044*"location" + 0.038*"thru" + 0.032*"staff"
# Topic: 1
# Words: 0.244*"order" + 0.203*"staff" + 0.203*"service" + 0.086*"food" + 0.086*"time" + 0.086*"location" + 0.046*"drive" + 0.046*"thru"
# Topic: 2
# Words: 0.182*"food" + 0.182*"time" + 0.182*"location" + 0.181*"staff" + 0.148*"order" + 0.077*"drive" + 0.041*"thru" + 0.007*"service"
# Topic: 3
# Words: 0.231*"food" + 0.230*"service" + 0.230*"location" + 0.125*"drive" + 0.124*"thru" + 0.022*"order" + 0.020*"time" + 0.019*"staff"
# Topic: 4
# Words: 0.323*"time" + 0.211*"drive" + 0.210*"order" + 0.093*"thru" + 0.059*"staff" + 0.036*"food" + 0.036*"service" + 0.033*"location"
# Topic: 5
# Words: 0.200*"drive" + 0.182*"time" + 0.150*"thru" + 0.131*"order" + 0.126*"location" + 0.100*"service" + 0.057*"staff" + 0.053*"food"

# %%
def predict_topic(text):
    text = util.preprocess_lda(text)
    bow_vector = dictionary.doc2bow(text)
    
    result = sorted(lda_opt[bow_vector], 
                    key=lambda x: -1*x[1])[0][0]
    
    return result
    
# Extract keywords into a dictionary or list
threshold = 0.1
topics_dict = {}
for topic_num, topic in lda_opt.show_topics(num_topics=10,
                                                num_words=10,
                                                formatted=False):
    keywords = [word for word, w in topic if w > threshold]
    topics_dict[topic_num] = keywords

# %%
topics_dict
# Out:
# {0: ['order', 'food'],
#  1: ['order', 'staff', 'service'],
#  2: ['food', 'time', 'location', 'staff', 'order'],
#  3: ['food', 'service', 'location', 'drive', 'thru'],
#  4: ['time', 'drive', 'order'],
#  5: ['drive', 'time', 'thru', 'order', 'location']}

# %%
tqdm.pandas()
df['topic'] = df_prc['token_clean'].progress_apply(predict_topic)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 262.08it/s]

# %%
tqdm.pandas()
df['key_topic'] = df['topic']\
                    .progress_apply(lambda x: ", ".join(topics_dict[x]))
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 198593.94it/s]

# %%
df.head()
# Out:
#    reviewer_id   review_time  \
# 0            1  3 months ago
# 1            2    5 days ago
# 2            3    5 days ago
# 3            4   a month ago
# 4            5  2 months ago
#
#                                               review   rating  topic  \
# 0  Why does it look like someone spit on my food?...   1 star      3
# 1  It'd McDonalds. It is what it is as far as the...  4 stars      2
# 2  Made a mobile order got to the speaker and che...   1 star      0
# 3  My mc. Crispy chicken sandwich was ÃÂ¯ÃÂ¿ÃÂ...  5 stars      1
# 4  I repeat my order 3 times in the drive thru, a...   1 star      4
#
#                               key_topic
# 0  food, service, location, drive, thru
# 1    food, time, location, staff, order
# 2                           order, food
# 3                 order, staff, service
# 4                    time, drive, order

# %%
# df.to_csv('result_mcd.csv', index=False)
