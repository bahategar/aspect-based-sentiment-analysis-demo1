# %%
# Utility: Preparation text

from contractions import CONTRACTION_MAP

##========== PREPARATION TEXT ===========##

# Contraction
def expand_contractions(sentence, contraction_mapping=CONTRACTION_MAP):
    """
    Expand the contractions in a sentence. For example don't => do not.
    
    Paramters:
    sentence (str): The input sentence to clean.
    contraction_mapping (dict): A dictionary for mapping contractions.
    
    
    Returns:
    str: The expanded contraction sentence.
    """
    
    contractions_pattern = re.compile('({})'.format('|'.join(contraction_mapping.keys())),
                                      flags=re.IGNORECASE|re.DOTALL)
    
    def expanded_match(contraction):
        """
        Filter for expanding the matched contraction.
        
        Parameters:
        contraction (str): The input of contraction
        
        Returns:
        str: The expanded contraction.
        """
        match = contraction.group(0)
        first_char = match[0]
        expanded_contraction = contraction_mapping.get(match) if contraction_mapping.get(match) else contraction_mapping.get(match.lower())
        
        expanded_contraction = first_char + expanded_contraction[1:]
        return expanded_contraction
    
    expanded_sentence = contractions_pattern.sub(expanded_match, sentence)
    return expanded_sentence


def remove_extra_spaces(sentence):
    # Use regex to replace multiple spaces with a single space
    return re.sub(r'\s+', ' ', sentence).strip()


def remove_non_ascii(text):
    """
    Remove all non-ASCII characters from the text.

    Parameters:
    text (str): The input text to clean.

    Returns:
    str: The cleaned text with only ASCII characters.
    
    """
    
    return ''.join([char for char in text if ord(char) < 128])

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import re
import json
import os

import torch
import torch.nn.functional as F
from transformers import BertTokenizer

from tqdm import tqdm

# %%
from model.model import bertATE, bertABSA
from transformers import pipeline

# %% [markdown]
# # Load Model

# %%
modelBertSum = pipeline('summarization', model='model/summarization-0', device=0)
modelBertSum
# Out:
# C:\Users\Baha Tegar\Desktop\Preparation\Transformers\.venv\Lib\site-packages\transformers\models\bart\configuration_bart.py:176: UserWarning: Please make sure the config includes `forced_bos_token_id=0` in future versions. The config can simply be saved and uploaded again to be fixed.
#   warnings.warn(

# %% [markdown]
# # Load Dataset

# %%
df = pd.read_csv("./sample-phone.csv")
print(df.info())
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   asin          100 non-null    object
#  1   name          100 non-null    object
#  2   rating        100 non-null    int64
#  3   date          100 non-null    object
#  4   verified      100 non-null    bool
#  5   title         100 non-null    object
#  6   body          100 non-null    object
#  7   helpfulVotes  100 non-null    float64
# dtypes: bool(1), float64(1), int64(1), object(5)
# memory usage: 5.7+ KB
# None
#          asin                name  rating               date  verified  \
# 0  B07K76LBLZ       PlaYboY BuNnY       5  February 14, 2019      True
# 1  B07P8MQHSH           Gemini_13       3     August 2, 2019      True
# 2  B01NC2MEJP         Kashm30uttz       2     April 30, 2018      True
# 3  B018OMP8ES           Techie241       3   January 16, 2017      True
# 4  B07QC4R451  Michelle Wildhagen       1      June 22, 2019      True
#
#                                                title  \
# 0                           Best phone money can buy
# 1               Pixel 3 has frequent display defects
# 2  the lower left corner of the phone doesnt work...
# 3           Great phone, be careful with the sellers
# 4  U had no issue with the seller they were great...
#
#                                                 body  helpfulVotes
# 0               So far this phone is the bees knees.           3.0
# 1  I like this phone model. I bought this phone a...          20.0
# 2  the lower left corner of the phone doesnt work...           1.0
# 3  The phone is wonderful, if you're considering ...          10.0
# 4  I was very disappointed in the way this phone ...           3.0

# %%
sample = df.iloc[0]['date']

print(sample)
pd.to_datetime(sample)
# Out:
# February 14, 2019
# Timestamp('2019-02-14 00:00:00')

# %%
# Check is asin unique
df['asin'].nunique()
# Out:
# 87

# %%
df['verified'].value_counts()
# Out:
# verified
# True     87
# False    13
# Name: count, dtype: int64

# %%
# Prepare data
df = df[df['verified'] == True]
df['date'] = df['date'].apply(lambda x: str(pd.to_datetime(x).date()))
df['review'] = df['title'] + ". " + df['body']
df = df.reset_index().rename({'index': 'review_id', 'date': 'review_time'}, axis=1)
df = df[['review_id', 'review_time', 'review_time', 'rating', 'helpfulVotes']].copy()

print(df.info())
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 87 entries, 0 to 86
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   review_id     87 non-null     int64
#  1   date          87 non-null     object
#  2   review        87 non-null     object
#  3   rating        87 non-null     int64
#  4   helpfulVotes  87 non-null     float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 3.5+ KB
# None
#    review_id        date                                             review  \
# 0          0  2019-02-14  Best phone money can buy.So far this phone is ...
# 1          1  2019-08-02  Pixel 3 has frequent display defects.I like th...
# 2          2  2018-04-30  the lower left corner of the phone doesnt work...
# 3          3  2017-01-16  Great phone, be careful with the sellers.The p...
# 4          4  2019-06-22  U had no issue with the seller they were great...
#
#    rating  helpfulVotes
# 0       5           3.0
# 1       3          20.0
# 2       2           1.0
# 3       3          10.0
# 4       1           3.0

# %%
# Apply extraction

def process_text(x):
    # Prepare sentence
    texts = expand_contractions(x)
    texts = remove_extra_spaces(x)
    texts = remove_non_ascii(x)
    
    return texts

df['review_processed'] = df['review'].apply(process_text)
df.head()
# Out:
#    review_id        date                                             review  \
# 0          0  2019-02-14  Best phone money can buy.So far this phone is ...
# 1          1  2019-08-02  Pixel 3 has frequent display defects.I like th...
# 2          2  2018-04-30  the lower left corner of the phone doesnt work...
# 3          3  2017-01-16  Great phone, be careful with the sellers.The p...
# 4          4  2019-06-22  U had no issue with the seller they were great...
#
#    rating  helpfulVotes                                   review_processed
# 0       5           3.0  Best phone money can buy.So far this phone is ...
# 1       3          20.0  Pixel 3 has frequent display defects.I like th...
# 2       2           1.0  the lower left corner of the phone doesnt work...
# 3       3          10.0  Great phone, be careful with the sellers.The p...
# 4       1           3.0  U had no issue with the seller they were great...

# %% [markdown]
# # Paraphrasing

# %%
sample = df['review_processed'].iloc[45]
actual = df['review'].iloc[45]

print("ACTUAL")
print(actual)
print("PROCESSED")
print(sample)
# Out:
# ACTUAL
# wifi problems.This phone like other sony phones has serious wifi issues. Even non flagship products from htc, samsung, huwaie don't have problems with wifi. It will connect but will not have internet while other devices on my network have no issues.
# PROCESSED
# wifi problems.This phone like other sony phones has serious wifi issues. Even non flagship products from htc, samsung, huwaie don't have problems with wifi. It will connect but will not have internet while other devices on my network have no issues.

# %%
modelBertSum(f"correct:{sample} </s>")
# Out:
# Your max_length is set to 142, but your input_length is only 62. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=31)
# [{'summary_text': "This phone like other sony phones has serious wifi issues. It will connect but will not have internet while other devices on my network have no issues. Even non flagship products from HTC, Samsung, and Sony don't have problems with wifi issues with these phones."}]

# %%
tqdm.pandas()
def process(x):
    if len(x) > 150:
        return  modelBertSum(f"correct:{x}</s>")[0]['summary_text']
    return x
df['review_processed'] = df['review_processed'].progress_apply(lambda x: process(x))
# Out:
#   0%|                                                                                           | 0/87 [00:00<?, ?it/s]Your max_length is set to 142, but your input_length is only 68. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=34)
#   3%|██▊                                                                                | 3/87 [00:10<05:00,  3.58s/it]Your max_length is set to 142, but your input_length is only 51. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=25)
#   5%|███▊                                                                               | 4/87 [00:21<08:19,  6.02s/it]Your max_length is set to 142, but your input_length is only 112. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=56)
#   6%|████▊                                                                              | 5/87 [00:31<09:48,  7.18s/it]Your max_length is set to 142, but your input_length is only 61. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=30)
#   9%|███████▋                                                                           | 8/87 [01:06<13:42, 10.41s/it]Your max_length is set to 142, but your input_length is only 49. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=24)
#  13%|██████████▎                                                                       | 11/87 [01:17<08:21,  6.60s/it]Your max_length is set to 142, but your input_length is only 54. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=27)
#  15%|████████████▎                                                                     | 13/87 [01:27<07:32,  6.11s/it]Your max_length is set to 142, but your input_length is only 52. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=26)
#  16%|█████████████▏                                                                    | 14/87 [01:38<08:25,  6.93s/it]Your max_length is set to 142, but your input_length is only 45. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=22)
#  18%|███████████████                                                                   | 16/87 [01:48<07:26,  6.29s/it]Your max_length is set to 142, but your input_length is only 85. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=42)
#  20%|████████████████                                                                  | 17/87 [01:59<08:24,  7.20s/it]Your max_length is set to 142, but your input_length is only 128. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=64)
#  21%|████████████████▉                                                                 | 18/87 [02:14<10:28,  9.11s/it]Your max_length is set to 142, but your input_length is only 114. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=57)
#  23%|██████████████████▊                                                               | 20/87 [02:24<08:22,  7.50s/it]Your max_length is set to 142, but your input_length is only 113. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=56)
#  24%|███████████████████▊                                                              | 21/87 [02:35<08:57,  8.14s/it]Your max_length is set to 142, but your input_length is only 122. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=61)
#  26%|█████████████████████▋                                                            | 23/87 [02:44<07:21,  6.91s/it]Your max_length is set to 142, but your input_length is only 86. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=43)
#  29%|███████████████████████▌                                                          | 25/87 [02:55<06:34,  6.36s/it]Your max_length is set to 142, but your input_length is only 49. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=24)
#  31%|█████████████████████████▍                                                        | 27/87 [03:07<06:12,  6.20s/it]Your max_length is set to 142, but your input_length is only 81. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=40)
#  37%|██████████████████████████████▏                                                   | 32/87 [03:41<05:34,  6.08s/it]Your max_length is set to 142, but your input_length is only 47. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=23)
#  38%|███████████████████████████████                                                   | 33/87 [03:53<06:31,  7.26s/it]Your max_length is set to 142, but your input_length is only 52. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=26)
#  39%|████████████████████████████████                                                  | 34/87 [04:05<07:15,  8.22s/it]Your max_length is set to 142, but your input_length is only 50. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=25)
#  41%|█████████████████████████████████▉                                                | 36/87 [04:38<10:19, 12.15s/it]Your max_length is set to 142, but your input_length is only 101. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=50)
#  46%|█████████████████████████████████████▋                                            | 40/87 [05:02<06:33,  8.36s/it]Your max_length is set to 142, but your input_length is only 54. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=27)
#  47%|██████████████████████████████████████▋                                           | 41/87 [05:13<06:47,  8.85s/it]Your max_length is set to 142, but your input_length is only 125. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=62)
#  48%|███████████████████████████████████████▌                                          | 42/87 [05:27<07:28,  9.96s/it]Your max_length is set to 142, but your input_length is only 49. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=24)
#  52%|██████████████████████████████████████████▍                                       | 45/87 [05:49<06:08,  8.77s/it]Your max_length is set to 142, but your input_length is only 73. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=36)
#  53%|███████████████████████████████████████████▎                                      | 46/87 [05:59<06:11,  9.05s/it]Your max_length is set to 142, but your input_length is only 61. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=30)
#  54%|████████████████████████████████████████████▎                                     | 47/87 [06:09<06:13,  9.35s/it]Your max_length is set to 142, but your input_length is only 110. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=55)
#  55%|█████████████████████████████████████████████▏                                    | 48/87 [06:20<06:27,  9.92s/it]Your max_length is set to 142, but your input_length is only 61. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=30)
#  61%|█████████████████████████████████████████████████▉                                | 53/87 [06:45<03:27,  6.11s/it]Your max_length is set to 142, but your input_length is only 46. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=23)
#  62%|██████████████████████████████████████████████████▉                               | 54/87 [06:56<03:48,  6.92s/it]Your max_length is set to 142, but your input_length is only 97. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=48)
#  64%|████████████████████████████████████████████████████▊                             | 56/87 [07:07<03:21,  6.50s/it]Your max_length is set to 142, but your input_length is only 117. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=58)
#  69%|████████████████████████████████████████████████████████▌                         | 60/87 [07:17<02:02,  4.54s/it]Your max_length is set to 142, but your input_length is only 40. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=20)
#  75%|█████████████████████████████████████████████████████████████▎                    | 65/87 [07:45<01:51,  5.07s/it]Your max_length is set to 142, but your input_length is only 49. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=24)
#  77%|███████████████████████████████████████████████████████████████▏                  | 67/87 [07:56<01:44,  5.22s/it]Your max_length is set to 142, but your input_length is only 134. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=67)
#  78%|████████████████████████████████████████████████████████████████                  | 68/87 [08:07<01:54,  6.04s/it]Your max_length is set to 142, but your input_length is only 68. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=34)
#  79%|█████████████████████████████████████████████████████████████████                 | 69/87 [08:17<02:01,  6.77s/it]Your max_length is set to 142, but your input_length is only 73. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=36)
#  85%|█████████████████████████████████████████████████████████████████████▋            | 74/87 [08:43<01:22,  6.34s/it]Your max_length is set to 142, but your input_length is only 119. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=59)
#  89%|████████████████████████████████████████████████████████████████████████▌         | 77/87 [09:09<01:10,  7.04s/it]Your max_length is set to 142, but your input_length is only 50. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=25)
#  91%|██████████████████████████████████████████████████████████████████████████▍       | 79/87 [09:19<00:51,  6.45s/it]Your max_length is set to 142, but your input_length is only 106. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=53)
#  92%|███████████████████████████████████████████████████████████████████████████▍      | 80/87 [09:30<00:50,  7.16s/it]Your max_length is set to 142, but your input_length is only 40. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=20)
#  93%|████████████████████████████████████████████████████████████████████████████▎     | 81/87 [09:40<00:46,  7.79s/it]Your max_length is set to 142, but your input_length is only 105. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=52)
#  94%|█████████████████████████████████████████████████████████████████████████████▎    | 82/87 [09:52<00:44,  8.87s/it]Your max_length is set to 142, but your input_length is only 55. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=27)
#  95%|██████████████████████████████████████████████████████████████████████████████▏   | 83/87 [10:03<00:37,  9.39s/it]Your max_length is set to 142, but your input_length is only 43. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=21)
#  98%|████████████████████████████████████████████████████████████████████████████████  | 85/87 [10:14<00:15,  7.67s/it]Your max_length is set to 142, but your input_length is only 48. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=24)
# 100%|██████████████████████████████████████████████████████████████████████████████████| 87/87 [10:42<00:00, 10.66s/it]Your max_length is set to 142, but your input_length is only 110. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=55)
# 100%|██████████████████████████████████████████████████████████████████████████████████| 87/87 [10:51<00:00,  7.49s/it]

# %% [markdown]
# # Save Dataset

# %%
result = df.to_dict('index')
result
# Out:
# {0: {'review_id': 0,
#   'review_time': '2019-02-14',
#   'review': 'Best phone money can buy.So far this phone is the bees knees.',
#   'rating': 5,
#   'helpfulVotes': 3.0,
#   'review_processed': 'Best phone money can buy.So far this phone is the bees knees.'},
#  1: {'review_id': 1,
#   'review_time': '2019-08-02',
#   'review': 'Pixel 3 has frequent display defects.I like this phone model. I bought this phone as a gift to my wife. Unfortunately, the phone turned out to be defective. There is a pink tint on the screen. Amazon does not want to properly help customers who are not in the USA. This is very sad.',
#   'rating': 3,
#   'helpfulVotes': 20.0,
#   'review_processed': 'There is a pink tint on the screen. Amazon does not want to properly help customers who are not in the U.S. This is very sad. I like this phone model, but it has frequent display defects. I bought it as a gift for my wife, but the phone is defective.'},
#  2: {'review_id': 2,
#   'review_time': '2018-04-30',
#   'review': 'the lower left corner of the phone doesnt work with ....the lower left corner of the phone doesnt work with the stylus. im just so sick of having to return and then wait for my money to come back that im over it',
#   'rating': 2,
#   'helpfulVotes': 1.0,
#   'review_processed': "The lower left corner of the phone doesn't work with the stylus. I'm so sick of having to return and then wait for my money to come back that I'm over it. correct: The lower left corners of the phones do not work with either of the styluses."},
#  3: {'review_id': 3,
#   'review_time': '2017-01-16',
#   'review': 'Great phone, be careful with the sellers.The phone is wonderful, if you\'re considering it, go for it, it\'s awesome. However my seller marked my phone as "like new" but the phone has scuffs on the corners (literally all four corners) and a scuff on the lock button that makes it feel gummy (no positive click like the volume buttons) and it has to be pressed hard, sometimes twice. I can live with it but I wish if I paid for like new I got like new.',
#   'rating': 3,
#   'helpfulVotes': 10.0,
#   'review_processed': 'The phone is wonderful, if you\'re considering it, go for it, it\'s awesome. However my seller marked my phone as "like new" but the phone has scuffs on the corners and a scuff on the lock button that makes it feel gummy.'},
#  4: {'review_id': 4,
#   'review_time': '2019-06-22',
#   'review': 'U had no issue with the seller they were great and very helpful!.I was very disappointed in the way this phone worked it was dropping calls constantly and losing service. Not to mention it was slow. It did take very nice photos. Not worth the $120 plus price tag.',
#   'rating': 1,
#   'helpfulVotes': 3.0,
#   'review_processed': "I was very disappointed in the way this phone worked. It was dropping calls constantly and losing service. It did take very nice photos, but it wasn't worth the $120 plus price tag. I had no issue with the seller; they were great and very helpful."},
#  5: {'review_id': 6,
#   'review_time': '2019-08-12',
#   'review': "Good phone!.I personally think this phone is near perfect. Delivery was quick but not teleportation quick. The box came with - Galaxy A50 - Case - Sim tool - Quick charge American adapter and cable type c - low quality headphones I have used this phone for a while now and its really almost flagship level. For the price it's perfect. It will work 4g lte GSM for most providers in the States. I'll update if it works on Cricket. Performance great. UI great. Camera great. The security is great as well. But the finger scanner in the screen is not the best but it gets the job done. It looks amazing as well! Overall good phone. Edit: It works perfectly with Cricket with 4g lte.",
#   'rating': 5,
#   'helpfulVotes': 1.0,
#   'review_processed': "I have used this phone for a while now and it's really almost flagship level. It will work with most providers in the States. The security is great as well. The finger scanner in the screen is not the best but it gets the job done. Overall good phone."},
#  6: {'review_id': 7,
#   'review_time': '2018-02-12',
#   'review': "Poorly fitted glass + bad reception = return.The phone I received was indeed an AT&T phone. The front and back glass had both been replaced and the finish was flawless. That, unfortunately, is where the good ends and the bad begins. I had to return this phone. I have extremely poor reception, which I suspect is a problem with the device I received rather than a problem inherent to the S6. The other issue is that, although the glass had been replaced, it was not seated properly or flush with the edges. I could get my thumb nail underneath the glass and see the dust/lint that had collected inside. Obviously does not have the water-resistant properties that it would have had from the factory. Thank god for amazon's return policy.",
#   'rating': 2,
#   'helpfulVotes': 1.0,
#   'review_processed': 'The phone I received was indeed an AT&T phone. The front and back glass had both been replaced and the finish was flawless. I have extremely poor reception, which I suspect is a problem with the device I received rather than a problem inherent to the S6. Although the glass had been replaced, it was not seated properly or flush with the edges.'},
#  7: {'review_id': 8,
#   'review_time': '2017-09-20',
#   'review': "Five Stars.Awesome phone, great value. Runs all apps smoothly, takes really good photos and it's overall comfortable to use.",
#   'rating': 5,
#   'helpfulVotes': 2.0,
#   'review_processed': "Five Stars.Awesome phone, great value. Runs all apps smoothly, takes really good photos and it's overall comfortable to use."},
#  8: {'review_id': 9,
#   'review_time': '2019-04-02',
#   'review': 'cheap and useful.huawei always gives us surprise! This price phone is amazing:D',
#   'rating': 5,
#   'helpfulVotes': 1.0,
#   'review_processed': 'cheap and useful.huawei always gives us surprise! This price phone is amazing:D'},
#  9: {'review_id': 10,
#   'review_time': '2019-11-06',
#   'review': 'Item came defective.The iphone is in good condition externally. But internally there was a serious issue with the battery and Face id would never work. Make sure to check the phone battery and Face id feature working.',
#   'rating': 1,
#   'helpfulVotes': 1.0,
#   'review_processed': 'The iPhone is in good condition externally, but internally there was a serious issue with the battery and Face ID would never work. Make sure to check the phone battery and the Face ID feature are working before you buy it. correct: Item came defective, but the battery was working.'},
#  10: {'review_id': 11,
#   'review_time': '2019-05-17',
#   'review': 'iPhone.So far, so good.',
#   'rating': 5,
#   'helpfulVotes': 1.0,
#   'review_processed': 'iPhone.So far, so good.'},
#  11: {'review_id': 12,
#   'review_time': '2016-10-20',
#   'review': 'Mobile not working.I am not able switch on my mobile since today morning. The last used yesterday night and when I woke up in morning I found my mobile was totally dead even not charging also. Kindly help me to find the solution.',
#   'rating': 1,
#   'helpfulVotes': 4.0,
#   'review_processed': 'I am not able to switch on my mobile since today morning. I last used yesterday night and when I woke up in morning I found my mobile was totally dead even not charging also. Kindly help me to find the solution. correct: Mobile not working;.'},
#  12: {'review_id': 13,
#   'review_time': '2016-11-23',
#   'review': "very disappointed.One month after purchasing the pone, it stop working. Samsung people in chile told me that it cannot be fix and that it has a turkish software and has been internaly manipulated. i'm very disappointed.",
#   'rating': 1,
#   'helpfulVotes': 4.0,
#   'review_processed': "One month after purchasing the phone, it stopped working. Samsung people in Chile told me that it cannot be fix and that it has a Turkish software and has been manipulated. I'm very disappointed. correct: very disappointed, but it's not going to work."},
#  13: {'review_id': 14,
#   'review_time': '2019-11-14',
#   'review': 'Its awesome.Wonderful phone',
#   'rating': 5,
#   'helpfulVotes': 2.0,
#   'review_processed': 'Its awesome.Wonderful phone'},
#  14: {'review_id': 15,
#   'review_time': '2019-02-22',
#   'review': 'good phone, functions as advertised.decent phone for the price, wish it didnt have as much uninstallable bloatware, but will likely just root and reimage it in a few months.',
#   'rating': 5,
#   'helpfulVotes': 4.0,
#   'review_processed': "Good phone, functions as advertised. Wish it didn't have as much uninstallable bloatware, but will likely just root and reimage it in a few months. It's a decent phone for the price, but it has too many unnecessary bloatwalls."},
#  15: {'review_id': 16,
#   'review_time': '2019-08-11',
#   'review': "Doesn't work..The phone I received came with with wifi broken. After numerous attempts to connect to multiple wifi connections, the phone refuses to actually connect. The wifi status is stuck in a connecting limbo, then immediately disconnects. I thought that since this was a Amazon Renewed product it would work, but I was wrong. Even after multiple factory resets, it still refuses to work.",
#   'rating': 1,
#   'helpfulVotes': 3.0,
#   'review_processed': 'The phone I received came with with wifi broken. After numerous attempts to connect to multiple wifi connections, the phone refuses to actually connect. The wifi status is stuck in a connecting limbo, then immediately disconnects. I thought that since this was a Amazon Renewed product it would work, but I was wrong.'},
#  16: {'review_id': 17,
#   'review_time': '2019-01-28',
#   'review': "Honest disclosure was expected. Didn't happen..Tech Ventures lied to me. After being very cooperate exchanging iPhone for a Note 5, then assuring me a GOOD Note 5, I learned that the rep on the phone has NO IMPUT as to which Note 5 would sent to me. Her call goes to a warehouse where the cell is simply removed from the storage location. I received the first model of the Note 5. Trust me, NOT TECH VENTURES...this Note 5 is a mess except for e-audio books; no email/gmail & it changes words at will. They really dropped the ball.",
#   'rating': 1,
#   'helpfulVotes': 1.0,
#   'review_processed': "After being very cooperative exchanging an iPhone for a Note 5, I learned that the rep on the phone has no clue as to which model will be sent to me. The rep's call goes to a warehouse where the cell is simply removed from the storage location. Trust me, NOT Tech Ventures. This Note 5 is a mess except for e-audio books; no email, and it changes words at will."},
#  17: {'review_id': 18,
#   'review_time': '2017-05-04',
#   'review': 'Five Stars.Like a brand new phone. No issues found. Seems to be pretty friendly customer service.',
#   'rating': 5,
#   'helpfulVotes': 1.0,
#   'review_processed': 'Five Stars.Like a brand new phone. No issues found. Seems to be pretty friendly customer service.'},
#  18: {'review_id': 19,
#   'review_time': '2013-12-19',
#   'review': "Broke after one month.Piece of crap. worked for about a month then it quit 'ringing' ( or making any kind of noise at all) and YES we checked to see if it was on silent or turned down. also will just randomly cut me off and start blinking weird stuff on the screen, going 'in and out' (no its not the server, def the phone). Says the battery is fully charged and then 20 minutes later shows battery as drained. DO NOT WASTE YOUR MONEY ON THIS PHONE!",
#   'rating': 1,
#   'helpfulVotes': 4.0,
#   'review_processed': "It stopped 'ringing' or making any kind of noise at all. It will randomly cut me off and start blinking weird things on the screen. Says the battery is fully charged and then 20 minutes later shows battery as drained. Do not waste your money on this piece of crap."},
#  19: {'review_id': 20,
#   'review_time': '2019-02-26',
#   'review': 'Phone is unusable.Phone came with zero instructions or paperwork. Device cannot be activated because it does NOT have a SIM card. Am returning this embarrassing excuse for a quality product. if you read every line of the description you will find a snippet that indicates there is no SIM card. Very clever! Please note that you will have to get a modern nano SIM card to use this phone. Every refurbished Verizon phone I have purchased always came with activation instructions and a Verizon SIM card. Look for another phone that is ready to be activated.',
#   'rating': 1,
#   'helpfulVotes': 24.0,
#   'review_processed': 'Phone came with no instructions or paperwork. Device cannot be activated because it does not have a SIM card. If you read every line of the description, you will find a snippet that indicates there is no SIM card; you will have to get a modern nano SIM card to use this phone.'},
#  20: {'review_id': 21,
#   'review_time': '2017-11-03',
#   'review': 'Not a happy.I bought this in July and it died completely in October. Not a happy camper',
#   'rating': 4,
#   'helpfulVotes': 1.0,
#   'review_processed': 'Not a happy.I bought this in July and it died completely in October. Not a happy camper'},
#  21: {'review_id': 23,
#   'review_time': '2018-12-29',
#   'review': 'Moto G6 2018 phone. Very nice good quality and nice camera.This is a very nice phone. Purchase two as a gift. nicely made, modern look good camera. For the price it’s an awsum phone. Call quality from the receiver side is clear and nice. From caller side I’ve been told no issues. I cannot comment on the battery life as of yet, I’ve received no feed back. Over all phone was not loaded with all the bloatware. Clean phone with just the google apps. Not an iPhone by any means but a great android phone.',
#   'rating': 4,
#   'helpfulVotes': 1.0,
#   'review_processed': 'Moto G6 is a very nice phone. Nice good quality and a nice camera. Not an iPhone by any means, but a great android phone. Phone was not loaded with all the bloatware. Clean phone with just the Google apps is a great phone.'},
#  22: {'review_id': 24,
#   'review_time': '2015-11-02',
#   'review': 'Four Stars.The product itself is great as I already have one.',
#   'rating': 4,
#   'helpfulVotes': 1.0,
#   'review_processed': 'Four Stars.The product itself is great as I already have one.'},
#  23: {'review_id': 25,
#   'review_time': '2017-01-06',
#   'review': "review of Samsung Galaxy 6 - refurbished 9by whom?).phone/charger seem good, lack of ANY documentation was a disappointment. Samsungs' changing SIM size caused a slight problem. My problem is to find time setting up features utilizing info from the additional books I have subsequently acquired. Formerly wore out 2 Samsung Galaxy G3s (and an LG G3 (thanks, T-Mobile)).",
#   'rating': 4,
#   'helpfulVotes': 5.0,
#   'review_processed': 'Review of Samsung Galaxy 6 - refurbished by whom? Phone and charger seem good, but lack of documentation was a disappointment. My problem is to find time setting up features utilizing info from the additional books I have acquired. Formerly wore out 2 Samsung Galaxy G3s and an LG G3.'},
#  24: {'review_id': 26,
#   'review_time': '2016-07-31',
#   'review': 'Five Stars.THE PHONE CAME FAST AND WPRKS GREAT',
#   'rating': 5,
#   'helpfulVotes': 2.0,
#   'review_processed': 'Five Stars.THE PHONE CAME FAST AND WPRKS GREAT'},
#  25: {'review_id': 27,
#   'review_time': '2019-06-13',
#   'review': 'awesome phone.The battery is 4000mAh . For all day , average use . This miui is pretty cool The android is updated The camera is fine Good, pretty and cheap Global model with LTE bands . Work good',
#   'rating': 5,
#   'helpfulVotes': 5.0,
#   'review_processed': "The battery is 4000mAh for all day, average use. The android is updated and the camera is fine. It is a global model with LTE bands, and it works well. It's pretty, pretty, and cheap. The battery lasts all day for all days, but it's not perfect."},
#  26: {'review_id': 29,
#   'review_time': '2019-02-06',
#   'review': 'Love this phone!.I like the phone, it does Band71, the extra battery is wonderful. I usually am on 100% charge all day, with only the external battery cycling -- which means I can replace that when it eventually wears out and still have full battery life on the internal battery. I really like the moto mods also - just wish there was more of them.',
#   'rating': 5,
#   'helpfulVotes': 1.0,
#   'review_processed': 'I like the phone, it does Band 71, and the extra battery is wonderful. I usually am on 100% charge all day, with only the external battery cycling. I really like the moto mods also - just wish there was more of them. correct: Love this phone!'},
#  27: {'review_id': 30,
#   'review_time': '2016-08-21',
#   'review': "Mediocre at best. Design is not very attractive not innovative.Mediocre at best. Design is not very attractive not innovative. The one and only reason to buy this phone is for the camera which is exceptional. Yes, it'd fast but there are plenty of other high end phones that blown this out of the water including the OnePlus Three that can basically be had for 3/4 the price. I reverted back to my Nexus 6P. That said, I've heard better things about the S7 edge and Note 7 but the note costs about 800 on contract and that is just absurd. Buy the 5x while the eBay sale is going on. You can get it for 200 new. If you want a bigger phone both the 6P and IPhone 6S are better. For a decent smaller sized the Oneplus Three is insanely fast with no bloat ware.",
#   'rating': 2,
#   'helpfulVotes': 1.0,
#   'review_processed': "The one and only reason to buy this phone is for the camera, which is exceptional. For a decent smaller size, the Oneplus Three is insanely fast with no bloatware. I've heard better things about the S7 edge and Note 7 but the Note 7 costs about 800 on contract and that is just absurd."},
#  28: {'review_id': 31,
#   'review_time': '2018-06-02',
#   'review': 'One Star.Horrible phone',
#   'rating': 1,
#   'helpfulVotes': 2.0,
#   'review_processed': 'One Star.Horrible phone'},
#  29: {'review_id': 32,
#   'review_time': '2016-09-05',
#   'review': "Great back up phone.Can't believe I got this perfect phone so cheap. Got it as a back up and it's still a good buy.",
#   'rating': 5,
#   'helpfulVotes': 1.0,
#   'review_processed': "Great back up phone.Can't believe I got this perfect phone so cheap. Got it as a back up and it's still a good buy."},
#  30: {'review_id': 33,
#   'review_time': '2018-01-29',
#   'review': 'Phone only lasted one month. Seller does not respond. Samsung warranty not valid..BUYER BEWARE. I ordered a "brand new" Samsung Galaxy S7 from TimeToCell for my father for Christmas from the seller and within a month the screen started going purple and no longer worked. Because I didn\'t give it to him until Christmas, it was outside of the 30 day return window. However, having bought it "brand new", I figured the Samsung one year manufacturer warranty would be good, but NOPE! When I contacted Samsung they took my IMEI number and told me the one year warranty had expired in August 2017.... I bought the phone in November 2017.... I have tried contacting the seller two times and both times received no response. Do not buy from this dealer.',
#   'rating': 1,
#   'helpfulVotes': 142.0,
#   'review_processed': "Within a month the screen started going purple and no longer worked. Because I didn't give it to him until Christmas, it was outside of the 30 day return window. I have tried contacting the seller two times and both times received no response. Do not buy from this dealer."},
#  31: {'review_id': 34,
#   'review_time': '2019-10-08',
#   'review': 'Great camera.I bought this phone beacuse of camera. And it does not make me disappointed. It works amazing! I am also a kpop fan so cant wait to use it during the concert!',
#   'rating': 5,
#   'helpfulVotes': 2.0,
#   'review_processed': "I bought this phone because of its camera. It works amazing! I can't wait to use it during the concert. It doesn't make me feel disappointed. It's a great phone! It's amazing. It has a great camera. I'm also a kpop fan, so I'm excited about the concert!"},
#  32: {'review_id': 35,
#   'review_time': '2019-11-05',
#   'review': "Not the latest version of Samsung phone but the A50 does everthing expected..I was hesitant originally to order an unlocked phone due to problems from other's experiences. This purchase was without any issues and worked perfectly out of the box.",
#   'rating': 5,
#   'helpfulVotes': 8.0,
#   'review_processed': 'Not the latest version of the Samsung phone, but the A50 does everything expected. I was hesitant to order an unlocked phone due to previous experiences, but this purchase was without any issues and worked perfectly out of the box. The A50 is not the latest Samsung phone but it does anything expected.'},
#  33: {'review_id': 36,
#   'review_time': '2016-09-15',
#   'review': "Stolen Phone.Oh the phone was great I was very excited to have it. Until I was informed by ATT that it had been reported stolen 6 months ago so I can't use it with my network. Con artists.",
#   'rating': 1,
#   'helpfulVotes': 2.0,
#   'review_processed': "I was excited to have the new phone, but it had been reported stolen 6 months ago, so I can't use it with my network. Con artists are the real culprits. The phone was great, but I was informed by ATT that it was reported stolen six months ago."},
#  34: {'review_id': 37,
#   'review_time': '2017-09-26',
#   'review': 'Sony Returns to Form.With the XZ1, Sony\'s Xperia line returns to form. After wandering in the cel phone wilderness for the last year or so, the electronics giant pulled their collective heads out of their collective hindquarters and have delivered a very good (if not quite great) flagship mobile device. The past 12-16 months gave us the X, the X Compact, the X Performance, the XZ, the XZS, the XA1, and a gaggle of other mid-tier offerings from Sony. Of them, only the XZS and the XZ Premium could come close to laying claim to flagship status, with the latter coming with one of the finest 4K displays in the business. Unfortunately XZS didn\'t come with a battery big enough to power the nice phone specs, and the XZ Premium was an exceptionally large phone, at an exceptionally large price. The XZ1 sees the company step up it\'s game. As of this writing, it\'s one of the few devices shipping with Android 8 / Oreo out of the box, running the latest Snapdragon 835 processor, with a beautiful 1080 display and a slightly-refined physical design and sturdy-feeling build-quality. And for nearly $700, it certainly should have a premium feel to it. Even the best phones are balancing acts of compromise, so while there\'s certainly something here for everyone, it\'s also unlikely to appeal to absolutely everyone. Most people either love or hate Sony\'s take on industrial design. Some bemoan the size of the top and bottom bezels. In a world where the S8 strives to give customers nothing-but-screen, Sony certainly isn\'t following the fashion train. But they sure as heck are following the functional-device-train. Having owned an S8, I certainly see the appeal. It\'s a beautiful looking device. But at the end of the day, I found the lack of bezels to be a problem in day to day use. With no edge on which to rest fingertips, I was constantly accidentally activating various apps, or accidentally hitting the wrong onscreen area within a given app. Nice to look at...but darn if it\'s not a pain to actually use. So, here\'s a subjective run down of Pros and Cons: PRO - Great screen. In addition to it\'s Triluminous setting, Sony has added a new video color-saturating setting. Honestly, it looks like they\'re taking a stab at the popping colors and deep blacks on OLED devices like the S8. And they\'ve done a good job...this is one of the sharpest, most color popping screens out there at the moment. - Great processor. The new Snapdragon is great. Everything runs smoothly. - Headphone jack / Audio processing. Yay for hanging on to this bit of tech, the old headphone jack. Bluetooth headphones are well and good, but they eat up a battery, and they can\'t deliver the same quality of audio as a wired set. If how your music sounds on your device is important to you, wired is still the way to go. For now at least. And Sony\'s DESS audio processing sounds pretty great to my ears. Pick up a third party audio player like Neutron if you\'d like even more control of the sound. CON - Physical design. This really doesn\'t belong in the "con" column, but the fact is either you like what Sony is doing here, or you don\'t. - Price. Sony offers a handful of budget models, but their flagship line has never been anything but pricey. Especially in America where the brand isn\'t known for it\'s mobile devices, the average android user might be hard pressed to pay $699 to a company they normally associate with televisions. In Europe and Asia, though, Sony remains a popular contender with Samsung and Apple for high end devices. - Battery. This also might not be a negative, as the new Snapdragon and Oreo are alleged to be more efficient with their power use. Running some benchmarks seem to bear this out, as while it leads in most areas, there are some processes they\'ve scaled back. So far, I don\'t see any penalty in processing power, but I\'ve also not had it long enough to take a firm stance on battery life. But anecdotally, it does seem to be an improvement  ...
#   'rating': 5,
#   'helpfulVotes': 46.0,
#   'review_processed': "With the XZ1, Sony's Xperia line returns to form. It's one of the few devices shipping with Android 8 / Oreo out of the box, running the latest Snapdragon 835 processor. It has a beautiful 1080p display and a slightly-refined physical design and sturdy build-quality."},
#  35: {'review_id': 38,
#   'review_time': '2016-11-29',
#   'review': 'Five Stars.Perfect, almost near perfect condition. No complaints',
#   'rating': 5,
#   'helpfulVotes': 1.0,
#   'review_processed': 'Five Stars.Perfect, almost near perfect condition. No complaints'},
#  36: {'review_id': 39,
#   'review_time': '2019-08-27',
#   'review': "Not worth the money!.This was a relatively low quality phone. The sound on it is poor at best. You can hardly hear it ring. I missed several phone calls until I figured it out. I decided to keep it, simply because it was easier then sending it back. I already sent back the first phone I got, and didn't want to do it again. I will not buy from this company again in the future. Their products just aren't worth the money.",
#   'rating': 3,
#   'helpfulVotes': 5.0,
#   'review_processed': "The sound on it is poor at best. I missed several phone calls until I figured it out. I already sent back the first phone I got, and didn't want to do it again. I will not buy from this company again in the future. Their products aren't worth the money."},
#  37: {'review_id': 40,
#   'review_time': '2019-08-28',
#   'review': 'Came broken.The phone does not turn on at all, I bought a new USB cable to test and still does not turn on.',
#   'rating': 1,
#   'helpfulVotes': 1.0,
#   'review_processed': 'Came broken.The phone does not turn on at all, I bought a new USB cable to test and still does not turn on.'},
#  38: {'review_id': 41,
#   'review_time': '2014-10-03',
#   'review': 'Awesome phone. best on market..Best phone. Things you should know. 1. Best battery life than any other Android phone I have had. 2. Most features that are exclusive for this phone I thought I would use. I do not. For example I do not use the stylus as much as I did. The recent update killed the ease of use and coverting text from handwriting to text. So I do not use it anymore. 3. Fast response. Have had this phone for about 9 months. Still just as fast responding to touch and opening apps as day one. 4. Can only be used with a max mini SD card of 64gb. This is a minor complaint only. 5. Does not get hot. Unless you are doing a lot of stuff while charging this device does not get hot to the touch. The normal running temp is about 100 degrees Fahrenheit but you can not feel it. 6. Charges fast from dead to full charge. This is based on stock charger that comes with phone which pushes 2.1 amps. I also use a 3.5 amp car charger which it charges faster with. 7. The IR ability I use a lot for controlling my TV and dvr. The app the phone comes with is the best app but the app does need improvement though this is not the phones fault. 8. WiFi is fast. My Internet speed tops at 40mb/s and the phone WiFi can do it. Unlike most phones WiFi usually cap at 20mb/s no matter what. 9. I have the Verizon 4G lte and the lte I have seen push 60mb/s for speeds so again the phone ability for strong and fast signal is impressive. A bunch of other things positive and negative. I am disappointed in Samsung and their lack more rather restrictions of app abilities but this is not the phone fault. Great phone and best I have had.',
#   'rating': 5,
#   'helpfulVotes': 2.0,
#   'review_processed': 'Most features that are exclusive for this phone I thought I would use, I do not. The app the phone comes with is the best app but the app does need improvement. WiFi is fast. My Internet speed tops at 40mb/s and the phone WiFi can do it.'},
#  39: {'review_id': 42,
#   'review_time': '2019-03-27',
#   'review': 'Arrived damaged.Phone arrived with a number of damages: a crack in the screen, the top right corner damaged and separating from the body, and dents and scrapes on all corners. Completely unacceptable "refurbished" condition.',
#   'rating': 1,
#   'helpfulVotes': 30.0,
#   'review_processed': 'A phone arrived with a number of damages, including a crack in the screen, the top right corner damaged and separating from the body, and dents and scrapes on all corners. It was in a completely unacceptable "refurbished" condition. correct:'},
#  40: {'review_id': 43,
#   'review_time': '2018-02-27',
#   'review': "Not a good choice for at&t.....I got this phone to because iPhone 7 plus unlocked had gotten slow after ios 11. This phone is nice but i use At&t and i just found out that when At&t checks your phone on the network they disable wifi calling and edge calling. I found out when my phone started dropping calls at the office about a month and a half after buying it. I didn't see anything about this issue when i bought the phone and now it's too late to return the phone. One more reason to leave At&t!!! Bad job Amazon!!!",
#   'rating': 2,
#   'helpfulVotes': 2.0,
#   'review_processed': "I got this phone because iPhone 7 plus unlocked had gotten slow after iOS 11. This phone is nice but I use At&t and I just found out that when At&T checks your phone on the network they disable wifi calling and edge calling. I didn't see anything about this issue when I bought the phone and now it's too late to return the phone."},
#  41: {'review_id': 44,
#   'review_time': '2016-03-01',
#   'review': 'Imei 35861.... is locked doesnt match ....Imei 35861....is locked doesnt match with unlock code .Please send me the correcta code',
#   'rating': 1,
#   'helpfulVotes': 1.0,
#   'review_processed': 'Imei 35861.... is locked doesnt match ....Imei 35861....is locked doesnt match with unlock code .Please send me the correcta code'},
#  42: {'review_id': 45,
#   'review_time': '2018-12-03',
#   'review': "Terrible screen durability.Battery life is very short,it hasn't been a week and already microscratches.Save your money and get a phone with decent durability,and every accessory for the phone is just garbage.",
#   'rating': 1,
#   'helpfulVotes': 3.0,
#   'review_processed': "It hasn't been a week and already there are some scratches. Save your money and get a phone with decent durability. Every accessory for the phone is just garbage. It's very short battery life is very short, and it's not very durable at all."},
#  43: {'review_id': 46,
#   'review_time': '2019-03-13',
#   'review': 'Sadly, have to return.This phone was great. Until I took the model number and discovered it ABSOLUTELY does not have band 71 (600MHZ) AS DESCRIBED in the listing. I do not think it was intentional, but the dual sim version G7 POWER does NOT have B71 as listed, only the mono-SIM G7 Power, USA version will have it. It is the reason I got the phone, so a terrible disappointment to find this out. ### EDIT ### They have updated the listing to reflect that band 71 (600 Mhz) is not on this variant. I am raising my rating to a 4 star as the specs combined with battery provide outstanding value, especially for dual SIM',
#   'rating': 4,
#   'helpfulVotes': 93.0,
#   'review_processed': 'The G7 Power does not have band 71 as listed in the listing. It is the reason I got the phone, so a terrible disappointment to find this out. I am raising my rating to a 4 star as the specs combined with battery provide outstanding value, especially for dual SIM.'},
#  44: {'review_id': 47,
#   'review_time': '2019-02-24',
#   'review': 'Descontento.Hola No recibí lo que compré Debería tener 4GB de RAM , lo que me mandaron es 3 GB de RAM y lo quiero devolver las 10 unidades O ME PUEDEN BAJAR EL PRECIO Y ME QUEDARE CON LA MERCANCÍA Gracias',
#   'rating': 1,
#   'helpfulVotes': 2.0,
#   'review_processed': "No, I don't receive anything that's been sent to me. My computer needs 4GB of RAM; the one I received is 3GB. I want to get 10 unidades; I'm not satisfied with what's being sent. I've already bought a book."},
#  45: {'review_id': 48,
#   'review_time': '2017-12-03',
#   'review': "wifi problems.This phone like other sony phones has serious wifi issues. Even non flagship products from htc, samsung, huwaie don't have problems with wifi. It will connect but will not have internet while other devices on my network have no issues.",
#   'rating': 1,
#   'helpfulVotes': 3.0,
#   'review_processed': "This phone like other sony phones has serious wifi issues. It will connect but will not have internet while other devices on my network have no issues. Even non flagship products from HTC, Samsung, and Sony don't have problems with wifi issues with these phones."},
#  46: {'review_id': 50,
#   'review_time': '2019-05-15',
#   'review': 'At $199 (at time of purchase) it is a steal.My Samsung Galaxy S7 was dying. I wanted a Galaxy S10, but didn\'t want to drop $1000. So I found this phone. It works for what I need it for. Still trying to get used to not having a physical "back button" like my S7. 64 GB RAM for the price is a steal. It did take many updates to update the phone to current (which is normal for any phone as well as computers).',
#   'rating': 5,
#   'helpfulVotes': 1.0,
#   'review_processed': 'I wanted a Galaxy S10, but didn\'t want to drop $1000, so I found this phone. It works for what I need it for. Still trying to get used to not having a physical "back button" like my S7. At $199 (at time of purchase), it is a steal.'},
#  47: {'review_id': 52,
#   'review_time': '2019-12-08',
#   'review': 'Only disappointment.Phone screen was in pretty rough shape when we got it. Expected much more but spent $200 on a new screen and then found out that the phone was warped. Not in the condition that it was promised, very disappointed. Will not buy from here again.',
#   'rating': 1,
#   'helpfulVotes': 2.0,
#   'review_processed': 'The phone screen was in pretty rough shape when we got it. Expected much more but spent $200 on a new screen and then found out that the phone was warped. Not in the condition that it was promised, very disappointed. Will not buy from here again.'},
#  48: {'review_id': 54,
#   'review_time': '2019-10-13',
#   'review': 'Disappointed.Horrible. Phone came locked unable to use with any carrier',
#   'rating': 1,
#   'helpfulVotes': 2.0,
#   'review_processed': 'Disappointed.Horrible. Phone came locked unable to use with any carrier'},
#  49: {'review_id': 55,
#   'review_time': '2017-07-27',
#   'review': "Great phones!.I purchased two of these for a couple of over seas friends, and according to them, the phones are working fine. Couldn't be happier!",
#   'rating': 5,
#   'helpfulVotes': 1.0,
#   'review_processed': "Great phones!.I purchased two of these for a couple of over seas friends, and according to them, the phones are working fine. Couldn't be happier!"},
#  50: {'review_id': 56,
#   'review_time': '2018-04-03',
#   'review': "One Star.They say it was new but it wasn't it was used 🙄",
#   'rating': 1,
#   'helpfulVotes': 1.0,
#   'review_processed': "One Star.They say it was new but it wasn't it was used "},
#  51: {'review_id': 57,
#   'review_time': '2019-02-01',
#   'review': "Switched from iPhone and absolutely loving it!!.This is an absolutely amazing phone! I exclusively used iPhone for the past 5 years and recently switched to the Huawei Mate 20 Pro after my iPhone screen cracked and ran out of memory space. I've been unimpressed by Apple's lack of innovation in recent years and decided to try the mate 20 Pro after doing a lot of research and reading a lot of reviews. This phone lives up to the hype and has exceeded all of my expectations! The camera is amazing, the resolution of the screen is beautiful, and the operating system took a little getting used to but the EMUI skin that Huawei utilises seems to be slightly inspired by iOS. I haven't noticed any of the green screen bleed that some people mention and I also can't attest to the overall security of the phone (alleged Chinese malware and spying). This phone is honestly so amazing that even if the spying allegations are true I'd still own/use this phone!",
#   'rating': 5,
#   'helpfulVotes': 78.0,
#   'review_processed': "I've been unimpressed with Apple's lack of innovation in recent years and decided to try the mate 20 Pro after doing a lot of research and reading reviews. The camera is amazing, the resolution of the screen is beautiful, and the operating system took a little getting used to but the EMUI skin seems to be inspired by iOS."},
#  52: {'review_id': 58,
#   'review_time': '2013-04-18',
#   'review': 'Okay.Meets expectations...in case if somebody does not want to use an i-phone....this could be an ideal set...try it out..otherwise it is just to receive and make calls',
#   'rating': 3,
#   'helpfulVotes': 3.0,
#   'review_processed': "In case someone doesn't want to use an i-phone, this could be an ideal set. Otherwise it is just to receive and make calls. It meets expectations. Try it out, and if you like it, you can buy it. It's a good buy."},
#  53: {'review_id': 59,
#   'review_time': '2019-11-08',
#   'review': 'Greatest phone ever. Beats the iPhone..Great so far. Get lots of comments about speed. Does everything expected and more.',
#   'rating': 5,
#   'helpfulVotes': 1.0,
#   'review_processed': 'Greatest phone ever. Beats the iPhone..Great so far. Get lots of comments about speed. Does everything expected and more.'},
#  54: {'review_id': 60,
#   'review_time': '2019-10-13',
#   'review': "Super fast and reliable.Amazing phone! I was skeptical as I've only ever had the Galaxy series of phones, but they've gotten so expensive that I had to make a change. I'm so glad I did. This phone has all the features I wanted from a Samsung and has nothing I don't need. I like the type of charger and the weight of the phone, I like the size of the screen and the speed of the fingerprint and facial recognition",
#   'rating': 5,
#   'helpfulVotes': 1.0,
#   'review_processed': "I like the size of the screen and the speed of the fingerprint and facial recognition. I like the type of charger and the weight of the phone. It has all the features I wanted from a Samsung and has nothing I don't need. I was skeptical as I've only ever had the Galaxy series of phones."},
#  55: {'review_id': 62,
#   'review_time': '2015-06-18',
#   'review': 'Five Stars.is perfect for the price!!! wonderful buy!',
#   'rating': 5,
#   'helpfulVotes': 1.0,
#   'review_processed': 'Five Stars.is perfect for the price!!! wonderful buy!'},
#  56: {'review_id': 63,
#   'review_time': '2017-07-29',
#   'review': 'Five Stars.Very good',
#   'rating': 5,
#   'helpfulVotes': 1.0,
#   'review_processed': 'Five Stars.Very good'},
#  57: {'review_id': 64,
#   'review_time': '2017-08-07',
#   'review': 'Good in Colombia, 10/10.Good in Colombia',
#   'rating': 5,
#   'helpfulVotes': 1.0,
#   'review_processed': 'Good in Colombia, 10/10.Good in Colombia'},
#  58: {'review_id': 65,
#   'review_time': '2018-06-20',
#   'review': 'See The Phone In Person. . ..I am interested in a all weather phone, so I began with this Convoy. . . Verizon does not offered coverage for the phones entire range of functions. . . The shift to LTE systems in 2019 might be the reason. . . That being stated; the phone appears durable, difficult to text with, and limited contact preset numbers. It does access bluetooth function, my age prevents me from gaining good audiblefrom the speakers. . . It gets further testing in Monterrey Bay, kayaking. . .',
#   'rating': 3,
#   'helpfulVotes': 2.0,
#   'review_processed': 'I am interested in an all weather phone, so I began with this Convoy. Verizon does not offered coverage for the phones entire range of functions. The shift to LTE systems in 2019 might be the reason. The phone appears durable, difficult to text with, and limited contact numbers.'},
#  59: {'review_id': 66,
#   'review_time': '2014-07-27',
#   'review': 'Great simple phone.Switching from iPhone 5 to this phone. Simple, long battery, good looking. iPhone took too much of my time and health, really.',
#   'rating': 5,
#   'helpfulVotes': 2.0,
#   'review_processed': 'Great simple phone.Switching from iPhone 5 to this phone. Simple, long battery, good looking. iPhone took too much of my time and health, really.'},
#  60: {'review_id': 67,
#   'review_time': '2019-03-16',
#   'review': 'Not compatible for any sim..Not compatible with the sim we have. Says it is unlocked. Verizon sim not recognized and it does not specify what carrier it is unlocked for...',
#   'rating': 1,
#   'helpfulVotes': 3.0,
#   'review_processed': "Not compatible with the sim we have. Verizon sim not recognized, and it does not specify what carrier it is unlocked for. correct: Not compatible for any sim; says it's unlocked, but it doesn't specify which carrier it's not compatible with. wrong: It doesn't recognize any sim."},
#  61: {'review_id': 68,
#   'review_time': '2017-07-20',
#   'review': 'Excellent phone.Good design, high-end product feel. No issues with the sim cards, reception and wifi. Overall a very good phone in this price range.',
#   'rating': 5,
#   'helpfulVotes': 3.0,
#   'review_processed': 'Excellent phone.Good design, high-end product feel. No issues with the sim cards, reception and wifi. Overall a very good phone in this price range.'},
#  62: {'review_id': 69,
#   'review_time': '2017-03-25',
#   'review': 'Five Stars.great',
#   'rating': 5,
#   'helpfulVotes': 3.0,
#   'review_processed': 'Five Stars.great'},
#  63: {'review_id': 70,
#   'review_time': '2013-12-08',
#   'review': "LOVE THIS Phone! Beautiful, light, fast ... Android users can't go wrong with this..Well, since I'm far from the first review of this phone I won't go into all the features (which I've only scratched the surface of anyway!). Instead I'll just give my overall impressions. I LOVE this phone. It looks great, fantastic screen and size, it's thin and light. The speed is excellent on just about every app and feature I've used. I really have no complaints after about 2 weeks of using it. Oh, battery life ... having had the S2 before this with battery life of - maybe - half a day this is a pleasure. For example, as I write this at about 11pm after an admittedly light usage day, the battery is still at 74% I'm not saying this is the norm but so far I have not had a day where the phone would have died before the end of the day if I hadn't charged it. We'll see how that holds up over time but for now, battery life is excellent. BATTERY UPDATE: Have had the phone close to 2 weeks now and I must say that battery life has been more than acceptable. Today is a fairly typical day I think. As I write this around 3:30pm I'm at close to 70% battery life. Considering that it was fully charged at 6:30am I'd say that's not too bad. Hope this is helpful. Oh, and as a kicker, I managed to snag this for $0.01 thanks to an unannounced (as far as I know) Amazon sale so that makes this phone even sweeter. Thanks Samsung ... thanks Amazon [it pays to poke around the site on Thanksgiving night!! lol] If you're an android user or switching to it, get this phone!! Hope this is helpful to some of you.",
#   'rating': 5,
#   'helpfulVotes': 1.0,
#   'review_processed': "Since I'm far from the first review, I won't go into all the features, but I'll just give my overall impressions. I really have no complaints after about 2 weeks of using it. The speed is excellent on just about every app and feature I've used. If you're an android user or switching to it, get this phone!!"},
#  64: {'review_id': 72,
#   'review_time': '2017-07-20',
#   'review': 'Works like a charm.Works like a charm. Great condition. Like new. Took it to the Samsung Store at Best Buy to have it updated.',
#   'rating': 5,
#   'helpfulVotes': 2.0,
#   'review_processed': 'Works like a charm.Works like a charm. Great condition. Like new. Took it to the Samsung Store at Best Buy to have it updated.'},
#  65: {'review_id': 74,
#   'review_time': '2018-08-31',
#   'review': 'Love this phone!!!.Fast phone and easy setup. Very intuitive and easy to use. So glad I switched from a Samsung!! Already have Pi installed and there were no install errors or slow down of apps after install.',
#   'rating': 5,
#   'helpfulVotes': 2.0,
#   'review_processed': 'Fast phone and easy setup. Very intuitive and easy to use. So glad I switched from a Samsung. Already have Pi installed and there were no install errors or slow down of apps after install. correct: Love this phone!!!. Back to Mail Online home. Back To the page you came from.'},
#  66: {'review_id': 75,
#   'review_time': '2019-12-14',
#   'review': 'Phone can only be unlocked by factory reset.I purchased this phone before my trip to Ireland. I took hundreds of pictures - only one picture from the entire trip backed up to google, and it was a picture from the middle of the trip! When I returned to the states, the phone locked and will only unlock with a factory reset, which will lose all my pictures that are on it. I called Google Help, Verizon Help, Pixel Help and after hours of attempts from these technicians - the phone would still not get out of the unlock loop. I now have a very expensive paperweight and no pictures from a once in a lifetime trip!',
#   'rating': 1,
#   'helpfulVotes': 1.0,
#   'review_processed': 'I purchased this phone before my trip to Ireland. I took hundreds of pictures, but only one from the entire trip backed up to Google. When I returned to the states, the phone locked and will only unlock with a factory reset, which will lose all my pictures that are on it.'},
#  67: {'review_id': 76,
#   'review_time': '2018-07-07',
#   'review': "Didn't works with boost mobile.Samsung Galaxy s8+ is a very good phone. My review is all about the description, it says unlocked, I tried to use it with boost Mobile and it didn't work, I try online, by phone, and in the store. Going to return it to Amazon",
#   'rating': 2,
#   'helpfulVotes': 1.0,
#   'review_processed': "Samsung Galaxy s8+ is a very good phone. My review is all about the description, it says unlocked. I tried to use it with boost Mobile and it didn't work. I try online, by phone, and in the store. Going to return it to Amazon."},
#  68: {'review_id': 77,
#   'review_time': '2018-08-31',
#   'review': 'No me gusta.Muy pequeño',
#   'rating': 1,
#   'helpfulVotes': 1.0,
#   'review_processed': 'No me gusta.Muy pequeo'},
#  69: {'review_id': 78,
#   'review_time': '2019-06-05',
#   'review': 'Samsung M10.Exelente',
#   'rating': 5,
#   'helpfulVotes': 1.0,
#   'review_processed': 'Samsung M10.Exelente'},
#  70: {'review_id': 80,
#   'review_time': '2018-11-18',
#   'review': "It's Great.Works just as if it was new. Great condition.",
#   'rating': 5,
#   'helpfulVotes': 2.0,
#   'review_processed': "It's Great.Works just as if it was new. Great condition."},
#  71: {'review_id': 81,
#   'review_time': '2019-04-03',
#   'review': "Excellent phone.Current phone was having issues and not what was expected. Got the Pixel 3 after using/having the original. No complaints and completely pleased with it's simplicity and user-friendliness. Easier to use than the Galaxy line. Would definitely recommend as a simple to use phone with ease of access features and a great camera.",
#   'rating': 5,
#   'helpfulVotes': 14.0,
#   'review_processed': "Current phone was having issues and not what was expected. Got the Pixel 3 after using and having the original. No complaints and completely pleased with it's simplicity and user-friendliness. Easier to use than the Galaxy line. Would definitely recommend as a simple to use phone with ease of access features and a great camera."},
#  72: {'review_id': 82,
#   'review_time': '2019-10-24',
#   'review': "You get what you pay for, but you do get a lot for the price w this phone..I don't think you could beat this for the price. I will say there is definitely a noticeable difference with processing compared to like an iPhone. when this does come into play is if you're using Google maps and you're trying to zoom in real fast or out. and sometimes the typing does not catch the proper letters and I think it has to do with this phone. Also sometimes when I use speak to text it's not responsive and I have to say the same thing twice which can definitely be annoying. but overall you cant complain too much with a phone like this for the price. It's funny, even while writing this review twice the speak to text did not respond. But again it takes pretty decent photos and it's impressive the low light photos that it takes. The phone seems to work okay and I've never really had a problem connecting to Wi-Fi etc. I'm definitely going back to the iPhone though I'll tell you that. I purchased this because I was in another country and I didn't have a choice. But it has done the job so if you're really really tight on money I would say this is a good option for you for sure or the newer Moto G7",
#   'rating': 4,
#   'helpfulVotes': 1.0,
#   'review_processed': "You get what you pay for, but you do get a lot for the price of this phone. I don't think you could beat this phone for its price. There is definitely a noticeable difference with processing compared to like an iPhone. It takes pretty decent photos and it's impressive the low light photos that it takes."},
#  73: {'review_id': 84,
#   'review_time': '2019-01-07',
#   'review': 'happy girl..i was so scared to order a $600 8 plus off amazon and after reading some of the reviews it made me a lil more scared. i just got my phone in the mail today and it came in a nice little assorted box with a charger and everything. i took the phone out it already had a screen protector on so that was a plus, i cut it on and activated it with no problem, and so far it’s working perfectly fine, just like new. so far so great :) thank you buyspry or however u spell it lol ❤️',
#   'rating': 5,
#   'helpfulVotes': 109.0,
#   'review_processed': 'I was so scared to order a $600 8 plus off Amazon, and after reading some of the reviews it made me a lil more scared. I just got my phone in the mail today and it came in a nice little assorted box with a charger and everything. It already had a screen protector on, so that was a plus, and so far its working perfectly fine, just like new.'},
#  74: {'review_id': 85,
#   'review_time': '2017-02-13',
#   'review': 'Four Stars.old school still working in the new age',
#   'rating': 4,
#   'helpfulVotes': 1.0,
#   'review_processed': 'Four Stars.old school still working in the new age'},
#  75: {'review_id': 87,
#   'review_time': '2019-08-26',
#   'review': 'Drops mobile data.Bought this phone in March 2019 and after a few months it started dropping mobile data. After repeated checks with my service provider it was confirmed that the problem was with the phone and not the service. This was verified through various forums and chats by other persons in different countries with the S10 who had the same problem. Whenever I leave an area with wifi, I have to go to the sim card manager and change from 4g to 3g then back to 4g to get mobile data. As soon as I get a call I lose mobile data and have to go 3g then 4g again to get it back. Same thing if the signal gets weak or I go in and out of a wifi area. Huge risk if attempted while driving. I have reset the phone, reseated the sim card and tried other recommended fixes to no avail. No warranty so buyer beware. Very disappointed.',
#   'rating': 2,
#   'helpfulVotes': 3.0,
#   'review_processed': 'After a few months it started dropping mobile data. After repeated checks with my service provider it was confirmed that the problem was with the phone and not the service. I have reset the phone, reseated the sim card and tried other recommended fixes to no avail. No warranty so buyer beware.'},
#  76: {'review_id': 88,
#   'review_time': '2019-05-16',
#   'review': 'Great value..Perfect phone.',
#   'rating': 5,
#   'helpfulVotes': 1.0,
#   'review_processed': 'Great value..Perfect phone.'},
#  77: {'review_id': 89,
#   'review_time': '2016-11-07',
#   'review': 'Great product.Excellent product, "like new". Really meant like new, no flaws or signs of use.Activated with no problems after getting sim card at Sprint dealer for no charge. Will buy from red cell again!',
#   'rating': 5,
#   'helpfulVotes': 1.0,
#   'review_processed': 'Great product. "Like new" really meant like new, with no flaws or signs of use. Will buy from red cell again.Activated with no problems after getting a sim card at Sprint dealer for no charge; will buy from them again. correct:'},
#  78: {'review_id': 91,
#   'review_time': '2016-10-06',
#   'review': "I got a bad phone, they don't have inventory so I have ....The phone doesn't work with T-Mobile SIM card, contacted Sony officials and they told me they do not know which carrier is compatible with Xperia and asked me to contact the seller. According the Amazon representatives, I got a bad phone, they don't have inventory so I have to get a refund. I don't know if I'm the only one experiencing this issue, but it's very annoying. Extra star for good looking",
#   'rating': 2,
#   'helpfulVotes': 15.0,
#   'review_processed': "I got a bad phone, they don't have inventory, so I have to get a refund. The phone doesn't work with T-Mobile SIM card. I don't know if I'm the only one experiencing this issue, but it's very annoying."},
#  79: {'review_id': 92,
#   'review_time': '2019-10-13',
#   'review': "Received used phone...The phone I received was used. It has a screen protector that it shouldn't and a scuff mark on the back from the previous owner case..",
#   'rating': 1,
#   'helpfulVotes': 5.0,
#   'review_processed': "The phone I received was used. It has a screen protector that it shouldn't have, and a scuff mark on the back from the previous owner's case. correct: received used phone, not new one; it has screen protector on it that shouldn't be there."},
#  80: {'review_id': 93,
#   'review_time': '2019-10-27',
#   'review': "Loving it.The phone arrived in great condition no scratches. I have been wanting to get this phone for a while and I think preowned version is worth it if it is certified from amazon Onky things I don't like are USB C cable and the charger. Both are poorly made and cable broke on the first day. I would appreciate it if I recieved a high quality cable and charger. Other than that I am having great time owning a pre preowned samsung s10e",
#   'rating': 5,
#   'helpfulVotes': 2.0,
#   'review_processed': "I have been wanting to get this phone for a while and I think preowned version is worth it if it is certified from Amazon. I don't like the USB C cable and the charger. Both are poorly made and cable broke on the first day. Other than that I am having great time owning a pre preowned samsung s10e."},
#  81: {'review_id': 94,
#   'review_time': '2014-09-21',
#   'review': 'Not happy that it was falsely advertised and window 7.This phone does not have window 8 as advertised. Not happy that it was falsely advertised and window 7.8 does not support what I need it to. I would not buy from this supplier.',
#   'rating': 1,
#   'helpfulVotes': 1.0,
#   'review_processed': "Not happy that it was falsely advertised and window 7.8 does not support what I need it to. I would not buy from this supplier. This phone does not have window 8 as advertised; I'm not happy with the quality of the phone. It's not worth buying."},
#  82: {'review_id': 95,
#   'review_time': '2019-05-17',
#   'review': 'Exelente compra calidad / precio.Exelente smartphone relación calidad precio, el producto es tal cual lo describe el vendedor, recomendado',
#   'rating': 5,
#   'helpfulVotes': 5.0,
#   'review_processed': 'Exelente compra calidad / precio.Exelente smartphone relacin calidad precio, el producto es tal cual lo describe el vendedor, recomendado'},
#  83: {'review_id': 96,
#   'review_time': '2018-07-09',
#   'review': 'Amazing 95%.I loved this s product so much!! It was afforable and it came with everything I needed! It only had a couple dents on the phone but overall I love it',
#   'rating': 5,
#   'helpfulVotes': 1.0,
#   'review_processed': "I loved this product so much! It was adorable and it came with everything I needed! It only had a couple dents on the phone, but overall I love it. It's amazing! It's an amazing product! I loved it so much. It was perfect!"},
#  84: {'review_id': 97,
#   'review_time': '2019-12-12',
#   'review': "Just ok.I bought this phone for my dad and he hasn't had any complains with it except for the fingerprint reader. The fingerprint reader never works on the first try. May be it takes getting used to.",
#   'rating': 4,
#   'helpfulVotes': 1.0,
#   'review_processed': "I bought this phone for my dad and he hasn't had any problems with it except for the fingerprint reader. The fingerprint reader never works on the first try. May be it takes getting used to; it's a new experience for him. It's just ok."},
#  85: {'review_id': 98,
#   'review_time': '2018-02-17',
#   'review': "If it doesn't work on your network, ask your provider if they'll troubleshoot for you.I nearly returned the phone because it originally didn't want to work on my network (T-mobile) however Buyspry emailed me saying that the phone is unlocked and should work. I figured I'd give T-Mobile a call and see if they could help. They said I could take it in and they would troubleshoot it for me. They managed to fix it and didn't charge me anything. All in all, I'm glad I didn't return it because it is a beautiful phone. It works great and looks brand new. Really glad this worked out",
#   'rating': 4,
#   'helpfulVotes': 1.0,
#   'review_processed': "If it doesn't work on your network, ask your provider if they'll troubleshoot for you. I nearly returned the phone because it originally didn't want to work on my network. However Buyspry emailed me saying that the phone is unlocked and should work. I figured I'd give T-Mobile a call and see if they could help. They managed to fix it and didn't charge me anything."},
#  86: {'review_id': 99,
#   'review_time': '2018-11-20',
#   'review': "Superb Seller not great product.I had two issues with the phone causing me to return it. 1) battery drained very quickly. Approximately 20% in an hour with the phone over heating, 2) Struggled to get cell signal(AT&T). Phone feels good (I have the Qualcomm US version) which I don't experience any of these issues. It might have been a bad unit or the Korean chip isn't as smooth as Qualcomm! Seller is impressive, responsive and the product was brand new sealed!",
#   'rating': 3,
#   'helpfulVotes': 2.0,
#   'review_processed': "I had two issues with the phone that caused me to return it. The battery drained very quickly. It might have been a bad unit or the Korean chip isn't as smooth as the US version. Seller is impressive, responsive and the product was brand new sealed!"}}

# %%
with open("temp_phone-1.json", "w") as file:
    json.dump(result, file, indent=4)
