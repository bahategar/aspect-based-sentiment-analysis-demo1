# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import spacy

import re
import os

import ast

from tqdm import tqdm

from nltk.corpus import stopwords
import gensim

# %%
# Load nlp model
nlp = spacy.load('en_core_web_lg')

# %%
df = pd.read_csv('example.csv')

# Convert the string columns to dictionaries
df['ability'] = df['ability'].apply(ast.literal_eval)
df['ability_filtered'] = df['ability_filtered'].apply(ast.literal_eval)
df['aspects'] = df['aspects'].apply(ast.literal_eval)

print(df.info())
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 91 entries, 0 to 90
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   index             91 non-null     int64
#  1   review            91 non-null     object
#  2   ability           91 non-null     object
#  3   ability_filtered  91 non-null     object
#  4   aspects           91 non-null     object
# dtypes: int64(1), object(4)
# memory usage: 3.7+ KB
# None
#    index                                             review  \
# 0      0  The staff were incredibly helpful and patient,...
# 1      1  I had a great experience purchasing my phone h...
# 2      2  Their selection of phones is amazing, and the ...
# 3      3  I appreciate how the staff walked me through s...
# 4      4  Great customer service, I left with the phone ...
#
#                                              ability  \
# 0  {0: [('staff', 'were helpful'), ('staff', 'wer...
# 1  {0: [('process', 'was smooth'), ('process', 'w...
# 2  {0: [('selection', 'is amazing'), ('price', 'a...
# 3  {0: [('I', 'appreciate walked through setting ...
# 4  {0: [('question', 'answered'), ('I', 'left wit...
#
#                                     ability_filtered             aspects
# 0  {0: [('staff', 'were helpful'), ('staff', 'wer...             [staff]
# 1                    {0: [('process', 'was quick')]}           [process]
# 2                 {0: [('selection', 'is amazing')]}  [price, selection]
# 3               {0: [('I', 'appreciate walked me')]}        [new device]
# 4  {0: [('question', 'answered'), ('I', 'left wit...          [question]

# %%
def contraction(x):
    flatten = [item for sublist in x.values() for item in sublist]

    temp = []
    for t in flatten:
        temp.append(' '.join(t))

    if len(temp) > 0:
        return '. '.join(temp) + '.'
    return ''
    
corpus = df['ability'].apply(contraction).values

corpus
# Out:
# array(['staff were helpful. staff were patient.',
#        'process was smooth. process was quick.',
#        'selection is amazing. price are competitive.',
#        'I appreciate walked through setting new device. I appreciate walked me.',
#        'question answered. I left with phone.',
#        'I could not resist upgrading. I could not resist offer amazing deals on phones.',
#        'technician fixed issue. I expected. technician fixed faster.',
#        'experience really know stuff.',
#        'variety was impressive. I found perfect case.',
#        'staff was knowledgeable.', 'price were reasonable.',
#        'staff really went mile.',
#        'service service be Excellent. they helped find.',
#        'deal was friendly. staff was friendly.',
#        'I love store. buying buying be experience. fixing buying be experience.',
#        'I got good deal on old phone.',
#        'service are quick. service are reliable.',
#        'staff was helpful in setting phone.', 'I m satisfied.',
#        'staff was patient with questions. variety was patient with questions.',
#        'I m thrilled. process was simple.',
#        'they helped choose within budget. they helped choose phone.',
#        'phone was fixed in minutes.', 'service is outstanding. I m.',
#        'store hands.', 'staff made. I was comfortable with purchase.',
#        'they helped get great deal. I found needed what.',
#        'store has fantastic service.',
#        'staff was informative. I learned lot about features.',
#        'store store be Excellent. variety store be Excellent.',
#        'they were quick in setting phone.',
#        'layout is easy. staff are ready.', 'they helped save lot.',
#        'one provides best service. I been to many stores.',
#        'service is top notch. they always resolve quickly. service is notch. they always resolve issues.',
#        'they not fail recommend to friends. they not fail recommend to family. they not fail recommend store.',
#        'staff took time.', 'place place be Amazing.', 'plan is worth.',
#        'they were able.', 'staff was accommodating.',
#        'I had great experience with program.',
#        'service was efficient. service was quick.',
#        'they even helped data. they even helped transfer without extra charge. they even helped transfer contacts.',
#        'phone has working flawlessly. I bought from here. I bought it.',
#        'they even gave discount on repair. they fixed screen. they fixed perfectly.',
#        'this is reliable.',
#        'they offer discounts. they offer fantastic promotions.',
#        'selection selection be Great. service selection be Great. service selection be phone. selection selection be phone.',
#        'they resolved issue. they resolved very quickly professionally.',
#        'store is organized. they fast attend to customers.',
#        'you re looking for good deals.',
#        'I always leave store. I made right purchase.',
#        'they really know received excellent advice from team. they really know products.',
#        'phone looks new.',
#        'staff was not apologetic. I had to wait over hour.',
#        'selection is limited. price are high.',
#        'service is poor. one seemed.', 'phone was defective.',
#        'staff was unhelpful. staff was rude. I m not coming back.',
#        'they charged extra for services. they charged me. they felt like scam.',
#        'I had took way. I had took too long.',
#        'I bought phone. they did not inform of hidden fees. they did not inform me.',
#        'staff seemed. staff gave incorrect information about plan.',
#        'warranty is useless. they refused.',
#        'they twice gave refund. I had to return faulty phone.',
#        'I very disorganized waited forever.',
#        'they refused to honor promotion.', 'I felt pressured.',
#        'phone broke within week. phone broke again. repair was done poorly.',
#        'service was slow. they need.', 'phone was working after repair.',
#        'phone still has same issue after getting.',
#        'they upsold on plan. they upsold me.',
#        'they did not want. staff was unprofessional.',
#        'I could not exchange phone. I could not exchange despite defects. policy is awful.',
#        'they did not apply discount.',
#        'store was messy. store was understaffed.',
#        'phone broke. warranty just expired.', 'they kept trying.',
#        'they refused to refund me. job was incomplete.',
#        'representative were rude on phone.',
#        'I had to call multiple times.',
#        'they did not explain anything. they rushed through purchase. they did not explain clearly. they rushed me.',
#        'support is non.',
#        'phone stopped working outside window. phone stopped quality.',
#        'store was with long lines. store was chaotic. store was with unhelpful staff.',
#        'they did not even have after promising me. it was available. they did not even have phone.',
#        'they lost order.', 'I felt overcharged.',
#        'technician damaged during repair. technician damaged phone. they did not take responsibility.'],
#       dtype=object)

# %%
def get_all_token_dep_right(token, dep):
    result = []
    if type(dep) == str:
        dep = [dep]
    for t in token.children:
        if t.dep_ in dep and t.i > token.i:
            result.append(t)
    return result

# Get token spcific dependency
def get_token_dep(token, dep):
    if type(dep) == str:
        dep = [dep]
    for t in token.children:
        if t.dep_ in dep:
            return t
    return None

def cross_product_tuple(first, second):
    """
    Do cross product

    parameters
    -----------
    first: list/string
    second: list/string

    return: list of tuple
    """
    temp = []
    if type(first) == str:
        first = [first]
    if type(second) == str:
        second = [second]
    for i in first:
        for j in second:
            temp.append((i, j))
    return temp

# %%
# Labeling (class, verb/adjective) on sentences
# NOTE:
# - Add sentiment, {adj: {'positive': [], 'negative': [], 'neutral': []}

def meta_data_swot(corpus):
    data = {}

    # Preparation data : UNCOMMENT THE CODE BELOW
    # category = ['verb', 'adj']
    # sentiment = ['positive', 'neutral', 'negative']
    # for c in category:
    #     for s in sentiment:
    #         data[c][s] = []

    for text in corpus:
        doc = nlp(text)
    
        for sent in doc.sents:
            subject = []
            verb = []
            adjv = []
            for token in sent:
                if token.dep_ in ['nsubj', 'nsubjpass']:
                    if token.pos_ != 'PRON':
                        subject.append(token.lemma_)
                        
                    if token.pos_ == 'PRON':
                        if token.text.lower() == 'they':
                            subject.append('staff')
                        elif token.text.lower() in ['i', 'this']:
                            subject.append('store')
    
                    if token.head.pos_ == 'VERB' and (token.head.lemma_ != 'be' or token.head.lemma_ != 'do'):
                        verb.append(token.head.lemma_)
    
                    if token.head.pos_ == 'AUX':
                        adj = get_token_dep(token.head ,'acomp')
                        if adj and len(adj.text) > 3:
                            adjv.append(adj.lemma_)

            if len(verb) > 0:
                temp = cross_product_tuple(subject, verb)
                for label in temp:
                    s, v = label
                    if data.get(s):
                        if data.get(s).get('verb'):
                            data[s]['verb'] += [(v, sent.text)]
                        else:
                            data[s].update({'verb': [(v, sent.text)]})
                    else:
                        data[s] = ({'verb': [(v, sent.text)]})
                                
            if len(adjv) > 0:
                temp = cross_product_tuple(subject, adjv)
                for label in temp:
                    s, a = label
                    if data.get(s):
                        if data.get(s).get('adj'):
                            data[s]['adj'] += [(a, sent.text)]
                        else:
                            data[s].update({'adj': [(a, sent.text)]})
                    else:
                        data[s] = {'adj': [(a, sent.text)]}
                        
    return data

# test = [labeling_text(text) for text in corpus]
test = meta_data_swot(corpus)
test
# Out:
# {'staff': {'adj': [('helpful', 'staff were helpful.'),
#    ('patient', 'staff were patient.'),
#    ('knowledgeable', 'staff was knowledgeable.'),
#    ('friendly', 'staff was friendly.'),
#    ('helpful', 'staff was helpful in setting phone.'),
#    ('patient', 'staff was patient with questions.'),
#    ('informative', 'staff was informative.'),
#    ('quick', 'they were quick in setting phone.'),
#    ('ready', 'staff are ready.'),
#    ('able', 'they were able.'),
#    ('apologetic', 'staff was not apologetic.'),
#    ('unhelpful', 'staff was unhelpful.'),
#    ('rude', 'staff was rude.'),
#    ('unprofessional', 'staff was unprofessional.')],
#   'verb': [('go', 'staff really went mile.'),
#    ('help', 'they helped find.'),
#    ('help', 'they helped choose within budget.'),
#    ('help', 'they helped choose phone.'),
#    ('make', 'staff made.'),
#    ('help', 'they helped get great deal.'),
#    ('help', 'they helped save lot.'),
#    ('resolve', 'they always resolve quickly.'),
#    ('resolve', 'they always resolve issues.'),
#    ('fail', 'they not fail recommend to friends.'),
#    ('fail', 'they not fail recommend to family.'),
#    ('fail', 'they not fail recommend store.'),
#    ('take', 'staff took time.'),
#    ('accommodate', 'staff was accommodating.'),
#    ('help', 'they even helped data.'),
#    ('help', 'they even helped transfer without extra charge.'),
#    ('help', 'they even helped transfer contacts.'),
#    ('give', 'they even gave discount on repair.'),
#    ('fix', 'they fixed screen.'),
#    ('fix', 'they fixed perfectly.'),
#    ('offer', 'they offer discounts.'),
#    ('offer', 'they offer fantastic promotions.'),
#    ('resolve', 'they resolved issue.'),
#    ('resolve', 'they resolved very quickly professionally.'),
#    ('attend', 'they fast attend to customers.'),
#    ('know', 'they really know received excellent advice from team.'),
#    ('know', 'they really know products.'),
#    ('charge', 'they charged extra for services.'),
#    ('charge', 'they charged me.'),
#    ('feel', 'they felt like scam.'),
#    ('inform', 'they did not inform of hidden fees.'),
#    ('inform', 'they did not inform me.'),
#    ('seem', 'staff seemed.'),
#    ('give', 'staff gave incorrect information about plan.'),
#    ('refuse', 'they refused.'),
#    ('give', 'they twice gave refund.'),
#    ('refuse', 'they refused to honor promotion.'),
#    ('need', 'they need.'),
#    ('upsold', 'they upsold on plan.'),
#    ('upsold', 'they upsold me.'),
#    ('want', 'they did not want.'),
#    ('apply', 'they did not apply discount.'),
#    ('keep', 'they kept trying.'),
#    ('refuse', 'they refused to refund me.'),
#    ('explain', 'they did not explain anything.'),
#    ('rush', 'they rushed through purchase.'),
#    ('explain', 'they did not explain clearly.'),
#    ('rush', 'they rushed me.'),
#    ('have', 'they did not even have after promising me.'),
#    ('have', 'they did not even have phone.'),
#    ('lose', 'they lost order.'),
#    ('take', 'they did not take responsibility.')]},
#  'process': {'adj': [('smooth', 'process was smooth.'),
#    ('quick', 'process was quick.'),
#    ('simple', 'process was simple.')]},
#  'selection': {'adj': [('amazing', 'selection is amazing.'),
#    ('great', 'selection selection be Great.'),
#    ('great', 'service selection be Great.'),
#    ('limited', 'selection is limited.')],
#   'verb': [('be', 'service selection be phone.'),
#    ('be', 'selection selection be phone.')]},
#  'price': {'adj': [('competitive', 'price are competitive.'),
#    ('reasonable', 'price were reasonable.'),
#    ('high', 'price are high.')]},
#  'store': {'verb': [('appreciate',
#     'I appreciate walked through setting new device.'),
#    ('appreciate', 'I appreciate walked me.'),
#    ('leave', 'I left with phone.'),
#    ('resist', 'I could not resist upgrading.'),
#    ('resist', 'I could not resist offer amazing deals on phones.'),
#    ('expect', 'I expected.'),
#    ('find', 'I found perfect case.'),
#    ('love', 'I love store.'),
#    ('get', 'I got good deal on old phone.'),
#    ('m', 'I m satisfied.'),
#    ('m', 'I m thrilled.'),
#    ('m.', 'I m.'),
#    ('find', 'I found needed what.'),
#    ('have', 'store has fantastic service.'),
#    ('learn', 'I learned lot about features.'),
#    ('be', 'I been to many stores.'),
#    ('have', 'I had great experience with program.'),
#    ('buy', 'I bought from here.'),
#    ('buy', 'I bought it.'),
#    ('organize', 'store is organized.'),
#    ('leave', 'I always leave store.'),
#    ('make', 'I made right purchase.'),
#    ('have', 'I had to wait over hour.'),
#    ('come', 'I m not coming back.'),
#    ('take', 'I had took way.'),
#    ('take', 'I had took too long.'),
#    ('buy', 'I bought phone.'),
#    ('have', 'I had to return faulty phone.'),
#    ('wait', 'I very disorganized waited forever.'),
#    ('feel', 'I felt pressured.'),
#    ('exchange', 'I could not exchange phone.'),
#    ('exchange', 'I could not exchange despite defects.'),
#    ('have', 'I had to call multiple times.'),
#    ('feel', 'I felt overcharged.')],
#   'adj': [('comfortable', 'I was comfortable with purchase.'),
#    ('excellent', 'store store be Excellent.'),
#    ('excellent', 'variety store be Excellent.'),
#    ('reliable', 'this is reliable.'),
#    ('messy', 'store was messy.'),
#    ('understaffed', 'store was understaffed.'),
#    ('chaotic', 'store was chaotic.')]},
#  'question': {'verb': [('answer', 'question answered.')]},
#  'technician': {'verb': [('fix', 'technician fixed faster.'),
#    ('damage', 'technician damaged during repair.')]},
#  'experience': {'verb': [('know', 'experience really know stuff.')]},
#  'variety': {'adj': [('impressive', 'variety was impressive.'),
#    ('patient', 'variety was patient with questions.')]},
#  'service': {'adj': [('excellent', 'service service be Excellent.'),
#    ('quick', 'service are quick.'),
#    ('reliable', 'service are reliable.'),
#    ('outstanding', 'service is outstanding.'),
#    ('notch', 'service is top notch.'),
#    ('notch', 'service is notch.'),
#    ('efficient', 'service was efficient.'),
#    ('quick', 'service was quick.'),
#    ('poor', 'service is poor.'),
#    ('slow', 'service was slow.')]},
#  'deal': {'adj': [('friendly', 'deal was friendly.')]},
#  'phone': {'verb': [('fix', 'phone was fixed in minutes.'),
#    ('work', 'phone has working flawlessly.'),
#    ('look', 'phone looks new.'),
#    ('break', 'phone broke within week.'),
#    ('break', 'phone broke again.'),
#    ('work', 'phone was working after repair.'),
#    ('have', 'phone still has same issue after getting.'),
#    ('stop', 'phone stopped working outside window.'),
#    ('stop', 'phone stopped quality.')],
#   'adj': [('defective', 'phone was defective.')]},
#  'layout': {'adj': [('easy', 'layout is easy.')]},
#  'one': {'verb': [('provide', 'one provides best service.')]},
#  'place': {'adj': [('amazing', 'place place be Amazing.')]},
#  'plan': {'adj': [('worth', 'plan is worth.')]},
#  'warranty': {'adj': [('useless', 'warranty is useless.')],
#   'verb': [('expire', 'warranty just expired.')]},
#  'repair': {'verb': [('do', 'repair was done poorly.')]},
#  'policy': {'adj': [('awful', 'policy is awful.')]},
#  'job': {'adj': [('incomplete', 'job was incomplete.')]},
#  'representative': {'adj': [('rude', 'representative were rude on phone.')]}}

# %%
mapper_classification = {
    'customer service' : ['staff', 'selection', 'support', 'deal', 'representative'],
    'phone service' : ['service', 'process', 'technician', 'experience', 'repair', ],
    'store atmosphere' : ['phone', 'store', 'price', 'variety', 'warranty', 'place', 'policy'],
}

# %%
def sentence_per_verb(data, class_):
    temp_data = data[class_]['verb']

    # Counting verb appears
    count_words = {}
    # total_words = 0
    # storage = []
    for element in temp_data:
        key, sentence = element
        if count_words.get(key):
            count, text = count_words.get(key)
            count_words[key] = (count + 1, text + ' ' + sentence)
        else:
            count_words[key] = (1, sentence)
            # total_words += 1
            
    return count_words

example = sentence_per_verb(test, 'staff')
example
# Out:
# {'go': (1, 'staff really went mile.'),
#  'help': (8,
#   'they helped find. they helped choose within budget. they helped choose phone. they helped get great deal. they helped save lot. they even helped data. they even helped transfer without extra charge. they even helped transfer contacts.'),
#  'make': (1, 'staff made.'),
#  'resolve': (4,
#   'they always resolve quickly. they always resolve issues. they resolved issue. they resolved very quickly professionally.'),
#  'fail': (3,
#   'they not fail recommend to friends. they not fail recommend to family. they not fail recommend store.'),
#  'take': (2, 'staff took time. they did not take responsibility.'),
#  'accommodate': (1, 'staff was accommodating.'),
#  'give': (3,
#   'they even gave discount on repair. staff gave incorrect information about plan. they twice gave refund.'),
#  'fix': (2, 'they fixed screen. they fixed perfectly.'),
#  'offer': (2, 'they offer discounts. they offer fantastic promotions.'),
#  'attend': (1, 'they fast attend to customers.'),
#  'know': (2,
#   'they really know received excellent advice from team. they really know products.'),
#  'charge': (2, 'they charged extra for services. they charged me.'),
#  'feel': (1, 'they felt like scam.'),
#  'inform': (2, 'they did not inform of hidden fees. they did not inform me.'),
#  'seem': (1, 'staff seemed.'),
#  'refuse': (3,
#   'they refused. they refused to honor promotion. they refused to refund me.'),
#  'need': (1, 'they need.'),
#  'upsold': (2, 'they upsold on plan. they upsold me.'),
#  'want': (1, 'they did not want.'),
#  'apply': (1, 'they did not apply discount.'),
#  'keep': (1, 'they kept trying.'),
#  'explain': (2,
#   'they did not explain anything. they did not explain clearly.'),
#  'rush': (2, 'they rushed through purchase. they rushed me.'),
#  'have': (2,
#   'they did not even have after promising me. they did not even have phone.'),
#  'lose': (1, 'they lost order.')}

# %%
def get_threshold(data, threshold=75):
    temp = []
    for count, _ in data.values():
        temp.append(count)
        
    return np.percentile(temp, threshold)

get_threshold(example)
# Out:
# 2.0
