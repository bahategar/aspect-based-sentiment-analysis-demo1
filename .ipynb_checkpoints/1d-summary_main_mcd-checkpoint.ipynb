# %%
import fasttext
model = fasttext.load_model('./util/cc.en.300.bin')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import json
import re

from tqdm import tqdm
# Out:
# C:\Users\Baha Tegar\anaconda3\Lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
import util.normalization as norm
import util.model as models
import util.utility as util

# %%
# Opening JSON file
with open("./mcd_result/map_second_clothes.json") as json_file:
    map_second_keys = json.load(json_file)

with open("./mcd_result/map_category_clothes.json") as json_file:
    map_category = json.load(json_file)

with open("./mcd_result/list_first_cycle_clothes.json") as json_file:
    list_first_cycle = json.load(json_file)

# %%
df_base = pd.read_csv("./mcd_result/base_mcd_v2.csv")

print(df_base.info())
df_base.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   reviewer_id       100 non-null    int64
#  1   review            100 non-null    object
#  2   summarize         100 non-null    object
#  3   aspect            100 non-null    object
#  4   token_sentence    100 non-null    object
#  5   token_lemma       100 non-null    object
#  6   rating            100 non-null    int64
#  7   residu            86 non-null     object
#  8   key_score_aspect  94 non-null     object
# dtypes: int64(2), object(7)
# memory usage: 7.2+ KB
# None
#    reviewer_id                                             review  \
# 0            0  So flattering and so comfortable! I am in love...
# 1            1  Cute but It Pills Great color and pattern, wit...
# 2            2  It fell apart after one wash One set fell apar...
# 3            3  Comfortable, nice color, but LOTS of pilling. ...
# 4            4  Cute dress that.even a short, skinny old woman...
#
#                                            summarize  \
# 0   So flattering and so comfortable! I am in lov...
# 1   Material began to pill after first wearing, a...
# 2   One set fell apart after one wash . Threads c...
# 3   Comfortable, nice color, but lots of pilling ...
# 4   Cute dress that.even a short, skinny old woma...
#
#                                               aspect  \
# 0  beige sandal, casual look, compliment, left si...
# 1  great color, material, slouchy look, wash cycl...
# 2  bad thing, string, set, thread, product info, ...
# 3  purchase, good care, nice color, fit, fabric, ...
# 4  necessary spot, material, old woman, woman ski...
#
#                                       token_sentence  \
# 0  It has a relaxed fit style as described, and I...
# 1  Cute but It Pills Great color and pattern, wit...
# 2  It fell apart after one wash One set fell apar...
# 3  nice color, I like the fit, weight, I would ha...
# 4  Cute dress that.even a short, skinny old woman...
#
#                                          token_lemma  rating  \
# 0  it have a relaxed fit style as described, and ...       5
# 1  cute but it pill great color and pattern, with...       3
# 2  it fell apart after one wash one set fell apar...       1
# 3  nice color, i like the fit, weight, i would ha...       3
# 4  cute dress that.even a short, skinny old woman...       5
#
#                                               residu  \
# 0  more item, profile, grocery, beige sandal, cro...
# 1  first washing, wash cycle, slouchy look, hand ...
# 2          tie, product info, bad thing, string, set
# 3                           weight, thats, good care
# 4  dress that.even, old woman, woman skinny, nece...
#
#                                     key_score_aspect
# 0  type, name, positive; other, compliment, posit...
# 1  ; properties, material, positive; application,...
# 2  application, wash, negative; ; other, thread, ...
# 3  service, good care, positive; emotion, good ca...
# 4  ; emotion, cute dress, positive; properties, m...

# %%
def split_all(x):
    temp = []
    for e in x:
        if len(e) == 0:
            continue
        temp.append(tuple(e.split(", ")))
        
    return temp



df_base = df_base.fillna("")

df_base['aspect'] = df_base['aspect'].apply(lambda x: x.split(", "))
df_base['token_sentence'] = df_base['token_sentence'].apply(lambda x: x.split(", "))
df_base['token_lemma'] = df_base['token_lemma'].apply(lambda x: x.split(", "))
df_base['residu'] = df_base['residu'].apply(lambda x: x.split(", "))

df_base['key_score_aspect'] = df_base['key_score_aspect'].apply(lambda x: x.split("; ")).apply(lambda x: split_all(x))

print(df_base.info())
df_base.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   reviewer_id       100 non-null    int64
#  1   review            100 non-null    object
#  2   summarize         100 non-null    object
#  3   aspect            100 non-null    object
#  4   token_sentence    100 non-null    object
#  5   token_lemma       100 non-null    object
#  6   rating            100 non-null    int64
#  7   residu            100 non-null    object
#  8   key_score_aspect  100 non-null    object
# dtypes: int64(2), object(7)
# memory usage: 7.2+ KB
# None
#    reviewer_id                                             review  \
# 0            0  So flattering and so comfortable! I am in love...
# 1            1  Cute but It Pills Great color and pattern, wit...
# 2            2  It fell apart after one wash One set fell apar...
# 3            3  Comfortable, nice color, but LOTS of pilling. ...
# 4            4  Cute dress that.even a short, skinny old woman...
#
#                                            summarize  \
# 0   So flattering and so comfortable! I am in lov...
# 1   Material began to pill after first wearing, a...
# 2   One set fell apart after one wash . Threads c...
# 3   Comfortable, nice color, but lots of pilling ...
# 4   Cute dress that.even a short, skinny old woma...
#
#                                               aspect  \
# 0  [beige sandal, casual look, compliment, left s...
# 1  [great color, material, slouchy look, wash cyc...
# 2  [bad thing, string, set, thread, product info,...
# 3  [purchase, good care, nice color, fit, fabric,...
# 4  [necessary spot, material, old woman, woman sk...
#
#                                       token_sentence  \
# 0  [It has a relaxed fit style as described, and ...
# 1  [Cute but It Pills Great color and pattern, wi...
# 2  [It fell apart after one wash One set fell apa...
# 3  [nice color, I like the fit, weight, I would h...
# 4  [Cute dress that.even a short, skinny old woma...
#
#                                          token_lemma  rating  \
# 0  [it have a relaxed fit style as described, and...       5
# 1  [cute but it pill great color and pattern, wit...       3
# 2  [it fell apart after one wash one set fell apa...       1
# 3  [nice color, i like the fit, weight, i would h...       3
# 4  [cute dress that.even a short, skinny old woma...       5
#
#                                               residu  \
# 0  [more item, profile, grocery, beige sandal, cr...
# 1  [first washing, wash cycle, slouchy look, hand...
# 2        [tie, product info, bad thing, string, set]
# 3                         [weight, thats, good care]
# 4  [dress that.even, old woman, woman skinny, nec...
#
#                                     key_score_aspect
# 0  [(type, name, positive), (other, compliment, p...
# 1  [(properties, material, positive), (applicatio...
# 2  [(application, wash, negative), (other, thread...
# 3  [(service, good care, positive), (emotion, goo...
# 4  [(emotion, cute dress, positive), (properties,...

# %%
df_main = df_base.copy()

df_main['token_sentence'] = df_main['token_sentence'].apply(lambda x: "\n".join("● " + item for item in x))

df_main.head()
# Out:
#    reviewer_id                                             review  \
# 0            0  So flattering and so comfortable! I am in love...
# 1            1  Cute but It Pills Great color and pattern, wit...
# 2            2  It fell apart after one wash One set fell apar...
# 3            3  Comfortable, nice color, but LOTS of pilling. ...
# 4            4  Cute dress that.even a short, skinny old woman...
#
#                                            summarize  \
# 0   So flattering and so comfortable! I am in lov...
# 1   Material began to pill after first wearing, a...
# 2   One set fell apart after one wash . Threads c...
# 3   Comfortable, nice color, but lots of pilling ...
# 4   Cute dress that.even a short, skinny old woma...
#
#                                               aspect  \
# 0  [beige sandal, casual look, compliment, left s...
# 1  [great color, material, slouchy look, wash cyc...
# 2  [bad thing, string, set, thread, product info,...
# 3  [purchase, good care, nice color, fit, fabric,...
# 4  [necessary spot, material, old woman, woman sk...
#
#                                       token_sentence  \
# 0  ● It has a relaxed fit style as described\n● a...
# 1  ● Cute but It Pills Great color and pattern\n●...
# 2  ● It fell apart after one wash One set fell ap...
# 3  ● nice color\n● I like the fit\n● weight\n● I ...
# 4  ● Cute dress that.even a short\n● skinny old w...
#
#                                          token_lemma  rating  \
# 0  [it have a relaxed fit style as described, and...       5
# 1  [cute but it pill great color and pattern, wit...       3
# 2  [it fell apart after one wash one set fell apa...       1
# 3  [nice color, i like the fit, weight, i would h...       3
# 4  [cute dress that.even a short, skinny old woma...       5
#
#                                               residu  \
# 0  [more item, profile, grocery, beige sandal, cr...
# 1  [first washing, wash cycle, slouchy look, hand...
# 2        [tie, product info, bad thing, string, set]
# 3                         [weight, thats, good care]
# 4  [dress that.even, old woman, woman skinny, nec...
#
#                                     key_score_aspect
# 0  [(type, name, positive), (other, compliment, p...
# 1  [(properties, material, positive), (applicatio...
# 2  [(application, wash, negative), (other, thread...
# 3  [(service, good care, positive), (emotion, goo...
# 4  [(emotion, cute dress, positive), (properties,...

# %%
def custom_text(x):
    temp = {}
    text = ""
    if not x:
        return text
    
    for s in x:
        category, key, sentiment = s

        if category not in temp:
            temp[category] = f"\t- {key} ({sentiment})"
        else:
            temp[category] = temp[category] + "\n" + f"\t- {key} ({sentiment})"



    categories = list(temp.keys())
    for category in categories:
        temp_text = f"● {category}:\n" + temp[category]

        text = text + temp_text + '\n'

    return text

# %%
df_main['information'] = df_main['key_score_aspect'].apply(lambda x: custom_text(x))

df_main = df_main.drop('key_score_aspect', axis=1)

# %%
columns = ['reviewer_id', 'review', 'summarize', 'token_sentence', 'information', 'rating']
df_main = df_main[columns]

df_main.to_csv('./mcd_result/main_mcd.csv', index=False)
