# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from tqdm import tqdm

# %%
import util.normalization as norm
import util.model as models
import util.utility as util

# %%
df = pd.read_csv("./sample-phone.csv")
df = df.reset_index(names='id')
# df = df.drop(['title', 'body'], axis=1)
print(df.info())
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            100 non-null    int64
#  1   asin          100 non-null    object
#  2   name          100 non-null    object
#  3   rating        100 non-null    int64
#  4   date          100 non-null    object
#  5   verified      100 non-null    bool
#  6   title         100 non-null    object
#  7   body          100 non-null    object
#  8   helpfulVotes  100 non-null    float64
# dtypes: bool(1), float64(1), int64(2), object(5)
# memory usage: 6.5+ KB
# None
#    id        asin                name  rating               date  verified  \
# 0   0  B07K76LBLZ       PlaYboY BuNnY       5  February 14, 2019      True
# 1   1  B07P8MQHSH           Gemini_13       3     August 2, 2019      True
# 2   2  B01NC2MEJP         Kashm30uttz       2     April 30, 2018      True
# 3   3  B018OMP8ES           Techie241       3   January 16, 2017      True
# 4   4  B07QC4R451  Michelle Wildhagen       1      June 22, 2019      True
#
#                                                title  \
# 0                           Best phone money can buy
# 1               Pixel 3 has frequent display defects
# 2  the lower left corner of the phone doesnt work...
# 3           Great phone, be careful with the sellers
# 4  U had no issue with the seller they were great...
#
#                                                 body  helpfulVotes
# 0               So far this phone is the bees knees.           3.0
# 1  I like this phone model. I bought this phone a...          20.0
# 2  the lower left corner of the phone doesnt work...           1.0
# 3  The phone is wonderful, if you're considering ...          10.0
# 4  I was very disappointed in the way this phone ...           3.0

# %% [markdown]
# # Normalization

# %%
# df_prc = df[['reviewer_id', 'review']].copy()

# # Remove non-ASCII
# df_prc['token_sentence'] = df_prc['review'].apply(norm.remove_non_ascii)

# # Expand contractions
# df_prc['token_sentence'] = df_prc['token_sentence'].apply(norm.expand_contractions)

# # Remove characters
# df_prc['token_sentence'] = df_prc['token_sentence'].apply(norm.remove_characters, args=(True,))

# # Remove enter tab
# df_prc['token_clean'] = df_prc['token_sentence'].apply(norm.remove_enter_tab)

# # Lemmatization
# df_prc['token_clean'] = df_prc['token_clean'].apply(norm.lemmatize_text)

# %%
# Tokenization into sentence

df_st = df.copy()
df_st['review'] = df_st['title'] + ". " + df_st['body']

df_st = df_st[['id', 'review']]

# Remove non-ASCII
df_st['token_sentence'] = df_st['review'].apply(norm.remove_non_ascii)

# Sentence Tokenization
df_st['token_sentence'] = df_st['token_sentence'].apply(norm.sentence_tokenize)
df_st = df_st.explode('token_sentence')
df_st['token_sentence'] = df_st['token_sentence'].str.strip()

# Expand contractions
df_st['token_sentence'] = df_st['token_sentence'].apply(norm.expand_contractions)

# Remove characters
df_st['token_sentence'] = df_st['token_sentence'].apply(norm.remove_characters, args=(True,))

# Remove enter tab
df_st['token_clean'] = df_st['token_sentence'].apply(norm.remove_enter_tab)

# Lemmatization
df_st['token_clean'] = df_st['token_clean'].apply(norm.lemmatize_text)

# %% [markdown]
# # Get Aspect (Rules Based)

# %%
# Get aspect from rules
tqdm.pandas()
df_st['sub_aspect'] = df_st['token_clean']\
                        .progress_apply(util.get_aspect_rules)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 972/972 [01:31<00:00, 10.60it/s]

# %%
df_st.head()
# Out:
#    id                                             review  \
# 0   0  Best phone money can buy. So far this phone is...
# 0   0  Best phone money can buy. So far this phone is...
# 1   1  Pixel 3 has frequent display defects. I like t...
# 1   1  Pixel 3 has frequent display defects. I like t...
# 1   1  Pixel 3 has frequent display defects. I like t...
#
#                               token_sentence  \
# 0                  Best phone money can buy.
# 0       So far this phone is the bees knees.
# 1      Pixel 3 has frequent display defects.
# 1                   I like this phone model.
# 1  I bought this phone as a gift to my wife.
#
#                                token_clean  \
# 0               best phone money can buy .
# 0      so far this phone be the bee knee .
# 1   pixel 3 have frequent display defect .
# 1                i like this phone model .
# 1  i buy this phone as a gift to my wife .
#
#                                   sub_aspect
# 0      {best phone, money best, phone money}
# 0                          {phone, bee knee}
# 1  {pixel, frequent display, display defect}
# 1                              {phone model}
# 1                                    {phone}

# %%
# Create summary
mask = df_st['sub_aspect'].apply(lambda x: False if len(x) == 0 else True).values

df_summary = df_st[mask].groupby(['id'])['token_sentence']\
                .apply(lambda x: '. '.join(x))\
                .reset_index()\
                .rename(columns={'token_sentence': 'summary'})

df_prc = df_st.groupby(['id'])\
                .agg({'sub_aspect': lambda x: set().union(*x),
                      'token_clean': lambda x: '. '.join(x),
                     })\
                .reset_index()

df_prc = df_prc.merge(df_summary, on='id', how='left').fillna("")
print(df_prc.info())
df_prc.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           100 non-null    int64
#  1   sub_aspect   100 non-null    object
#  2   token_clean  100 non-null    object
#  3   summary      100 non-null    object
# dtypes: int64(1), object(3)
# memory usage: 3.3+ KB
# None
#    id                                         sub_aspect  \
# 0   0  {best phone, phone, money best, phone money, b...
# 1   1  {amazon, pixel, customer, frequent display, ph...
# 2   2       {money sick, leave corner, phone, low leave}
# 3   3  {volume button, scuff, great phone, seller, lo...
# 4   4  {service, drop call, phone work, nice photo, i...
#
#                                          token_clean  \
# 0  best phone money can buy .. so far this phone ...
# 1  pixel 3 have frequent display defect .. i like...
# 2  the low leave corner of the phone doesnt work ...
# 3  great phone. be careful with the seller .. the...
# 4  u have no issue with the seller they be great ...
#
#                                              summary
# 0  Best phone money can buy.. So far this phone i...
# 1  Pixel 3 has frequent display defects.. I like ...
# 2  the lower left corner of the phone doesnt work...
# 3  Great phone. The phone is wonderful. However m...
# 4  U had no issue with the seller they were great...

# %%
# # Get aspect from rules
# tqdm.pandas()
# df_prc['sub_aspect'] = df_prc['token_clean']\
#                         .progress_apply(util.get_aspect_rules)

# %%
# print(df_prc.info())
# df_prc.head()

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

text = ""
sub_aspect = df_prc['sub_aspect'].values
for i in range(df_prc.shape[0]):
    text = text + " " + " ".join(list(sub_aspect[i]))
    

text = text.strip()

wordcloud = WordCloud(background_color='white').generate(text)
plt.style.use('classic')
plt.figure(figsize=(12,10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
# df['sub_aspect'] = df_prc['sub_aspect'].apply(lambda x: ", ".join(list(x)))

# %% [markdown]
# # Get Topic

# %%
def get_optimum_lda(dictionary, corpus, texts, limit,
                    start=2, step=1, get_result=False,
                    iterations=20, passes=1):
    coherence_values = []
    
    for n in range(start, limit, step):
        lda = gensim.models.LdaMulticore(corpus=corpus,
                                         num_topics=n,
                                         id2word=dictionary,
                                         iterations=iterations,
                                         passes=passes)
        
        # Create coherence
        coherence_model = CoherenceModel(model=lda, 
                                         texts=texts,
                                         dictionary=dictionary, 
                                         coherence='c_v')
        coherence_values.append(coherence_model.get_coherence())
    
    
    opt_num_topics = start + coherence_values.index(max(coherence_values))
    
    lda_opt = gensim.models.LdaMulticore(corpus=corpus,
                                         num_topics=opt_num_topics,
                                         id2word=dictionary)
    
    if get_result:
        print(coherence_values)
    
    return lda_opt

# %%
import gensim
from gensim.models import CoherenceModel


texts = df_prc['token_clean'].apply(norm.preprocess_lda)

dictionary = gensim.corpora.Dictionary(texts)

dictionary.filter_extremes(no_below=15, no_above=0.5, keep_n=100_000)
bow_corpus = [dictionary.doc2bow(doc) for doc in texts]

lda_opt = get_optimum_lda(dictionary, bow_corpus,
                          texts, 10, get_result=True,
                          passes=50, iterations=100)
# Out:
# WARNING:gensim.models.ldamulticore:too few updates, training might not converge; consider increasing the number of passes or iterations to improve accuracy
# [0.2409174736265154, 0.2409174736265154, 0.2409174736265154, 0.24091747362651544, 0.24091747362651542, 0.24091747362651542, 0.2409174736265154, 0.24091747362651544]

# %%
# Print topic
for idx, topic in lda_opt.print_topics(-1):
    print('Topic: {} \nWords: {}'.format(idx, topic))
# Out:
# Topic: 0
# Words: 0.291*"iphone" + 0.249*"great" + 0.209*"samsung" + 0.172*"good" + 0.050*"screen" + 0.010*"work" + 0.010*"battery" + 0.009*"issue"
# Topic: 1
# Words: 0.325*"good" + 0.174*"samsung" + 0.173*"iphone" + 0.123*"work" + 0.089*"issue" + 0.056*"screen" + 0.038*"battery" + 0.023*"great"
# Topic: 2
# Words: 0.287*"great" + 0.163*"battery" + 0.155*"work" + 0.116*"good" + 0.103*"samsung" + 0.083*"issue" + 0.069*"screen" + 0.025*"iphone"
# Topic: 3
# Words: 0.384*"screen" + 0.295*"iphone" + 0.206*"great" + 0.026*"good" + 0.023*"samsung" + 0.022*"work" + 0.022*"issue" + 0.022*"battery"
# Topic: 4
# Words: 0.288*"battery" + 0.181*"great" + 0.174*"screen" + 0.133*"good" + 0.092*"issue" + 0.059*"work" + 0.056*"iphone" + 0.016*"samsung"

# %%
def predict_topic(text):
    text = util.preprocess_lda(text)
    bow_vector = dictionary.doc2bow(text)
    
    result = sorted(lda_opt[bow_vector], 
                    key=lambda x: -1*x[1])[0][0]
    
    return result
    
# Extract keywords into a dictionary or list
threshold = 0.1
topics_dict = {}
for topic_num, topic in lda_opt.show_topics(num_topics=10,
                                                num_words=10,
                                                formatted=False):
    keywords = [word for word, w in topic if w > threshold]
    topics_dict[topic_num] = keywords

# %%
topics_dict
# Out:
# {0: ['iphone', 'great', 'samsung', 'good'],
#  1: ['good', 'samsung', 'iphone', 'work'],
#  2: ['great', 'battery', 'work', 'good', 'samsung'],
#  3: ['screen', 'iphone', 'great'],
#  4: ['battery', 'great', 'screen', 'good']}

# %%
df = df.merge(df_prc[['id', 'summary', 'sub_aspect']], on='id', how='left', )

# %%
tqdm.pandas()
df['topic'] = df_prc['token_clean'].progress_apply(predict_topic)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 118.04it/s]

# %%
tqdm.pandas()
df['key_topic'] = df['topic']\
                    .progress_apply(lambda x: ", ".join(topics_dict[x]))
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████| 100/100 [00:00<?, ?it/s]

# %%
tqdm.pandas()
df['sub_aspect'] = df['sub_aspect']\
                    .progress_apply(lambda x: ", ".join(list(x)))
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 19955.77it/s]

# %%
df.head()
# Out:
#    id        asin                name  rating               date  verified  \
# 0   0  B07K76LBLZ       PlaYboY BuNnY       5  February 14, 2019      True
# 1   1  B07P8MQHSH           Gemini_13       3     August 2, 2019      True
# 2   2  B01NC2MEJP         Kashm30uttz       2     April 30, 2018      True
# 3   3  B018OMP8ES           Techie241       3   January 16, 2017      True
# 4   4  B07QC4R451  Michelle Wildhagen       1      June 22, 2019      True
#
#                                                title  \
# 0                           Best phone money can buy
# 1               Pixel 3 has frequent display defects
# 2  the lower left corner of the phone doesnt work...
# 3           Great phone, be careful with the sellers
# 4  U had no issue with the seller they were great...
#
#                                                 body  helpfulVotes  topic  \
# 0               So far this phone is the bees knees.           3.0      0
# 1  I like this phone model. I bought this phone a...          20.0      3
# 2  the lower left corner of the phone doesnt work...           1.0      2
# 3  The phone is wonderful, if you're considering ...          10.0      2
# 4  I was very disappointed in the way this phone ...           3.0      2
#
#                              key_topic  \
# 0         iphone, great, samsung, good
# 1                screen, iphone, great
# 2  great, battery, work, good, samsung
# 3  great, battery, work, good, samsung
# 4  great, battery, work, good, samsung
#
#                                              summary  \
# 0  Best phone money can buy.. So far this phone i...
# 1  Pixel 3 has frequent display defects.. I like ...
# 2  the lower left corner of the phone doesnt work...
# 3  Great phone. The phone is wonderful. However m...
# 4  U had no issue with the seller they were great...
#
#                                           sub_aspect
# 0  best phone, phone, money best, phone money, be...
# 1  amazon, pixel, customer, frequent display, pho...
# 2         money sick, leave corner, phone, low leave
# 3  volume button, scuff, great phone, seller, loc...
# 4  service, drop call, phone work, nice photo, is...

# %%
df.to_csv('result_phone.csv', index=False)
