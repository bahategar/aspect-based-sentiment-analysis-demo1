# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from tqdm import tqdm

# %%
import util.normalization as norm
import util.model as models
import util.utility as util

# %%
df = pd.read_csv('./sample-mcd.csv', encoding='latin1')
df = df[['reviewer_id', 'review_time', 'review', 'rating']]
print(df.info())
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   reviewer_id  100 non-null    int64
#  1   review_time  100 non-null    object
#  2   review       100 non-null    object
#  3   rating       100 non-null    object
# dtypes: int64(1), object(3)
# memory usage: 3.3+ KB
# None
#    reviewer_id   review_time  \
# 0            1  3 months ago
# 1            2    5 days ago
# 2            3    5 days ago
# 3            4   a month ago
# 4            5  2 months ago
#
#                                               review   rating
# 0  Why does it look like someone spit on my food?...   1 star
# 1  It'd McDonalds. It is what it is as far as the...  4 stars
# 2  Made a mobile order got to the speaker and che...   1 star
# 3  My mc. Crispy chicken sandwich was ÃÂ¯ÃÂ¿ÃÂ...  5 stars
# 4  I repeat my order 3 times in the drive thru, a...   1 star

# %% [markdown]
# # Normalization

# %%
df_sm = df[['reviewer_id', 'review']].copy()

# Remove non-ASCII
df_sm['review_clean'] = df_sm['review'].apply(norm.remove_non_ascii)

# Expand contractions
df_sm['review_clean'] = df_sm['review_clean'].apply(norm.expand_contractions)

# Remove characters
df_sm['review_clean'] = df_sm['review_clean'].apply(norm.remove_characters, args=(True, ))

# %%
df_sm.head()
# Out:
#    reviewer_id                                             review  \
# 0            1  Why does it look like someone spit on my food?...
# 1            2  It'd McDonalds. It is what it is as far as the...
# 2            3  Made a mobile order got to the speaker and che...
# 3            4  My mc. Crispy chicken sandwich was ÃÂ¯ÃÂ¿ÃÂ...
# 4            5  I repeat my order 3 times in the drive thru, a...
#
#                                         review_clean
# 0  Why does it look like someone spit on my food\...
# 1  It would McDonalds. It is what it is as far as...
# 2  Made a mobile order got to the speaker and che...
# 3  My mc. Crispy chicken sandwich was  customer s...
# 4  I repeat my order 3 times in the drive thru, a...

# %%
from transformers import pipeline

classifier = pipeline("summarization")
# Out:
# No model was supplied, defaulted to sshleifer/distilbart-cnn-12-6 (https://huggingface.co/sshleifer/distilbart-cnn-12-6)
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
def get_summarize(text, min_length=25, max_length=68):
    result = classifier(text, min_length=min_length, max_length=max_length)
    return result[0]['summary_text']

# %%
tqdm.pandas()
df_sm['summarize'] = df_sm['review_clean'].progress_apply(get_summarize)
print(df_sm.info())
df_sm.head()
# Out:
#   0%|                                                                                          | 0/100 [00:00<?, ?it/s]Your max_length is set to 68, but you input_length is only 63. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=31)
#   2%|█▋                                                                                | 2/100 [00:06<05:17,  3.24s/it]Your max_length is set to 68, but you input_length is only 52. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=26)
#   4%|███▎                                                                              | 4/100 [00:16<07:13,  4.51s/it]Your max_length is set to 68, but you input_length is only 17. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=8)
#   6%|████▉                                                                             | 6/100 [00:26<07:50,  5.01s/it]Your max_length is set to 68, but you input_length is only 51. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=25)
#   9%|███████▍                                                                          | 9/100 [00:44<08:15,  5.45s/it]Your max_length is set to 68, but you input_length is only 44. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=22)
#  11%|████████▉                                                                        | 11/100 [00:53<07:37,  5.14s/it]Your max_length is set to 68, but you input_length is only 4. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=2)
#  15%|████████████▏                                                                    | 15/100 [01:13<07:19,  5.17s/it]Your max_length is set to 68, but you input_length is only 44. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=22)
#  16%|████████████▉                                                                    | 16/100 [01:18<07:21,  5.25s/it]Your max_length is set to 68, but you input_length is only 32. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=16)
#  18%|██████████████▌                                                                  | 18/100 [01:28<07:01,  5.14s/it]Your max_length is set to 68, but you input_length is only 35. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=17)
#  20%|████████████████▏                                                                | 20/100 [01:38<07:05,  5.32s/it]Your max_length is set to 68, but you input_length is only 45. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=22)
#  23%|██████████████████▋                                                              | 23/100 [01:57<07:51,  6.12s/it]Your max_length is set to 68, but you input_length is only 24. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=12)
#  24%|███████████████████▍                                                             | 24/100 [02:01<07:02,  5.56s/it]Your max_length is set to 68, but you input_length is only 64. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=32)
#  25%|████████████████████▎                                                            | 25/100 [02:06<06:40,  5.34s/it]Your max_length is set to 68, but you input_length is only 9. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=4)
#  26%|█████████████████████                                                            | 26/100 [02:09<05:44,  4.66s/it]Your max_length is set to 68, but you input_length is only 34. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=17)
#  27%|█████████████████████▊                                                           | 27/100 [02:12<05:15,  4.33s/it]Your max_length is set to 68, but you input_length is only 14. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=7)
#  28%|██████████████████████▋                                                          | 28/100 [02:15<04:45,  3.97s/it]Your max_length is set to 68, but you input_length is only 3. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=1)
#  29%|███████████████████████▍                                                         | 29/100 [02:20<04:59,  4.22s/it]Your max_length is set to 68, but you input_length is only 25. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=12)
#  30%|████████████████████████▎                                                        | 30/100 [02:24<04:41,  4.02s/it]Your max_length is set to 68, but you input_length is only 37. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=18)
#  31%|█████████████████████████                                                        | 31/100 [02:28<04:38,  4.03s/it]Your max_length is set to 68, but you input_length is only 37. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=18)
#  33%|██████████████████████████▋                                                      | 33/100 [02:37<04:52,  4.37s/it]Your max_length is set to 68, but you input_length is only 16. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=8)
#  35%|████████████████████████████▎                                                    | 35/100 [02:47<05:12,  4.81s/it]Your max_length is set to 68, but you input_length is only 30. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=15)
#  36%|█████████████████████████████▏                                                   | 36/100 [02:51<04:55,  4.61s/it]Your max_length is set to 68, but you input_length is only 53. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=26)
#  37%|█████████████████████████████▉                                                   | 37/100 [02:58<05:25,  5.16s/it]Your max_length is set to 68, but you input_length is only 10. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=5)
#  38%|██████████████████████████████▊                                                  | 38/100 [03:01<04:54,  4.75s/it]Your max_length is set to 68, but you input_length is only 13. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=6)
#  39%|███████████████████████████████▌                                                 | 39/100 [03:04<04:15,  4.20s/it]Your max_length is set to 68, but you input_length is only 11. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=5)
#  41%|█████████████████████████████████▏                                               | 41/100 [03:12<04:04,  4.15s/it]Your max_length is set to 68, but you input_length is only 27. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=13)
#  43%|██████████████████████████████████▊                                              | 43/100 [03:23<04:34,  4.82s/it]Your max_length is set to 68, but you input_length is only 48. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=24)
#  44%|███████████████████████████████████▋                                             | 44/100 [03:28<04:31,  4.84s/it]Your max_length is set to 68, but you input_length is only 33. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=16)
#  45%|████████████████████████████████████▍                                            | 45/100 [03:30<03:47,  4.14s/it]Your max_length is set to 68, but you input_length is only 21. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=10)
#  47%|██████████████████████████████████████                                           | 47/100 [03:37<03:13,  3.65s/it]Your max_length is set to 68, but you input_length is only 19. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=9)
#  49%|███████████████████████████████████████▋                                         | 49/100 [03:47<03:51,  4.54s/it]Your max_length is set to 68, but you input_length is only 66. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=33)
#  51%|█████████████████████████████████████████▎                                       | 51/100 [04:01<04:44,  5.81s/it]Your max_length is set to 68, but you input_length is only 41. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=20)
#  52%|██████████████████████████████████████████                                       | 52/100 [04:04<03:57,  4.95s/it]Your max_length is set to 68, but you input_length is only 62. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=31)
#  53%|██████████████████████████████████████████▉                                      | 53/100 [04:11<04:12,  5.37s/it]Your max_length is set to 68, but you input_length is only 43. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=21)
#  54%|███████████████████████████████████████████▋                                     | 54/100 [04:16<04:02,  5.28s/it]Your max_length is set to 68, but you input_length is only 52. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=26)
#  55%|████████████████████████████████████████████▌                                    | 55/100 [04:22<04:06,  5.49s/it]Your max_length is set to 68, but you input_length is only 18. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=9)
#  56%|█████████████████████████████████████████████▎                                   | 56/100 [04:25<03:32,  4.82s/it]Your max_length is set to 68, but you input_length is only 9. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=4)
#  60%|████████████████████████████████████████████████▌                                | 60/100 [04:46<03:44,  5.61s/it]Your max_length is set to 68, but you input_length is only 18. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=9)
#  62%|██████████████████████████████████████████████████▏                              | 62/100 [04:58<03:45,  5.94s/it]Your max_length is set to 68, but you input_length is only 60. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=30)
#  64%|███████████████████████████████████████████████████▊                             | 64/100 [05:11<03:41,  6.16s/it]Your max_length is set to 68, but you input_length is only 45. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=22)
#  65%|████████████████████████████████████████████████████▋                            | 65/100 [05:16<03:25,  5.87s/it]Your max_length is set to 68, but you input_length is only 52. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=26)
#  67%|██████████████████████████████████████████████████████▎                          | 67/100 [05:25<02:45,  5.03s/it]Your max_length is set to 68, but you input_length is only 5. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=2)
#  70%|████████████████████████████████████████████████████████▋                        | 70/100 [05:37<02:20,  4.68s/it]Your max_length is set to 68, but you input_length is only 67. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=33)
#  72%|██████████████████████████████████████████████████████████▎                      | 72/100 [05:51<02:41,  5.77s/it]Your max_length is set to 68, but you input_length is only 59. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=29)
#  75%|████████████████████████████████████████████████████████████▊                    | 75/100 [06:07<02:18,  5.52s/it]Your max_length is set to 68, but you input_length is only 64. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=32)
#  77%|██████████████████████████████████████████████████████████████▎                  | 77/100 [06:17<01:58,  5.14s/it]Your max_length is set to 68, but you input_length is only 42. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=21)
#  78%|███████████████████████████████████████████████████████████████▏                 | 78/100 [06:21<01:46,  4.84s/it]Your max_length is set to 68, but you input_length is only 24. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=12)
#  79%|███████████████████████████████████████████████████████████████▉                 | 79/100 [06:25<01:35,  4.53s/it]Your max_length is set to 68, but you input_length is only 25. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=12)
#  80%|████████████████████████████████████████████████████████████████▊                | 80/100 [06:28<01:23,  4.19s/it]Your max_length is set to 68, but you input_length is only 26. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=13)
#  82%|██████████████████████████████████████████████████████████████████▍              | 82/100 [06:37<01:19,  4.40s/it]Your max_length is set to 68, but you input_length is only 53. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=26)
#  83%|███████████████████████████████████████████████████████████████████▏             | 83/100 [06:43<01:19,  4.66s/it]Your max_length is set to 68, but you input_length is only 66. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=33)
#  85%|████████████████████████████████████████████████████████████████████▊            | 85/100 [06:52<01:09,  4.66s/it]Your max_length is set to 68, but you input_length is only 36. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=18)
#  87%|██████████████████████████████████████████████████████████████████████▍          | 87/100 [07:02<01:05,  5.03s/it]Your max_length is set to 68, but you input_length is only 33. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=16)
#  88%|███████████████████████████████████████████████████████████████████████▎         | 88/100 [07:06<00:57,  4.78s/it]Your max_length is set to 68, but you input_length is only 44. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=22)
#  98%|███████████████████████████████████████████████████████████████████████████████▍ | 98/100 [08:02<00:10,  5.49s/it]Your max_length is set to 68, but you input_length is only 32. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=16)
#  99%|████████████████████████████████████████████████████████████████████████████████▏| 99/100 [08:05<00:04,  4.90s/it]Your max_length is set to 68, but you input_length is only 16. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=8)
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [08:08<00:00,  4.28s/it]Your max_length is set to 68, but you input_length is only 55. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=27)
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [08:13<00:00,  4.93s/it]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   reviewer_id   100 non-null    int64
#  1   review        100 non-null    object
#  2   review_clean  100 non-null    object
#  3   summarize     100 non-null    object
# dtypes: int64(1), object(3)
# memory usage: 3.3+ KB
# None
#    reviewer_id                                             review  \
# 0            1  Why does it look like someone spit on my food?...
# 1            2  It'd McDonalds. It is what it is as far as the...
# 2            3  Made a mobile order got to the speaker and che...
# 3            4  My mc. Crispy chicken sandwich was ÃÂ¯ÃÂ¿ÃÂ...
# 4            5  I repeat my order 3 times in the drive thru, a...
#
#                                         review_clean  \
# 0  Why does it look like someone spit on my food\...
# 1  It would McDonalds. It is what it is as far as...
# 2  Made a mobile order got to the speaker and che...
# 3  My mc. Crispy chicken sandwich was  customer s...
# 4  I repeat my order 3 times in the drive thru, a...
#
#                                            summarize
# 0   Why does it look like someone spit on my food...
# 1   The staff at McDonalds are always friendly an...
# 2   Never got the refund in the app. Made a mobil...
# 3   My mc. Crispy chicken sandwich was  customer ...
# 4   I repeat my order 3 times in the drive thru, ...

# %%
df_sm['summarize'].iloc[2]
# Out:
# ' Never got the refund in the app. Made a mobile order got to the speaker and checked it in. Line was not moving so I had to leave otherwise Id be late for work . Never got refund in app. Called them and they said I could only get my money back in person because it was stuck in the system .'

# %%
df_sm['review_clean'].iloc[2]
# Out:
# 'Made a mobile order got to the speaker and checked it in.\nLine was not moving so I had to leave otherwise Id be late for work.\nNever got the refund in the app.\nI called them and they said I could only get my money back in person because it was stuck in the system.\nWent there in person the next day  and the manager told me she wasn'

# %%
# Sentence Tokenization
df_st = df_sm.copy()
df_st['token_sentence'] = df_st['summarize'].apply(norm.sentence_tokenize)
df_st = df_st.explode('token_sentence')
df_st['token_sentence'] = df_st['token_sentence'].str.strip()

# Remove characters
df_st['token_sentence'] = df_st['token_sentence'].apply(norm.remove_characters, args=(True, ))

# Lemmatization
df_st['token_sentence'] = df_st['token_sentence'].apply(norm.lemmatize_text)

# %% [markdown]
# # Get Aspect (Rules Based)

# %%
# Get aspect from rules
tqdm.pandas()
df_st['sub_aspect'] = df_st['token_sentence']\
                        .progress_apply(util.get_aspect_rules)

print(df_st.info())
df_st.head()
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 385/385 [00:36<00:00, 10.66it/s]
# <class 'pandas.core.frame.DataFrame'>
# Index: 385 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   reviewer_id     385 non-null    int64
#  1   review          385 non-null    object
#  2   review_clean    385 non-null    object
#  3   summarize       385 non-null    object
#  4   token_sentence  385 non-null    object
#  5   sub_aspect      385 non-null    object
# dtypes: int64(1), object(5)
# memory usage: 21.1+ KB
# None
#    reviewer_id                                             review  \
# 0            1  Why does it look like someone spit on my food?...
# 0            1  Why does it look like someone spit on my food?...
# 0            1  Why does it look like someone spit on my food?...
# 0            1  Why does it look like someone spit on my food?...
# 0            1  Why does it look like someone spit on my food?...
#
#                                         review_clean  \
# 0  Why does it look like someone spit on my food\...
# 0  Why does it look like someone spit on my food\...
# 0  Why does it look like someone spit on my food\...
# 0  Why does it look like someone spit on my food\...
# 0  Why does it look like someone spit on my food\...
#
#                                            summarize  \
# 0   Why does it look like someone spit on my food...
# 0   Why does it look like someone spit on my food...
# 0   Why does it look like someone spit on my food...
# 0   Why does it look like someone spit on my food...
# 0   Why does it look like someone spit on my food...
#
#                                       token_sentence            sub_aspect
# 0        why do it look like someone spit on my food        {someone spit}
# 0                        i have a normal transaction  {normal transaction}
# 0                       everyone be chill and polite            {everyone}
# 0                  but now i dont want to eat this .                    {}
# 0  im try not to think about what this milky whit...     {clear substance}

# %%
mask = df_st['sub_aspect'].apply(lambda x: False if len(x) == 0 else True).values

df_prc = df_st.groupby(['reviewer_id'])\
                .agg({'sub_aspect': lambda x: set().union(*x),})\
                .reset_index()

df_prc = df_sm.merge(df_prc, on='reviewer_id', how='left')
print(df_prc.info())
df_prc.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   reviewer_id   100 non-null    int64
#  1   review        100 non-null    object
#  2   review_clean  100 non-null    object
#  3   summarize     100 non-null    object
#  4   sub_aspect    100 non-null    object
# dtypes: int64(1), object(4)
# memory usage: 4.0+ KB
# None
#    reviewer_id                                             review  \
# 0            1  Why does it look like someone spit on my food?...
# 1            2  It'd McDonalds. It is what it is as far as the...
# 2            3  Made a mobile order got to the speaker and che...
# 3            4  My mc. Crispy chicken sandwich was ÃÂ¯ÃÂ¿ÃÂ...
# 4            5  I repeat my order 3 times in the drive thru, a...
#
#                                         review_clean  \
# 0  Why does it look like someone spit on my food\...
# 1  It would McDonalds. It is what it is as far as...
# 2  Made a mobile order got to the speaker and che...
# 3  My mc. Crispy chicken sandwich was  customer s...
# 4  I repeat my order 3 times in the drive thru, a...
#
#                                            summarize  \
# 0   Why does it look like someone spit on my food...
# 1   The staff at McDonalds are always friendly an...
# 2   Never got the refund in the app. Made a mobil...
# 3   My mc. Crispy chicken sandwich was  customer ...
# 4   I repeat my order 3 times in the drive thru, ...
#
#                                           sub_aspect
# 0  {normal transaction, clear substance, everyone...
# 1               {mcdonalds, food, atmosphere, staff}
# 2                {refund, money, line, mobile order}
# 3  {chicken sandwich, customer, crispy chicken, c...
# 4  {double filet, close attention, order, large m...

# %%
df_prc['sub_aspect'].iloc[0]
# Out:
# {'clear substance', 'everyone', 'normal transaction', 'someone spit'}

# %%
df_prc['summarize'].iloc[0]
# Out:
# ' Why does it look like someone spit on my food? I had a normal transaction,  everyone was chill and polite, but now i dont want to eat this . Im trying not to think about what this milky white/clear substance is all over my food, i d sure am not coming back .'

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

text = ""
sub_aspect = df_prc['sub_aspect'].values
for i in range(df_prc.shape[0]):
    text = text + " " + " ".join(list(sub_aspect[i]))
    

text = text.strip()

wordcloud = WordCloud(background_color='white').generate(text)
plt.style.use('classic')
plt.figure(figsize=(12,10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# # Get Topic

# %%
def get_optimum_lda(dictionary, corpus, texts, limit,
                    start=2, step=1, get_result=False,
                    iterations=20, passes=1):
    coherence_values = []
    
    for n in range(start, limit, step):
        lda = gensim.models.LdaMulticore(corpus=corpus,
                                         num_topics=n,
                                         id2word=dictionary,
                                         iterations=iterations,
                                         passes=passes)
        
        # Create coherence
        coherence_model = CoherenceModel(model=lda, 
                                         texts=texts,
                                         dictionary=dictionary, 
                                         coherence='c_v')
        coherence_values.append(coherence_model.get_coherence())
    
    
    opt_num_topics = start + coherence_values.index(max(coherence_values))
    
    lda_opt = gensim.models.LdaMulticore(corpus=corpus,
                                         num_topics=opt_num_topics,
                                         id2word=dictionary)
    
    if get_result:
        print(coherence_values)
    
    return lda_opt

# %%
import gensim
from gensim.models import CoherenceModel


# texts = df_prc['summarize'].apply(util.preprocess_lda)
texts = df_prc['sub_aspect'].apply(lambda x: ', '.join(list(x))).apply(util.preprocess_lda)

dictionary = gensim.corpora.Dictionary(texts)

dictionary.filter_extremes(no_below=15, no_above=0.5, keep_n=100_000)
bow_corpus = [dictionary.doc2bow(doc) for doc in texts]

lda_opt = get_optimum_lda(dictionary, bow_corpus,
                          texts, 10, get_result=True,
                          passes=75, iterations=150)
# Out:
# WARNING:gensim.models.ldamulticore:too few updates, training might not converge; consider increasing the number of passes or iterations to improve accuracy
# [0.5814159995573465, 0.5814159995573465, 0.5814159995573465, 0.5814159995573465, 0.5814159995573464, 0.5814159995573464, 0.5814159995573465, 0.5814159995573465]

# %%
# Print topic
for idx, topic in lda_opt.print_topics(-1):
    print('Topic: {} \nWords: {}'.format(idx, topic))
# Out:
# Topic: 0
# Words: 0.359*"order" + 0.356*"food" + 0.285*"service"
# Topic: 1
# Words: 0.506*"order" + 0.296*"food" + 0.198*"service"

# %%
def predict_topic(text):
    text = util.preprocess_lda(text)
    bow_vector = dictionary.doc2bow(text)
    
    result = sorted(lda_opt[bow_vector], 
                    key=lambda x: -1*x[1])[0][0]
    
    return result
    
# Extract keywords into a dictionary or list
threshold = 0.05
topics_dict = {}
for topic_num, topic in lda_opt.show_topics(num_topics=10,
                                                num_words=10,
                                                formatted=False):
    keywords = [word for word, w in topic if w > threshold]
    topics_dict[topic_num] = keywords

# %%
topics_dict
# Out:
# {0: ['order', 'food', 'service'], 1: ['order', 'food', 'service']}

# %%
tqdm.pandas()
df_prc['topic'] = df_prc['summarize'].progress_apply(predict_topic)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 208.40it/s]

# %%
tqdm.pandas()
df_prc['topic_keys'] = df_prc['topic'].progress_apply(lambda x: topics_dict[x])
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 35584.15it/s]

# %%
df_prc
# Out:
#     reviewer_id                                             review  \
# 0             1  Why does it look like someone spit on my food?...
# 1             2  It'd McDonalds. It is what it is as far as the...
# 2             3  Made a mobile order got to the speaker and che...
# 3             4  My mc. Crispy chicken sandwich was ÃÂ¯ÃÂ¿ÃÂ...
# 4             5  I repeat my order 3 times in the drive thru, a...
# ..          ...                                                ...
# 95           96  If I could give negative stars I would. This l...
# 96           97  When ordering food the employees conveniently ...
# 97           98  I donÃÂ¯ÃÂ¿ÃÂ½ÃÂ¯ÃÂ¿ÃÂ½ÃÂ¯ÃÂ¿ÃÂ½ÃÂ¯Ã...
# 98           99  Allways has the best Fries and Ice cream in th...
# 99          100  Mcdonalds is great but they really need to hir...
#
#                                          review_clean  \
# 0   Why does it look like someone spit on my food\...
# 1   It would McDonalds. It is what it is as far as...
# 2   Made a mobile order got to the speaker and che...
# 3   My mc. Crispy chicken sandwich was  customer s...
# 4   I repeat my order 3 times in the drive thru, a...
# ..                                                ...
# 95  If I could give negative stars I would. This l...
# 96  When ordering food the employees conveniently ...
# 97  I dont usually review places but this location...
# 98  Allways has the best Fries and Ice cream in th...
# 99  Mcdonalds is great but they really need to hir...
#
#                                             summarize  \
# 0    Why does it look like someone spit on my food...
# 1    The staff at McDonalds are always friendly an...
# 2    Never got the refund in the app. Made a mobil...
# 3    My mc. Crispy chicken sandwich was  customer ...
# 4    I repeat my order 3 times in the drive thru, ...
# ..                                                ...
# 95   The staff is horrible. Corporate needs to sen...
# 96   When ordering food the employees forgot to tu...
# 97   I dont usually review places but this locatio...
# 98   Allways has the best Fries and Ice cream in t...
# 99   Mcdonalds is great but they really need to hi...
#
#                                            sub_aspect  topic  \
# 0   {normal transaction, clear substance, everyone...      0
# 1                {mcdonalds, food, atmosphere, staff}      0
# 2                 {refund, money, line, mobile order}      1
# 3   {chicken sandwich, customer, crispy chicken, c...      0
# 4   {double filet, close attention, order, large m...      1
# ..                                                ...    ...
# 95  {corporate need, basic manor, staff, work ethi...      0
# 96           {order food, microphone, employee, mess}      0
# 97       {location, place, rude service, order wrong}      0
# 98                     {allways, best fry, ice cream}      0
# 99                {mcdonalds, order, people, english}      1
#
#                 topic_keys
# 0   [order, food, service]
# 1   [order, food, service]
# 2   [order, food, service]
# 3   [order, food, service]
# 4   [order, food, service]
# ..                     ...
# 95  [order, food, service]
# 96  [order, food, service]
# 97  [order, food, service]
# 98  [order, food, service]
# 99  [order, food, service]
#
# [100 rows x 7 columns]

# %%
result.merge(df[['reviewer_id','rating']], on='reviewer_id', how='left').info()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[79], line 1
# ----> 1 result.merge(df[['reviewer_id','rating']], on='reviewer_id', how='left').info()
#
# AttributeError: 'NoneType' object has no attribute 'merge'

# %% [markdown]
# # Save Result

# %%
result = df_prc.copy()
result = result.merge(df[['reviewer_id','rating']],
                      on='reviewer_id',
                      how='left').info()

# result['sub_aspect'] = result['sub_aspect'].apply(lambda x: ', '.join(list(x)))
# result['topic_keys'] = result['topic_keys'].apply(lambda x: ', '.join(x))

result.to_csv("coding_mcd.csv", index=False)
