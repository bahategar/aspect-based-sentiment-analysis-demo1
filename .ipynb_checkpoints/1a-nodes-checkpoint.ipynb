# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from tqdm import tqdm

# %%
df = pd.read_csv("./mcd_result/base_mcd.csv")

df['aspect'] = df['aspect'].apply(lambda x: x.split(", "))
df['token_sentence'] = df['token_sentence'].apply(lambda x: x.split('.\n'))
# df['topic_keys'] = df['topic_keys'].apply(lambda x: x.split(", "))
print(df.info())
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   reviewer_id     100 non-null    int64
#  1   review          100 non-null    object
#  2   summarize       100 non-null    object
#  3   aspect          100 non-null    object
#  4   token_sentence  100 non-null    object
#  5   token_lemma     100 non-null    object
#  6   rating          100 non-null    int64
# dtypes: int64(2), object(5)
# memory usage: 5.6+ KB
# None
#    reviewer_id                                             review  \
# 0            1  Why does it look like someone spit on my food?...
# 1            2  It'd McDonalds. It is what it is as far as the...
# 2            3  Made a mobile order got to the speaker and che...
# 3            4  My mc. Crispy chicken sandwich was ÃÂ¯ÃÂ¿ÃÂ...
# 4            5  I repeat my order 3 times in the drive thru, a...
#
#                                            summarize  \
# 0   Why does it look like someone spit on my food...
# 1   The staff at McDonalds are always friendly an...
# 2   Never got the refund in the app. Made a mobil...
# 3   My mc. Crispy chicken sandwich was  customer ...
# 4   I repeat my order 3 times in the drive thru, ...
#
#                                               aspect  \
# 0  [someone spit, clear substance, everyone, norm...
# 1               [atmosphere, staff, food, mcdonalds]
# 2                [refund, money, mobile order, line]
# 3  [customer, chicken sandwich, crispy chicken, c...
# 4  [order, large meal, close attention, english, ...
#
#                                       token_sentence  \
# 0  [Why does it look like someone spit on my food...
# 1  [The staff at McDonalds are always friendly an...
# 2  [Never got the refund in the app., Made a mobi...
# 3  [Crispy chicken sandwich was  customer service...
# 4  [I repeat my order 3 times in the drive thru, ...
#
#                                          token_lemma  rating
# 0  why do it look like someone spit on my food.\n...       1
# 1  the staff at mcdonalds be always friendly and ...       4
# 2  never get the refund in the app ..\nmake a mob...       1
# 3  crispy chicken sandwich be customer service be...       5
# 4  i repeat my order 3 time in the drive thru.\ni...       1

# %%
df_an = df[['reviewer_id', 'aspect']].copy()
df_an.head()
# Out:
#    reviewer_id                                             aspect
# 0            1  [someone spit, clear substance, everyone, norm...
# 1            2               [atmosphere, staff, food, mcdonalds]
# 2            3                [refund, money, mobile order, line]
# 3            4  [customer, chicken sandwich, crispy chicken, c...
# 4            5  [order, large meal, close attention, english, ...

# %% [markdown]
# # Coding Process

# %%
# map_categorize = {
#     0: 'order and food',
#     1: 'service and time',
#     2: 'order and food',
#     3: 'order and food',
#     4: 'service and time',
#     5: 'order and food',
#     6: 'service and time',
# }

# df['category'] = df['topic'].apply(lambda x: map_categorize[x])

# print(df.info())
# df.head()

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

text = ""
aspects = df_an['aspect'].values
for i in range(df_an.shape[0]):
    text = text + " " + " ".join(list(aspects[i]))
    

text = text.strip()

wordcloud = WordCloud(background_color='white').generate(text)
plt.style.use('classic')
plt.figure(figsize=(12,10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
words_count = {}

words = text.split()

for word in words:
    word = word.lower()
    if word in words_count:
        words_count[word] += 1
    else:
        words_count[word] = 1
        
# words_count = dict(
#                 sorted(words_count.items(),
#                        key=lambda x: x[1],
#                        reverse=True))

# %%
df_word = pd.DataFrame(data=words_count.values(),
                       index=words_count.keys(), 
                       columns=['count'])

df_word.head(25).sort_values(by='count', ascending=True).plot(kind='barh')
plt.show()

# %%
# Show 75% words

threshold = df_word.quantile(q=0.75).iloc[0]
# threshold = 0.25 * df_word.max().iloc[0]
# threshold = df_word.mean().iloc[0]
print(threshold)

df_plot = df_word[df_word['count'] > threshold]\
        .head(50)

ax = df_plot\
        .sort_values(by='count', ascending=True)\
        .plot(kind='barh', figsize=(10, 20))

for container in ax.containers:
    ax.bar_label(container)

plt.show()
# Out:
# 2.0

# %%
category_aspect = list(df_word[df_word['count'] > threshold].index)
print(len(category_aspect))

# Additional filter
category_aspect = [word for word in category_aspect if len(word) >= 3]

def first_cycle(x):
        
    set1 = set(" ".join(x).split(" "))
    set2 = set(category_aspect)
    
    temp = set1 & set2
    
    if len(temp) != len(set1):
        temp.add("other")
    return temp

def get_other(x):
    set1 = set(" ".join(x).split(" "))
    set2 = set(category_aspect)
    
    temp = set1.difference(set2)
    
    return temp

tqdm.pandas()
df_an['first_cycle'] = df_an['aspect'].progress_apply(lambda x: first_cycle(x))

df_an['residu'] = df_an['aspect'].progress_apply(lambda x: get_other(x))

df_an = df_an.explode('first_cycle').reset_index(drop=True)
df_an
# Out:
# 70
# 100%|█████████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 49414.51it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████████| 100/100 [00:00<?, ?it/s]
#      reviewer_id                                             aspect  \
# 0              1  [someone spit, clear substance, everyone, norm...
# 1              1  [someone spit, clear substance, everyone, norm...
# 2              2               [atmosphere, staff, food, mcdonalds]
# 3              2               [atmosphere, staff, food, mcdonalds]
# 4              2               [atmosphere, staff, food, mcdonalds]
# ..           ...                                                ...
# 447           99                     [ice cream, best fry, allways]
# 448          100                [order, english, people, mcdonalds]
# 449          100                [order, english, people, mcdonalds]
# 450          100                [order, english, people, mcdonalds]
# 451          100                [order, english, people, mcdonalds]
#
#     first_cycle                                             residu
# 0        normal  {transaction, substance, someone, everyone, cl...
# 1         other  {transaction, substance, someone, everyone, cl...
# 2     mcdonalds                                       {atmosphere}
# 3          food                                       {atmosphere}
# 4         staff                                       {atmosphere}
# ..          ...                                                ...
# 447       other                                          {allways}
# 448       order                                          {english}
# 449      people                                          {english}
# 450   mcdonalds                                          {english}
# 451       other                                          {english}
#
# [452 rows x 4 columns]

# %%
map_second_code = {'situation': ['normal', 'line', 'large', 'long', 'regular', 'people', 'wait',
                                 'night', 'hour', 'wrong', 'minute', 'mess', 'day'], 
                   'place': ['mcdonald', 'mcdonalds', 'location', 'place', 'car', 'restaurant', 'window', 'store', 'drive',],
                   'emotion': ['great', 'best', 'bad', 'great', 'horrible', 'good', 'happy', 'rude',], 
                   'service': ['staff', 'customer', 'service', 'location', 'regular', 'time', 'lady', 'experience', 'crew',
                               'manager', 'employee', 'price', 'management', 'attitude', 'work', 'issue'],
                   'food': ['food', 'order', 'chicken', 'sandwich', 'meal', 'fry',
                            'nugget', 'item', 'cream', 'pickle', 'strawberry', 'burger'],
                   'drink': ['coffee', 'cup', 'item', 'drink', 'cream', 'strawberry', 'ice'] 
                  }

def second_cycle(x):
    temp = set()
    for key in map_second_code.keys():
        if x in map_second_code[key]:
            temp.add(key)
    if len(temp) == 0:
        temp.add('other')
        
    return temp


tqdm.pandas()
df_an['second_cycle'] = df_an['first_cycle'].progress_apply(lambda x: second_cycle(x))
# EXPERIMENT
experiment = df_an[['reviewer_id', 'residu', 'second_cycle']].copy()

df_an = df_an.explode('second_cycle').reset_index(drop=True)

df_an
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████| 452/452 [00:00<00:00, 65019.05it/s]
#      reviewer_id                                             aspect  \
# 0              1  [someone spit, clear substance, everyone, norm...
# 1              1  [someone spit, clear substance, everyone, norm...
# 2              2               [atmosphere, staff, food, mcdonalds]
# 3              2               [atmosphere, staff, food, mcdonalds]
# 4              2               [atmosphere, staff, food, mcdonalds]
# ..           ...                                                ...
# 471           99                     [ice cream, best fry, allways]
# 472          100                [order, english, people, mcdonalds]
# 473          100                [order, english, people, mcdonalds]
# 474          100                [order, english, people, mcdonalds]
# 475          100                [order, english, people, mcdonalds]
#
#     first_cycle                                             residu  \
# 0        normal  {transaction, substance, someone, everyone, cl...
# 1         other  {transaction, substance, someone, everyone, cl...
# 2     mcdonalds                                       {atmosphere}
# 3          food                                       {atmosphere}
# 4         staff                                       {atmosphere}
# ..          ...                                                ...
# 471       other                                          {allways}
# 472       order                                          {english}
# 473      people                                          {english}
# 474   mcdonalds                                          {english}
# 475       other                                          {english}
#
#     second_cycle
# 0      situation
# 1          other
# 2          place
# 3           food
# 4        service
# ..           ...
# 471        other
# 472         food
# 473    situation
# 474        place
# 475        other
#
# [476 rows x 5 columns]

# %%
result = df_an[['reviewer_id', 'first_cycle', 'second_cycle', 'residu']]\
            .copy()\
            .reset_index()\
            .rename(columns={'index': 'node_id'})

print(result.info())
result.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 476 entries, 0 to 475
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   node_id       476 non-null    int64
#  1   reviewer_id   476 non-null    int64
#  2   first_cycle   476 non-null    object
#  3   second_cycle  476 non-null    object
#  4   residu        476 non-null    object
# dtypes: int64(2), object(3)
# memory usage: 18.7+ KB
# None
#    node_id  reviewer_id first_cycle second_cycle  \
# 0        0            1      normal    situation
# 1        1            1       other        other
# 2        2            2   mcdonalds        place
# 3        3            2        food         food
# 4        4            2       staff      service
#
#                                               residu
# 0  {transaction, substance, someone, everyone, cl...
# 1  {transaction, substance, someone, everyone, cl...
# 2                                       {atmosphere}
# 3                                       {atmosphere}
# 4                                       {atmosphere}

# %% [markdown]
# # Categorizing

# %%
map_categorizing = {
    'sentiment': ['emotion'],
    'place and service': ['service', 'situation', 'place'],
    'food and drink': ['food', 'drink'],
}

def final_categorizing(x):
    for key in map_categorizing.keys():
        if x in map_categorizing[key]:
            return key
    return "other"

tqdm.pandas()
result['category'] = result['second_cycle'].progress_apply(lambda x: final_categorizing(x))
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████| 476/476 [00:00<00:00, 294510.80it/s]

# %%
result
# Out:
#      node_id  reviewer_id first_cycle second_cycle  \
# 0          0            1      normal    situation
# 1          1            1       other        other
# 2          2            2   mcdonalds        place
# 3          3            2        food         food
# 4          4            2       staff      service
# ..       ...          ...         ...          ...
# 471      471           99       other        other
# 472      472          100       order         food
# 473      473          100      people    situation
# 474      474          100   mcdonalds        place
# 475      475          100       other        other
#
#                                                 residu           category
# 0    {transaction, substance, someone, everyone, cl...  place and service
# 1    {transaction, substance, someone, everyone, cl...              other
# 2                                         {atmosphere}  place and service
# 3                                         {atmosphere}     food and drink
# 4                                         {atmosphere}  place and service
# ..                                                 ...                ...
# 471                                          {allways}              other
# 472                                          {english}     food and drink
# 473                                          {english}  place and service
# 474                                          {english}  place and service
# 475                                          {english}              other
#
# [476 rows x 6 columns]

# %% [markdown]
# # Linking Nodes

# %%
import networkx as nx

for cat in np.unique(df_an['second_cycle'].values):
    df_plot = df_an[df_an['second_cycle'] == cat]
    G = nx.from_pandas_edgelist(df_plot, 'first_cycle', 'second_cycle')
    nx.draw_kamada_kawai(G, with_labels=True, node_color='skyblue', node_size=1000)
    plt.show()

# %%
result.to_csv("./mcd_result/nodes_mcd.csv", index=False)

# %%
df[['reviewer_id', 'review', 'summarize', 'rating']].to_csv("./mcd_result/final_mcd.csv", index=False)
