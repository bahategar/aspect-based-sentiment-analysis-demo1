# %%
import fasttext
model = fasttext.load_model('./util/cc.en.300.bin')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import re
import json

from tqdm import tqdm

# %%
import util.normalization as norm
import util.model as models
import util.utility as util

# %%
pd.set_option("display.max_rows", 250)

# %%
df = pd.read_csv("./mcd_result/base_mcd.csv")

df['aspect'] = df['aspect'].apply(lambda x: x.split(", "))
df['token_sentence'] = df['token_sentence'].apply(lambda x: x.split('.\n'))
# df['topic_keys'] = df['topic_keys'].apply(lambda x: x.split(", "))
print(df.info())
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   reviewer_id     100 non-null    int64
#  1   review          100 non-null    object
#  2   summarize       100 non-null    object
#  3   aspect          100 non-null    object
#  4   token_sentence  100 non-null    object
#  5   token_lemma     100 non-null    object
#  6   rating          100 non-null    int64
# dtypes: int64(2), object(5)
# memory usage: 5.6+ KB
# None
#    reviewer_id                                             review  \
# 0            1  Why does it look like someone spit on my food?...
# 1            2  It'd McDonalds. It is what it is as far as the...
# 2            3  Made a mobile order got to the speaker and che...
# 3            4  My mc. Crispy chicken sandwich was ÃÂ¯ÃÂ¿ÃÂ...
# 4            5  I repeat my order 3 times in the drive thru, a...
#
#                                            summarize  \
# 0   Why does it look like someone spit on my food...
# 1   The staff at McDonalds are always friendly an...
# 2   Never got the refund in the app. Made a mobil...
# 3   My mc. Crispy chicken sandwich was  customer ...
# 4   I repeat my order 3 times in the drive thru, ...
#
#                                               aspect  \
# 0  [clear substance, someone spit, everyone, norm...
# 1               [mcdonalds, atmosphere, staff, food]
# 2                [line, mobile order, money, refund]
# 3  [service, crispy chicken, customer service, ch...
# 4  [order, large fry, large meal, close attention...
#
#                                       token_sentence  \
# 0  [Why does it look like someone spit on my food...
# 1  [The staff at McDonalds are always friendly an...
# 2  [Never got the refund in the app., Made a mobi...
# 3  [Crispy chicken sandwich was  customer service...
# 4  [I repeat my order 3 times in the drive thru, ...
#
#                                          token_lemma  rating
# 0  why do it look like someone spit on my food.\n...       1
# 1  the staff at mcdonalds be always friendly and ...       4
# 2  never get the refund in the app ..\nmake a mob...       1
# 3  crispy chicken sandwich be customer service be...       5
# 4  i repeat my order 3 time in the drive thru.\ni...       1

# %%
df_an = df[['reviewer_id', 'aspect']].copy()
df_an.head()
# Out:
#    reviewer_id                                             aspect
# 0            1  [clear substance, someone spit, everyone, norm...
# 1            2               [mcdonalds, atmosphere, staff, food]
# 2            3                [line, mobile order, money, refund]
# 3            4  [service, crispy chicken, customer service, ch...
# 4            5  [order, large fry, large meal, close attention...

# %% [markdown]
# # Coding Process

# %%
# map_categorize = {
#     0: 'order and food',
#     1: 'service and time',
#     2: 'order and food',
#     3: 'order and food',
#     4: 'service and time',
#     5: 'order and food',
#     6: 'service and time',
# }

# df['category'] = df['topic'].apply(lambda x: map_categorize[x])

# print(df.info())
# df.head()

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

text = ""
aspects = df_an['aspect'].values
for i in range(df_an.shape[0]):
    text = text + " " + " ".join(list(aspects[i]))
    

text = text.strip()

wordcloud = WordCloud(background_color='white').generate(text)
plt.style.use('classic')
plt.figure(figsize=(12,10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
words_count = {}

words = text.split()

for word in words:
    word = word.lower()
    if word in words_count:
        words_count[word] += 1
    else:
        words_count[word] = 1
        
# words_count = dict(
#                 sorted(words_count.items(),
#                        key=lambda x: x[1],
#                        reverse=True))

# %%
df_word = pd.DataFrame(data=words_count.values(),
                       index=words_count.keys(), 
                       columns=['count'])

df_word.head(25).sort_values(by='count', ascending=True).plot(kind='barh')
plt.show()

# %%
# Show 75% words

threshold = df_word.quantile(q=0.75).iloc[0]
# threshold = 0.25 * df_word.max().iloc[0]
# threshold = df_word.mean().iloc[0]
print(threshold)

df_plot = df_word[df_word['count'] > threshold]\
        .head(50)

ax = df_plot\
        .sort_values(by='count', ascending=True)\
        .plot(kind='barh', figsize=(10, 20))

for container in ax.containers:
    ax.bar_label(container)

plt.show()
# Out:
# 2.0

# %% [markdown]
# ## A. First Cycle

# %%
list_first_cycle = list(df_word[df_word['count'] > threshold].index)
print(len(list_first_cycle))

# Additional filter
list_first_cycle = [word for word in list_first_cycle if len(word) >= 3]

def first_cycle(x):
    global list_first_cycle
        
    set1 = set(" ".join(x).split(" "))
    set2 = set(list_first_cycle)
    
    temp = set1 & set2
    
    if len(temp) != len(set1):
        temp.add("other")
    return temp

def get_other(x):
    global list_first_cycle
    
    set1 = set(" ".join(x).split(" "))
    set2 = set(list_first_cycle)
    
    temp = set1.difference(set2)
    
    return temp

def get_residu(x):
    texts = x['residu']
    array = x['aspect']

    temp = []
    print(texts)
    for text in texts:
        pattern = re.compile(rf"{text}")
        
        result = [element for element in array if pattern.search(element)]
        temp = temp + result

    return set(temp)



tqdm.pandas()
df_an['first_cycle'] = df_an['aspect'].progress_apply(lambda x: first_cycle(x))

df_an['residu'] = df_an['aspect'].progress_apply(lambda x: get_other(x))

df_an['residu'] = [get_residu(x[-1]) for x in df_an.iterrows()]

df_an = df_an.explode('first_cycle').reset_index(drop=True)
df_an
# Out:
# 71
# 100%|████████████████████████████████████████████████████████████████████████████████████████| 100/100 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████████| 100/100 [00:00<?, ?it/s]
# {'substance', 'everyone', 'clear', 'spit', 'someone', 'transaction'}
# {'atmosphere'}
# {'mobile', 'refund', 'money'}
# {'crispy'}
# {'double', 'attention', 'filet', 'english', 'close'}
# {'dash', 'covid', 'door'}
# {'home', 'hamburg', 'cooky', 'simple'}
# {'w', 'full'}
# {'hard', 'sauce', 'piece'}
# {'quality', 'mcds'}
# {'globe', 'effort', 'golden', 'series'}
# {'husband', 'task'}
# {'morning', 'different'}
# {'#', 'big', 'thing', 'full', 'condiment', 'breakfast', 'cake', 'hot'}
# {'part', 'poor', 'hand', 'girl'}
# {'table'}
# {'pie', 'substitute', 'apple', 'cinnabun'}
# {'boy'}
# {'smh', 'banana', 'fact', 'straight', 'disappointed', 'water', 'smoothie', 'hash', 'smoothy'}
# {'lobby', 'learning', 'perpetual'}
# {'take', 'more', 'other', 'name', 'taker', 'rush'}
# {'morning', 'year', 'past', 'evening'}
# {'caffeine'}
# {'cold', 'microwave'}
# {'card'}
# {'machine', 'reply', 'broken'}
# {'everything', 'clean'}
# {'ireporter', 'snapshot', 'cnn.com', 'ireport.com/travel', 'travel', 'visit', 'cnn', 'gallery', 'friday', 'photo', 'shot', 'week', 'weekly'}
# {'lazy', 'unqualified'}
# {'pounder', 'sausage', 'last', 'double', 'quarter', 'plain', 'biscuit'}
# {'sarcasm', 'temperature', 'mocha', 'room', 'caramel'}
# {'parking', 'dinner'}
# {'thing', 'usual', 'advertised'}
# {'24/7', 'open', 'accord', 'seat', 'anyone'}
# {'everything'}
# {'omar', 'delgado', 'manger', 'eduardo', 'general'}
# {'third', 'ups'}
# {'centre'}
# {'awesome'}
# {'pay', 'spicey', 'crispy', 'deluxe'}
# {'menu', 'disgust', 'id', 'br', 'few'}
# {'leadership', 'worst'}
# {'mobile', 'girlfriend', 'tonight', 'deal', 'system'}
# {'few', 'year'}
# set()
# {'need'}
# {'call'}
# {'major', 'shift'}
# {'hair', 'worker', 'stank', 'reason'}
# {'last'}
# {'mcflurry', 'oreo', 'different'}
# {'negative', 'complimentary', 'unprofessional', 'cold', 'overcook', 'review'}
# {'pretend', 'representative'}
# {'fast', 'finish'}
# {'quick'}
# {'guy'}
# {'nvr', 'wrap', 'star'}
# set()
# {'open', 'clothes', 'eleventeen', 'teeth'}
# {'person'}
# {'austin', 'north', 'research', 'blvd.in', 'tx'}
# {'woman', 'fat', 'mother'}
# {'huge', 'little', 'young', 'bit', 'second', 'keep'}
# {'change', 'welcome', 'other'}
# {'part', 'huge', 'container', 'sauce', 'room', 'dining'}
# {'dish', 'funky', 'tea', 'soap', 'fountain'}
# set()
# {'self'}
# {'uber', 'tone', 'connectivity'}
# {'parent', 'unhealthy', 'medium', 'ticket', 'sized', 'single', 'bit', 'little'}
# {'game', 'play', 'visit', 'jock', 'money'}
# {'cashier', 'affordable'}
# {'silence', 'total'}
# {'second', 'dozen', 'trouble', 'soda'}
# {'cheese', 'face', 'wrapper', 'nothing', 'hamburger'}
# {'buyer', 'mistake', 'something', 'incorrect', 'love'}
# {'creek', 'quick', 'most', 'lake', 'bite'}
# {'cashier'}
# {'satisfied'}
# set()
# {'help', 'everytime', 'person', 'evening', 'proper', 'way', 'nice'}
# {'entrance', 'manner', 'preferred', 'timely'}
# {'attendant', 'scream'}
# {'period', 'fresher'}
# {'machine', 'shop'}
# {'yourselves'}
# {'grandkids', 'cheeseburger', 'plain'}
# {'fast', 'robot', 'kitchen', 'company'}
# {'complete', 'single', 'shove'}
# {'team', 'difference'}
# {'youd', 'lesson', 'number', 'suck'}
# {'ground', 'size', 'worst'}
# {'attention', 'attempt', 'sign'}
# {'someone', 'kiosk', 'number'}
# {'raw', 'counter'}
# {'basic', 'ethic', 'manor', 'corporate', 'need'}
# {'microphone'}
# set()
# {'allways'}
# {'english'}
#      reviewer_id                                             aspect  \
# 0              1  [clear substance, someone spit, everyone, norm...
# 1              1  [clear substance, someone spit, everyone, norm...
# 2              2               [mcdonalds, atmosphere, staff, food]
# 3              2               [mcdonalds, atmosphere, staff, food]
# 4              2               [mcdonalds, atmosphere, staff, food]
# ..           ...                                                ...
# 449           99                     [ice cream, best fry, allways]
# 450          100                [mcdonalds, people, order, english]
# 451          100                [mcdonalds, people, order, english]
# 452          100                [mcdonalds, people, order, english]
# 453          100                [mcdonalds, people, order, english]
#
#     first_cycle                                             residu
# 0        normal  {everyone, someone spit, normal transaction, c...
# 1         other  {everyone, someone spit, normal transaction, c...
# 2     mcdonalds                                       {atmosphere}
# 3         other                                       {atmosphere}
# 4          food                                       {atmosphere}
# ..          ...                                                ...
# 449       cream                                          {allways}
# 450   mcdonalds                                          {english}
# 451      people                                          {english}
# 452       other                                          {english}
# 453       order                                          {english}
#
# [454 rows x 4 columns]

# %% [markdown]
# ## B. Second Cycle

# %%
map_second_code = {'situation': ['normal', 'line', 'large', 'long', 'regular', 'people', 'wait',
                                 'night', 'hour', 'wrong', 'minute', 'mess', 'day'], 
                   'place': ['mcdonald', 'mcdonalds', 'location', 'place', 'car', 'restaurant', 'window', 'store', 'drive',],
                   'emotion': ['great', 'best', 'bad', 'great', 'horrible', 'good', 'happy', 'rude',], 
                   'service': ['staff', 'customer', 'service', 'location', 'regular', 'time', 'lady', 'experience', 'crew',
                               'manager', 'employee', 'price', 'management', 'attitude', 'work', 'issue'],
                   'food': ['food', 'order', 'chicken', 'sandwich', 'meal', 'fry',
                            'nugget', 'item', 'cream', 'pickle', 'strawberry', 'burger'],
                   'drink': ['coffee', 'cup', 'item', 'drink', 'cream', 'strawberry', 'ice'] 
                  }

def second_cycle(x):
    temp = set()
    for key in map_second_code.keys():
        if x in map_second_code[key]:
            temp.add(key)
#     if len(temp) == 0:
#         temp.add('other')
        
    return temp


tqdm.pandas()
df_an['second_cycle'] = df_an['first_cycle'].progress_apply(lambda x: second_cycle(x))
# # EXPERIMENT
experiment = df_an[['reviewer_id', 'aspect', 'residu', 'first_cycle', 'second_cycle']].copy()
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████| 454/454 [00:00<?, ?it/s]

# %%
# Extract residu

def extract_residu(x):
    global map_second_code
    
    residu = x['residu']
    first_cycle = x['first_cycle']
    second_keys = list(map_second_code.keys())
    temp = []
    
    if first_cycle != 'other':
        return set()
    
    for s in residu:
        result = util.get_nearest_word(s, second_keys,
                                       model, threshold=.35)
        
        if result:
            temp.append(result)
    return set(temp)

def merge_residu(x):
    set1 = x['second_cycle']
    set2 = x['extract_residu']
    
    result = set1.union(set2)
    
    if len(result) == 0:
        return set(['other'])
    return set1.union(set2)


df_an['extract_residu'] = [extract_residu(x[-1]) for x in df_an.iterrows()]
df_an['second_cycle'] = [merge_residu(x[-1]) for x in df_an.iterrows()]


df_an = df_an.explode('second_cycle').reset_index(drop=True).drop('extract_residu', axis=1)

df_an
# Out:
#      reviewer_id                                             aspect  \
# 0              1  [clear substance, someone spit, everyone, norm...
# 1              1  [clear substance, someone spit, everyone, norm...
# 2              2               [mcdonalds, atmosphere, staff, food]
# 3              2               [mcdonalds, atmosphere, staff, food]
# 4              2               [mcdonalds, atmosphere, staff, food]
# ..           ...                                                ...
# 495           99                     [ice cream, best fry, allways]
# 496          100                [mcdonalds, people, order, english]
# 497          100                [mcdonalds, people, order, english]
# 498          100                [mcdonalds, people, order, english]
# 499          100                [mcdonalds, people, order, english]
#
#     first_cycle                                             residu  \
# 0        normal  {everyone, someone spit, normal transaction, c...
# 1         other  {everyone, someone spit, normal transaction, c...
# 2     mcdonalds                                       {atmosphere}
# 3         other                                       {atmosphere}
# 4          food                                       {atmosphere}
# ..          ...                                                ...
# 495       cream                                          {allways}
# 496   mcdonalds                                          {english}
# 497      people                                          {english}
# 498       other                                          {english}
# 499       order                                          {english}
#
#     second_cycle
# 0      situation
# 1          drink
# 2          place
# 3          place
# 4           food
# ..           ...
# 495         food
# 496        place
# 497    situation
# 498        other
# 499         food
#
# [500 rows x 5 columns]

# %%
# Store residu data

residu_frame = df_an.groupby('reviewer_id')['residu']\
                .apply(lambda x: set().union(*x))\
                .reset_index()

residu_frame['residu'] = residu_frame['residu'].apply(lambda x: ", ".join(list(x)))

# %%
result = df_an[['reviewer_id', 'first_cycle', 'second_cycle']]\
            .copy()\
            .reset_index()\
            .rename(columns={'index': 'node_id'})

print(result.info())
result.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   node_id       500 non-null    int64
#  1   reviewer_id   500 non-null    int64
#  2   first_cycle   500 non-null    object
#  3   second_cycle  500 non-null    object
# dtypes: int64(2), object(2)
# memory usage: 15.8+ KB
# None
#    node_id  reviewer_id first_cycle second_cycle
# 0        0            1      normal    situation
# 1        1            1       other        drink
# 2        2            2   mcdonalds        place
# 3        3            2       other        place
# 4        4            2        food         food

# %% [markdown]
# ## C. Categorizing

# %%
map_categorizing = {
    'sentiment': ['emotion'],
    'place and service': ['service', 'situation', 'place'],
    'food and drink': ['food', 'drink'],
}

def final_categorizing(x):
    for key in map_categorizing.keys():
        if x in map_categorizing[key]:
            return key
    return "other"

tqdm.pandas()
result['category'] = result['second_cycle'].progress_apply(lambda x: final_categorizing(x))
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████| 500/500 [00:00<00:00, 472864.04it/s]

# %%
result
# Out:
#      node_id  reviewer_id first_cycle second_cycle           category
# 0          0            1      normal    situation  place and service
# 1          1            1       other        drink     food and drink
# 2          2            2   mcdonalds        place  place and service
# 3          3            2       other        place  place and service
# 4          4            2        food         food     food and drink
# ..       ...          ...         ...          ...                ...
# 495      495           99       cream         food     food and drink
# 496      496          100   mcdonalds        place  place and service
# 497      497          100      people    situation  place and service
# 498      498          100       other        other              other
# 499      499          100       order         food     food and drink
#
# [500 rows x 5 columns]

# %% [markdown]
# # Linking Nodes

# %%
import networkx as nx

for cat in np.unique(df_an['second_cycle'].values):
    df_plot = df_an[df_an['second_cycle'] == cat]
    G = nx.from_pandas_edgelist(df_plot, 'first_cycle', 'second_cycle')
    nx.draw_kamada_kawai(G, with_labels=True, node_color='skyblue', node_size=1000)
    plt.show()

# %% [markdown]
# # Add Residu to Data Base (Update Base)

# %%
df = df.merge(residu_frame, on='reviewer_id', how='left')

df['aspect'] = df['aspect'].apply(lambda x: ", ".join(list(x)))
df['token_sentence'] = df['token_sentence'].apply(lambda x: ", ".join(list(x)))

print(df.info())
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   reviewer_id     100 non-null    int64
#  1   review          100 non-null    object
#  2   summarize       100 non-null    object
#  3   aspect          100 non-null    object
#  4   token_sentence  100 non-null    object
#  5   token_lemma     100 non-null    object
#  6   rating          100 non-null    int64
#  7   residu          100 non-null    object
# dtypes: int64(2), object(6)
# memory usage: 6.4+ KB
# None
#    reviewer_id                                             review  \
# 0            1  Why does it look like someone spit on my food?...
# 1            2  It'd McDonalds. It is what it is as far as the...
# 2            3  Made a mobile order got to the speaker and che...
# 3            4  My mc. Crispy chicken sandwich was ÃÂ¯ÃÂ¿ÃÂ...
# 4            5  I repeat my order 3 times in the drive thru, a...
#
#                                            summarize  \
# 0   Why does it look like someone spit on my food...
# 1   The staff at McDonalds are always friendly an...
# 2   Never got the refund in the app. Made a mobil...
# 3   My mc. Crispy chicken sandwich was  customer ...
# 4   I repeat my order 3 times in the drive thru, ...
#
#                                               aspect  \
# 0  clear substance, someone spit, everyone, norma...
# 1                 mcdonalds, atmosphere, staff, food
# 2                  line, mobile order, money, refund
# 3  service, crispy chicken, customer service, chi...
# 4  order, large fry, large meal, close attention,...
#
#                                       token_sentence  \
# 0  Why does it look like someone spit on my food,...
# 1  The staff at McDonalds are always friendly and...
# 2  Never got the refund in the app., Made a mobil...
# 3  Crispy chicken sandwich was  customer service ...
# 4  I repeat my order 3 times in the drive thru, i...
#
#                                          token_lemma  rating  \
# 0  why do it look like someone spit on my food.\n...       1
# 1  the staff at mcdonalds be always friendly and ...       4
# 2  never get the refund in the app ..\nmake a mob...       1
# 3  crispy chicken sandwich be customer service be...       5
# 4  i repeat my order 3 time in the drive thru.\ni...       1
#
#                                               residu
# 0  normal transaction, clear substance, everyone,...
# 1                                         atmosphere
# 2                        refund, mobile order, money
# 3                                     crispy chicken
# 4             double filet, english, close attention

# %% [markdown]
# # Save Important Files

# %%
result.to_csv("./mcd_result/nodes_mcd.csv", index=False)

# %%
df.to_csv("./mcd_result/base_mcd_v1.csv", index=False)

# %%
with open("./mcd_result/map_second_mcd.json", 'w') as file:
    json.dump(map_second_code, file)
    
with open("./mcd_result/map_category_mcd.json", "w") as file:
    json.dump(map_categorizing, file)
    
with open("./mcd_result/list_first_cycle_mcd.json", "w") as file:
    json.dump(list_first_cycle, file)
