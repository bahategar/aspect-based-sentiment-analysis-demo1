# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import networkx as nx

from tqdm import tqdm

# %%
df = pd.read_csv("./mcd_result/nodes_mcd.csv")
# df = df.drop('reviewer_id', axis=1)
df = df.drop(['reviewer_id', 'category'], axis=1)
print(df.info())
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 476 entries, 0 to 475
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   node_id       476 non-null    int64
#  1   first_cycle   476 non-null    object
#  2   second_cycle  476 non-null    object
# dtypes: int64(1), object(2)
# memory usage: 11.3+ KB
# None
#    node_id first_cycle second_cycle
# 0        0       other        other
# 1        1      normal    situation
# 2        2       other        other
# 3        3        food         food
# 4        4   mcdonalds        place

# %%
# edges = []

# for idx, row in df.iterrows():
#     edges.append((row['first_cycle'], row['second_cycle']))
#     edges.append((row['second_cycle'], row['category']))
    
# edges = np.array(edges)

# %%
edges = df[['first_cycle', 'second_cycle']].values
Q = nx.Graph()
Q.add_edges_from(edges)
coordinates = nx.spring_layout(Q)

coordinates
# Out:
# {'other': array([ 0.65879672, -0.52766984]),
#  'normal': array([-0.3523717 ,  0.45767599]),
#  'situation': array([-0.33203018,  0.53728149]),
#  'food': array([-0.54194799, -0.39156811]),
#  'mcdonalds': array([0.54538272, 0.5633263 ]),
#  'place': array([0.52001291, 0.48581917]),
#  'staff': array([0.08702131, 0.6374221 ]),
#  'service': array([0.12552783, 0.56602534]),
#  'line': array([-0.38993562,  0.62184813]),
#  'order': array([-0.57254321, -0.31561047]),
#  'customer': array([0.05405832, 0.56561941]),
#  'chicken': array([-0.6018269 , -0.42260671]),
#  'sandwich': array([-0.5275706 , -0.33016725]),
#  'meal': array([-0.64064301, -0.42670305]),
#  'fry': array([-0.6093742 , -0.33983863]),
#  'large': array([-0.42487732,  0.59417459]),
#  'job': array([ 0.59832241, -0.5816333 ]),
#  'long': array([-0.39228325,  0.56673329]),
#  'new': array([ 0.72049267, -0.56575237]),
#  'regular': array([-0.10533135,  0.54378751]),
#  'location': array([0.32702308, 0.51421388]),
#  'coffee': array([-0.28537795, -0.48072605]),
#  'drink': array([-0.34803648, -0.43862067]),
#  'cup': array([-0.33458514, -0.50986176]),
#  'restaurant': array([0.62035194, 0.49831442]),
#  'time': array([0.05401063, 0.61691334]),
#  'nugget': array([-0.63322828, -0.3760526 ]),
#  'lady': array([0.16144293, 0.49258406]),
#  'extra': array([ 0.75494388, -0.5436683 ]),
#  'people': array([-0.31087606,  0.61409001]),
#  'best': array([-0.25378822, -0.9525822 ]),
#  'emotion': array([-0.31643428, -0.90905638]),
#  'mcdonald': array([0.54006545, 0.42438925]),
#  'item': array([-0.4324137 , -0.39496073]),
#  'night': array([-0.43724272,  0.54808861]),
#  'car': array([0.57875497, 0.51476605]),
#  'hour': array([-0.27790107,  0.54400764]),
#  'wait': array([-0.38844269,  0.49829368]),
#  'experience': array([0.19634325, 0.60160047]),
#  'crew': array([0.14512819, 0.63524407]),
#  'lid': array([ 0.60393005, -0.5354507 ]),
#  'wrong': array([-0.40494019,  0.46579693]),
#  'burger': array([-0.54435225, -0.46586476]),
#  'minute': array([-0.43362767,  0.50695038]),
#  'cream': array([-0.44087674, -0.42660518]),
#  'bag': array([ 0.680433  , -0.61342854]),
#  'ice': array([-0.28486926, -0.42169357]),
#  'taste': array([ 0.57662738, -0.46213628]),
#  'lot': array([ 0.6369196 , -0.60757577]),
#  'bad': array([-0.28029147, -0.9885433 ]),
#  'manager': array([0.19723864, 0.64113776]),
#  'great': array([-0.3564866 , -0.98374082]),
#  'next': array([ 0.726608  , -0.60473824]),
#  'employee': array([0.11542817, 0.49111125]),
#  'horrible': array([-0.32017479, -1.        ]),
#  'pickle': array([-0.59431724, -0.46851448]),
#  'price': array([0.07257304, 0.51481513]),
#  'window': array([0.58493895, 0.42372012]),
#  'store': array([0.60897013, 0.45798209]),
#  '3rd': array([ 0.71332687, -0.46675106]),
#  'drive': array([0.59656094, 0.54982571]),
#  'good': array([-0.38375967, -0.90721516]),
#  'management': array([0.1578839 , 0.67205389]),
#  'mess': array([-0.30436529,  0.4799269 ]),
#  'attitude': array([0.10811911, 0.67081281]),
#  'day': array([-0.35084023,  0.63088926]),
#  'phone': array([ 0.6651634 , -0.46104711]),
#  'happy': array([-0.38818285, -0.95779294]),
#  'work': array([0.21339801, 0.56684001]),
#  'rude': array([-0.28338204, -0.85886432]),
#  'one': array([ 0.74070205, -0.50158333]),
#  'issue': array([0.19302778, 0.52454297])}

# %%
df_coor = pd.DataFrame\
            .from_dict(coordinates).T\
            .rename(columns={0: 'X', 1: 'Y'})\
            .reset_index()\
            .rename(columns={'index': 'NodeName'})

print(df_coor.info())
df_coor.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72 entries, 0 to 71
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   NodeName  72 non-null     object
#  1   X         72 non-null     float64
#  2   Y         72 non-null     float64
# dtypes: float64(2), object(1)
# memory usage: 1.8+ KB
# None
#     NodeName         X         Y
# 0      other  0.658797 -0.527670
# 1     normal -0.352372  0.457676
# 2  situation -0.332030  0.537281
# 3       food -0.541948 -0.391568
# 4  mcdonalds  0.545383  0.563326

# %%
# Create connection bridge dataframe

temp_1 = df[['node_id', 'first_cycle']].rename(columns={'first_cycle': 'NodeName'})
temp_2 = df[['node_id', 'second_cycle']].rename(columns={'second_cycle':'NodeName'})

df_connection = pd.concat([temp_1, temp_2], axis=0).sort_values(by='node_id')

# %%
# # Create connection bridge
# edges = edges.reshape(-1)
# print(edges.shape)

# df_connector = pd.DataFrame(edges, columns=['NodeName'])

# array_idx = []
# for i in range(1, len(edges) + 1):
#     array_idx.append((i + 1) // 2)


# print(len(array_idx))
# df_connector['c_index'] = array_idx
# df_connector.head()
# Out:
# (1904,)
# 1904
#   NodeName  c_index
# 0    other        1
# 1    other        1
# 2    other        2
# 3    other        2
# 4   normal        3

# %%
df_coor.to_csv("./mcd_result/coordinate_nodes_mcd.csv", index=False)
df_connection.to_csv("./mcd_result/connection_nodes_mcd.csv", index=False)
