# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import re
import json

import torch
import torch.nn.functional as F
from transformers import BertTokenizer

from tqdm import tqdm

# %%
from transformers import pipeline

# %% [markdown]
# # Load Model

# %%
modelBertSum = pipeline('summarization', model='model/summarization-0', device=0)
modelBertSum

# %% [markdown]
# # Load Data

# %%
with open("meta-data.json", "r") as file:
    data = json.load(file)

data
# Out:
# {'0': {'reviewer_id': 1,
#   'review_time': '2024-09-04',
#   'rating': 1,
#   'review_processed': "I had a normal transaction, everyone was calm and polite, but now I don't want to eat this. I'm trying not to think about what this milky white/clear substance is all over my food, and I'm sure I'm not coming back.",
#   'aspect_sentiment': [{'term': 'food',
#     'class': 'negative',
#     'probability': [0.9815933108329773,
#      0.015454968437552452,
#      0.002951699076220393],
#     'context': ["I had a normal transaction, everyone was calm and polite, but now I don't want to eat this.",
#      "I'm trying not to think about what this milky white/clear substance is all over my food, and I'm sure I'm not coming back."]},
#    {'term': 'substance',
#     'class': 'negative',
#     'probability': [0.5997273921966553,
#      0.004296493716537952,
#      0.39597612619400024],
#     'context': ["I had a normal transaction, everyone was calm and polite, but now I don't want to eat this.",
#      "I'm trying not to think about what this milky white/clear substance is all over my food, and I'm sure I'm not coming back."]}],
#   'sentiment': 'negative',
#   'topic': {'topic': 2,
#    'probability': 0.9146000146865845,
#    'terms': 'cream, job, ice, happen, food, mcdonald, take, location, answer, student, think, order, staff, sauce, company, got, menu, different, normal, eat'}},
#  '1': {'reviewer_id': 2,
#   'review_time': '2024-11-29',
#   'rating': 4,
#   'review_processed': "The staff at McDonald's are friendly, accommodating and always smiling. It is what it is as far as the food and atmosphere go; it's what it's always been. It makes for a more pleasant experience than many other fast food places in the area.",
#   'aspect_sentiment': [{'term': 'fast food',
#     'class': 'positive',
#     'probability': [0.006815647706389427,
#      0.03166038542985916,
#      0.9615239500999451],
#     'context': ["The staff at McDonald's are friendly, accommodating and always smiling.",
#      "It is what it is as far as the food and atmosphere go; it's what it's always been.",
#      'It makes for a more pleasant experience than many other fast food places in the area.']},
#    {'term': 'atmosphere',
#     'class': 'positive',
#     'probability': [0.0012359353713691235,
#      0.0019914235454052687,
#      0.9967727065086365],
#     'context': ["The staff at McDonald's are friendly, accommodating and always smiling.",
#      "It is what it is as far as the food and atmosphere go; it's what it's always been.",
#      'It makes for a more pleasant experience than many other fast food places in the area.']},
#    {'term': 'food',
#     'class': 'positive',
#     'probability': [0.002793692983686924,
#      0.004679643549025059,
#      0.992526650428772],
#     'context': ["The staff at McDonald's are friendly, accommodating and always smiling.",
#      "It is what it is as far as the food and atmosphere go; it's what it's always been.",
#      'It makes for a more pleasant experience than many other fast food places in the area.']},
#    {'term': 'staff',
#     'class': 'positive',
#     'probability': [0.00021674683375749737,
#      0.0003625940880738199,
#      0.9994207620620728],
#     'context': ["The staff at McDonald's are friendly, accommodating and always smiling.",
#      "It is what it is as far as the food and atmosphere go; it's what it's always been.",
#      'It makes for a more pleasant experience than many other fast food places in the area.']}],
#   'sentiment': 'positive',
#   'topic': {'topic': 3,
#    'probability': 0.9120000004768372,
#    'terms': 'staff, chicken, time, get, restaurant, say, location, wait, smoothie, meal, sandwich, food, pleasant, unhappy, service, clean, place, take, upgrade, period'}},
#  '2': {'reviewer_id': 3,
#   'review_time': '2024-11-29',
#   'rating': 1,
#   'review_processed': 'I made a mobile order got to the speaker and checked it in, but the line was not moving, so I had to leave. I never got the refund in the app. I called them and they said I could only get my money back in person because it was stuck in the system.',
#   'aspect_sentiment': [{'term': 'speaker',
#     'class': 'neutral',
#     'probability': [0.33699119091033936,
#      0.65718674659729,
#      0.005822065286338329],
#     'context': ['I made a mobile order got to the speaker and checked it in, but the line was not moving, so I had to leave.',
#      'I never got the refund in the app.',
#      'I called them and they said I could only get my money back in person because it was stuck in the system.']}],
#   'sentiment': 'negative',
#   'topic': {'topic': 4,
#    'probability': 0.9196000099182129,
#    'terms': 'order, get, taste, rude, late, wrong, meal, large, good, fry, long, line, item, person, finish, ask, pay, taker, tell, service'}},
#  '3': {'reviewer_id': 4,
#   'review_time': '2024-11-04',
#   'rating': 5,
#   'review_processed': "Crispy chicken sandwich was delicious, and customer service was quick and efficient. My mc. was correct: My sandwich was crisp, but the service was fast and friendly. 'My mc. is correct': My sandwich is delicious, but my customer service is fast, friendly, and professional.",
#   'aspect_sentiment': [{'term': 'sandwich',
#     'class': 'positive',
#     'probability': [0.11512675136327744,
#      0.007394721265882254,
#      0.8774785399436951],
#     'context': ['Crispy chicken sandwich was delicious, and customer service was quick and efficient.',
#      'My mc.',
#      'was correct: My sandwich was crisp, but the service was fast and friendly.',
#      "'My mc.",
#      "is correct': My sandwich is delicious, but my customer service is fast, friendly, and professional."]},
#    {'term': 'service',
#     'class': 'positive',
#     'probability': [0.06365323811769485,
#      0.0026424317620694637,
#      0.9337043166160583],
#     'context': ['Crispy chicken sandwich was delicious, and customer service was quick and efficient.',
#      'My mc.',
#      'was correct: My sandwich was crisp, but the service was fast and friendly.',
#      "'My mc.",
#      "is correct': My sandwich is delicious, but my customer service is fast, friendly, and professional."]},
#    {'term': 'customer',
#     'class': 'positive',
#     'probability': [0.0929778441786766,
#      0.00539865018799901,
#      0.901623547077179],
#     'context': ['Crispy chicken sandwich was delicious, and customer service was quick and efficient.',
#      'My mc.',
#      'was correct: My sandwich was crisp, but the service was fast and friendly.',
#      "'My mc.",
#      "is correct': My sandwich is delicious, but my customer service is fast, friendly, and professional."]},
#    {'term': 'crispy chicken sandwich',
#     'class': 'positive',
#     'probability': [0.04437816143035889,
#      0.002110624685883522,
#      0.9535112977027893],
#     'context': ['Crispy chicken sandwich was delicious, and customer service was quick and efficient.',
#      'My mc.',
#      'was correct: My sandwich was crisp, but the service was fast and friendly.',
#      "'My mc.",
#      "is correct': My sandwich is delicious, but my customer service is fast, friendly, and professional."]}],
#   'sentiment': 'positive',
#   'topic': {'topic': 1,
#    'probability': 0.9114999771118164,
#    'terms': 'nice, friendly, world, good, sandwich, manager, exist, food, great, fry, price, customer, money, coffee, fast, point, hour, mcdonald, fair, run'}},
#  '4': {'reviewer_id': 5,
#   'review_time': '2024-10-04',
#   'rating': 1,
#   'review_processed': 'I repeat my order three times in the drive thru, and she still manages to mess it up. It was suppose to be a large meal double filet of fish with large fries, but it was all wrong. They either need to pay close attention to the order being made, or they need not to work at a drive thru.',
#   'aspect_sentiment': [{'term': 'fries',
#     'class': 'negative',
#     'probability': [0.8274237513542175,
#      0.03699015825986862,
#      0.13558609783649445],
#     'context': ['I repeat my order three times in the drive thru, and she still manages to mess it up.',
#      'It was suppose to be a large meal double filet of fish with large fries, but it was all wrong.',
#      'They either need to pay close attention to the order being made, or they need not to work at a drive thru.']},
#    {'term': 'meal',
#     'class': 'negative',
#     'probability': [0.5714789628982544,
#      0.3977477252483368,
#      0.03077329508960247],
#     'context': ['I repeat my order three times in the drive thru, and she still manages to mess it up.',
#      'It was suppose to be a large meal double filet of fish with large fries, but it was all wrong.',
#      'They either need to pay close attention to the order being made, or they need not to work at a drive thru.']},
#    {'term': 'filet of fish',
#     'class': 'neutral',
#     'probability': [0.3450517952442169,
#      0.6001273989677429,
#      0.05482081323862076],
#     'context': ['I repeat my order three times in the drive thru, and she still manages to mess it up.',
#      'It was suppose to be a large meal double filet of fish with large fries, but it was all wrong.',
#      'They either need to pay close attention to the order being made, or they need not to work at a drive thru.']}],
#   'sentiment': 'negative',
#   'topic': {'topic': 6,
#    'probability': 0.9243000149726868,
#    'terms': 'amazing, drink, service, food, attitude, great, answer, last, wrong, beginning, drive, try, price, make, boy, welcome, double, leave, order, customer'}},
#  '5': {'reviewer_id': 6,
#   'review_time': '2024-12-01',
#   'rating': 1,
#   'review_processed': "I work for door dash and they locked us all out to wait in a long line for no reason at 10. I tried to beg them to open it because I'm door dash, but they refused. Covid is over; I'm getting a new job.",
#   'aspect_sentiment': [{'term': 'wait',
#     'class': 'negative',
#     'probability': [0.9932532906532288,
#      0.006253655068576336,
#      0.0004929883871227503],
#     'context': ['I work for door dash and they locked us all out to wait in a long line for no reason at 10.',
#      "I tried to beg them to open it because I'm door dash, but they refused.",
#      "Covid is over; I'm getting a new job."]},
#    {'term': 'door',
#     'class': 'negative',
#     'probability': [0.9924323558807373,
#      0.0022597189527004957,
#      0.005308002699166536],
#     'context': ['I work for door dash and they locked us all out to wait in a long line for no reason at 10.',
#      "I tried to beg them to open it because I'm door dash, but they refused.",
#      "Covid is over; I'm getting a new job."]}],
#   'sentiment': 'negative',
#   'topic': {'topic': 4,
#    'probability': 0.9108999967575073,
#    'terms': 'order, get, taste, rude, late, wrong, meal, large, good, fry, long, line, item, person, finish, ask, pay, taker, tell, service'}},
#  '6': {'reviewer_id': 7,
#   'review_time': '2024-09-04',
#   'rating': 1,
#   'review_processed': "If I could give this location a zero on customer service, I would. It's a horrible experience every time as you can see by other reviews. After getting home, I had no regular hamburg but had cookies. Don't even bother going to this location again.",
#   'aspect_sentiment': [{'term': 'cookies',
#     'class': 'positive',
#     'probability': [0.15484055876731873,
#      0.015986056998372078,
#      0.8291733860969543],
#     'context': ['If I could give this location a zero on customer service, I would.',
#      "It's a horrible experience every time as you can see by other reviews.",
#      'After getting home, I had no regular hamburg but had cookies.',
#      "Don't even bother going to this location again."]},
#    {'term': 'hamburg',
#     'class': 'negative',
#     'probability': [0.998023509979248,
#      0.0009887544438242912,
#      0.0009877586271613836],
#     'context': ['If I could give this location a zero on customer service, I would.',
#      "It's a horrible experience every time as you can see by other reviews.",
#      'After getting home, I had no regular hamburg but had cookies.',
#      "Don't even bother going to this location again."]},
#    {'term': 'customer service',
#     'class': 'negative',
#     'probability': [0.9984126091003418,
#      0.0005393950268626213,
#      0.0010479566408321261],
#     'context': ['If I could give this location a zero on customer service, I would.',
#      "It's a horrible experience every time as you can see by other reviews.",
#      'After getting home, I had no regular hamburg but had cookies.',
#      "Don't even bother going to this location again."]}],
#   'sentiment': 'negative',
#   'topic': {'topic': 3,
#    'probability': 0.9133999943733215,
#    'terms': 'staff, chicken, time, get, restaurant, say, location, wait, smoothie, meal, sandwich, food, pleasant, unhappy, service, clean, place, take, upgrade, period'}},
#  '7': {'reviewer_id': 8,
#   'review_time': '2023-12-04',
#   'rating': 1,
#   'review_processed': 'I asked the employee if they could give me a Large coffee w/no ice and she said no. I always get a large sweet tea with no ice and it always tastes good. They handed me a cup that was less than half way full. I was willing to pay more to get a full cup.',
#   'aspect_sentiment': [{'term': 'cup',
#     'class': 'positive',
#     'probability': [0.14494062960147858,
#      0.2756275236606598,
#      0.5794318318367004],
#     'context': ['I asked the employee if they could give me a Large coffee w/no ice and she said no.',
#      'I always get a large sweet tea with no ice and it always tastes good.',
#      'They handed me a cup that was less than half way full.',
#      'I was willing to pay more to get a full cup.']},
#    {'term': 'tea',
#     'class': 'positive',
#     'probability': [0.16581080853939056,
#      0.07779897004365921,
#      0.7563902735710144],
#     'context': ['I asked the employee if they could give me a Large coffee w/no ice and she said no.',
#      'I always get a large sweet tea with no ice and it always tastes good.',
#      'They handed me a cup that was less than half way full.',
#      'I was willing to pay more to get a full cup.']},
#    {'term': 'sweet',
#     'class': 'positive',
#     'probability': [0.16649764776229858,
#      0.22194929420948029,
#      0.6115531325340271],
#     'context': ['I asked the employee if they could give me a Large coffee w/no ice and she said no.',
#      'I always get a large sweet tea with no ice and it always tastes good.',
#      'They handed me a cup that was less than half way full.',
#      'I was willing to pay more to get a full cup.']},
#    {'term': 'coffee',
#     'class': 'positive',
#     'probability': [0.1834869384765625,
#      0.08739488571882248,
#      0.7291181087493896],
#     'context': ['I asked the employee if they could give me a Large coffee w/no ice and she said no.',
#      'I always get a large sweet tea with no ice and it always tastes good.',
#      'They handed me a cup that was less than half way full.',
#      'I was willing to pay more to get a full cup.']}],
#   'sentiment': 'positive',
#   'topic': {'topic': 4,
#    'probability': 0.9221000075340271,
#    'terms': 'order, get, taste, rude, late, wrong, meal, large, good, fry, long, line, item, person, finish, ask, pay, taker, tell, service'}},
#  '8': {'reviewer_id': 9,
#   'review_time': '2024-09-04',
#   'rating': 1,
#   'review_processed': 'My 10 pieces of chicken were missing. The restaurant gave me a hard time about extra sauce. I was very unhappy with the service at the restaurant. The manager was very unsympathetic to my request to get the chicken McNuggets back. The customer was also very unhappy.',
#   'aspect_sentiment': [{'term': 'chicken mcnuggets',
#     'class': 'positive',
#     'probability': [0.31099334359169006,
#      0.16668684780597687,
#      0.5223197937011719],
#     'context': ['My 10 pieces of chicken were missing.',
#      'The restaurant gave me a hard time about extra sauce.',
#      'I was very unhappy with the service at the restaurant.',
#      'The manager was very unsympathetic to my request to get the chicken McNuggets back.',
#      'The customer was also very unhappy.']},
#    {'term': 'manager',
#     'class': 'negative',
#     'probability': [0.9987077713012695,
#      0.0004580307868309319,
#      0.0008342147921212018],
#     'context': ['My 10 pieces of chicken were missing.',
#      'The restaurant gave me a hard time about extra sauce.',
#      'I was very unhappy with the service at the restaurant.',
#      'The manager was very unsympathetic to my request to get the chicken McNuggets back.',
#      'The customer was also very unhappy.']},
#    {'term': 'service',
#     'class': 'negative',
#     'probability': [0.9980725049972534,
#      0.0016530909342691302,
#      0.0002743771765381098],
#     'context': ['My 10 pieces of chicken were missing.',
#      'The restaurant gave me a hard time about extra sauce.',
#      'I was very unhappy with the service at the restaurant.',
#      'The manager was very unsympathetic to my request to get the chicken McNuggets back.',
#      'The customer was also very unhappy.']},
#    {'term': 'sauce',
#     'class': 'negative',
#     'probability': [0.9985558390617371,
#      0.0011071250773966312,
#      0.00033698396873660386],
#     'context': ['My 10 pieces of chicken were missing.',
#      'The restaurant gave me a hard time about extra sauce.',
#      'I was very unhappy with the service at the restaurant.',
#      'The manager was very unsympathetic to my request to get the chicken McNuggets back.',
#      'The customer was also very unhappy.']},
#    {'term': 'chicken',
#     'class': 'negative',
#     'probability': [0.9976153373718262,
#      0.002048772294074297,
#      0.0003359100373927504],
#     'context': ['My 10 pieces of chicken were missing.',
#      'The restaurant gave me a hard time about extra sauce.',
#      'I was very unhappy with the service at the restaurant.',
#      'The manager was very unsympathetic to my request to get the chicken McNuggets back.',
#      'The customer was also very unhappy.']}],
#   'sentiment': 'negative',
#   'topic': {'topic': 3,
#    'probability': 0.9139999747276306,
#    'terms': 'staff, chicken, time, get, restaurant, say, location, wait, smoothie, meal, sandwich, food, pleasant, unhappy, service, clean, place, take, upgrade, period'}},
#  '9': {'reviewer_id': 10,
#   'review_time': '2024-09-04',
#   'rating': 4,
#   'review_processed': "I'm not a huge fan of fast food, but I have two teenage daughters who enjoy McD's. The staff here is always friendly and always get their orders correct. I always enjoy and appreciate quality service from quality people, and you'll definitely find it here.",
#   'aspect_sentiment': [{'term': 'service',
#     'class': 'positive',
#     'probability': [0.001063541043549776,
#      0.00024696311447769403,
#      0.998689591884613],
#     'context': ["I'm not a huge fan of fast food, but I have two teenage daughters who enjoy McD's.",
#      'The staff here is always friendly and always get their orders correct.',
#      "I always enjoy and appreciate quality service from quality people, and you'll definitely find it here."]},
#    {'term': 'staff',
#     'class': 'positive',
#     'probability': [0.0011739794863387942,
#      0.00024848702014423907,
#      0.9985775947570801],
#     'context': ["I'm not a huge fan of fast food, but I have two teenage daughters who enjoy McD's.",
#      'The staff here is always friendly and always get their orders correct.',
#      "I always enjoy and appreciate quality service from quality people, and you'll definitely find it here."]},
#    {'term': 'fast food',
#     'class': 'positive',
#     'probability': [0.34771257638931274,
#      0.014774005860090256,
#      0.6375134587287903],
#     'context': ["I'm not a huge fan of fast food, but I have two teenage daughters who enjoy McD's.",
#      'The staff here is always friendly and always get their orders correct.',
#      "I always enjoy and appreciate quality service from quality people, and you'll definitely find it here."]}],
#   'sentiment': 'positive',
#   'topic': {'topic': 1,
#    'probability': 0.916100025177002,
#    'terms': 'nice, friendly, world, good, sandwich, manager, exist, food, great, fry, price, customer, money, coffee, fast, point, hour, mcdonald, fair, run'}},
#  '10': {'reviewer_id': 11,
#   'review_time': '2024-09-04',
#   'rating': 1,
#   'review_processed': "The best McDonald's is the worst McDonald's, says the chain's owner. It's the only McDonald's in the U.S.; it's the worst in the world. It is the world's only fast food chain, and it's a terrible one.",
#   'aspect_sentiment': [{'term': 'fast food',
#     'class': 'negative',
#     'probability': [0.9725459814071655,
#      0.006914272904396057,
#      0.020539719611406326],
#     'context': ["The best McDonald's is the worst McDonald's, says the chain's owner.",
#      "It's the only McDonald's in the U.S.; it's the worst in the world.",
#      "It is the world's only fast food chain, and it's a terrible one."]}],
#   'sentiment': 'negative',
#   'topic': {'topic': 1,
#    'probability': 0.8999999761581421,
#    'terms': 'nice, friendly, world, good, sandwich, manager, exist, food, great, fry, price, customer, money, coffee, fast, point, hour, mcdonald, fair, run'}},
#  '11': {'reviewer_id': 12,
#   'review_time': '2024-06-04',
#   'rating': 2,
#   'review_processed': 'Our order was supposed to have 3 food items and 2 drinks, but they missed a food item. The lady ignored me when I told her. My husband went to get it, she finished her task then handed it to him without a word or a smile or anything.',
#   'aspect_sentiment': [{'term': 'food',
#     'class': 'neutral',
#     'probability': [0.03177140653133392,
#      0.9670061469078064,
#      0.0012224643724039197],
#     'context': ['Our order was supposed to have 3 food items and 2 drinks, but they missed a food item.',
#      'The lady ignored me when I told her.',
#      'My husband went to get it, she finished her task then handed it to him without a word or a smile or anything.']},
#    {'term': 'drinks',
#     'class': 'neutral',
#     'probability': [0.006546773482114077,
#      0.9927389025688171,
#      0.0007143780821934342],
#     'context': ['Our order was supposed to have 3 food items and 2 drinks, but they missed a food item.',
#      'The lady ignored me when I told her.',
#      'My husband went to get it, she finished her task then handed it to him without a word or a smile or anything.']},
#    {'term': 'food items',
#     'class': 'neutral',
#     'probability': [0.014800053089857101,
#      0.9838448166847229,
#      0.0013551837764680386],
#     'context': ['Our order was supposed to have 3 food items and 2 drinks, but they missed a food item.',
#      'The lady ignored me when I told her.',
#      'My husband went to get it, she finished her task then handed it to him without a word or a smile or anything.']}],
#   'sentiment': 'negative',
#   'topic': {'topic': 4,
#    'probability': 0.9153000116348267,
#    'terms': 'order, get, taste, rude, late, wrong, meal, large, good, fry, long, line, item, person, finish, ask, pay, taker, tell, service'}},
#  '12': {'reviewer_id': 13,
#   'review_time': '2024-06-04',
#   'rating': 1,
#   'review_processed': "The morning crew seems fast and efficient, but the night crew is a whole different experience. The staff is so rude you leave wanting to crash your car through the building. Don't forget they will mistake your order almost every single time as well and serve it to you cold.",
#   'aspect_sentiment': [{'term': 'staff',
#     'class': 'negative',
#     'probability': [0.9865595102310181,
#      0.0008878746884875,
#      0.012552599422633648],
#     'context': ['The morning crew seems fast and efficient, but the night crew is a whole different experience.',
#      'The staff is so rude you leave wanting to crash your car through the building.',
#      "Don't forget they will mistake your order almost every single time as well and serve it to you cold."]},
#    {'term': 'night crew',
#     'class': 'positive',
#     'probability': [0.1201997622847557,
#      0.0037240320816636086,
#      0.8760762810707092],
#     'context': ['The morning crew seems fast and efficient, but the night crew is a whole different experience.',
#      'The staff is so rude you leave wanting to crash your car through the building.',
#      "Don't forget they will mistake your order almost every single time as well and serve it to you cold."]},
#    {'term': 'morning crew',
#     'class': 'positive',
#     'probability': [0.04071913659572601,
#      0.0013627063017338514,
#      0.9579181671142578],
#     'context': ['The morning crew seems fast and efficient, but the night crew is a whole different experience.',
#      'The staff is so rude you leave wanting to crash your car through the building.',
#      "Don't forget they will mistake your order almost every single time as well and serve it to you cold."]}],
#   'sentiment': 'negative',
#   'topic': {'topic': 4,
#    'probability': 0.9280999898910522,
#    'terms': 'order, get, taste, rude, late, wrong, meal, large, good, fry, long, line, item, person, finish, ask, pay, taker, tell, service'}},
#  '13': {'reviewer_id': 14,
#   'review_time': '2023-12-04',
#   'rating': 3,
#   'review_processed': 'I was disappointed that the restaurant did not get me my full order, meaning I did not receive my condiments for my big breakfast with hot cakes. No butter, no syrup, and no utensils. Oh, and the egg was half the size of the sausage.',
#   'aspect_sentiment': [{'term': 'sausage',
#     'class': 'negative',
#     'probability': [0.9789081811904907,
#      0.019984861835837364,
#      0.0011069513857364655],
#     'context': ['I was disappointed that the restaurant did not get me my full order, meaning I did not receive my condiments for my big breakfast with hot cakes.',
#      'No butter, no syrup, and no utensils.',
#      'Oh, and the egg was half the size of the sausage.']},
#    {'term': 'egg',
#     'class': 'negative',
#     'probability': [0.9930011034011841,
#      0.002290455624461174,
#      0.00470846937969327],
#     'context': ['I was disappointed that the restaurant did not get me my full order, meaning I did not receive my condiments for my big breakfast with hot cakes.',
#      'No butter, no syrup, and no utensils.',
#      'Oh, and the egg was half the size of the sausage.']},
#    {'term': 'syrup',
#     'class': 'negative',
#     'probability': [0.9983137845993042,
#      0.0005611283122561872,
#      0.0011251039104536176],
#     'context': ['I was disappointed that the restaurant did not get me my full order, meaning I did not receive my condiments for my big breakfast with hot cakes.',
#      'No butter, no syrup, and no utensils.',
#      'Oh, and the egg was half the size of the sausage.']},
#    {'term': 'butter',
#     'class': 'negative',
#     'probability': [0.9982079267501831,
#      0.0008565931930206716,
#      0.0009354839567095041],
#     'context': ['I was disappointed that the restaurant did not get me my full order, meaning I did not receive my condiments for my big breakfast with hot cakes.',
#      'No butter, no syrup, and no utensils.',
#      'Oh, and the egg was half the size of the sausage.']},
#    {'term': 'breakfast with hot cakes',
#     'class': 'neutral',
#     'probability': [0.10337114334106445,
#      0.8078848719596863,
#      0.08874398469924927],
#     'context': ['I was disappointed that the restaurant did not get me my full order, meaning I did not receive my condiments for my big breakfast with hot cakes.',
#      'No butter, no syrup, and no utensils.',
#      'Oh, and the egg was half the size of the sausage.']},
#    {'term': 'utensils',
#     'class': 'negative',
#     'probability': [0.9965523481369019,
#      0.002759113209322095,
#      0.0006885712500661612],
#     'context': ['I was disappointed that the restaurant did not get me my full order, meaning I did not receive my condiments for my big breakfast with hot cakes.',
#      'No butter, no syrup, and no utensils.',
#      'Oh, and the egg was half the size of the sausage.']},
#    {'term': 'condiments',
#     'class': 'negative',
#     'probability': [0.9474828839302063,
#      0.04992890730500221,
#      0.0025881922338157892],
#     'context': ['I was disappointed that the restaurant did not get me my full order, meaning I did not receive my condiments for my big breakfast with hot cakes.',
#      'No butter, no syrup, and no utensils.',
#      'Oh, and the egg was half the size of the sausage.']}],
#   'sentiment': 'negative',
#   'topic': {'topic': 3,
#    'probability': 0.9211999773979187,
#    'terms': 'staff, chicken, time, get, restaurant, say, location, wait, smoothie, meal, sandwich, food, pleasant, unhappy, service, clean, place, take, upgrade, period'}},
#  '14': {'reviewer_id': 15,
#   'review_time': '2024-07-04',
#   'rating': 1,
#   'review_processed': 'Ordered food wrong and left out part of the order also. One of the drink cups were not filled; poor service girl handed the order at the window on January 7, 2023 at 1 p.m. correct: Ordered food burger wrong, left out some of the orders also.',
#   'aspect_sentiment': [{'term': 'food burger',
#     'class': 'negative',
#     'probability': [0.9960941672325134,
#      0.003144483547657728,
#      0.0007613926427438855],
#     'context': ['Ordered food wrong and left out part of the order also.',
#      'One of the drink cups were not filled; poor service girl handed the order at the window on January 7, 2023 at 1 p.m. correct: Ordered food burger wrong, left out some of the orders also.']},
#    {'term': 'drink cups',
#     'class': 'negative',
#     'probability': [0.9877892732620239,
#      0.011494306847453117,
#      0.0007163902628235519],
#     'context': ['Ordered food wrong and left out part of the order also.',
#      'One of the drink cups were not filled; poor service girl handed the order at the window on January 7, 2023 at 1 p.m. correct: Ordered food burger wrong, left out some of the orders also.']},
#    {'term': 'food',
#     'class': 'negative',
#     'probability': [0.994797945022583,
#      0.004450373817235231,
#      0.0007516511250287294],
#     'context': ['Ordered food wrong and left out part of the order also.',
#      'One of the drink cups were not filled; poor service girl handed the order at the window on January 7, 2023 at 1 p.m. correct: Ordered food burger wrong, left out some of the orders also.']}],
#   'sentiment': 'negative',
#   'topic': {'topic': 6,
#    'probability': 0.9176999926567078,
#    'terms': 'amazing, drink, service, food, attitude, great, answer, last, wrong, beginning, drive, try, price, make, boy, welcome, double, leave, order, customer'}},
#  '15': {'reviewer_id': 16,
#   'review_time': '2024-10-04',
#   'rating': 2,
#   'review_processed': "This was a dine in experience. The tables were all dirty, and we did not get our food after waiting 35 minutes. Chicken sandwich was burnt; tables were dirty and we didn't receive our food until after 35 minutes had passed; and the food was uneaten.",
#   'aspect_sentiment': [{'term': 'chicken sandwich',
#     'class': 'negative',
#     'probability': [0.9991394281387329,
#      0.00037128617987036705,
#      0.0004893332370556891],
#     'context': ['This was a dine in experience.',
#      'The tables were all dirty, and we did not get our food after waiting 35 minutes.',
#      "Chicken sandwich was burnt; tables were dirty and we didn't receive our food until after 35 minutes had passed; and the food was uneaten."]},
#    {'term': 'food',
#     'class': 'negative',
#     'probability': [0.9963996410369873,
#      0.003311085281893611,
#      0.00028918657335452735],
#     'context': ['This was a dine in experience.',
#      'The tables were all dirty, and we did not get our food after waiting 35 minutes.',
#      "Chicken sandwich was burnt; tables were dirty and we didn't receive our food until after 35 minutes had passed; and the food was uneaten."]},
#    {'term': 'tables',
#     'class': 'negative',
#     'probability': [0.9990373849868774,
#      0.0005781945656053722,
#      0.0003844642487820238],
#     'context': ['This was a dine in experience.',
#      'The tables were all dirty, and we did not get our food after waiting 35 minutes.',
#      "Chicken sandwich was burnt; tables were dirty and we didn't receive our food until after 35 minutes had passed; and the food was uneaten."]}],
#   'sentiment': 'negative',
#   'topic': {'topic': 1,
#    'probability': 0.910099983215332,
#    'terms': 'nice, friendly, world, good, sandwich, manager, exist, food, great, fry, price, customer, money, coffee, fast, point, hour, mcdonald, fair, run'}},
#  '16': {'reviewer_id': 17,
#   'review_time': '2023-12-04',
#   'rating': 4,
#   'review_processed': 'The line was extremely big and was moving very slowly, plus they were out of apples and strawberries, but they gave me a substitute cookie. The staff were very apologetic for being slow, but it was the middle of the night and they were extremely under-staffed.',
#   'aspect_sentiment': [{'term': 'staff',
#     'class': 'negative',
#     'probability': [0.9847680926322937,
#      0.0013101707445457578,
#      0.013921706937253475],
#     'context': ['The line was extremely big and was moving very slowly, plus they were out of apples and strawberries, but they gave me a substitute cookie.',
#      'The staff were very apologetic for being slow, but it was the middle of the night and they were extremely under-staffed.']},
#    {'term': 'cookie',
#     'class': 'negative',
#     'probability': [0.9897438883781433,
#      0.0049213538877666,
#      0.00533474562689662],
#     'context': ['The line was extremely big and was moving very slowly, plus they were out of apples and strawberries, but they gave me a substitute cookie.',
#      'The staff were very apologetic for being slow, but it was the middle of the night and they were extremely under-staffed.']},
#    {'term': 'apples strawberries',
#     'class': 'neutral',
#     'probability': [0.07545929402112961,
#      0.9139658808708191,
#      0.0105748837813735],
#     'context': ['The line was extremely big and was moving very slowly, plus they were out of apples and strawberries, but they gave me a substitute cookie.',
#      'The staff were very apologetic for being slow, but it was the middle of the night and they were extremely under-staffed.']}],
#   'sentiment': 'negative',
#   'topic': {'topic': 1,
#    'probability': 0.9172000288963318,
#    'terms': 'nice, friendly, world, good, sandwich, manager, exist, food, great, fry, price, customer, money, coffee, fast, point, hour, mcdonald, fair, run'}},
#  '17': {'reviewer_id': 18,
#   'review_time': '2024-10-04',
#   'rating': 1,
#   'review_processed': "The boy who attended me made me wait, and when he saw that the drink was wrong he threw the bag of food at me with a grimace. He was so disappointed, he was so angry! The boy was making me wait; he didn't want me to wait.",
#   'aspect_sentiment': [{'term': 'bag of food',
#     'class': 'neutral',
#     'probability': [0.11328613013029099,
#      0.8842231035232544,
#      0.002490766579285264],
#     'context': ['The boy who attended me made me wait, and when he saw that the drink was wrong he threw the bag of food at me with a grimace.',
#      'He was so disappointed, he was so angry!',
#      "The boy was making me wait; he didn't want me to wait."]},
#    {'term': 'drink',
#     'class': 'negative',
#     'probability': [0.7699991464614868,
#      0.2245049625635147,
#      0.005495852790772915],
#     'context': ['The boy who attended me made me wait, and when he saw that the drink was wrong he threw the bag of food at me with a grimace.',
#      'He was so disappointed, he was so angry!',
#      "The boy was making me wait; he didn't want me to wait."]}],
#   'sentiment': 'negative',
#   'topic': {'topic': 6,
#    'probability': 0.9053000211715698,
#    'terms': 'amazing, drink, service, food, attitude, great, answer, last, wrong, beginning, drive, try, price, make, boy, welcome, double, leave, order, customer'}},
#  '18': {'reviewer_id': 19,
#   'review_time': '2024-05-04',
#   'rating': 1,
#   'review_processed': 'I went and bought 4 Strawberry Banana smoothies and and 2 hash browns and my smoothies tasted like straight ice and water. I am very disappointed in there service. My smoothie should never taste like that, especially the fact I bought it for not only me but my kids.',
#   'aspect_sentiment': [{'term': 'service',
#     'class': 'negative',
#     'probability': [0.9974496960639954,
#      0.0014037463115528226,
#      0.00114648905582726],
#     'context': ['I went and bought 4 Strawberry Banana smoothies and and 2 hash browns and my smoothies tasted like straight ice and water.',
#      'I am very disappointed in there service.',
#      'My smoothie should never taste like that, especially the fact I bought it for not only me but my kids.']},
#    {'term': 'water',
#     'class': 'positive',
#     'probability': [0.08196575194597244,
#      0.034085072576999664,
#      0.8839491009712219],
#     'context': ['I went and bought 4 Strawberry Banana smoothies and and 2 hash browns and my smoothies tasted like straight ice and water.',
#      'I am very disappointed in there service.',
#      'My smoothie should never taste like that, especially the fact I bought it for not only me but my kids.']},
#    {'term': 'strawberry banana smoothies',
#     'class': 'positive',
#     'probability': [0.27268412709236145,
#      0.0066567654721438885,
#      0.7206591367721558],
#     'context': ['I went and bought 4 Strawberry Banana smoothies and and 2 hash browns and my smoothies tasted like straight ice and water.',
#      'I am very disappointed in there service.',
#      'My smoothie should never taste like that, especially the fact I bought it for not only me but my kids.']},
#    {'term': 'smoothie',
#     'class': 'negative',
#     'probability': [0.5565332174301147,
#      0.05360134318470955,
#      0.3898654580116272],
#     'context': ['I went and bought 4 Strawberry Banana smoothies and and 2 hash browns and my smoothies tasted like straight ice and water.',
#      'I am very disappointed in there service.',
#      'My smoothie should never taste like that, especially the fact I bought it for not only me but my kids.']},
#    {'term': 'hash brownsies',
#     'class': 'positive',
#     'probability': [0.04074759781360626,
#      0.006972364149987698,
#      0.9522801041603088],
#     'context': []}],
#   'sentiment': 'negative',
#   'topic': {'topic': 3,
#    'probability': 0.9045000076293945,
#    'terms': 'staff, chicken, time, get, restaurant, say, location, wait, smoothie, meal, sandwich, food, pleasant, unhappy, service, clean, place, take, upgrade, period'}},
#  '19': {'reviewer_id': 20,
#   'review_time': '2024-05-04',
#   'rating': 4,
#   'review_processed': 'The staff seems to always be different, which makes ordering sometimes a little difficult because they are in a state of perpetual learning. The lobby is always clean as well as the bathrooms, but the wait is always longer due to their constant changes in appearance. The staff are always different, making ordering difficult.',
#   'aspect_sentiment': [{'term': 'appearance',
#     'class': 'negative',
#     'probability': [0.9731659889221191,
#      0.024411581456661224,
#      0.0024223667569458485],
#     'context': ['The staff seems to always be different, which makes ordering sometimes a little difficult because they are in a state of perpetual learning.',
#      'The lobby is always clean as well as the bathrooms, but the wait is always longer due to their constant changes in appearance.',
#      'The staff are always different, making ordering difficult.']},
#    {'term': 'wait',
#     'class': 'negative',
#     'probability': [0.9962146878242493,
#      0.0017749888356775045,
#      0.0020102967973798513],
#     'context': ['The staff seems to always be different, which makes ordering sometimes a little difficult because they are in a state of perpetual learning.',
#      'The lobby is always clean as well as the bathrooms, but the wait is always longer due to their constant changes in appearance.',
#      'The staff are always different, making ordering difficult.']},
#    {'term': 'bathrooms',
#     'class': 'neutral',
#     'probability': [0.07573594897985458,
#      0.6802747249603271,
#      0.24398933351039886],
#     'context': ['The staff seems to always be different, which makes ordering sometimes a little difficult because they are in a state of perpetual learning.',
#      'The lobby is always clean as well as the bathrooms, but the wait is always longer due to their constant changes in appearance.',
#      'The staff are always different, making ordering difficult.']},
#    {'term': 'lobby',
#     'class': 'positive',
#     'probability': [0.16022616624832153,
#      0.0077795060351490974,
#      0.831994354724884],
#     'context': ['The staff seems to always be different, which makes ordering sometimes a little difficult because they are in a state of perpetual learning.',
#      'The lobby is always clean as well as the bathrooms, but the wait is always longer due to their constant changes in appearance.',
#      'The staff are always different, making ordering difficult.']},
#    {'term': 'staff',
#     'class': 'negative',
#     'probability': [0.7863964438438416,
#      0.013776720501482487,
#      0.19982686638832092],
#     'context': ['The staff seems to always be different, which makes ordering sometimes a little difficult because they are in a state of perpetual learning.',
#      'The lobby is always clean as well as the bathrooms, but the wait is always longer due to their constant changes in appearance.',
#      'The staff are always different, making ordering difficult.']}],
#   'sentiment': 'negative',
#   'topic': {'topic': 2,
#    'probability': 0.9192000031471252,
#    'terms': 'cream, job, ice, happen, food, mcdonald, take, location, answer, student, think, order, staff, sauce, company, got, menu, different, normal, eat'}},
#  '20': {'reviewer_id': 21,
#   'review_time': '2024-02-04',
#   'rating': 1,
#   'review_processed': "Can't believe experience with order taker. Went from drive thru and employee directly asked what do you want. He keeps rushing while taking order with no other cars placing order. We wanted to add one more item and asked for a minute. When I said we are ready - no response.",
#   'aspect_sentiment': [{'term': 'order taker',
#     'class': 'negative',
#     'probability': [0.9969251751899719,
#      0.0028428477235138416,
#      0.0002319530030945316],
#     'context': ["Can't believe experience with order taker.",
#      'Went from drive thru and employee directly asked what do you want.',
#      'He keeps rushing while taking order with no other cars placing order.',
#      'We wanted to add one more item and asked for a minute.',
#      'When I said we are ready - no response.']}],
#   'sentiment': 'negative',
#   'topic': {'topic': 4,
#    'probability': 0.9251000285148621,
#    'terms': 'order, get, taste, rude, late, wrong, meal, large, good, fry, long, line, item, person, finish, ask, pay, taker, tell, service'}},
#  '21': {'reviewer_id': 22,
#   'review_time': '2020-12-04',
#   'rating': 1,
#   'review_processed': 'I only go here when they are not busy, in hope that my order is correct when I go to leave. When I finally get the correct order, it is generally tasty. The evening staff is pleasant, but the morning staff leaves a lot to be desired. The morning staff thinks they can talk negatively about people in Spanish out in the open.',
#   'aspect_sentiment': [{'term': 'morning staff',
#     'class': 'positive',
#     'probability': [0.29298898577690125,
#      0.004363544750958681,
#      0.7026475071907043],
#     'context': ['I only go here when they are not busy, in hope that my order is correct when I go to leave.',
#      'When I finally get the correct order, it is generally tasty.',
#      'The evening staff is pleasant, but the morning staff leaves a lot to be desired.',
#      'The morning staff thinks they can talk negatively about people in Spanish out in the open.']},
#    {'term': 'evening staff',
#     'class': 'positive',
#     'probability': [0.18166635930538177,
#      0.0032298490405082703,
#      0.8151037693023682],
#     'context': ['I only go here when they are not busy, in hope that my order is correct when I go to leave.',
#      'When I finally get the correct order, it is generally tasty.',
#      'The evening staff is pleasant, but the morning staff leaves a lot to be desired.',
#      'The morning staff thinks they can talk negatively about people in Spanish out in the open.']}],
#   'sentiment': 'negative',
#   'topic': {'topic': 3,
#    'probability': 0.9200000166893005,
#    'terms': 'staff, chicken, time, get, restaurant, say, location, wait, smoothie, meal, sandwich, food, pleasant, unhappy, service, clean, place, take, upgrade, period'}},
#  '22': {'reviewer_id': 23,
#   'review_time': '2024-11-04',
#   'rating': 2,
#   'review_processed': "The staff at the drive thru just shoved the drink in my hands. It's not very professional. I just needed caffeine; I'm not a big fan of fast food. The food was good, but the service was unappetiteful and unprofessional.",
#   'aspect_sentiment': [{'term': 'service',
#     'class': 'negative',
#     'probability': [0.9968095421791077,
#      0.0007321911980397999,
#      0.0024582671467214823],
#     'context': ['The staff at the drive thru just shoved the drink in my hands.',
#      "It's not very professional.",
#      "I just needed caffeine; I'm not a big fan of fast food.",
#      'The food was good, but the service was unappetiteful and unprofessional.']},
#    {'term': 'food',
#     'class': 'neutral',
#     'probability': [0.07116822898387909,
#      0.6706492304801941,
#      0.25818249583244324],
#     'context': ['The staff at the drive thru just shoved the drink in my hands.',
#      "It's not very professional.",
#      "I just needed caffeine; I'm not a big fan of fast food.",
#      'The food was good, but the service was unappetiteful and unprofessional.']},
#    {'term': 'fast food',
#     'class': 'neutral',
#     'probability': [0.102867990732193, 0.4722709655761719, 0.4248610734939575],
#     'context': ['The staff at the drive thru just shoved the drink in my hands.',
#      "It's not very professional.",
#      "I just needed caffeine; I'm not a big fan of fast food.",
#      'The food was good, but the service was unappetiteful and unprofessional.']},
#    {'term': 'drink',
#     'class': 'neutral',
#     'probability': [0.01874767430126667,
#      0.9803789854049683,
#      0.0008733723079785705],
#     'context': ['The staff at the drive thru just shoved the drink in my hands.',
#      "It's not very professional.",
#      "I just needed caffeine; I'm not a big fan of fast food.",
#      'The food was good, but the service was unappetiteful and unprofessional.']},
#    {'term': 'staff',
#     'class': 'negative',
#     'probability': [0.9944396018981934,
#      0.000629544083494693,
#      0.004930817522108555],
#     'context': ['The staff at the drive thru just shoved the drink in my hands.',
#      "It's not very professional.",
#      "I just needed caffeine; I'm not a big fan of fast food.",
#      'The food was good, but the service was unappetiteful and unprofessional.']},
#    {'term': 'caffeine',
#     'class': 'neutral',
#     'probability': [0.033860109746456146,
#      0.9015904664993286,
#      0.06454944610595703],
#     'context': ['The staff at the drive thru just shoved the drink in my hands.',
#      "It's not very professional.",
#      "I just needed caffeine; I'm not a big fan of fast food.",
#      'The food was good, but the service was unappetiteful and unprofessional.']}],
#   'sentiment': 'negative',
#   'topic': {'topic': 2,
#    'probability': 0.9180999994277954,
#    'terms': 'cream, job, ice, happen, food, mcdonald, take, location, answer, student, think, order, staff, sauce, company, got, menu, different, normal, eat'}},
#  '23': {'reviewer_id': 24,
#   'review_time': '2024-04-04',
#   'rating': 1,
#   'review_processed': "Microwaved nuggets, cold fries and a 30 minute wait? What more can you ask for? Don't go there ever! You're better off going hungry or giving the meal you paid for to the homeless by the donation box behind the drive thru.",
#   'aspect_sentiment': [{'term': 'meal',
#     'class': 'negative',
#     'probability': [0.9807120561599731,
#      0.004715777467936277,
#      0.014572146348655224],
#     'context': ['Microwaved nuggets, cold fries and a 30 minute wait?',
#      'What more can you ask for?',
#      "Don't go there ever!",
#      "You're better off going hungry or giving the meal you paid for to the homeless by the donation box behind the drive thru."]},
#    {'term': 'wait',
#     'class': 'negative',
#     'probability': [0.9969077706336975,
#      0.0026386796962469816,
#      0.0004534372710622847],
#     'context': ['Microwaved nuggets, cold fries and a 30 minute wait?',
#      'What more can you ask for?',
#      "Don't go there ever!",
# ...
#      'Seriously?',
#      "That's the response?",
#      'Will not be returning.']}],
#   'sentiment': 'negative',
#   'topic': {'topic': 4,
#    'probability': 0.911899983882904,
#    'terms': 'order, get, taste, rude, late, wrong, meal, large, good, fry, long, line, item, person, finish, ask, pay, taker, tell, service'}},
#  '90': {'reviewer_id': 91,
#   'review_time': '2019-12-04',
#   'rating': 1,
#   'review_processed': "This is the 3rd time in a row that we've been burned going through the drive thru. You'd think by now that I would have learned my lesson, but I thought this would be quick and easy. This location sucks. I tried calling the number in the receipt but no one answers.",
#   'aspect_sentiment': [],
#   'sentiment': 'negative',
#   'topic': {'topic': 2,
#    'probability': 0.9215999841690063,
#    'terms': 'cream, job, ice, happen, food, mcdonald, take, location, answer, student, think, order, staff, sauce, company, got, menu, different, normal, eat'}},
#  '91': {'reviewer_id': 92,
#   'review_time': '2021-12-04',
#   'rating': 1,
#   'review_processed': 'All I asked for was a regular size coffee. Coffee was full of coffee grounds to the point I was spitting them out. Also asked for 3 splendas and 4 creamers on the side and received 3 regular sugars and 2 creamers. And as a little plus there was a piece of plastic! Never again!',
#   'aspect_sentiment': [{'term': 'coffee grounds',
#     'class': 'negative',
#     'probability': [0.7095144391059875,
#      0.27448341250419617,
#      0.016002189368009567],
#     'context': ['All I asked for was a regular size coffee.',
#      'Coffee was full of coffee grounds to the point I was spitting them out.',
#      'Also asked for 3 splendas and 4 creamers on the side and received 3 regular sugars and 2 creamers.',
#      'And as a little plus there was a piece of plastic!',
#      'Never again!']},
#    {'term': 'coffee',
#     'class': 'negative',
#     'probability': [0.8361466526985168,
#      0.1547451764345169,
#      0.009108172729611397],
#     'context': ['All I asked for was a regular size coffee.',
#      'Coffee was full of coffee grounds to the point I was spitting them out.',
#      'Also asked for 3 splendas and 4 creamers on the side and received 3 regular sugars and 2 creamers.',
#      'And as a little plus there was a piece of plastic!',
#      'Never again!']},
#    {'term': 'sugars',
#     'class': 'negative',
#     'probability': [0.9795821905136108,
#      0.015034454874694347,
#      0.005383349489420652],
#     'context': ['All I asked for was a regular size coffee.',
#      'Coffee was full of coffee grounds to the point I was spitting them out.',
#      'Also asked for 3 splendas and 4 creamers on the side and received 3 regular sugars and 2 creamers.',
#      'And as a little plus there was a piece of plastic!',
#      'Never again!']},
#    {'term': 'creamers',
#     'class': 'negative',
#     'probability': [0.9829748272895813,
#      0.013136506080627441,
#      0.0038886505644768476],
#     'context': ['All I asked for was a regular size coffee.',
#      'Coffee was full of coffee grounds to the point I was spitting them out.',
#      'Also asked for 3 splendas and 4 creamers on the side and received 3 regular sugars and 2 creamers.',
#      'And as a little plus there was a piece of plastic!',
#      'Never again!']},
#    {'term': 'splendas',
#     'class': 'negative',
#     'probability': [0.9824161529541016,
#      0.014306364580988884,
#      0.003277549287304282],
#     'context': ['All I asked for was a regular size coffee.',
#      'Coffee was full of coffee grounds to the point I was spitting them out.',
#      'Also asked for 3 splendas and 4 creamers on the side and received 3 regular sugars and 2 creamers.',
#      'And as a little plus there was a piece of plastic!',
#      'Never again!']}],
#   'sentiment': 'negative',
#   'topic': {'topic': 1,
#    'probability': 0.9187999963760376,
#    'terms': 'nice, friendly, world, good, sandwich, manager, exist, food, great, fry, price, customer, money, coffee, fast, point, hour, mcdonald, fair, run'}},
#  '92': {'reviewer_id': 93,
#   'review_time': '2019-12-04',
#   'rating': 1,
#   'review_processed': "I tried to go through the drive thru at 430 a. It said it was 24 hours, but no one seemed to be taking orders. I drove around twice just in case and tried again but still no answer. I saw one employee in the kitchen but couldn't get his attention. It's very bad business.",
#   'aspect_sentiment': [{'term': 'kitchen',
#     'class': 'negative',
#     'probability': [0.5457109212875366,
#      0.45042192935943604,
#      0.003867190098389983],
#     'context': ['I tried to go through the drive thru at 430 a.',
#      'It said it was 24 hours, but no one seemed to be taking orders.',
#      'I drove around twice just in case and tried again but still no answer.',
#      "I saw one employee in the kitchen but couldn't get his attention.",
#      "It's very bad business."]}],
#   'sentiment': 'negative',
#   'topic': {'topic': 6,
#    'probability': 0.9172999858856201,
#    'terms': 'amazing, drink, service, food, attitude, great, answer, last, wrong, beginning, drive, try, price, make, boy, welcome, double, leave, order, customer'}},
#  '93': {'reviewer_id': 94,
#   'review_time': '2020-12-04',
#   'rating': 3,
#   'review_processed': "I ordered a frozen lemonade, paid for it, then sat down. I was there for a bit before someone came and told me they were out. It was too much trouble to get a refund for the difference. I'm not sure I like this new way.",
#   'aspect_sentiment': [{'term': 'frozen lemonade',
#     'class': 'negative',
#     'probability': [0.4706272482872009,
#      0.38040411472320557,
#      0.14896859228610992],
#     'context': ['I ordered a frozen lemonade, paid for it, then sat down.',
#      'I was there for a bit before someone came and told me they were out.',
#      'It was too much trouble to get a refund for the difference.',
#      "I'm not sure I like this new way."]}],
#   'sentiment': 'negative',
#   'topic': {'topic': 4,
#    'probability': 0.9187999963760376,
#    'terms': 'order, get, taste, rude, late, wrong, meal, large, good, fry, long, line, item, person, finish, ask, pay, taker, tell, service'}},
#  '94': {'reviewer_id': 95,
#   'review_time': '2021-12-04',
#   'rating': 1,
#   'review_processed': 'My burger was completely raw in the middle, and when I took it back in to get it remade, the lady behind the counter treated me like I was some stuck up brat for not wanting to eat a raw burger. I will never eat there again.',
#   'aspect_sentiment': [{'term': 'lady',
#     'class': 'negative',
#     'probability': [0.9987659454345703,
#      0.00045107313781045377,
#      0.0007829025271348655],
#     'context': ['My burger was completely raw in the middle, and when I took it back in to get it remade, the lady behind the counter treated me like I was some stuck up brat for not wanting to eat a raw burger.',
#      'I will never eat there again.']},
#    {'term': 'burger',
#     'class': 'negative',
#     'probability': [0.9936532974243164,
#      0.005539106670767069,
#      0.000807653705123812],
#     'context': ['My burger was completely raw in the middle, and when I took it back in to get it remade, the lady behind the counter treated me like I was some stuck up brat for not wanting to eat a raw burger.',
#      'I will never eat there again.']}],
#   'sentiment': 'negative',
#   'topic': {'topic': 5,
#    'probability': 0.9021000266075134,
#    'terms': 'order, letter, eat, thru, drive, store, wait, minute, lady, time, confuse, raw, receipt, situation, publish, article, issue, burger, caramel, temperature'}},
#  '95': {'reviewer_id': 96,
#   'review_time': '2020-12-04',
#   'rating': 1,
#   'review_processed': 'Every single time I go they f up my order! Then give attitude when they need to correct their mistakes. The staff is horrible. Corporate needs to send all their staff over to a week of training at chic-fil-A college to learn about work ethic, time management, teamwork and basic manors.',
#   'aspect_sentiment': [{'term': 'time management',
#     'class': 'negative',
#     'probability': [0.9895713329315186,
#      0.009903143160045147,
#      0.0005255448049865663],
#     'context': ['Every single time I go they f up my order!',
#      'Then give attitude when they need to correct their mistakes.',
#      'The staff is horrible.',
#      'Corporate needs to send all their staff over to a week of training at chic-fil-A college to learn about work ethic, time management, teamwork and basic manors.']},
#    {'term': 'work',
#     'class': 'negative',
#     'probability': [0.959642767906189,
#      0.0379057452082634,
#      0.0024514507967978716],
#     'context': ['Every single time I go they f up my order!',
#      'Then give attitude when they need to correct their mistakes.',
#      'The staff is horrible.',
#      'Corporate needs to send all their staff over to a week of training at chic-fil-A college to learn about work ethic, time management, teamwork and basic manors.']},
#    {'term': 'staff',
#     'class': 'negative',
#     'probability': [0.9991330504417419,
#      0.000503927527461201,
#      0.0003630200808402151],
#     'context': ['Every single time I go they f up my order!',
#      'Then give attitude when they need to correct their mistakes.',
#      'The staff is horrible.',
#      'Corporate needs to send all their staff over to a week of training at chic-fil-A college to learn about work ethic, time management, teamwork and basic manors.']},
#    {'term': 'manors',
#     'class': 'negative',
#     'probability': [0.9981818199157715,
#      0.0011882988037541509,
#      0.000629953108727932],
#     'context': ['Every single time I go they f up my order!',
#      'Then give attitude when they need to correct their mistakes.',
#      'The staff is horrible.',
#      'Corporate needs to send all their staff over to a week of training at chic-fil-A college to learn about work ethic, time management, teamwork and basic manors.']},
#    {'term': 'teamwork',
#     'class': 'negative',
#     'probability': [0.9969677329063416,
#      0.001958282431587577,
#      0.0010740001453086734],
#     'context': ['Every single time I go they f up my order!',
#      'Then give attitude when they need to correct their mistakes.',
#      'The staff is horrible.',
#      'Corporate needs to send all their staff over to a week of training at chic-fil-A college to learn about work ethic, time management, teamwork and basic manors.']}],
#   'sentiment': 'negative',
#   'topic': {'topic': 3,
#    'probability': 0.9316999912261963,
#    'terms': 'staff, chicken, time, get, restaurant, say, location, wait, smoothie, meal, sandwich, food, pleasant, unhappy, service, clean, place, take, upgrade, period'}},
#  '96': {'reviewer_id': 97,
#   'review_time': '2022-12-04',
#   'rating': 1,
#   'review_processed': 'When ordering food, the employees forgot to turn off their microphones and were talking messily about all the food we had ordered. This is very unprofessional and honestly uncalled for. When I asked for a receipt, they said it was in the bad and it was not in there.',
#   'aspect_sentiment': [{'term': 'employees',
#     'class': 'negative',
#     'probability': [0.9987253546714783,
#      0.0005044877761974931,
#      0.000770182756241411],
#     'context': ['When ordering food, the employees forgot to turn off their microphones and were talking messily about all the food we had ordered.',
#      'This is very unprofessional and honestly uncalled for.',
#      'When I asked for a receipt, they said it was in the bad and it was not in there.']},
#    {'term': 'food',
#     'class': 'negative',
#     'probability': [0.9288522005081177,
#      0.06959313899278641,
#      0.0015547084622085094],
#     'context': ['When ordering food, the employees forgot to turn off their microphones and were talking messily about all the food we had ordered.',
#      'This is very unprofessional and honestly uncalled for.',
#      'When I asked for a receipt, they said it was in the bad and it was not in there.']}],
#   'sentiment': 'negative',
#   'topic': {'topic': 5,
#    'probability': 0.9063000082969666,
#    'terms': 'order, letter, eat, thru, drive, store, wait, minute, lady, time, confuse, raw, receipt, situation, publish, article, issue, burger, caramel, temperature'}},
#  '97': {'reviewer_id': 98,
#   'review_time': '2021-12-04',
#   'rating': 1,
#   'review_processed': "I don't usually review places, but this location has ridiculously rude service and consistently gets the orders wrong. Even when not busy, they are rude. If I were rude, I wouldn't be able to enjoy the experience at this location. It's ridiculous.",
#   'aspect_sentiment': [{'term': 'orders',
#     'class': 'negative',
#     'probability': [0.9989007711410522,
#      0.0005099655245430768,
#      0.0005892295157536864],
#     'context': ["I don't usually review places, but this location has ridiculously rude service and consistently gets the orders wrong.",
#      'Even when not busy, they are rude.',
#      "If I were rude, I wouldn't be able to enjoy the experience at this location.",
#      "It's ridiculous."]},
#    {'term': 'service',
#     'class': 'negative',
#     'probability': [0.9983295798301697,
#      0.0003267021384090185,
#      0.0013437323505058885],
#     'context': ["I don't usually review places, but this location has ridiculously rude service and consistently gets the orders wrong.",
#      'Even when not busy, they are rude.',
#      "If I were rude, I wouldn't be able to enjoy the experience at this location.",
#      "It's ridiculous."]}],
#   'sentiment': 'negative',
#   'topic': {'topic': 4,
#    'probability': 0.9031000137329102,
#    'terms': 'order, get, taste, rude, late, wrong, meal, large, good, fry, long, line, item, person, finish, ask, pay, taker, tell, service'}},
#  '98': {'reviewer_id': 99,
#   'review_time': '2024-06-04',
#   'rating': 5,
#   'review_processed': "Allways has the best fries and ice cream in the world; it's the best in the whole world! correct: It has the world's best fries, and the best ice cream anywhere! It's very tasty. It's amazing. It is the best!",
#   'aspect_sentiment': [{'term': 'ice cream',
#     'class': 'positive',
#     'probability': [0.0001824156061047688,
#      0.0002252057456644252,
#      0.9995923638343811],
#     'context': ["Allways has the best fries and ice cream in the world; it's the best in the whole world!",
#      "correct: It has the world's best fries, and the best ice cream anywhere!",
#      "It's very tasty.",
#      "It's amazing.",
#      'It is the best!']},
#    {'term': 'fries',
#     'class': 'positive',
#     'probability': [0.00017211318481713533,
#      0.00021300360094755888,
#      0.999614953994751],
#     'context': ["Allways has the best fries and ice cream in the world; it's the best in the whole world!",
#      "correct: It has the world's best fries, and the best ice cream anywhere!",
#      "It's very tasty.",
#      "It's amazing.",
#      'It is the best!']}],
#   'sentiment': 'positive',
#   'topic': {'topic': 1,
#    'probability': 0.8967999815940857,
#    'terms': 'nice, friendly, world, good, sandwich, manager, exist, food, great, fry, price, customer, money, coffee, fast, point, hour, mcdonald, fair, run'}},
#  '99': {'reviewer_id': 100,
#   'review_time': '2023-12-04',
#   'rating': 4,
#   'review_processed': "McDonald's is great, but they need to hire people who understand both English and Spanish. The people are really nice, but be smarter about who you put in the drive thru and lobby to take orders. The staff are all Spanish speakers trying to take English orders.",
#   'aspect_sentiment': [{'term': 'staff',
#     'class': 'positive',
#     'probability': [0.02162514440715313,
#      0.06668327003717422,
#      0.9116915464401245],
#     'context': ["McDonald's is great, but they need to hire people who understand both English and Spanish.",
#      'The people are really nice, but be smarter about who you put in the drive thru and lobby to take orders.',
#      'The staff are all Spanish speakers trying to take English orders.']}],
#   'sentiment': 'positive',
#   'topic': {'topic': 1,
#    'probability': 0.9217000007629395,
#    'terms': 'nice, friendly, world, good, sandwich, manager, exist, food, great, fry, price, customer, money, coffee, fast, point, hour, mcdonald, fair, run'}}}

# %%
df = pd.DataFrame.from_dict(data, orient='index')
print(df.info())
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 100 entries, 0 to 99
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   reviewer_id       100 non-null    int64
#  1   review_time       100 non-null    object
#  2   rating            100 non-null    int64
#  3   review_processed  100 non-null    object
#  4   aspect_sentiment  100 non-null    object
#  5   sentiment         100 non-null    object
#  6   topic             100 non-null    object
# dtypes: int64(2), object(5)
# memory usage: 6.2+ KB
# None
#    reviewer_id review_time  rating  \
# 0            1  2024-09-04       1
# 1            2  2024-11-29       4
# 2            3  2024-11-29       1
# 3            4  2024-11-04       5
# 4            5  2024-10-04       1
#
#                                     review_processed  \
# 0  I had a normal transaction, everyone was calm ...
# 1  The staff at McDonald's are friendly, accommod...
# 2  I made a mobile order got to the speaker and c...
# 3  Crispy chicken sandwich was delicious, and cus...
# 4  I repeat my order three times in the drive thr...
#
#                                     aspect_sentiment sentiment  \
# 0  [{'term': 'food', 'class': 'negative', 'probab...  negative
# 1  [{'term': 'fast food', 'class': 'positive', 'p...  positive
# 2  [{'term': 'speaker', 'class': 'neutral', 'prob...  negative
# 3  [{'term': 'sandwich', 'class': 'positive', 'pr...  positive
# 4  [{'term': 'fries', 'class': 'negative', 'proba...  negative
#
#                                                topic
# 0  {'topic': 2, 'probability': 0.9146000146865845...
# 1  {'topic': 3, 'probability': 0.9120000004768372...
# 2  {'topic': 4, 'probability': 0.9196000099182129...
# 3  {'topic': 1, 'probability': 0.9114999771118164...
# 4  {'topic': 6, 'probability': 0.9243000149726868...

# %% [markdown]
# # Exploratory Data Analysis

# %%
aspects = {}

for items in df['aspect_sentiment'].values:
    for item in items:
        term = item.get('term')
        word = aspects.get(term)
        if word not in aspects.keys():
            aspects[term] = 1
        else:
            print(aspects.get(word))
            aspects[word] = aspects[word] + 1
aspects
# Out:
# {'food': 1,
#  'substance': 1,
#  'fast food': 1,
#  'atmosphere': 1,
#  'staff': 1,
#  'speaker': 1,
#  'sandwich': 1,
#  'service': 1,
#  'customer': 1,
#  'crispy chicken sandwich': 1,
#  'fries': 1,
#  'meal': 1,
#  'filet of fish': 1,
#  'wait': 1,
#  'door': 1,
#  'cookies': 1,
#  'hamburg': 1,
#  'customer service': 1,
#  'cup': 1,
#  'tea': 1,
#  'sweet': 1,
#  'coffee': 1,
#  'chicken mcnuggets': 1,
#  'manager': 1,
#  'sauce': 1,
#  'chicken': 1,
#  'drinks': 1,
#  'food items': 1,
#  'night crew': 1,
#  'morning crew': 1,
#  'sausage': 1,
#  'egg': 1,
#  'syrup': 1,
#  'butter': 1,
#  'breakfast with hot cakes': 1,
#  'utensils': 1,
#  'condiments': 1,
#  'food burger': 1,
#  'drink cups': 1,
#  'chicken sandwich': 1,
#  'tables': 1,
#  'cookie': 1,
#  'apples strawberries': 1,
#  'bag of food': 1,
#  'drink': 1,
#  'water': 1,
#  'strawberry banana smoothies': 1,
#  'smoothie': 1,
#  'hash brownsies': 1,
#  'appearance': 1,
#  'bathrooms': 1,
#  'lobby': 1,
#  'order taker': 1,
#  'morning staff': 1,
#  'evening staff': 1,
#  'caffeine': 1,
#  'money': 1,
#  'card': 1,
#  'ice cream': 1,
#  'taste': 1,
#  'employees': 1,
#  'pounder': 1,
#  'quarter': 1,
#  'double': 1,
#  'sausage biscuit': 1,
#  'caramel mocha': 1,
#  'order menu': 1,
#  'thru line': 1,
#  'drive': 1,
#  'dinner': 1,
#  'orders': 1,
#  'pinball arcade': 1,
#  'price': 1,
#  'pickles': 1,
#  'google': 1,
#  'supervisor': 1,
#  'general': 1,
#  'deluxe': 1,
#  'spicy chicken sandwich': 1,
#  'chicken sandwiches': 1,
#  'fry': 1,
#  'large': 1,
#  'lettuce and tomato': 1,
#  'spicey chicken sandwiches': 1,
#  'br': 1,
#  'menu': 1,
#  'cooks': 1,
#  'mcdonald': 1,
#  'lunch': 1,
#  'breakfast': 1,
#  'served': 1,
#  'employee': 1,
#  'management': 1,
#  'portion': 1,
#  'carton': 1,
#  'messed': 1,
#  'shift manager': 1,
#  'extra': 1,
#  'cream': 1,
#  'ice': 1,
#  'oreo mcry': 1,
#  'baked beans': 1,
#  'representative': 1,
#  'robots': 1,
#  'order': 1,
#  'coke': 1,
#  'area': 1,
#  'price range': 1,
#  'prices': 1,
#  'fry containerss': 1,
#  'fountain drinks': 1,
#  'dish soap': 1,
#  'bbq sauce': 1,
#  'staffed': 1,
#  'cashier': 1,
#  'nuggets': 1,
#  'worker': 1,
#  'serving': 1,
#  'hamburger wrapper': 1,
#  'cheese': 1,
#  'bag': 1,
#  'meat': 1,
#  'buns': 1,
#  'bite': 1,
#  'crew': 1,
#  'places': 1,
#  'entrances': 1,
#  'drive thru line': 1,
#  'attendant': 1,
#  'attendants': 1,
#  'heat lamp': 1,
#  'meal periods': 1,
#  'workers': 1,
#  'uber': 1,
#  'meals': 1,
#  'burgers': 1,
#  'cheeseburgers': 1,
#  'kitchen staff': 1,
#  'food window': 1,
#  'coffee grounds': 1,
#  'sugars': 1,
#  'creamers': 1,
#  'splendas': 1,
#  'kitchen': 1,
#  'frozen lemonade': 1,
#  'lady': 1,
#  'burger': 1,
#  'time management': 1,
#  'work': 1,
#  'manors': 1,
#  'teamwork': 1}

# %%
classify_words = {
  "Food and Drinks": [
    "food",
    "fast food",
    "sandwich",
    "crispy chicken sandwich",
    "fry",
    "meal",
    "filet of fish",
    "cooky",
    "hamburg",
    "tea",
    "sweet",
    "coffee",
    "chicken mcnuggets",
    "sauce",
    "chicken",
    "food items",
    "sausage",
    "egg",
    "syrup",
    "butter",
    "breakfast with hot cakes",
    "food burger",
    "drink cups",
    "chicken sandwich",
    "cookie",
    "apples strawberries",
    "bag of food",
    "water",
    "strawberry banana smoothies",
    "smoothie",
    "hash brownsies",
    "ice cream",
    "caramel mocha",
    "pickles",
    "spicy chicken sandwich",
    "chicken sandwiches",
    "spicey chicken sandwiches",
    "lettuce and tomato",
    "menu",
    "lunch",
    "breakfast",
    "cream",
    "ice",
    "baked beans",
    "coke",
    "nuggets",
    "cheese",
    "meat",
    "buns",
    "burgers",
    "cheeseburgers",
    "frozen lemonade",
    "burger"
  ],
  "Staff": [
    "staff",
    "manager",
    "night crew",
    "morning crew",
    "morning staff",
    "evening staff",
    "supervisor",
    "employee",
    "shift manager",
    "representative",
    "worker",
    "attendant",
    "kitchen staff",
    "crew"
  ],
  "Service and Customer Experience": [
    "atmosphere",
    "service",
    "customer",
    "customer service",
    "order taker",
    "cashier",
    "serving",
    "drive thru line",
    "time management",
    "teamwork",
    "manors"
  ],
  "Utensils and Accessories": [
    "utensils",
    "condiments",
    "fry containers",
    "hamburger wrapper",
    "carton",
    "sugars",
    "creamers",
    "splendas"
  ],
  "Physical Environment": [
    "door",
    "table",
    "appearance",
    "bathroom",
    "lobby",
    "area",
    "place",
    "entrance",
    "heat lamp",
    "food window",
    "kitchen"
  ],
  "Miscellaneous": [
    "money",
    "card",
    "order",
    "general",
    "deluxe",
    "br",
    "google",
    "uber",
    "price",
    "price range",
    "messed",
    "extra",
    "staffed",
    "management",
    "dish soap",
    "robot",
    "work"
  ]
}

# %%
pd.DataFrame.from_dict(classify_words, 'index')
# Out:
#                                          0           1               2   \
# Food and Drinks                        food   fast food        sandwich
# Staff                                 staff     manager      night crew
# Service and Customer Experience  atmosphere     service        customer
# Utensils and Accessories           utensils  condiments  fry containers
# Physical Environment                   door       table      appearance
# Miscellaneous                         money        card           order
#
#                                                       3              4   \
# Food and Drinks                  crispy chicken sandwich            fry
# Staff                                       morning crew  morning staff
# Service and Customer Experience         customer service    order taker
# Utensils and Accessories               hamburger wrapper         carton
# Physical Environment                            bathroom          lobby
# Miscellaneous                                    general         deluxe
#
#                                             5              6   \
# Food and Drinks                           meal  filet of fish
# Staff                            evening staff     supervisor
# Service and Customer Experience        cashier        serving
# Utensils and Accessories                sugars       creamers
# Physical Environment                      area          place
# Miscellaneous                               br         google
#
#                                               7                8   \
# Food and Drinks                            cooky          hamburg
# Staff                                   employee    shift manager
# Service and Customer Experience  drive thru line  time management
# Utensils and Accessories                splendas             None
# Physical Environment                    entrance        heat lamp
# Miscellaneous                               uber            price
#
#                                              9   ...           43    44  \
# Food and Drinks                             tea  ...  baked beans  coke
# Staff                            representative  ...         None  None
# Service and Customer Experience        teamwork  ...         None  None
# Utensils and Accessories                   None  ...         None  None
# Physical Environment                food window  ...         None  None
# Miscellaneous                       price range  ...         None  None
#
#                                       45      46    47    48       49  \
# Food and Drinks                  nuggets  cheese  meat  buns  burgers
# Staff                               None    None  None  None     None
# Service and Customer Experience     None    None  None  None     None
# Utensils and Accessories            None    None  None  None     None
# Physical Environment                None    None  None  None     None
# Miscellaneous                       None    None  None  None     None
#
#                                             50               51      52
# Food and Drinks                  cheeseburgers  frozen lemonade  burger
# Staff                                     None             None    None
# Service and Customer Experience           None             None    None
# Utensils and Accessories                  None             None    None
# Physical Environment                      None             None    None
# Miscellaneous                             None             None    None
#
# [6 rows x 53 columns]

# %%
def get_key(dictionary, value):
    for k, v in dictionary.items():
        if value in v:
            return k
    return 'Miscellaneous'

# %%
data = {k: "" for k, _ in classify_words.items()}
data
# Out:
# {'Food and Drinks': '',
#  'Staff': '',
#  'Service and Customer Experience': '',
#  'Utensils and Accessories': '',
#  'Physical Environment': '',
#  'Miscellaneous': ''}

# %%
data = {k: {'positive': '', 'negative': '', 'neutral': ''} for k, _ in classify_words.items()}

for items in df['aspect_sentiment'].values:
    for item in items:
        print(item)
        if len(item) == 0:
            continue
        term = item.get('term')
        context = item.get('context')
        sentiment = item.get('class')
        if len(context) > 0:
            context = context[0]
            class_ = get_key(classify_words, term)
            if context not in data[class_][sentiment]:
                data[class_][sentiment] = data[class_][sentiment] + context + "\n"

data

# %%
data = {k: "" for k, _ in classify_words.items()}

for items in df['aspect_sentiment'].values:
    for item in items:
        if len(item) == 0:
            continue
        term = item.get('term')
        context = item.get('context')
        if len(context) > 0:
            context = context[0]
            class_ = get_key(classify_words, term)
            if context not in data[class_]:
                data[class_] = data[class_] + "- " + context + "\n"

pd.DataFrame.from_dict(data, 'index', columns=['context']).T
# Out:
#                                            Food and Drinks  \
# context  - I had a normal transaction, everyone was cal...
#
#                                                      Staff  \
# context  - The staff at McDonald's are friendly, accomm...
#
#                            Service and Customer Experience  \
# context  - The staff at McDonald's are friendly, accomm...
#
#                                   Utensils and Accessories  \
# context  - I was disappointed that the restaurant did n...
#
#                                       Physical Environment  \
# context  - I work for door dash and they locked us all ...
#
#                                              Miscellaneous
# context  - I had a normal transaction, everyone was cal...

# %% [markdown]
# PROMPT SUMMARIZE FORMAT:
#
# Descriptive sentiment summary with bullet point format: <text>
