# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from tqdm import tqdm

# %%
import util.normalization as norm
import util.model as models
import util.utility as util

# %%
df = pd.read_csv('./sample-mcd.csv', encoding='latin1')
df = df[['reviewer_id', 'review_time', 'review', 'rating']]

df['rating'] = df['rating'].apply(lambda x: int(x.split(" ")[0]))

print(df.info())
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   reviewer_id  100 non-null    int64
#  1   review_time  100 non-null    object
#  2   review       100 non-null    object
#  3   rating       100 non-null    int64
# dtypes: int64(2), object(2)
# memory usage: 3.3+ KB
# None
#    reviewer_id   review_time  \
# 0            1  3 months ago
# 1            2    5 days ago
# 2            3    5 days ago
# 3            4   a month ago
# 4            5  2 months ago
#
#                                               review  rating
# 0  Why does it look like someone spit on my food?...       1
# 1  It'd McDonalds. It is what it is as far as the...       4
# 2  Made a mobile order got to the speaker and che...       1
# 3  My mc. Crispy chicken sandwich was ÃÂ¯ÃÂ¿ÃÂ...       5
# 4  I repeat my order 3 times in the drive thru, a...       1

# %% [markdown]
# # Normalization

# %%
df_sm = df[['reviewer_id', 'review']].copy()

# Remove non-ASCII
df_sm['review_clean'] = df_sm['review'].apply(norm.remove_non_ascii)

# Expand contractions
df_sm['review_clean'] = df_sm['review_clean'].apply(norm.expand_contractions)

# Remove characters
df_sm['review_clean'] = df_sm['review_clean'].apply(norm.remove_characters, args=(True, ))

# %%
df_sm.head()
# Out:
#    reviewer_id                                             review  \
# 0            1  Why does it look like someone spit on my food?...
# 1            2  It'd McDonalds. It is what it is as far as the...
# 2            3  Made a mobile order got to the speaker and che...
# 3            4  My mc. Crispy chicken sandwich was ÃÂ¯ÃÂ¿ÃÂ...
# 4            5  I repeat my order 3 times in the drive thru, a...
#
#                                         review_clean
# 0  Why does it look like someone spit on my food\...
# 1  It would McDonalds. It is what it is as far as...
# 2  Made a mobile order got to the speaker and che...
# 3  My mc. Crispy chicken sandwich was  customer s...
# 4  I repeat my order 3 times in the drive thru, a...

# %%
from transformers import pipeline

classifier = pipeline("summarization")
# Out:
# No model was supplied, defaulted to sshleifer/distilbart-cnn-12-6 (https://huggingface.co/sshleifer/distilbart-cnn-12-6)
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
def get_summarize(text, min_length=25, max_length=68):
    result = classifier(text, min_length=min_length, max_length=max_length)
    return result[0]['summary_text']

# %%
tqdm.pandas()
df_sm['summarize'] = df_sm['review_clean'].progress_apply(get_summarize)
print(df_sm.info())
df_sm.head()
# Out:
#   0%|                                                                                          | 0/100 [00:00<?, ?it/s]Your max_length is set to 68, but you input_length is only 63. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=31)
#   2%|█▋                                                                                | 2/100 [00:06<05:23,  3.30s/it]Your max_length is set to 68, but you input_length is only 52. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=26)
#   4%|███▎                                                                              | 4/100 [00:16<07:15,  4.54s/it]Your max_length is set to 68, but you input_length is only 17. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=8)
#   6%|████▉                                                                             | 6/100 [00:26<07:47,  4.97s/it]Your max_length is set to 68, but you input_length is only 51. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=25)
#   9%|███████▍                                                                          | 9/100 [00:43<08:03,  5.31s/it]Your max_length is set to 68, but you input_length is only 44. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=22)
#  11%|████████▉                                                                        | 11/100 [00:51<07:04,  4.77s/it]Your max_length is set to 68, but you input_length is only 4. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=2)
#  15%|████████████▏                                                                    | 15/100 [01:09<06:36,  4.66s/it]Your max_length is set to 68, but you input_length is only 44. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=22)
#  16%|████████████▉                                                                    | 16/100 [01:14<07:01,  5.02s/it]Your max_length is set to 68, but you input_length is only 32. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=16)
#  18%|██████████████▌                                                                  | 18/100 [01:24<06:51,  5.02s/it]Your max_length is set to 68, but you input_length is only 35. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=17)
#  20%|████████████████▏                                                                | 20/100 [01:34<06:53,  5.17s/it]Your max_length is set to 68, but you input_length is only 45. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=22)
#  23%|██████████████████▋                                                              | 23/100 [01:51<07:09,  5.58s/it]Your max_length is set to 68, but you input_length is only 24. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=12)
#  24%|███████████████████▍                                                             | 24/100 [01:54<06:02,  4.77s/it]Your max_length is set to 68, but you input_length is only 64. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=32)
#  25%|████████████████████▎                                                            | 25/100 [01:57<05:23,  4.32s/it]Your max_length is set to 68, but you input_length is only 9. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=4)
#  26%|█████████████████████                                                            | 26/100 [01:59<04:34,  3.70s/it]Your max_length is set to 68, but you input_length is only 34. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=17)
#  27%|█████████████████████▊                                                           | 27/100 [02:02<04:04,  3.35s/it]Your max_length is set to 68, but you input_length is only 14. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=7)
#  28%|██████████████████████▋                                                          | 28/100 [02:04<03:39,  3.05s/it]Your max_length is set to 68, but you input_length is only 3. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=1)
#  29%|███████████████████████▍                                                         | 29/100 [02:08<03:46,  3.20s/it]Your max_length is set to 68, but you input_length is only 25. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=12)
#  30%|████████████████████████▎                                                        | 30/100 [02:10<03:25,  2.94s/it]Your max_length is set to 68, but you input_length is only 37. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=18)
#  31%|█████████████████████████                                                        | 31/100 [02:13<03:21,  2.91s/it]Your max_length is set to 68, but you input_length is only 37. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=18)
#  33%|██████████████████████████▋                                                      | 33/100 [02:20<03:36,  3.24s/it]Your max_length is set to 68, but you input_length is only 16. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=8)
#  35%|████████████████████████████▎                                                    | 35/100 [02:27<03:53,  3.58s/it]Your max_length is set to 68, but you input_length is only 30. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=15)
#  36%|█████████████████████████████▏                                                   | 36/100 [02:30<03:36,  3.38s/it]Your max_length is set to 68, but you input_length is only 53. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=26)
#  37%|█████████████████████████████▉                                                   | 37/100 [02:35<03:51,  3.68s/it]Your max_length is set to 68, but you input_length is only 10. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=5)
#  38%|██████████████████████████████▊                                                  | 38/100 [02:37<03:26,  3.33s/it]Your max_length is set to 68, but you input_length is only 13. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=6)
#  39%|███████████████████████████████▌                                                 | 39/100 [02:39<02:59,  2.94s/it]Your max_length is set to 68, but you input_length is only 11. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=5)
#  41%|█████████████████████████████████▏                                               | 41/100 [02:44<02:49,  2.87s/it]Your max_length is set to 68, but you input_length is only 27. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=13)
#  43%|██████████████████████████████████▊                                              | 43/100 [02:53<03:25,  3.60s/it]Your max_length is set to 68, but you input_length is only 48. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=24)
#  44%|███████████████████████████████████▋                                             | 44/100 [02:57<03:23,  3.64s/it]Your max_length is set to 68, but you input_length is only 33. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=16)
#  45%|████████████████████████████████████▍                                            | 45/100 [02:58<02:48,  3.07s/it]Your max_length is set to 68, but you input_length is only 21. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=10)
#  47%|██████████████████████████████████████                                           | 47/100 [03:03<02:18,  2.62s/it]Your max_length is set to 68, but you input_length is only 19. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=9)
#  49%|███████████████████████████████████████▋                                         | 49/100 [03:10<02:40,  3.14s/it]Your max_length is set to 68, but you input_length is only 66. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=33)
#  51%|█████████████████████████████████████████▎                                       | 51/100 [03:20<03:17,  4.02s/it]Your max_length is set to 68, but you input_length is only 41. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=20)
#  52%|██████████████████████████████████████████                                       | 52/100 [03:22<02:48,  3.50s/it]Your max_length is set to 68, but you input_length is only 62. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=31)
#  53%|██████████████████████████████████████████▉                                      | 53/100 [03:27<03:03,  3.90s/it]Your max_length is set to 68, but you input_length is only 43. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=21)
#  54%|███████████████████████████████████████████▋                                     | 54/100 [03:30<02:53,  3.76s/it]Your max_length is set to 68, but you input_length is only 52. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=26)
#  55%|████████████████████████████████████████████▌                                    | 55/100 [03:34<02:53,  3.86s/it]Your max_length is set to 68, but you input_length is only 18. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=9)
#  56%|█████████████████████████████████████████████▎                                   | 56/100 [03:36<02:28,  3.38s/it]Your max_length is set to 68, but you input_length is only 9. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=4)
#  60%|████████████████████████████████████████████████▌                                | 60/100 [03:51<02:31,  3.80s/it]Your max_length is set to 68, but you input_length is only 18. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=9)
#  62%|██████████████████████████████████████████████████▏                              | 62/100 [04:00<02:36,  4.12s/it]Your max_length is set to 68, but you input_length is only 60. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=30)
#  64%|███████████████████████████████████████████████████▊                             | 64/100 [04:08<02:34,  4.30s/it]Your max_length is set to 68, but you input_length is only 45. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=22)
#  65%|████████████████████████████████████████████████████▋                            | 65/100 [04:12<02:27,  4.23s/it]Your max_length is set to 68, but you input_length is only 52. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=26)
#  67%|██████████████████████████████████████████████████████▎                          | 67/100 [04:19<01:59,  3.63s/it]Your max_length is set to 68, but you input_length is only 5. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=2)
#  70%|████████████████████████████████████████████████████████▋                        | 70/100 [04:28<01:42,  3.43s/it]Your max_length is set to 68, but you input_length is only 67. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=33)
#  72%|██████████████████████████████████████████████████████████▎                      | 72/100 [04:37<01:52,  4.01s/it]Your max_length is set to 68, but you input_length is only 59. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=29)
#  75%|████████████████████████████████████████████████████████████▊                    | 75/100 [04:48<01:35,  3.82s/it]Your max_length is set to 68, but you input_length is only 64. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=32)
#  77%|██████████████████████████████████████████████████████████████▎                  | 77/100 [04:56<01:26,  3.74s/it]Your max_length is set to 68, but you input_length is only 42. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=21)
#  78%|███████████████████████████████████████████████████████████████▏                 | 78/100 [04:59<01:16,  3.48s/it]Your max_length is set to 68, but you input_length is only 24. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=12)
#  79%|███████████████████████████████████████████████████████████████▉                 | 79/100 [05:01<01:07,  3.23s/it]Your max_length is set to 68, but you input_length is only 25. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=12)
#  80%|████████████████████████████████████████████████████████████████▊                | 80/100 [05:04<00:58,  2.95s/it]Your max_length is set to 68, but you input_length is only 26. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=13)
#  82%|██████████████████████████████████████████████████████████████████▍              | 82/100 [05:09<00:54,  3.01s/it]Your max_length is set to 68, but you input_length is only 53. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=26)
#  83%|███████████████████████████████████████████████████████████████████▏             | 83/100 [05:13<00:53,  3.15s/it]Your max_length is set to 68, but you input_length is only 66. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=33)
#  85%|████████████████████████████████████████████████████████████████████▊            | 85/100 [05:19<00:46,  3.12s/it]Your max_length is set to 68, but you input_length is only 36. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=18)
#  87%|██████████████████████████████████████████████████████████████████████▍          | 87/100 [05:26<00:43,  3.36s/it]Your max_length is set to 68, but you input_length is only 33. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=16)
#  88%|███████████████████████████████████████████████████████████████████████▎         | 88/100 [05:29<00:38,  3.21s/it]Your max_length is set to 68, but you input_length is only 44. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=22)
#  98%|███████████████████████████████████████████████████████████████████████████████▍ | 98/100 [06:07<00:07,  3.87s/it]Your max_length is set to 68, but you input_length is only 32. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=16)
#  99%|████████████████████████████████████████████████████████████████████████████████▏| 99/100 [06:10<00:03,  3.53s/it]Your max_length is set to 68, but you input_length is only 16. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=8)
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [06:12<00:00,  3.13s/it]Your max_length is set to 68, but you input_length is only 55. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=27)
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [06:15<00:00,  3.76s/it]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   reviewer_id   100 non-null    int64
#  1   review        100 non-null    object
#  2   review_clean  100 non-null    object
#  3   summarize     100 non-null    object
# dtypes: int64(1), object(3)
# memory usage: 3.3+ KB
# None
#    reviewer_id                                             review  \
# 0            1  Why does it look like someone spit on my food?...
# 1            2  It'd McDonalds. It is what it is as far as the...
# 2            3  Made a mobile order got to the speaker and che...
# 3            4  My mc. Crispy chicken sandwich was ÃÂ¯ÃÂ¿ÃÂ...
# 4            5  I repeat my order 3 times in the drive thru, a...
#
#                                         review_clean  \
# 0  Why does it look like someone spit on my food\...
# 1  It would McDonalds. It is what it is as far as...
# 2  Made a mobile order got to the speaker and che...
# 3  My mc. Crispy chicken sandwich was  customer s...
# 4  I repeat my order 3 times in the drive thru, a...
#
#                                            summarize
# 0   Why does it look like someone spit on my food...
# 1   The staff at McDonalds are always friendly an...
# 2   Never got the refund in the app. Made a mobil...
# 3   My mc. Crispy chicken sandwich was  customer ...
# 4   I repeat my order 3 times in the drive thru, ...

# %%
# Sentence Tokenization
df_st = df_sm.copy()
df_st['token_sentence'] = df_st['summarize'].apply(norm.sentence_tokenize)
df_st = df_st.explode('token_sentence')
df_st['token_sentence'] = df_st['token_sentence'].str.strip()

# Remove characters
df_st['token_sentence'] = df_st['token_sentence'].apply(norm.remove_characters, args=(True, ))

# Lower text
# df_st['token_sentence'] = df_st['token_sentence'].apply(lambda x: x.lower())

# Lemmatization
df_st['token_lemma'] = df_st['token_sentence'].apply(norm.lemmatize_text)

# %% [markdown]
# # Get Aspect and Applied Sentiment Analysis (Rules Based)

# %%
# Get aspect from rules
tqdm.pandas()
df_st['aspect'] = df_st['token_lemma']\
                        .progress_apply(util.get_aspect_rules)

print(df_st.info())
df_st.head()
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 385/385 [00:16<00:00, 23.55it/s]
# <class 'pandas.core.frame.DataFrame'>
# Index: 385 entries, 0 to 99
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   reviewer_id     385 non-null    int64
#  1   review          385 non-null    object
#  2   review_clean    385 non-null    object
#  3   summarize       385 non-null    object
#  4   token_sentence  385 non-null    object
#  5   token_lemma     385 non-null    object
#  6   aspect          385 non-null    object
# dtypes: int64(1), object(6)
# memory usage: 24.1+ KB
# None
#    reviewer_id                                             review  \
# 0            1  Why does it look like someone spit on my food?...
# 0            1  Why does it look like someone spit on my food?...
# 0            1  Why does it look like someone spit on my food?...
# 0            1  Why does it look like someone spit on my food?...
# 0            1  Why does it look like someone spit on my food?...
#
#                                         review_clean  \
# 0  Why does it look like someone spit on my food\...
# 0  Why does it look like someone spit on my food\...
# 0  Why does it look like someone spit on my food\...
# 0  Why does it look like someone spit on my food\...
# 0  Why does it look like someone spit on my food\...
#
#                                            summarize  \
# 0   Why does it look like someone spit on my food...
# 0   Why does it look like someone spit on my food...
# 0   Why does it look like someone spit on my food...
# 0   Why does it look like someone spit on my food...
# 0   Why does it look like someone spit on my food...
#
#                                       token_sentence  \
# 0      Why does it look like someone spit on my food
# 0                         I had a normal transaction
# 0                      everyone was chill and polite
# 0                  but now i dont want to eat this .
# 0  Im trying not to think about what this milky w...
#
#                                          token_lemma                aspect
# 0        why do it look like someone spit on my food        {someone spit}
# 0                        i have a normal transaction  {normal transaction}
# 0                       everyone be chill and polite            {everyone}
# 0                  but now i dont want to eat this .                    {}
# 0  im try not to think about what this milky whit...     {clear substance}

# %%
df_st
# Out:
#     reviewer_id                                             review  \
# 0             1  Why does it look like someone spit on my food?...
# 0             1  Why does it look like someone spit on my food?...
# 0             1  Why does it look like someone spit on my food?...
# 0             1  Why does it look like someone spit on my food?...
# 0             1  Why does it look like someone spit on my food?...
# ..          ...                                                ...
# 98           99  Allways has the best Fries and Ice cream in th...
# 99          100  Mcdonalds is great but they really need to hir...
# 99          100  Mcdonalds is great but they really need to hir...
# 99          100  Mcdonalds is great but they really need to hir...
# 99          100  Mcdonalds is great but they really need to hir...
#
#                                          review_clean  \
# 0   Why does it look like someone spit on my food\...
# 0   Why does it look like someone spit on my food\...
# 0   Why does it look like someone spit on my food\...
# 0   Why does it look like someone spit on my food\...
# 0   Why does it look like someone spit on my food\...
# ..                                                ...
# 98  Allways has the best Fries and Ice cream in th...
# 99  Mcdonalds is great but they really need to hir...
# 99  Mcdonalds is great but they really need to hir...
# 99  Mcdonalds is great but they really need to hir...
# 99  Mcdonalds is great but they really need to hir...
#
#                                             summarize  \
# 0    Why does it look like someone spit on my food...
# 0    Why does it look like someone spit on my food...
# 0    Why does it look like someone spit on my food...
# 0    Why does it look like someone spit on my food...
# 0    Why does it look like someone spit on my food...
# ..                                                ...
# 98   Allways has the best Fries and Ice cream in t...
# 99   Mcdonalds is great but they really need to hi...
# 99   Mcdonalds is great but they really need to hi...
# 99   Mcdonalds is great but they really need to hi...
# 99   Mcdonalds is great but they really need to hi...
#
#                                        token_sentence  \
# 0       Why does it look like someone spit on my food
# 0                          I had a normal transaction
# 0                       everyone was chill and polite
# 0                   but now i dont want to eat this .
# 0   Im trying not to think about what this milky w...
# ..                                                ...
# 98  Allways also has the world's best fries and ic...
# 99                                 Mcdonalds is great
# 99  they really need to hire people who understand...
# 99                         The people are really nice
# 99  be smarter about who you put in the drive thru...
#
#                                           token_lemma  \
# 0         why do it look like someone spit on my food
# 0                         i have a normal transaction
# 0                        everyone be chill and polite
# 0                   but now i dont want to eat this .
# 0   im try not to think about what this milky whit...
# ..                                                ...
# 98  allways also have the world 's best fry and ic...
# 99                                 mcdonalds be great
# 99  they really need to hire people who understand...
# 99                          the people be really nice
# 99  be smarter about who you put in the drive thru...
#
#                             aspect pattern_prediction
# 0                   {someone spit}           negative
# 0             {normal transaction}           positive
# 0                       {everyone}           negative
# 0                               {}           negative
# 0                {clear substance}           negative
# ..                             ...                ...
# 98  {allways, best fry, ice cream}           positive
# 99                     {mcdonalds}           positive
# 99               {english, people}           negative
# 99                        {people}           positive
# 99                         {order}           negative
#
# [385 rows x 8 columns]

# %%
mask = df_st['aspect'].apply(lambda x: False if len(x) == 0 else True).values

temp = df_st[mask].groupby(['reviewer_id'])\
                .agg({'token_sentence': lambda x: '.\n'.join(x),
                      'token_lemma': lambda x: '.\n'.join(x)})\
                .reset_index()

df_prc = df_st.groupby(['reviewer_id'])\
                .agg({'aspect': lambda x: set().union(*x),})\
                .reset_index()

df_prc = df_prc.merge(temp, on='reviewer_id', how='left').fillna("")

df_prc = df_sm.merge(df_prc, on='reviewer_id', how='left')
print(df_prc.info())
df_prc.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   reviewer_id     100 non-null    int64
#  1   review          100 non-null    object
#  2   review_clean    100 non-null    object
#  3   summarize       100 non-null    object
#  4   aspect          100 non-null    object
#  5   token_sentence  100 non-null    object
#  6   token_lemma     100 non-null    object
# dtypes: int64(1), object(6)
# memory usage: 5.6+ KB
# None
#    reviewer_id                                             review  \
# 0            1  Why does it look like someone spit on my food?...
# 1            2  It'd McDonalds. It is what it is as far as the...
# 2            3  Made a mobile order got to the speaker and che...
# 3            4  My mc. Crispy chicken sandwich was ÃÂ¯ÃÂ¿ÃÂ...
# 4            5  I repeat my order 3 times in the drive thru, a...
#
#                                         review_clean  \
# 0  Why does it look like someone spit on my food\...
# 1  It would McDonalds. It is what it is as far as...
# 2  Made a mobile order got to the speaker and che...
# 3  My mc. Crispy chicken sandwich was  customer s...
# 4  I repeat my order 3 times in the drive thru, a...
#
#                                            summarize  \
# 0   Why does it look like someone spit on my food...
# 1   The staff at McDonalds are always friendly an...
# 2   Never got the refund in the app. Made a mobil...
# 3   My mc. Crispy chicken sandwich was  customer ...
# 4   I repeat my order 3 times in the drive thru, ...
#
#                                               aspect  \
# 0  {everyone, clear substance, someone spit, norm...
# 1               {food, mcdonalds, atmosphere, staff}
# 2                {refund, line, mobile order, money}
# 3  {chicken sandwich, customer service, customer,...
# 4  {double filet, large meal, large fry, order, e...
#
#                                       token_sentence  \
# 0  Why does it look like someone spit on my food....
# 1  The staff at McDonalds are always friendly and...
# 2  Never got the refund in the app..\nMade a mobi...
# 3  Crispy chicken sandwich was  customer service ...
# 4  I repeat my order 3 times in the drive thru.\n...
#
#                                          token_lemma
# 0  why do it look like someone spit on my food.\n...
# 1  the staff at mcdonalds be always friendly and ...
# 2  never get the refund in the app ..\nmake a mob...
# 3  crispy chicken sandwich be customer service be...
# 4  i repeat my order 3 time in the drive thru.\ni...

# %%
df_prc['token_sentence'].iloc[0]
# Out:
# 'Why does it look like someone spit on my food.\nI had a normal transaction.\neveryone was chill and polite.\nIm trying not to think about what this milky white/clear substance is all over my food'

# %%
df_prc['summarize'].iloc[0]
# Out:
# ' Why does it look like someone spit on my food? I had a normal transaction,  everyone was chill and polite, but now i dont want to eat this . Im trying not to think about what this milky white/clear substance is all over my food, i d sure am not coming back .'

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

text = ""
sub_aspect = df_prc['aspect'].values
for i in range(df_prc.shape[0]):
    text = text + " " + " ".join(list(sub_aspect[i]))
    

text = text.strip()

wordcloud = WordCloud(background_color='white').generate(text)
plt.style.use('classic')
plt.figure(figsize=(12,10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# # Get Topic

# %%
# def get_optimum_lda(dictionary, corpus, texts, limit,
#                     start=2, step=1, get_result=False,
#                     iterations=20, passes=1):
#     coherence_values = []
    
#     for n in range(start, limit, step):
#         lda = gensim.models.LdaMulticore(corpus=corpus,
#                                          num_topics=n,
#                                          id2word=dictionary,
#                                          iterations=iterations,
#                                          passes=passes)
        
#         # Create coherence
#         coherence_model = CoherenceModel(model=lda, 
#                                          texts=texts,
#                                          dictionary=dictionary, 
#                                          coherence='c_v')
#         coherence_values.append(coherence_model.get_coherence())
    
    
#     opt_num_topics = start + coherence_values.index(max(coherence_values))
    
#     lda_opt = gensim.models.LdaMulticore(corpus=corpus,
#                                          num_topics=opt_num_topics,
#                                          id2word=dictionary)
    
#     if get_result:
#         print(coherence_values)
    
#     return lda_opt

# %%
# import gensim
# from gensim.models import CoherenceModel


# texts = df_prc['summarize'].apply(util.preprocess_lda)
# # texts = df_prc['sub_aspect'].apply(lambda x: ', '.join(list(x))).apply(util.preprocess_lda)

# dictionary = gensim.corpora.Dictionary(texts)

# dictionary.filter_extremes(no_below=15, no_above=0.5, keep_n=100_000)
# bow_corpus = [dictionary.doc2bow(doc) for doc in texts]

# lda_opt = get_optimum_lda(dictionary, bow_corpus,
#                           texts, 10, get_result=True,
#                           passes=75, iterations=150)

# %%
# # Print topic
# for idx, topic in lda_opt.print_topics(-1):
#     print('Topic: {} \nWords: {}'.format(idx, topic))

# %%
# def predict_topic(text):
#     text = util.preprocess_lda(text)
#     bow_vector = dictionary.doc2bow(text)
    
#     result = sorted(lda_opt[bow_vector], 
#                     key=lambda x: -1*x[1])[0][0]
    
#     return result
    
# # Extract keywords into a dictionary or list
# threshold = 0.05
# topics_dict = {}
# for topic_num, topic in lda_opt.show_topics(num_topics=10,
#                                                 num_words=10,
#                                                 formatted=False):
#     keywords = [word for word, w in topic if w > threshold]
#     topics_dict[topic_num] = keywords

# %%
# topics_dict

# %%
# tqdm.pandas()
# df_prc['topic'] = df_prc['summarize'].progress_apply(predict_topic)

# %%
# tqdm.pandas()
# df_prc['topic_keys'] = df_prc['topic'].progress_apply(lambda x: topics_dict[x])

# %%
# df_prc

# %% [markdown]
# # Save Result

# %%
# result = df_prc[['reviewer_id', 'review', 'summarize', 'aspect', 'topic_sentence', 'rating']].copy()
result = df_prc.drop('review_clean', axis=1).copy()
result = result.merge(df[['reviewer_id','rating']],
                      on='reviewer_id',
                      how='left')

result['aspect'] = result['aspect'].apply(lambda x: ', '.join(list(x)))
# result['sub_aspect'] = result['sub_aspect'].apply(lambda x: list(x))
# result['topic_keys'] = result['topic_keys'].apply(lambda x: ', '.join(x))

result.to_csv("./mcd_result/base_mcd.csv", index=False)
