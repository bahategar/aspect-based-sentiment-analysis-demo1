# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import re
import json

from tqdm import tqdm

# %%
import nltk
from nltk.corpus import stopwords

import spacy
import gensim

# %% [markdown]
# # Load Model

# %%
# Load nlp model
nlp = spacy.load('en_core_web_sm')

# %% [markdown]
# # Load Dataset

# %%
with open("temp-2.json", "r") as file:
    data = json.load(file)

data
# Out:
# {'0': {'reviewer_id': 1,
#   'review_time': '2024-09-04',
#   'rating': 1,
#   'review_processed': "I had a normal transaction, everyone was calm and polite, but now I don't want to eat this. I'm trying not to think about what this milky white/clear substance is all over my food, and I'm sure I'm not coming back.",
#   'aspect_sentiment': [{'term': 'food',
#     'class': 'negative',
#     'probability': [0.9815933108329773,
#      0.015454968437552452,
#      0.002951699076220393],
#     'context': ["I'm trying not to think about what this milky white/clear substance is all over my food, and I'm sure I'm not coming back."]},
#    {'term': 'substance',
#     'class': 'negative',
#     'probability': [0.5997273921966553,
#      0.004296493716537952,
#      0.39597612619400024],
#     'context': ["I'm trying not to think about what this milky white/clear substance is all over my food, and I'm sure I'm not coming back."]}],
#   'sentiment': 'negative'},
#  '1': {'reviewer_id': 2,
#   'review_time': '2024-11-29',
#   'rating': 4,
#   'review_processed': "The staff at McDonald's are friendly, accommodating and always smiling. It is what it is as far as the food and atmosphere go; it's what it's always been. It makes for a more pleasant experience than many other fast food places in the area.",
#   'aspect_sentiment': [{'term': 'fast food',
#     'class': 'postive',
#     'probability': [0.006815647706389427,
#      0.03166038542985916,
#      0.9615239500999451],
#     'context': ['It makes for a more pleasant experience than many other fast food places in the area.']},
#    {'term': 'atmosphere',
#     'class': 'postive',
#     'probability': [0.0012359353713691235,
#      0.0019914235454052687,
#      0.9967727065086365],
#     'context': ["It is what it is as far as the food and atmosphere go; it's what it's always been."]},
#    {'term': 'food',
#     'class': 'postive',
#     'probability': [0.002793692983686924,
#      0.004679643549025059,
#      0.992526650428772],
#     'context': ["It is what it is as far as the food and atmosphere go; it's what it's always been.",
#      'It makes for a more pleasant experience than many other fast food places in the area.']},
#    {'term': 'staff',
#     'class': 'postive',
#     'probability': [0.00021674683375749737,
#      0.0003625940880738199,
#      0.9994207620620728],
#     'context': ["The staff at McDonald's are friendly, accommodating and always smiling."]}],
#   'sentiment': 'positive'},
#  '2': {'reviewer_id': 3,
#   'review_time': '2024-11-29',
#   'rating': 1,
#   'review_processed': 'I made a mobile order got to the speaker and checked it in, but the line was not moving, so I had to leave. I never got the refund in the app. I called them and they said I could only get my money back in person because it was stuck in the system.',
#   'aspect_sentiment': [{'term': 'speaker',
#     'class': 'neutral',
#     'probability': [0.33699119091033936,
#      0.65718674659729,
#      0.005822065286338329],
#     'context': ['I made a mobile order got to the speaker and checked it in, but the line was not moving, so I had to leave.']}],
#   'sentiment': 'negative'},
#  '3': {'reviewer_id': 4,
#   'review_time': '2024-11-04',
#   'rating': 5,
#   'review_processed': "Crispy chicken sandwich was delicious, and customer service was quick and efficient. My mc. was correct: My sandwich was crisp, but the service was fast and friendly. 'My mc. is correct': My sandwich is delicious, but my customer service is fast, friendly, and professional.",
#   'aspect_sentiment': [{'term': 'sandwich',
#     'class': 'postive',
#     'probability': [0.11512675136327744,
#      0.007394721265882254,
#      0.8774785399436951],
#     'context': ['Crispy chicken sandwich was delicious, and customer service was quick and efficient.',
#      'was correct: My sandwich was crisp, but the service was fast and friendly.',
#      "is correct': My sandwich is delicious, but my customer service is fast, friendly, and professional."]},
#    {'term': 'service',
#     'class': 'postive',
#     'probability': [0.06365323811769485,
#      0.0026424317620694637,
#      0.9337043166160583],
#     'context': ['Crispy chicken sandwich was delicious, and customer service was quick and efficient.',
#      'was correct: My sandwich was crisp, but the service was fast and friendly.',
#      "is correct': My sandwich is delicious, but my customer service is fast, friendly, and professional."]},
#    {'term': 'customer',
#     'class': 'postive',
#     'probability': [0.0929778441786766,
#      0.00539865018799901,
#      0.901623547077179],
#     'context': ['Crispy chicken sandwich was delicious, and customer service was quick and efficient.',
#      "is correct': My sandwich is delicious, but my customer service is fast, friendly, and professional."]},
#    {'term': 'crispy chicken sandwich',
#     'class': 'postive',
#     'probability': [0.04437816143035889,
#      0.002110624685883522,
#      0.9535112977027893],
#     'context': ['Crispy chicken sandwich was delicious, and customer service was quick and efficient.']}],
#   'sentiment': 'positive'},
#  '4': {'reviewer_id': 5,
#   'review_time': '2024-10-04',
#   'rating': 1,
#   'review_processed': 'I repeat my order three times in the drive thru, and she still manages to mess it up. It was suppose to be a large meal double filet of fish with large fries, but it was all wrong. They either need to pay close attention to the order being made, or they need not to work at a drive thru.',
#   'aspect_sentiment': [{'term': 'fries',
#     'class': 'negative',
#     'probability': [0.8274237513542175,
#      0.03699015825986862,
#      0.13558609783649445],
#     'context': ['It was suppose to be a large meal double filet of fish with large fries, but it was all wrong.']},
#    {'term': 'filet of fish',
#     'class': 'neutral',
#     'probability': [0.3450517952442169,
#      0.6001273989677429,
#      0.05482081323862076],
#     'context': ['It was suppose to be a large meal double filet of fish with large fries, but it was all wrong.']},
#    {'term': 'meal',
#     'class': 'negative',
#     'probability': [0.5714789628982544,
#      0.3977477252483368,
#      0.03077329508960247],
#     'context': ['It was suppose to be a large meal double filet of fish with large fries, but it was all wrong.']}],
#   'sentiment': 'negative'},
#  '5': {'reviewer_id': 6,
#   'review_time': '2024-12-01',
#   'rating': 1,
#   'review_processed': "I work for door dash and they locked us all out to wait in a long line for no reason at 10. I tried to beg them to open it because I'm door dash, but they refused. Covid is over; I'm getting a new job.",
#   'aspect_sentiment': [{'term': 'wait',
#     'class': 'negative',
#     'probability': [0.9932532906532288,
#      0.006253655068576336,
#      0.0004929883871227503],
#     'context': ['I work for door dash and they locked us all out to wait in a long line for no reason at 10.']},
#    {'term': 'door',
#     'class': 'negative',
#     'probability': [0.9924323558807373,
#      0.0022597189527004957,
#      0.005308002699166536],
#     'context': ['I work for door dash and they locked us all out to wait in a long line for no reason at 10.',
#      "I tried to beg them to open it because I'm door dash, but they refused."]}],
#   'sentiment': 'negative'},
#  '6': {'reviewer_id': 7,
#   'review_time': '2024-09-04',
#   'rating': 1,
#   'review_processed': "If I could give this location a zero on customer service, I would. It's a horrible experience every time as you can see by other reviews. After getting home, I had no regular hamburg but had cookies. Don't even bother going to this location again.",
#   'aspect_sentiment': [{'term': 'cookies',
#     'class': 'postive',
#     'probability': [0.15484055876731873,
#      0.015986056998372078,
#      0.8291733860969543],
#     'context': ['After getting home, I had no regular hamburg but had cookies.']},
#    {'term': 'hamburg',
#     'class': 'negative',
#     'probability': [0.998023509979248,
#      0.0009887544438242912,
#      0.0009877586271613836],
#     'context': ['After getting home, I had no regular hamburg but had cookies.']},
#    {'term': 'customer service',
#     'class': 'negative',
#     'probability': [0.9984126091003418,
#      0.0005393950268626213,
#      0.0010479566408321261],
#     'context': ['If I could give this location a zero on customer service, I would.']}],
#   'sentiment': 'negative'},
#  '7': {'reviewer_id': 8,
#   'review_time': '2023-12-04',
#   'rating': 1,
#   'review_processed': 'I asked the employee if they could give me a Large coffee w/no ice and she said no. I always get a large sweet tea with no ice and it always tastes good. They handed me a cup that was less than half way full. I was willing to pay more to get a full cup.',
#   'aspect_sentiment': [{'term': 'cup',
#     'class': 'postive',
#     'probability': [0.14494062960147858,
#      0.2756275236606598,
#      0.5794318318367004],
#     'context': ['They handed me a cup that was less than half way full.',
#      'I was willing to pay more to get a full cup.']},
#    {'term': 'tea',
#     'class': 'postive',
#     'probability': [0.16581080853939056,
#      0.07779897004365921,
#      0.7563902735710144],
#     'context': ['I always get a large sweet tea with no ice and it always tastes good.']},
#    {'term': 'sweet',
#     'class': 'postive',
#     'probability': [0.16649764776229858,
#      0.22194929420948029,
#      0.6115531325340271],
#     'context': ['I always get a large sweet tea with no ice and it always tastes good.']},
#    {'term': 'coffee',
#     'class': 'postive',
#     'probability': [0.1834869384765625,
#      0.08739488571882248,
#      0.7291181087493896],
#     'context': ['I asked the employee if they could give me a Large coffee w/no ice and she said no.']}],
#   'sentiment': 'positive'},
#  '8': {'reviewer_id': 9,
#   'review_time': '2024-09-04',
#   'rating': 1,
#   'review_processed': 'My 10 pieces of chicken were missing. The restaurant gave me a hard time about extra sauce. I was very unhappy with the service at the restaurant. The manager was very unsympathetic to my request to get the chicken McNuggets back. The customer was also very unhappy.',
#   'aspect_sentiment': [{'term': 'chicken mcnuggets',
#     'class': 'postive',
#     'probability': [0.31099334359169006,
#      0.16668684780597687,
#      0.5223197937011719],
#     'context': ['The manager was very unsympathetic to my request to get the chicken McNuggets back.']},
#    {'term': 'manager',
#     'class': 'negative',
#     'probability': [0.9987077713012695,
#      0.0004580307868309319,
#      0.0008342147921212018],
#     'context': ['The manager was very unsympathetic to my request to get the chicken McNuggets back.']},
#    {'term': 'service',
#     'class': 'negative',
#     'probability': [0.9980725049972534,
#      0.0016530909342691302,
#      0.0002743771765381098],
#     'context': ['I was very unhappy with the service at the restaurant.']},
#    {'term': 'sauce',
#     'class': 'negative',
#     'probability': [0.9985558390617371,
#      0.0011071250773966312,
#      0.00033698396873660386],
#     'context': ['The restaurant gave me a hard time about extra sauce.']},
#    {'term': 'chicken',
#     'class': 'negative',
#     'probability': [0.9976153373718262,
#      0.002048772294074297,
#      0.0003359100373927504],
#     'context': ['My 10 pieces of chicken were missing.',
#      'The manager was very unsympathetic to my request to get the chicken McNuggets back.']}],
#   'sentiment': 'negative'},
#  '9': {'reviewer_id': 10,
#   'review_time': '2024-09-04',
#   'rating': 4,
#   'review_processed': "I'm not a huge fan of fast food, but I have two teenage daughters who enjoy McD's. The staff here is always friendly and always get their orders correct. I always enjoy and appreciate quality service from quality people, and you'll definitely find it here.",
#   'aspect_sentiment': [{'term': 'service',
#     'class': 'postive',
#     'probability': [0.001063541043549776,
#      0.00024696311447769403,
#      0.998689591884613],
#     'context': ["I always enjoy and appreciate quality service from quality people, and you'll definitely find it here."]},
#    {'term': 'staff',
#     'class': 'postive',
#     'probability': [0.0011739794863387942,
#      0.00024848702014423907,
#      0.9985775947570801],
#     'context': ['The staff here is always friendly and always get their orders correct.']},
#    {'term': 'fast food',
#     'class': 'postive',
#     'probability': [0.34771257638931274,
#      0.014774005860090256,
#      0.6375134587287903],
#     'context': ["I'm not a huge fan of fast food, but I have two teenage daughters who enjoy McD's."]}],
#   'sentiment': 'positive'},
#  '10': {'reviewer_id': 11,
#   'review_time': '2024-09-04',
#   'rating': 1,
#   'review_processed': "The best McDonald's is the worst McDonald's, says the chain's owner. It's the only McDonald's in the U.S.; it's the worst in the world. It is the world's only fast food chain, and it's a terrible one.",
#   'aspect_sentiment': [{'term': 'fast food',
#     'class': 'negative',
#     'probability': [0.9725459814071655,
#      0.006914272904396057,
#      0.020539719611406326],
#     'context': ["It is the world's only fast food chain, and it's a terrible one."]}],
#   'sentiment': 'negative'},
#  '11': {'reviewer_id': 12,
#   'review_time': '2024-06-04',
#   'rating': 2,
#   'review_processed': 'Our order was supposed to have 3 food items and 2 drinks, but they missed a food item. The lady ignored me when I told her. My husband went to get it, she finished her task then handed it to him without a word or a smile or anything.',
#   'aspect_sentiment': [{'term': 'food',
#     'class': 'neutral',
#     'probability': [0.03177140653133392,
#      0.9670061469078064,
#      0.0012224643724039197],
#     'context': ['Our order was supposed to have 3 food items and 2 drinks, but they missed a food item.']},
#    {'term': 'drinks',
#     'class': 'neutral',
#     'probability': [0.006546773482114077,
#      0.9927389025688171,
#      0.0007143780821934342],
#     'context': ['Our order was supposed to have 3 food items and 2 drinks, but they missed a food item.']},
#    {'term': 'food items',
#     'class': 'neutral',
#     'probability': [0.014800053089857101,
#      0.9838448166847229,
#      0.0013551837764680386],
#     'context': ['Our order was supposed to have 3 food items and 2 drinks, but they missed a food item.']}],
#   'sentiment': 'negative'},
#  '12': {'reviewer_id': 13,
#   'review_time': '2024-06-04',
#   'rating': 1,
#   'review_processed': "The morning crew seems fast and efficient, but the night crew is a whole different experience. The staff is so rude you leave wanting to crash your car through the building. Don't forget they will mistake your order almost every single time as well and serve it to you cold.",
#   'aspect_sentiment': [{'term': 'staff',
#     'class': 'negative',
#     'probability': [0.9865595102310181,
#      0.0008878746884875,
#      0.012552599422633648],
#     'context': ['The staff is so rude you leave wanting to crash your car through the building.']},
#    {'term': 'night crew',
#     'class': 'postive',
#     'probability': [0.1201997622847557,
#      0.0037240320816636086,
#      0.8760762810707092],
#     'context': ['The morning crew seems fast and efficient, but the night crew is a whole different experience.']},
#    {'term': 'morning crew',
#     'class': 'postive',
#     'probability': [0.04071913659572601,
#      0.0013627063017338514,
#      0.9579181671142578],
#     'context': ['The morning crew seems fast and efficient, but the night crew is a whole different experience.']}],
#   'sentiment': 'negative'},
#  '13': {'reviewer_id': 14,
#   'review_time': '2023-12-04',
#   'rating': 3,
#   'review_processed': 'I was disappointed that the restaurant did not get me my full order, meaning I did not receive my condiments for my big breakfast with hot cakes. No butter, no syrup, and no utensils. Oh, and the egg was half the size of the sausage.',
#   'aspect_sentiment': [{'term': 'sausage',
#     'class': 'negative',
#     'probability': [0.9789081811904907,
#      0.019984861835837364,
#      0.0011069513857364655],
#     'context': ['Oh, and the egg was half the size of the sausage.']},
#    {'term': 'egg',
#     'class': 'negative',
#     'probability': [0.9930011034011841,
#      0.002290455624461174,
#      0.00470846937969327],
#     'context': ['Oh, and the egg was half the size of the sausage.']},
#    {'term': '##ensils',
#     'class': 'negative',
#     'probability': [0.8582509160041809,
#      0.07489224523305893,
#      0.06685690581798553],
#     'context': []},
#    {'term': 'ut',
#     'class': 'negative',
#     'probability': [0.9965523481369019,
#      0.002759113209322095,
#      0.0006885712500661612],
#     'context': []},
#    {'term': 'syrup',
#     'class': 'negative',
#     'probability': [0.9983137845993042,
#      0.0005611283122561872,
#      0.0011251039104536176],
#     'context': ['No butter, no syrup, and no utensils.']},
#    {'term': 'butter',
#     'class': 'negative',
#     'probability': [0.9982079267501831,
#      0.0008565931930206716,
#      0.0009354839567095041],
#     'context': ['No butter, no syrup, and no utensils.']},
#    {'term': 'breakfast with hot cakes',
#     'class': 'neutral',
#     'probability': [0.10337114334106445,
#      0.8078848719596863,
#      0.08874398469924927],
#     'context': ['I was disappointed that the restaurant did not get me my full order, meaning I did not receive my condiments for my big breakfast with hot cakes.']},
#    {'term': '##diments',
#     'class': 'negative',
#     'probability': [0.89311683177948,
#      0.05806119740009308,
#      0.04882201552391052],
#     'context': []},
#    {'term': 'con',
#     'class': 'negative',
#     'probability': [0.9474828839302063,
#      0.04992890730500221,
#      0.0025881922338157892],
#     'context': []}],
#   'sentiment': 'negative'},
#  '14': {'reviewer_id': 15,
#   'review_time': '2024-07-04',
#   'rating': 1,
#   'review_processed': 'Ordered food wrong and left out part of the order also. One of the drink cups were not filled; poor service girl handed the order at the window on January 7, 2023 at 1 p.m. correct: Ordered food burger wrong, left out some of the orders also.',
#   'aspect_sentiment': [{'term': 'food burger',
#     'class': 'negative',
#     'probability': [0.9960941672325134,
#      0.003144483547657728,
#      0.0007613926427438855],
#     'context': ['One of the drink cups were not filled; poor service girl handed the order at the window on January 7, 2023 at 1 p.m. correct: Ordered food burger wrong, left out some of the orders also.']},
#    {'term': 'drink cups',
#     'class': 'negative',
#     'probability': [0.9877892732620239,
#      0.011494306847453117,
#      0.0007163902628235519],
#     'context': ['One of the drink cups were not filled; poor service girl handed the order at the window on January 7, 2023 at 1 p.m. correct: Ordered food burger wrong, left out some of the orders also.']},
#    {'term': 'food',
#     'class': 'negative',
#     'probability': [0.994797945022583,
#      0.004450373817235231,
#      0.0007516511250287294],
#     'context': ['Ordered food wrong and left out part of the order also.',
#      'One of the drink cups were not filled; poor service girl handed the order at the window on January 7, 2023 at 1 p.m. correct: Ordered food burger wrong, left out some of the orders also.']}],
#   'sentiment': 'negative'},
#  '15': {'reviewer_id': 16,
#   'review_time': '2024-10-04',
#   'rating': 2,
#   'review_processed': "This was a dine in experience. The tables were all dirty, and we did not get our food after waiting 35 minutes. Chicken sandwich was burnt; tables were dirty and we didn't receive our food until after 35 minutes had passed; and the food was uneaten.",
#   'aspect_sentiment': [{'term': 'chicken sandwich',
#     'class': 'negative',
#     'probability': [0.9991394281387329,
#      0.00037128617987036705,
#      0.0004893332370556891],
#     'context': ["Chicken sandwich was burnt; tables were dirty and we didn't receive our food until after 35 minutes had passed; and the food was uneaten."]},
#    {'term': 'food',
#     'class': 'negative',
#     'probability': [0.9963996410369873,
#      0.003311085281893611,
#      0.00028918657335452735],
#     'context': ['The tables were all dirty, and we did not get our food after waiting 35 minutes.',
#      "Chicken sandwich was burnt; tables were dirty and we didn't receive our food until after 35 minutes had passed; and the food was uneaten."]},
#    {'term': 'tables',
#     'class': 'negative',
#     'probability': [0.9990373849868774,
#      0.0005781945656053722,
#      0.0003844642487820238],
#     'context': ['The tables were all dirty, and we did not get our food after waiting 35 minutes.',
#      "Chicken sandwich was burnt; tables were dirty and we didn't receive our food until after 35 minutes had passed; and the food was uneaten."]}],
#   'sentiment': 'negative'},
#  '16': {'reviewer_id': 17,
#   'review_time': '2023-12-04',
#   'rating': 4,
#   'review_processed': 'The line was extremely big and was moving very slowly, plus they were out of apples and strawberries, but they gave me a substitute cookie. The staff were very apologetic for being slow, but it was the middle of the night and they were extremely under-staffed.',
#   'aspect_sentiment': [{'term': 'staff',
#     'class': 'negative',
#     'probability': [0.9847680926322937,
#      0.0013101707445457578,
#      0.013921706937253475],
#     'context': ['The staff were very apologetic for being slow, but it was the middle of the night and they were extremely under-staffed.']},
#    {'term': 'cookie',
#     'class': 'negative',
#     'probability': [0.9897438883781433,
#      0.0049213538877666,
#      0.00533474562689662],
#     'context': ['The line was extremely big and was moving very slowly, plus they were out of apples and strawberries, but they gave me a substitute cookie.']},
#    {'term': 'apples strawberries',
#     'class': 'neutral',
#     'probability': [0.07545929402112961,
#      0.9139658808708191,
#      0.0105748837813735],
#     'context': []}],
#   'sentiment': 'negative'},
#  '17': {'reviewer_id': 18,
#   'review_time': '2024-10-04',
#   'rating': 1,
#   'review_processed': "The boy who attended me made me wait, and when he saw that the drink was wrong he threw the bag of food at me with a grimace. He was so disappointed, he was so angry! The boy was making me wait; he didn't want me to wait.",
#   'aspect_sentiment': [{'term': 'bag of food',
#     'class': 'neutral',
#     'probability': [0.11328613013029099,
#      0.8842231035232544,
#      0.002490766579285264],
#     'context': ['The boy who attended me made me wait, and when he saw that the drink was wrong he threw the bag of food at me with a grimace.']},
#    {'term': 'drink',
#     'class': 'negative',
#     'probability': [0.7699991464614868,
#      0.2245049625635147,
#      0.005495852790772915],
#     'context': ['The boy who attended me made me wait, and when he saw that the drink was wrong he threw the bag of food at me with a grimace.']}],
#   'sentiment': 'negative'},
#  '18': {'reviewer_id': 19,
#   'review_time': '2024-05-04',
#   'rating': 1,
#   'review_processed': 'I went and bought 4 Strawberry Banana smoothies and and 2 hash browns and my smoothies tasted like straight ice and water. I am very disappointed in there service. My smoothie should never taste like that, especially the fact I bought it for not only me but my kids.',
#   'aspect_sentiment': [{'term': 'smoothie',
#     'class': 'negative',
#     'probability': [0.5565332174301147,
#      0.05360134318470955,
#      0.3898654580116272],
#     'context': ['My smoothie should never taste like that, especially the fact I bought it for not only me but my kids.']},
#    {'term': 'service',
#     'class': 'negative',
#     'probability': [0.9974496960639954,
#      0.0014037463115528226,
#      0.00114648905582726],
#     'context': ['I am very disappointed in there service.']},
#    {'term': 'water',
#     'class': 'postive',
#     'probability': [0.08196575194597244,
#      0.034085072576999664,
#      0.8839491009712219],
#     'context': ['I went and bought 4 Strawberry Banana smoothies and and 2 hash browns and my smoothies tasted like straight ice and water.']},
#    {'term': 'hash brownsies',
#     'class': 'postive',
#     'probability': [0.04074759781360626,
#      0.006972364149987698,
#      0.9522801041603088],
#     'context': []},
#    {'term': 'strawberry banana smoothies',
#     'class': 'postive',
#     'probability': [0.27268412709236145,
#      0.0066567654721438885,
#      0.7206591367721558],
#     'context': ['I went and bought 4 Strawberry Banana smoothies and and 2 hash browns and my smoothies tasted like straight ice and water.']}],
#   'sentiment': 'negative'},
#  '19': {'reviewer_id': 20,
#   'review_time': '2024-05-04',
#   'rating': 4,
#   'review_processed': 'The staff seems to always be different, which makes ordering sometimes a little difficult because they are in a state of perpetual learning. The lobby is always clean as well as the bathrooms, but the wait is always longer due to their constant changes in appearance. The staff are always different, making ordering difficult.',
#   'aspect_sentiment': [{'term': 'appearance',
#     'class': 'negative',
#     'probability': [0.9731659889221191,
#      0.024411581456661224,
#      0.0024223667569458485],
#     'context': ['The lobby is always clean as well as the bathrooms, but the wait is always longer due to their constant changes in appearance.']},
#    {'term': 'wait',
#     'class': 'negative',
#     'probability': [0.9962146878242493,
#      0.0017749888356775045,
#      0.0020102967973798513],
#     'context': ['The lobby is always clean as well as the bathrooms, but the wait is always longer due to their constant changes in appearance.']},
#    {'term': 'bathrooms',
#     'class': 'neutral',
#     'probability': [0.07573594897985458,
#      0.6802747249603271,
#      0.24398933351039886],
#     'context': ['The lobby is always clean as well as the bathrooms, but the wait is always longer due to their constant changes in appearance.']},
#    {'term': 'lobby',
#     'class': 'postive',
#     'probability': [0.16022616624832153,
#      0.0077795060351490974,
#      0.831994354724884],
#     'context': ['The lobby is always clean as well as the bathrooms, but the wait is always longer due to their constant changes in appearance.']},
#    {'term': 'staff',
#     'class': 'negative',
#     'probability': [0.7863964438438416,
#      0.013776720501482487,
#      0.19982686638832092],
#     'context': ['The staff seems to always be different, which makes ordering sometimes a little difficult because they are in a state of perpetual learning.',
#      'The staff are always different, making ordering difficult.']}],
#   'sentiment': 'negative'},
#  '20': {'reviewer_id': 21,
#   'review_time': '2024-02-04',
#   'rating': 1,
#   'review_processed': "Can't believe experience with order taker. Went from drive thru and employee directly asked what do you want. He keeps rushing while taking order with no other cars placing order. We wanted to add one more item and asked for a minute. When I said we are ready - no response.",
#   'aspect_sentiment': [{'term': 'order taker',
#     'class': 'negative',
#     'probability': [0.9969251751899719,
#      0.0028428477235138416,
#      0.0002319530030945316],
#     'context': ["Can't believe experience with order taker."]}],
#   'sentiment': 'negative'},
#  '21': {'reviewer_id': 22,
#   'review_time': '2020-12-04',
#   'rating': 1,
#   'review_processed': 'I only go here when they are not busy, in hope that my order is correct when I go to leave. When I finally get the correct order, it is generally tasty. The evening staff is pleasant, but the morning staff leaves a lot to be desired. The morning staff thinks they can talk negatively about people in Spanish out in the open.',
#   'aspect_sentiment': [{'term': 'morning staff',
#     'class': 'postive',
#     'probability': [0.29298898577690125,
#      0.004363544750958681,
#      0.7026475071907043],
#     'context': ['The evening staff is pleasant, but the morning staff leaves a lot to be desired.',
#      'The morning staff thinks they can talk negatively about people in Spanish out in the open.']},
#    {'term': 'evening staff',
#     'class': 'postive',
#     'probability': [0.18166635930538177,
#      0.0032298490405082703,
#      0.8151037693023682],
#     'context': ['The evening staff is pleasant, but the morning staff leaves a lot to be desired.']}],
#   'sentiment': 'negative'},
#  '22': {'reviewer_id': 23,
#   'review_time': '2024-11-04',
#   'rating': 2,
#   'review_processed': "The staff at the drive thru just shoved the drink in my hands. It's not very professional. I just needed caffeine; I'm not a big fan of fast food. The food was good, but the service was unappetiteful and unprofessional.",
#   'aspect_sentiment': [{'term': 'service',
#     'class': 'negative',
#     'probability': [0.9968095421791077,
#      0.0007321911980397999,
#      0.0024582671467214823],
#     'context': ['The food was good, but the service was unappetiteful and unprofessional.']},
#    {'term': 'food',
#     'class': 'neutral',
#     'probability': [0.07116822898387909,
#      0.6706492304801941,
#      0.25818249583244324],
#     'context': ["I just needed caffeine; I'm not a big fan of fast food.",
#      'The food was good, but the service was unappetiteful and unprofessional.']},
#    {'term': 'fast food',
#     'class': 'neutral',
#     'probability': [0.102867990732193, 0.4722709655761719, 0.4248610734939575],
#     'context': ["I just needed caffeine; I'm not a big fan of fast food."]},
#    {'term': '##feine',
#     'class': 'negative',
#     'probability': [0.8221876621246338,
#      0.008761527948081493,
#      0.16905087232589722],
#     'context': []},
#    {'term': 'caf',
#     'class': 'neutral',
#     'probability': [0.033860109746456146,
#      0.9015904664993286,
#      0.06454944610595703],
#     'context': []},
#    {'term': 'drink',
#     'class': 'neutral',
#     'probability': [0.01874767430126667,
#      0.9803789854049683,
#      0.0008733723079785705],
#     'context': ['The staff at the drive thru just shoved the drink in my hands.']},
#    {'term': 'staff',
#     'class': 'negative',
#     'probability': [0.9944396018981934,
#      0.000629544083494693,
#      0.004930817522108555],
#     'context': ['The staff at the drive thru just shoved the drink in my hands.']}],
#   'sentiment': 'negative'},
#  '23': {'reviewer_id': 24,
#   'review_time': '2024-04-04',
#   'rating': 1,
#   'review_processed': "Microwaved nuggets, cold fries and a 30 minute wait? What more can you ask for? Don't go there ever! You're better off going hungry or giving the meal you paid for to the homeless by the donation box behind the drive thru.",
#   'aspect_sentiment': [{'term': 'meal',
#     'class': 'negative',
#     'probability': [0.9807120561599731,
#      0.004715777467936277,
#      0.014572146348655224],
#     'context': ["You're better off going hungry or giving the meal you paid for to the homeless by the donation box behind the drive thru."]},
#    {'term': 'wait',
#     'class': 'negative',
#     'probability': [0.9969077706336975,
#      0.0026386796962469816,
#      0.0004534372710622847],
#     'context': ['Microwaved nuggets, cold fries and a 30 minute wait?']},
#    {'term': 'fries',
#     'class': 'postive',
#     'probability': [0.02401219867169857,
#      0.2507196068763733,
#      0.7252681851387024],
#     'context': ['Microwaved nuggets, cold fries and a 30 minute wait?']}],
#   'sentiment': 'negative'},
#  '24': {'reviewer_id': 25,
#   'review_time': '2024-08-04',
#   'rating': 1,
#   'review_processed': "Didn't take a card. But didn't have any money on her. It's not true. No, it wasn't true. It wasn't there. It didn't exist. It doesn't exist at all. It never existed at all; it never existed.",
#   'aspect_sentiment': [{'term': 'money',
#     'class': 'negative',
#     'probability': [0.9988659620285034,
#      0.0006195291643962264,
#      0.0005145296454429626],
#     'context': ["But didn't have any money on her."]},
#    {'term': 'card',
#     'class': 'negative',
#     'probability': [0.9989323019981384,
#      0.0006905178306624293,
#      0.0003770860203076154],
#     'context': ["Didn't take a card."]}],
#   'sentiment': 'negative'},
#  '25': {'reviewer_id': 26,
#   'review_time': '2024-06-04',
#   'rating': 1,
#   'review_processed': "McDonald's is proud to own the most broken ice cream machines on the planet. When I asked at the drive through if they had ice cream, the lady replied that they didn't have any ice cream at all. It's a shame, because they have some of the best ice cream in the world.",
#   'aspect_sentiment': [{'term': 'ice cream',
#     'class': 'negative',
#     'probability': [0.8867460489273071,
#      0.07630795985460281,
#      0.036946043372154236],
#     'context': ["McDonald's is proud to own the most broken ice cream machines on the planet.",
#      "When I asked at the drive through if they had ice cream, the lady replied that they didn't have any ice cream at all.",
#      "It's a shame, because they have some of the best ice cream in the world."]}],
#   'sentiment': 'negative'},
#  '26': {'reviewer_id': 27,
#   'review_time': '2024-11-04',
#   'rating': 4,
#   'review_processed': 'With all the new upgrades, everything looks great and is clean and neat. The staff are great and have a great staff. correct: With all the upgrades, the staff are very clean and well-mannered. incorrect: The staff is very friendly and friendly.',
#   'aspect_sentiment': [{'term': 'staff',
#     'class': 'postive',
#     'probability': [0.00019963973318226635,
#      0.00026557687669992447,
#      0.9995348453521729],
#     'context': ['The staff are great and have a great staff.',
#      'correct: With all the upgrades, the staff are very clean and well-mannered.',
#      'incorrect: The staff is very friendly and friendly.']}],
#   'sentiment': 'positive'},
#  '27': {'reviewer_id': 28,
#   'review_time': '2024-11-04',
#   'rating': 2,
#   'review_processed': 'This article has been updated since it was published in the spring of 2012. It is the first published version of this article to feature a corrected spelling of the word \'taste\' The error occurred due to misbelief that the word "taste" referred to the food.',
#   'aspect_sentiment': [{'term': 'food',
#     'class': 'neutral',
#     'probability': [0.25921422243118286,
#      0.7359218001365662,
#      0.004863974172621965],
#     'context': ['It is the first published version of this article to feature a corrected spelling of the word \'taste\' The error occurred due to misbelief that the word "taste" referred to the food.']},
#    {'term': '"',
#     'class': 'neutral',
#     'probability': [0.4206438362598419,
#      0.5757195353507996,
#      0.0036366696003824472],
#     'context': []},
#    {'term': 'taste',
#     'class': 'negative',
#     'probability': [0.8525221347808838,
#      0.14425751566886902,
#      0.0032203206792473793],
#     'context': ['It is the first published version of this article to feature a corrected spelling of the word \'taste\' The error occurred due to misbelief that the word "taste" referred to the food.']},
#    {'term': "'",
#     'class': 'neutral',
#     'probability': [0.40049421787261963,
#      0.5950559377670288,
#      0.004449840169399977],
#     'context': []}],
#   'sentiment': 'negative'},
#  '28': {'reviewer_id': 29,
#   'review_time': '2024-09-04',
#   'rating': 1,
#   'review_processed': "A McDonald's with horrible service and lazy employees. I mean, do they intentionally hire unqualified people? It's yet another McDonald's where the service is horrible and the employees are unqualified. It's ridiculous! It's like a movie! It doesn't get any worse.",
#   'aspect_sentiment': [{'term': 'employees',
#     'class': 'negative',
#     'probability': [0.9987545013427734,
#      0.0008405973203480244,
#      0.0004048882401548326],
#     'context': ["A McDonald's with horrible service and lazy employees.",
#      "It's yet another McDonald's where the service is horrible and the employees are unqualified."]},
#    {'term': 'service',
#     'class': 'negative',
#     'probability': [0.9988682270050049,
#      0.000763076706789434,
#      0.00036880504922010005],
#     'context': ["A McDonald's with horrible service and lazy employees.",
#      "It's yet another McDonald's where the service is horrible and the employees are unqualified."]}],
#   'sentiment': 'negative'},
#  '29': {'reviewer_id': 30,
#   'review_time': '2021-12-04',
#   'rating': 1,
#   'review_processed': "First and last time I went to this location. Look at my receipt and what I got. That's a plain sausage biscuit and a double quarter pounder. I didn't go there before; it's the first and last place I've ever been.",
#   'aspect_sentiment': [{'term': 'pounder',
#     'class': 'postive',
#     'probability': [0.006075546611100435,
#      0.005678566638380289,
#      0.9882458448410034],
#     'context': ["That's a plain sausage biscuit and a double quarter pounder."]},
#    {'term': 'quarter',
#     'class': 'postive',
#     'probability': [0.007255909498780966,
#      0.02992238849401474,
#      0.9628216624259949],
#     'context': ["That's a plain sausage biscuit and a double quarter pounder."]},
#    {'term': 'double',
#     'class': 'postive',
#     'probability': [0.006429081317037344,
#      0.006671649869531393,
#      0.9868992567062378],
#     'context': ["That's a plain sausage biscuit and a double quarter pounder."]},
#    {'term': 'sausage biscuit',
#     'class': 'postive',
#     'probability': [0.012622660025954247,
#      0.004381369799375534,
#      0.9829960465431213],
#     'context': ["That's a plain sausage biscuit and a double quarter pounder."]}],
#   'sentiment': 'negative'},
#  '30': {'reviewer_id': 31,
#   'review_time': '2022-12-04',
#   'rating': 1,
#   'review_processed': "A 20 minute wait in the drive through for a room temperature caramel mocha that was less than 2/3 full. This was exactly what I ordered! It's what I had ordered, and it's exactly where I ordered it to be. It's perfect!",
#   'aspect_sentiment': [{'term': 'caramel mocha',
#     'class': 'postive',
#     'probability': [0.031187569722533226,
#      0.004736708477139473,
#      0.9640757441520691],
#     'context': ['A 20 minute wait in the drive through for a room temperature caramel mocha that was less than 2/3 full.']},
#    {'term': 'wait',
#     'class': 'negative',
#     'probability': [0.9422491788864136,
#      0.01572427712380886,
#      0.042026620358228683],
#     'context': ['A 20 minute wait in the drive through for a room temperature caramel mocha that was less than 2/3 full.']}],
#   'sentiment': 'positive'},
#  '31': {'reviewer_id': 32,
#   'review_time': '2024-03-04',
#   'rating': 2,
#   'review_processed': "They will literally stop taking orders and make people sit in the parking lot for 12 minutes until 3 a.m. so that they don't get to order dinner. We have gone multiple times right after leaving the pinball arcade just to wait in the drive-thru line while they do nothing but wait for the order menu to change.",
#   'aspect_sentiment': [{'term': 'order menu',
#     'class': 'negative',
#     'probability': [0.9835450053215027,
#      0.015292356722056866,
#      0.0011626201448962092],
#     'context': ['We have gone multiple times right after leaving the pinball arcade just to wait in the drive-thru line while they do nothing but wait for the order menu to change.']},
#    {'term': 'thru line',
#     'class': 'negative',
#     'probability': [0.9862879514694214,
#      0.004368256777524948,
#      0.009343740530312061],
#     'context': ['We have gone multiple times right after leaving the pinball arcade just to wait in the drive-thru line while they do nothing but wait for the order menu to change.']},
#    {'term': '-',
#     'class': 'neutral',
#     'probability': [0.37977904081344604,
#      0.6033185720443726,
#      0.016902383416891098],
#     'context': ['We have gone multiple times right after leaving the pinball arcade just to wait in the drive-thru line while they do nothing but wait for the order menu to change.']},
#    {'term': 'drive',
#     'class': 'neutral',
#     'probability': [0.09000447392463684,
#      0.9051740169525146,
#      0.00482152309268713],
#     'context': ['We have gone multiple times right after leaving the pinball arcade just to wait in the drive-thru line while they do nothing but wait for the order menu to change.']},
#    {'term': 'pinball arcade',
#     'class': 'neutral',
#     'probability': [0.06662467122077942,
#      0.9219281077384949,
#      0.011447218246757984],
#     'context': ['We have gone multiple times right after leaving the pinball arcade just to wait in the drive-thru line while they do nothing but wait for the order menu to change.']},
#    {'term': 'dinner',
#     'class': 'neutral',
#     'probability': [0.02694079652428627,
#      0.9721358418464661,
#      0.0009233492310158908],
#     'context': ["They will literally stop taking orders and make people sit in the parking lot for 12 minutes until 3 a.m. so that they don't get to order dinner."]},
#    {'term': 'orders',
#     'class': 'negative',
#     'probability': [0.99802565574646,
#      0.0013995227636769414,
#      0.0005749202100560069],
#     'context': ["They will literally stop taking orders and make people sit in the parking lot for 12 minutes until 3 a.m. so that they don't get to order dinner."]}],
#   'sentiment': 'negative'},
#  '32': {'reviewer_id': 33,
#   'review_time': '2023-12-04',
#   'rating': 1,
#   'review_processed': "They did not honor there advertised price. This is extra pickles; they did not pay the advertised price for them. They did not have any leftovers from the previous batch of food. It's not their fault; they didn't pay the price they were promised.",
#   'aspect_sentiment': [{'term': 'food',
#     'class': 'negative',
#     'probability': [0.982486367225647,
#      0.016986140981316566,
#      0.0005274800350889564],
#     'context': ['They did not have any leftovers from the previous batch of food.']},
#    {'term': 'pickles',
#     'class': 'negative',
#     'probability': [0.9961330890655518,
#      0.002983743092045188,
#      0.0008831787272356451],
#     'context': ['This is extra pickles; they did not pay the advertised price for them.']},
#    {'term': 'price',
#     'class': 'negative',
#     'probability': [0.9990266561508179,
#      0.0005869690212421119,
#      0.00038637255784124136],
#     'context': ['They did not honor there advertised price.',
#      'This is extra pickles; they did not pay the advertised price for them.',
#      "It's not their fault; they didn't pay the price they were promised."]}],
#   'sentiment': 'negative'},
#  '33': {'reviewer_id': 34,
#   'review_time': '2023-12-04',
#   'rating': 1,
#   'review_processed': "Just spent 10 minutes waiting at this McDonald's. According to Google they're open 24/7. One employee was seated in the lobby and another at the window. Whoever these two are, they need to be replaced. 0/10 would not recommend this location for a meal.",
#   'aspect_sentiment': [{'term': 'meal',
#     'class': 'neutral',
#     'probability': [0.045597657561302185,
#      0.9524163603782654,
#      0.001985999057069421],
#     'context': ['0/10 would not recommend this location for a meal.']},
#    {'term': 'google',
#     'class': 'neutral',
#     'probability': [0.4669345021247864,
#      0.5241920948028564,
#      0.00887339934706688],
#     'context': ["According to Google they're open 24/7."]}],
#   'sentiment': 'negative'},
#  '34': {'reviewer_id': 35,
#   'review_time': '2024-02-04',
#   'rating': 2,
#   'review_processed': "In the beginning everything was great, but that didn't last long. The service is fast but with attitude, and the service is very friendly and friendly. We hit it off pretty well in the beginning, but it didn'tLast week, we had a fight.",
#   'aspect_sentiment': [{'term': 'service',
#     'class': 'postive',
#     'probability': [0.007160842884331942,
#      0.0008863030816428363,
#      0.9919528365135193],
#     'context': ['The service is fast but with attitude, and the service is very friendly and friendly.']}],
#   'sentiment': 'positive'},
#  '35': {'reviewer_id': 36,
#   'review_time': '2023-12-04',
#   'rating': 1,
#   'review_processed': "This location is a horrible store to work for. The General Manger doesn't know how to run a store efficiently. The Supervisor, Eduardo, doesn't care how its ran either. As someone who used to work here at the store, I can relate to this situation.",
#   'aspect_sentiment': [{'term': 'supervisor',
#     'class': 'negative',
#     'probability': [0.9990584254264832,
#      0.00034282912383787334,
#      0.0005986870964989066],
#     'context': ["The Supervisor, Eduardo, doesn't care how its ran either."]},
#    {'term': 'general',
#     'class': 'negative',
#     'probability': [0.9989423155784607,
#      0.0003922644827980548,
#      0.000665473286062479],
#     'context': ["The General Manger doesn't know how to run a store efficiently."]}],
#   'sentiment': 'negative'},
#  '36': {'reviewer_id': 37,
#   'review_time': '2024-05-04',
#   'rating': 1,
#   'review_processed': "This is the third time I've received this letter; this is the first time I got this letter. correct: This is the 3rd time I get this letter, and the last time I'm getting this letter is in the mail. It's a gift.",
#   'aspect_sentiment': [],
#   'sentiment': 'positive'},
#  '37': {'reviewer_id': 38,
#   'review_time': '2024-08-04',
#   'rating': 5,
#   'review_processed': 'The staff are very friendly and they do their job perfectly. correct: The staff are friendly, and they are doing their jobs perfectly. The students are friendly and doing their job well.correct: The student is friendly and the student is doing his job properly.',
#   'aspect_sentiment': [{'term': 'staff',
#     'class': 'postive',
#     'probability': [0.00024570926325395703,
#      0.00013594975462183356,
#      0.9996182918548584],
#     'context': ['The staff are very friendly and they do their job perfectly.',
#      'correct: The staff are friendly, and they are doing their jobs perfectly.']}],
#   'sentiment': 'positive'},
#  '38': {'reviewer_id': 39,
#   'review_time': '2024-09-04',
#   'rating': 5,
#   'review_processed': 'Great service, food hot, and good food are the best things ever. correct: Awesome service, great food, and great service. Wrong: Amazing service, amazing food, amazing service, and best service ever. "Best ever"? It\'s amazing. It\'s perfect.',
#   'aspect_sentiment': [{'term': 'food',
#     'class': 'postive',
#     'probability': [0.000191781873581931,
#      0.00014328377437777817,
#      0.9996650218963623],
#     'context': ['Great service, food hot, and good food are the best things ever.',
#      'correct: Awesome service, great food, and great service.',
#      'Wrong: Amazing service, amazing food, amazing service, and best service ever.']},
#    {'term': 'service',
#     'class': 'postive',
#     'probability': [0.00018787728913594037,
#      0.00013917651085648686,
#      0.9996728897094727],
#     'context': ['Great service, food hot, and good food are the best things ever.',
#      'correct: Awesome service, great food, and great service.',
#      'Wrong: Amazing service, amazing food, amazing service, and best service ever.']}],
#   'sentiment': 'positive'},
#  '39': {'reviewer_id': 40,
#   'review_time': '2024-03-04',
#   'rating': 1,
#   'review_processed': 'I ordered a large fry and two chicken sandwiches, but they read it back as two spicey chicken sandwiches. They said they would fix it after having to pay a second time for the lettuce and tomato. When I got the order, it was still a spicy chicken sandwich inside a deluxe crispy chicken sandwich.',
#   'aspect_sentiment': [{'term': 'crispy chicken sandwich',
#     'class': 'negative',
#     'probability': [0.8380516767501831,
#      0.12650436162948608,
#      0.0354439914226532],
#     'context': ['When I got the order, it was still a spicy chicken sandwich inside a deluxe crispy chicken sandwich.']},
#    {'term': 'deluxe',
#     'class': 'negative',
#     'probability': [0.975402295589447,
#      0.010478089563548565,
#      0.014119605533778667],
#     'context': ['When I got the order, it was still a spicy chicken sandwich inside a deluxe crispy chicken sandwich.']},
#    {'term': 'spicy chicken sandwich',
#     'class': 'negative',
#     'probability': [0.9181748628616333,
#      0.04561581835150719,
#      0.036209311336278915],
#     'context': ['When I got the order, it was still a spicy chicken sandwich inside a deluxe crispy chicken sandwich.']},
#    {'term': '##tuce and tomato',
#     'class': 'negative',
#     'probability': [0.8694651126861572,
#      0.09339189529418945,
#      0.03714299947023392],
#     'context': []},
#    {'term': 'let',
#     'class': 'negative',
#     'probability': [0.8370802402496338,
#      0.13040561974048615,
#      0.032514121383428574],
#     'context': []},
#    {'term': 'spicey chicken sandwiches',
#     'class': 'negative',
#     'probability': [0.8035503625869751,
#      0.1727941334247589,
#      0.023655526340007782],
# ...
#      0.9877874255180359],
#     'context': ["It's always a good sign when the coffee is on point."]},
#    {'term': 'workers',
#     'class': 'postive',
#     'probability': [0.000749895058106631,
#      0.00023644225439056754,
#      0.9990136623382568],
#     'context': ['Always get me to work on time with fast workers.']}],
#   'sentiment': 'positive'},
#  '85': {'reviewer_id': 86,
#   'review_time': '2021-12-04',
#   'rating': 3,
#   'review_processed': 'When I order during the day, I have no issues. They are listed as a 24 hour location, so they show up on Uber Eats late at night. Anytime I order after midnight, they will accept my order and then sit around for an hour before canceling it.',
#   'aspect_sentiment': [{'term': 'uber',
#     'class': 'neutral',
#     'probability': [0.001879181363619864,
#      0.9919121265411377,
#      0.006208683829754591],
#     'context': ['They are listed as a 24 hour location, so they show up on Uber Eats late at night.']}],
#   'sentiment': 'negative'},
#  '86': {'reviewer_id': 87,
#   'review_time': '2022-12-04',
#   'rating': 1,
#   'review_processed': "I ordered four happy meals with plain cheeseburgers. All the burgers were wrong. Do you know what it's like to have four grandkids that can eat all the food you ordered? It's not fair. It's just not fair! It's the way it is.",
#   'aspect_sentiment': [{'term': 'food',
#     'class': 'postive',
#     'probability': [0.2917945384979248,
#      0.32830333709716797,
#      0.3799021244049072],
#     'context': ["Do you know what it's like to have four grandkids that can eat all the food you ordered?"]},
#    {'term': 'burgers',
#     'class': 'negative',
#     'probability': [0.9946276545524597,
#      0.004160794895142317,
#      0.0012115460122004151],
#     'context': ['All the burgers were wrong.']},
#    {'term': '##burgers',
#     'class': 'negative',
#     'probability': [0.6617902517318726,
#      0.14209651947021484,
#      0.1961132436990738],
#     'context': []},
#    {'term': 'cheese',
#     'class': 'neutral',
#     'probability': [0.03235480934381485,
#      0.7476292252540588,
#      0.2200159877538681],
#     'context': []},
#    {'term': 'meals',
#     'class': 'postive',
#     'probability': [0.021736709401011467,
#      0.009722050279378891,
#      0.9685413241386414],
#     'context': ['I ordered four happy meals with plain cheeseburgers.']}],
#   'sentiment': 'negative'},
#  '87': {'reviewer_id': 88,
#   'review_time': '2023-12-04',
#   'rating': 1,
#   'review_processed': "McDonald's is not a fast food company anymore. They're just a food company now. There's always a line wrapped around the building that never moves. When are robots going to replace the kitchen staff who hate their jobs? It's not going to happen soon.",
#   'aspect_sentiment': [{'term': 'kitchen staff',
#     'class': 'negative',
#     'probability': [0.9988484382629395,
#      0.0003263555117882788,
#      0.0008251780527643859],
#     'context': ['When are robots going to replace the kitchen staff who hate their jobs?']},
#    {'term': 'fast food',
#     'class': 'negative',
#     'probability': [0.6209200620651245,
#      0.37634900212287903,
#      0.002730959327891469],
#     'context': ["McDonald's is not a fast food company anymore."]}],
#   'sentiment': 'negative'},
#  '88': {'reviewer_id': 89,
#   'review_time': '2021-12-04',
#   'rating': 1,
#   'review_processed': "This McDonald's constantly gets orders wrong. We have ordered at the window and over the phone and every time we don't get a complete order. Today we went back to get our fries and the manager gave us a new one, but the girl at the front window shoved the bag in our hands and when I asked her to stop, she made a rude face and turned away.",
#   'aspect_sentiment': [{'term': 'manager',
#     'class': 'negative',
#     'probability': [0.9913186430931091,
#      0.0016886949306353927,
#      0.006992637179791927],
#     'context': ['Today we went back to get our fries and the manager gave us a new one, but the girl at the front window shoved the bag in our hands and when I asked her to stop, she made a rude face and turned away.']},
#    {'term': 'fries',
#     'class': 'postive',
#     'probability': [0.20578721165657043,
#      0.34283310174942017,
#      0.4513796865940094],
#     'context': ['Today we went back to get our fries and the manager gave us a new one, but the girl at the front window shoved the bag in our hands and when I asked her to stop, she made a rude face and turned away.']}],
#   'sentiment': 'negative'},
#  '89': {'reviewer_id': 90,
#   'review_time': '2023-12-04',
#   'rating': 1,
#   'review_processed': "I ordered a meal with an extra fry, but when I got to the food window, was only given the fry with the meal. I offered to pay the difference for the extra fry but was told I needed to drive back around and order again. Seriously? That's the response? Will not be returning.",
#   'aspect_sentiment': [{'term': 'food window',
#     'class': 'neutral',
#     'probability': [0.038910411298274994,
#      0.9590328931808472,
#      0.002056698314845562],
#     'context': ['I ordered a meal with an extra fry, but when I got to the food window, was only given the fry with the meal.']},
#    {'term': 'fry',
#     'class': 'neutral',
#     'probability': [0.13860642910003662,
#      0.8576528429985046,
#      0.003740777028724551],
#     'context': ['I ordered a meal with an extra fry, but when I got to the food window, was only given the fry with the meal.',
#      'I offered to pay the difference for the extra fry but was told I needed to drive back around and order again.']},
#    {'term': 'meal',
#     'class': 'neutral',
#     'probability': [0.0832051932811737,
#      0.914055585861206,
#      0.002739212941378355],
#     'context': ['I ordered a meal with an extra fry, but when I got to the food window, was only given the fry with the meal.']}],
#   'sentiment': 'negative'},
#  '90': {'reviewer_id': 91,
#   'review_time': '2019-12-04',
#   'rating': 1,
#   'review_processed': "This is the 3rd time in a row that we've been burned going through the drive thru. You'd think by now that I would have learned my lesson, but I thought this would be quick and easy. This location sucks. I tried calling the number in the receipt but no one answers.",
#   'aspect_sentiment': [],
#   'sentiment': 'negative'},
#  '91': {'reviewer_id': 92,
#   'review_time': '2021-12-04',
#   'rating': 1,
#   'review_processed': 'All I asked for was a regular size coffee. Coffee was full of coffee grounds to the point I was spitting them out. Also asked for 3 splendas and 4 creamers on the side and received 3 regular sugars and 2 creamers. And as a little plus there was a piece of plastic! Never again!',
#   'aspect_sentiment': [{'term': 'sugars',
#     'class': 'negative',
#     'probability': [0.9795821905136108,
#      0.015034454874694347,
#      0.005383349489420652],
#     'context': ['Also asked for 3 splendas and 4 creamers on the side and received 3 regular sugars and 2 creamers.']},
#    {'term': 'creamers',
#     'class': 'negative',
#     'probability': [0.9829748272895813,
#      0.013136506080627441,
#      0.0038886505644768476],
#     'context': ['Also asked for 3 splendas and 4 creamers on the side and received 3 regular sugars and 2 creamers.']},
#    {'term': '##lendas',
#     'class': 'negative',
#     'probability': [0.9824161529541016,
#      0.014306364580988884,
#      0.003277549287304282],
#     'context': []},
#    {'term': 'sp',
#     'class': 'neutral',
#     'probability': [0.3061542809009552,
#      0.6778585314750671,
#      0.01598716713488102],
#     'context': []},
#    {'term': 'coffee grounds',
#     'class': 'negative',
#     'probability': [0.7095144391059875,
#      0.27448341250419617,
#      0.016002189368009567],
#     'context': ['Coffee was full of coffee grounds to the point I was spitting them out.']},
#    {'term': 'coffee',
#     'class': 'negative',
#     'probability': [0.8361466526985168,
#      0.1547451764345169,
#      0.009108172729611397],
#     'context': ['All I asked for was a regular size coffee.',
#      'Coffee was full of coffee grounds to the point I was spitting them out.']}],
#   'sentiment': 'negative'},
#  '92': {'reviewer_id': 93,
#   'review_time': '2019-12-04',
#   'rating': 1,
#   'review_processed': "I tried to go through the drive thru at 430 a. It said it was 24 hours, but no one seemed to be taking orders. I drove around twice just in case and tried again but still no answer. I saw one employee in the kitchen but couldn't get his attention. It's very bad business.",
#   'aspect_sentiment': [{'term': 'kitchen',
#     'class': 'negative',
#     'probability': [0.5457109212875366,
#      0.45042192935943604,
#      0.003867190098389983],
#     'context': ["I saw one employee in the kitchen but couldn't get his attention."]}],
#   'sentiment': 'negative'},
#  '93': {'reviewer_id': 94,
#   'review_time': '2020-12-04',
#   'rating': 3,
#   'review_processed': "I ordered a frozen lemonade, paid for it, then sat down. I was there for a bit before someone came and told me they were out. It was too much trouble to get a refund for the difference. I'm not sure I like this new way.",
#   'aspect_sentiment': [{'term': 'frozen lemonade',
#     'class': 'negative',
#     'probability': [0.4706272482872009,
#      0.38040411472320557,
#      0.14896859228610992],
#     'context': ['I ordered a frozen lemonade, paid for it, then sat down.']}],
#   'sentiment': 'negative'},
#  '94': {'reviewer_id': 95,
#   'review_time': '2021-12-04',
#   'rating': 1,
#   'review_processed': 'My burger was completely raw in the middle, and when I took it back in to get it remade, the lady behind the counter treated me like I was some stuck up brat for not wanting to eat a raw burger. I will never eat there again.',
#   'aspect_sentiment': [{'term': 'lady',
#     'class': 'negative',
#     'probability': [0.9987659454345703,
#      0.00045107313781045377,
#      0.0007829025271348655],
#     'context': ['My burger was completely raw in the middle, and when I took it back in to get it remade, the lady behind the counter treated me like I was some stuck up brat for not wanting to eat a raw burger.']},
#    {'term': 'burger',
#     'class': 'negative',
#     'probability': [0.9936532974243164,
#      0.005539106670767069,
#      0.000807653705123812],
#     'context': ['My burger was completely raw in the middle, and when I took it back in to get it remade, the lady behind the counter treated me like I was some stuck up brat for not wanting to eat a raw burger.']}],
#   'sentiment': 'negative'},
#  '95': {'reviewer_id': 96,
#   'review_time': '2020-12-04',
#   'rating': 1,
#   'review_processed': 'Every single time I go they f up my order! Then give attitude when they need to correct their mistakes. The staff is horrible. Corporate needs to send all their staff over to a week of training at chic-fil-A college to learn about work ethic, time management, teamwork and basic manors.',
#   'aspect_sentiment': [{'term': 'manors',
#     'class': 'negative',
#     'probability': [0.9981818199157715,
#      0.0011882988037541509,
#      0.000629953108727932],
#     'context': ['Corporate needs to send all their staff over to a week of training at chic-fil-A college to learn about work ethic, time management, teamwork and basic manors.']},
#    {'term': 'teamwork',
#     'class': 'negative',
#     'probability': [0.9969677329063416,
#      0.001958282431587577,
#      0.0010740001453086734],
#     'context': ['Corporate needs to send all their staff over to a week of training at chic-fil-A college to learn about work ethic, time management, teamwork and basic manors.']},
#    {'term': 'time management',
#     'class': 'negative',
#     'probability': [0.9895713329315186,
#      0.009903143160045147,
#      0.0005255448049865663],
#     'context': ['Corporate needs to send all their staff over to a week of training at chic-fil-A college to learn about work ethic, time management, teamwork and basic manors.']},
#    {'term': 'work',
#     'class': 'negative',
#     'probability': [0.959642767906189,
#      0.0379057452082634,
#      0.0024514507967978716],
#     'context': ['Corporate needs to send all their staff over to a week of training at chic-fil-A college to learn about work ethic, time management, teamwork and basic manors.']},
#    {'term': 'staff',
#     'class': 'negative',
#     'probability': [0.9991330504417419,
#      0.000503927527461201,
#      0.0003630200808402151],
#     'context': ['The staff is horrible.',
#      'Corporate needs to send all their staff over to a week of training at chic-fil-A college to learn about work ethic, time management, teamwork and basic manors.']}],
#   'sentiment': 'negative'},
#  '96': {'reviewer_id': 97,
#   'review_time': '2022-12-04',
#   'rating': 1,
#   'review_processed': 'When ordering food, the employees forgot to turn off their microphones and were talking messily about all the food we had ordered. This is very unprofessional and honestly uncalled for. When I asked for a receipt, they said it was in the bad and it was not in there.',
#   'aspect_sentiment': [{'term': 'employees',
#     'class': 'negative',
#     'probability': [0.9987253546714783,
#      0.0005044877761974931,
#      0.000770182756241411],
#     'context': ['When ordering food, the employees forgot to turn off their microphones and were talking messily about all the food we had ordered.']},
#    {'term': 'food',
#     'class': 'negative',
#     'probability': [0.9288522005081177,
#      0.06959313899278641,
#      0.0015547084622085094],
#     'context': ['When ordering food, the employees forgot to turn off their microphones and were talking messily about all the food we had ordered.']}],
#   'sentiment': 'negative'},
#  '97': {'reviewer_id': 98,
#   'review_time': '2021-12-04',
#   'rating': 1,
#   'review_processed': "I don't usually review places, but this location has ridiculously rude service and consistently gets the orders wrong. Even when not busy, they are rude. If I were rude, I wouldn't be able to enjoy the experience at this location. It's ridiculous.",
#   'aspect_sentiment': [{'term': 'orders',
#     'class': 'negative',
#     'probability': [0.9989007711410522,
#      0.0005099655245430768,
#      0.0005892295157536864],
#     'context': ["I don't usually review places, but this location has ridiculously rude service and consistently gets the orders wrong."]},
#    {'term': 'service',
#     'class': 'negative',
#     'probability': [0.9983295798301697,
#      0.0003267021384090185,
#      0.0013437323505058885],
#     'context': ["I don't usually review places, but this location has ridiculously rude service and consistently gets the orders wrong."]}],
#   'sentiment': 'negative'},
#  '98': {'reviewer_id': 99,
#   'review_time': '2024-06-04',
#   'rating': 5,
#   'review_processed': "Allways has the best fries and ice cream in the world; it's the best in the whole world! correct: It has the world's best fries, and the best ice cream anywhere! It's very tasty. It's amazing. It is the best!",
#   'aspect_sentiment': [{'term': 'ice cream',
#     'class': 'postive',
#     'probability': [0.0001824156061047688,
#      0.0002252057456644252,
#      0.9995923638343811],
#     'context': ["Allways has the best fries and ice cream in the world; it's the best in the whole world!",
#      "correct: It has the world's best fries, and the best ice cream anywhere!"]},
#    {'term': 'fries',
#     'class': 'postive',
#     'probability': [0.00017211318481713533,
#      0.00021300360094755888,
#      0.999614953994751],
#     'context': ["Allways has the best fries and ice cream in the world; it's the best in the whole world!",
#      "correct: It has the world's best fries, and the best ice cream anywhere!"]}],
#   'sentiment': 'positive'},
#  '99': {'reviewer_id': 100,
#   'review_time': '2023-12-04',
#   'rating': 4,
#   'review_processed': "McDonald's is great, but they need to hire people who understand both English and Spanish. The people are really nice, but be smarter about who you put in the drive thru and lobby to take orders. The staff are all Spanish speakers trying to take English orders.",
#   'aspect_sentiment': [{'term': 'staff',
#     'class': 'postive',
#     'probability': [0.02162514440715313,
#      0.06668327003717422,
#      0.9116915464401245],
#     'context': ['The staff are all Spanish speakers trying to take English orders.']}],
#   'sentiment': 'positive'}}

# %%
df = pd.DataFrame.from_dict(data, 'index')

print(df.info())
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   reviewer_id       100 non-null    int64
#  1   review_time       100 non-null    object
#  2   rating            100 non-null    int64
#  3   review_processed  100 non-null    object
#  4   aspect_sentiment  100 non-null    object
#  5   sentiment         100 non-null    object
# dtypes: int64(2), object(4)
# memory usage: 5.5+ KB
# None
#    reviewer_id review_time  rating  \
# 0            1  2024-09-04       1
# 1            2  2024-11-29       4
# 2            3  2024-11-29       1
# 3            4  2024-11-04       5
# 4            5  2024-10-04       1
#
#                                     review_processed  \
# 0  I had a normal transaction, everyone was calm ...
# 1  The staff at McDonald's are friendly, accommod...
# 2  I made a mobile order got to the speaker and c...
# 3  Crispy chicken sandwich was delicious, and cus...
# 4  I repeat my order three times in the drive thr...
#
#                                     aspect_sentiment sentiment
# 0  [{'term': 'food', 'class': 'negative', 'probab...  negative
# 1  [{'term': 'fast food', 'class': 'postive', 'pr...  positive
# 2  [{'term': 'speaker', 'class': 'neutral', 'prob...  negative
# 3  [{'term': 'sandwich', 'class': 'postive', 'pro...  positive
# 4  [{'term': 'fries', 'class': 'negative', 'proba...  negative

# %% [markdown]
# # Modeling

# %%
corpus = df['review_processed'].values

# %%
# Define the list of stopwords
stop_words = set(stopwords.words('english'))

# %%
# Preprocessing text
def preprocessing(text):

    # Get token of words
    doc = nlp(text)
    result = []
    for token in doc:
        t = token.lemma_.lower()

        if re.match(r'^[0-9\W]+$', t) or len(t) < 3 or t in stop_words:
            continue
        # If the token is adjective, noun, propn, or verb
        if token.pos_ in ['NOUN', 'PROPN']:
            result.append(t)
        elif token.pos_ in ['ADJ', 'VERB']:
            result.append(t)
        else:
            continue
    return result

# Create texts
texts = [preprocessing(document) for document in corpus]

# Create dictionary
dictionary = gensim.corpora.Dictionary(texts)


# Convert documents into Bag-of-words format
corpus_bow = [dictionary.doc2bow(text) for text in texts]

# Train the TF-IDF model
tfidf_model = gensim.models.TfidfModel(corpus_bow)

# Get corpus tfidf 
corpus_tfidf = tfidf_model[corpus_bow]

# %%
def topic_model_coherence_generator(corpus, texts, dictionary,
                                    start_topic_count=2, end_topic_count=10,
                                    step=1, cpus=1):
    models = []
    coherence_scores = []
    for topic_nums in tqdm(range(start_topic_count, end_topic_count+1, step)):
        lda_model = gensim.models.LdaModel(corpus=corpus, id2word=dictionary,
                                           chunksize=1740, alpha='auto',
                                           eta='auto', random_state=42,
                                           iterations=500, num_topics=topic_nums,
                                           passes=20, eval_every=None)

        cv_coherence_model_lda = gensim.models.CoherenceModel(model=lda_model,
                                                                     corpus=corpus,
                                                                     texts=texts,
                                                                     dictionary=dictionary,
                                                                     coherence='c_v')
        coherence_score = cv_coherence_model_lda.get_coherence()
        coherence_scores.append(coherence_score)
        models.append(lda_model)


    return models, coherence_scores

models, coherence_scores = topic_model_coherence_generator(corpus=corpus_tfidf,
                                                           texts=texts,
                                                           dictionary=dictionary)
opt_model = models[np.argmax(coherence_scores)]
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████| 9/9 [01:00<00:00,  6.68s/it]

# %%
# opt_model = models[3]

# %%
# Calculate overall mean coherence score
topics_coherences = opt_model.top_topics(corpus_tfidf, topn=20)

# %%
coherence_scores
# Out:
# [0.3733855034629775,
#  0.3974876417762688,
#  0.4367221281119681,
#  0.4745998024115434,
#  0.5003586436412433,
#  0.4970216453772654,
#  0.4942239209087066,
#  0.4672160213893543,
#  0.4960869715331455]

# %% [markdown]
# # Result

# %%
# Visualize result: Topic with weights

topics_with_wts = [item[0] for item in topics_coherences]
print("LDA Topics with Weights")
print('='*50)
for idx, topic in enumerate(topics_with_wts):
  print(f'Topic {idx + 1}:')
  print([(term, round(wt, 3)) for wt, term in topic])
  print()
# Out:
# LDA Topics with Weights
# ==================================================
# Topic 1:
# [('good', 0.01), ('amazing', 0.008), ('food', 0.008), ('ice', 0.008), ('order', 0.007), ('cream', 0.007), ('service', 0.007), ('wrong', 0.006), ('come', 0.005), ('quick', 0.005), ('correct', 0.005), ('get', 0.005), ('taste', 0.005), ('late', 0.005), ('fast', 0.005), ('mcdonald', 0.005), ('great', 0.004), ('door', 0.004), ('right', 0.004), ('line', 0.004)]
#
# Topic 2:
# [('food', 0.006), ('time', 0.006), ('letter', 0.006), ('order', 0.006), ('love', 0.006), ('well', 0.005), ('fry', 0.005), ('customer', 0.005), ('difference', 0.004), ('raw', 0.004), ('give', 0.004), ('get', 0.004), ('meal', 0.004), ('experience', 0.004), ('mess', 0.004), ('take', 0.004), ('extra', 0.004), ('call', 0.004), ('cold', 0.004), ('minute', 0.004)]
#
# Topic 3:
# [('rude', 0.006), ('nice', 0.005), ('hour', 0.005), ('people', 0.005), ('manager', 0.005), ('exist', 0.005), ('issue', 0.005), ('order', 0.005), ('enjoy', 0.005), ('try', 0.005), ('say', 0.005), ('coffee', 0.004), ('point', 0.004), ('mcdonald', 0.004), ('location', 0.004), ('place', 0.004), ('work', 0.004), ('spanish', 0.004), ('day', 0.004), ('know', 0.004)]
#
# Topic 4:
# [('drink', 0.007), ('large', 0.006), ('thru', 0.006), ('menu', 0.005), ('take', 0.005), ('order', 0.005), ('job', 0.005), ('staff', 0.005), ('drive', 0.004), ('last', 0.004), ('employee', 0.004), ('student', 0.004), ('line', 0.004), ('make', 0.004), ('sauce', 0.004), ('sit', 0.004), ('get', 0.004), ('store', 0.004), ('change', 0.004), ('sandwich', 0.004)]
#
# Topic 5:
# [('staff', 0.006), ('wait', 0.005), ('make', 0.005), ('manager', 0.005), ('great', 0.005), ('smoothie', 0.004), ('miss', 0.004), ('customer', 0.004), ('correct', 0.004), ('boy', 0.004), ('meal', 0.004), ('confuse', 0.004), ('unhappy', 0.004), ('clean', 0.004), ('fresh', 0.004), ('leave', 0.004), ('upgrade', 0.004), ('period', 0.004), ('fresher', 0.004), ('attitude', 0.004)]

# %%
topics = [[(term, round(wt, 3))
              for term, wt in opt_model.show_topic(n, topn=20)]
          for n in range(0, opt_model.num_topics)
          ]

topic_df = pd.DataFrame([', '.join([term for term, wt in topic]) for topic in topics],
                       columns=['Term per Topic'],
                       index=[str(t) for t in range(1, opt_model.num_topics+1)])
topic_df
# Out:
#                                       Term per Topic
# 1  rude, nice, hour, people, manager, exist, issu...
# 2  drink, large, thru, menu, take, order, job, st...
# 3  staff, wait, make, manager, great, smoothie, m...
# 4  good, amazing, food, ice, order, cream, servic...
# 5  food, time, letter, order, love, well, fry, cu...

# %%
topic_json = topic_df.reset_index().rename({'index': 'topic', 'Term per Topic': 'term'}, axis=1).to_dict('records')

topic_json
# Out:
# [{'topic': '1',
#   'term': 'rude, nice, hour, people, manager, exist, issue, order, enjoy, try, say, coffee, point, mcdonald, location, place, work, spanish, day, know'},
#  {'topic': '2',
#   'term': 'drink, large, thru, menu, take, order, job, staff, drive, last, employee, student, line, make, sauce, sit, get, store, change, sandwich'},
#  {'topic': '3',
#   'term': 'staff, wait, make, manager, great, smoothie, miss, customer, correct, boy, meal, confuse, unhappy, clean, fresh, leave, upgrade, period, fresher, attitude'},
#  {'topic': '4',
#   'term': 'good, amazing, food, ice, order, cream, service, wrong, come, quick, correct, get, taste, late, fast, mcdonald, great, door, right, line'},
#  {'topic': '5',
#   'term': 'food, time, letter, order, love, well, fry, customer, difference, raw, give, get, meal, experience, mess, take, extra, call, cold, minute'}]

# %%
# Interpreting result
tm_results = opt_model[corpus_tfidf]

# Corpus Topics
corpus_topics = [sorted(topics, key=lambda record: -record[1])[0]
                 for topics in tm_results]

corpus_topics[:5]
# Out:
# [(3, 0.9312262),
#  (4, 0.91646194),
#  (2, 0.92595273),
#  (3, 0.9244299),
#  (1, 0.9345906)]

# %%
count = 0
for topics in tm_results:
    count += 1
    temp = [t[-1] for t in topics]
    if count == 2:
        break
print(temp)
sum(temp)
# Out:
# [0.020123467, 0.020095162, 0.016854065, 0.026465379, 0.91646194]
# 1.0000000167638063

# %%
corpus_topic_df = pd.DataFrame(index=df['reviewer_id'].values)
corpus_topic_df['topic'] = [item[0]+1 for item in corpus_topics]
corpus_topic_df['probability'] = [round(item[1], 4) for item in corpus_topics]
corpus_topic_df['terms'] = [topic_df.iloc[t[0]]['Term per Topic'] for t in corpus_topics]
# corpus_topic_df['reviewer_id'] = df['reviewer_id'].values

corpus_topic_df.head()
# Out:
#    topic  probability                                              terms
# 1      4       0.9312  good, amazing, food, ice, order, cream, servic...
# 2      5       0.9165  food, time, letter, order, love, well, fry, cu...
# 3      3       0.9260  staff, wait, make, manager, great, smoothie, m...
# 4      4       0.9244  good, amazing, food, ice, order, cream, servic...
# 5      2       0.9346  drink, large, thru, menu, take, order, job, st...

# %%
corpus_topic_json = corpus_topic_df.to_dict('index')

corpus_topic_json
# Out:
# {1: {'topic': 4,
#   'probability': 0.9312000274658203,
#   'terms': 'good, amazing, food, ice, order, cream, service, wrong, come, quick, correct, get, taste, late, fast, mcdonald, great, door, right, line'},
#  2: {'topic': 5,
#   'probability': 0.9164999723434448,
#   'terms': 'food, time, letter, order, love, well, fry, customer, difference, raw, give, get, meal, experience, mess, take, extra, call, cold, minute'},
#  3: {'topic': 3,
#   'probability': 0.9259999990463257,
#   'terms': 'staff, wait, make, manager, great, smoothie, miss, customer, correct, boy, meal, confuse, unhappy, clean, fresh, leave, upgrade, period, fresher, attitude'},
#  4: {'topic': 4,
#   'probability': 0.9243999719619751,
#   'terms': 'good, amazing, food, ice, order, cream, service, wrong, come, quick, correct, get, taste, late, fast, mcdonald, great, door, right, line'},
#  5: {'topic': 2,
#   'probability': 0.9345999956130981,
#   'terms': 'drink, large, thru, menu, take, order, job, staff, drive, last, employee, student, line, make, sauce, sit, get, store, change, sandwich'},
#  6: {'topic': 4,
#   'probability': 0.9276000261306763,
#   'terms': 'good, amazing, food, ice, order, cream, service, wrong, come, quick, correct, get, taste, late, fast, mcdonald, great, door, right, line'},
#  7: {'topic': 5,
#   'probability': 0.9178000092506409,
#   'terms': 'food, time, letter, order, love, well, fry, customer, difference, raw, give, get, meal, experience, mess, take, extra, call, cold, minute'},
#  8: {'topic': 4,
#   'probability': 0.9366999864578247,
#   'terms': 'good, amazing, food, ice, order, cream, service, wrong, come, quick, correct, get, taste, late, fast, mcdonald, great, door, right, line'},
#  9: {'topic': 3,
#   'probability': 0.9207000136375427,
#   'terms': 'staff, wait, make, manager, great, smoothie, miss, customer, correct, boy, meal, confuse, unhappy, clean, fresh, leave, upgrade, period, fresher, attitude'},
#  10: {'topic': 1,
#   'probability': 0.921999990940094,
#   'terms': 'rude, nice, hour, people, manager, exist, issue, order, enjoy, try, say, coffee, point, mcdonald, location, place, work, spanish, day, know'},
#  11: {'topic': 1,
#   'probability': 0.9070000052452087,
#   'terms': 'rude, nice, hour, people, manager, exist, issue, order, enjoy, try, say, coffee, point, mcdonald, location, place, work, spanish, day, know'},
#  12: {'topic': 3,
#   'probability': 0.9218999743461609,
#   'terms': 'staff, wait, make, manager, great, smoothie, miss, customer, correct, boy, meal, confuse, unhappy, clean, fresh, leave, upgrade, period, fresher, attitude'},
#  13: {'topic': 4,
#   'probability': 0.9416999816894531,
#   'terms': 'good, amazing, food, ice, order, cream, service, wrong, come, quick, correct, get, taste, late, fast, mcdonald, great, door, right, line'},
#  14: {'topic': 4,
#   'probability': 0.9359999895095825,
#   'terms': 'good, amazing, food, ice, order, cream, service, wrong, come, quick, correct, get, taste, late, fast, mcdonald, great, door, right, line'},
#  15: {'topic': 4,
#   'probability': 0.9345999956130981,
#   'terms': 'good, amazing, food, ice, order, cream, service, wrong, come, quick, correct, get, taste, late, fast, mcdonald, great, door, right, line'},
#  16: {'topic': 4,
#   'probability': 0.9232000112533569,
#   'terms': 'good, amazing, food, ice, order, cream, service, wrong, come, quick, correct, get, taste, late, fast, mcdonald, great, door, right, line'},
#  17: {'topic': 2,
#   'probability': 0.9230999946594238,
#   'terms': 'drink, large, thru, menu, take, order, job, staff, drive, last, employee, student, line, make, sauce, sit, get, store, change, sandwich'},
#  18: {'topic': 3,
#   'probability': 0.9146000146865845,
#   'terms': 'staff, wait, make, manager, great, smoothie, miss, customer, correct, boy, meal, confuse, unhappy, clean, fresh, leave, upgrade, period, fresher, attitude'},
#  19: {'topic': 3,
#   'probability': 0.911899983882904,
#   'terms': 'staff, wait, make, manager, great, smoothie, miss, customer, correct, boy, meal, confuse, unhappy, clean, fresh, leave, upgrade, period, fresher, attitude'},
#  20: {'topic': 2,
#   'probability': 0.9291999936103821,
#   'terms': 'drink, large, thru, menu, take, order, job, staff, drive, last, employee, student, line, make, sauce, sit, get, store, change, sandwich'},
#  21: {'topic': 4,
#   'probability': 0.9391999840736389,
#   'terms': 'good, amazing, food, ice, order, cream, service, wrong, come, quick, correct, get, taste, late, fast, mcdonald, great, door, right, line'},
#  22: {'topic': 3,
#   'probability': 0.9262999892234802,
#   'terms': 'staff, wait, make, manager, great, smoothie, miss, customer, correct, boy, meal, confuse, unhappy, clean, fresh, leave, upgrade, period, fresher, attitude'},
#  23: {'topic': 2,
#   'probability': 0.9282000064849854,
#   'terms': 'drink, large, thru, menu, take, order, job, staff, drive, last, employee, student, line, make, sauce, sit, get, store, change, sandwich'},
#  24: {'topic': 5,
#   'probability': 0.9223999977111816,
#   'terms': 'food, time, letter, order, love, well, fry, customer, difference, raw, give, get, meal, experience, mess, take, extra, call, cold, minute'},
#  25: {'topic': 1,
#   'probability': 0.8562999963760376,
#   'terms': 'rude, nice, hour, people, manager, exist, issue, order, enjoy, try, say, coffee, point, mcdonald, location, place, work, spanish, day, know'},
#  26: {'topic': 4,
#   'probability': 0.9164000153541565,
#   'terms': 'good, amazing, food, ice, order, cream, service, wrong, come, quick, correct, get, taste, late, fast, mcdonald, great, door, right, line'},
#  27: {'topic': 3,
#   'probability': 0.9075000286102295,
#   'terms': 'staff, wait, make, manager, great, smoothie, miss, customer, correct, boy, meal, confuse, unhappy, clean, fresh, leave, upgrade, period, fresher, attitude'},
#  28: {'topic': 4,
#   'probability': 0.9301999807357788,
#   'terms': 'good, amazing, food, ice, order, cream, service, wrong, come, quick, correct, get, taste, late, fast, mcdonald, great, door, right, line'},
#  29: {'topic': 2,
#   'probability': 0.9153000116348267,
#   'terms': 'drink, large, thru, menu, take, order, job, staff, drive, last, employee, student, line, make, sauce, sit, get, store, change, sandwich'},
#  30: {'topic': 2,
#   'probability': 0.9205999970436096,
#   'terms': 'drink, large, thru, menu, take, order, job, staff, drive, last, employee, student, line, make, sauce, sit, get, store, change, sandwich'},
#  31: {'topic': 5,
#   'probability': 0.9070000052452087,
#   'terms': 'food, time, letter, order, love, well, fry, customer, difference, raw, give, get, meal, experience, mess, take, extra, call, cold, minute'},
#  32: {'topic': 2,
#   'probability': 0.9372000098228455,
#   'terms': 'drink, large, thru, menu, take, order, job, staff, drive, last, employee, student, line, make, sauce, sit, get, store, change, sandwich'},
#  33: {'topic': 4,
#   'probability': 0.9240999817848206,
#   'terms': 'good, amazing, food, ice, order, cream, service, wrong, come, quick, correct, get, taste, late, fast, mcdonald, great, door, right, line'},
#  34: {'topic': 3,
#   'probability': 0.9236999750137329,
#   'terms': 'staff, wait, make, manager, great, smoothie, miss, customer, correct, boy, meal, confuse, unhappy, clean, fresh, leave, upgrade, period, fresher, attitude'},
#  35: {'topic': 4,
#   'probability': 0.9172000288963318,
#   'terms': 'good, amazing, food, ice, order, cream, service, wrong, come, quick, correct, get, taste, late, fast, mcdonald, great, door, right, line'},
#  36: {'topic': 2,
#   'probability': 0.9187999963760376,
#   'terms': 'drink, large, thru, menu, take, order, job, staff, drive, last, employee, student, line, make, sauce, sit, get, store, change, sandwich'},
#  37: {'topic': 5,
#   'probability': 0.8851000070571899,
#   'terms': 'food, time, letter, order, love, well, fry, customer, difference, raw, give, get, meal, experience, mess, take, extra, call, cold, minute'},
#  38: {'topic': 2,
#   'probability': 0.8672999739646912,
#   'terms': 'drink, large, thru, menu, take, order, job, staff, drive, last, employee, student, line, make, sauce, sit, get, store, change, sandwich'},
#  39: {'topic': 4,
#   'probability': 0.913100004196167,
#   'terms': 'good, amazing, food, ice, order, cream, service, wrong, come, quick, correct, get, taste, late, fast, mcdonald, great, door, right, line'},
#  40: {'topic': 2,
#   'probability': 0.9193000197410583,
#   'terms': 'drink, large, thru, menu, take, order, job, staff, drive, last, employee, student, line, make, sauce, sit, get, store, change, sandwich'},
#  41: {'topic': 2,
#   'probability': 0.8989999890327454,
#   'terms': 'drink, large, thru, menu, take, order, job, staff, drive, last, employee, student, line, make, sauce, sit, get, store, change, sandwich'},
#  42: {'topic': 3,
#   'probability': 0.9254000186920166,
#   'terms': 'staff, wait, make, manager, great, smoothie, miss, customer, correct, boy, meal, confuse, unhappy, clean, fresh, leave, upgrade, period, fresher, attitude'},
#  43: {'topic': 5,
#   'probability': 0.9284999966621399,
#   'terms': 'food, time, letter, order, love, well, fry, customer, difference, raw, give, get, meal, experience, mess, take, extra, call, cold, minute'},
#  44: {'topic': 3,
#   'probability': 0.9189000129699707,
#   'terms': 'staff, wait, make, manager, great, smoothie, miss, customer, correct, boy, meal, confuse, unhappy, clean, fresh, leave, upgrade, period, fresher, attitude'},
#  45: {'topic': 2,
#   'probability': 0.8920999765396118,
#   'terms': 'drink, large, thru, menu, take, order, job, staff, drive, last, employee, student, line, make, sauce, sit, get, store, change, sandwich'},
#  46: {'topic': 4,
#   'probability': 0.9340999722480774,
#   'terms': 'good, amazing, food, ice, order, cream, service, wrong, come, quick, correct, get, taste, late, fast, mcdonald, great, door, right, line'},
#  47: {'topic': 5,
#   'probability': 0.909600019454956,
#   'terms': 'food, time, letter, order, love, well, fry, customer, difference, raw, give, get, meal, experience, mess, take, extra, call, cold, minute'},
#  48: {'topic': 4,
#   'probability': 0.9347000122070312,
#   'terms': 'good, amazing, food, ice, order, cream, service, wrong, come, quick, correct, get, taste, late, fast, mcdonald, great, door, right, line'},
#  49: {'topic': 3,
#   'probability': 0.9366999864578247,
#   'terms': 'staff, wait, make, manager, great, smoothie, miss, customer, correct, boy, meal, confuse, unhappy, clean, fresh, leave, upgrade, period, fresher, attitude'},
#  50: {'topic': 2,
#   'probability': 0.9332000017166138,
#   'terms': 'drink, large, thru, menu, take, order, job, staff, drive, last, employee, student, line, make, sauce, sit, get, store, change, sandwich'},
#  51: {'topic': 4,
#   'probability': 0.9251999855041504,
#   'terms': 'good, amazing, food, ice, order, cream, service, wrong, come, quick, correct, get, taste, late, fast, mcdonald, great, door, right, line'},
#  52: {'topic': 2,
#   'probability': 0.934499979019165,
#   'terms': 'drink, large, thru, menu, take, order, job, staff, drive, last, employee, student, line, make, sauce, sit, get, store, change, sandwich'},
#  53: {'topic': 1,
#   'probability': 0.9211999773979187,
#   'terms': 'rude, nice, hour, people, manager, exist, issue, order, enjoy, try, say, coffee, point, mcdonald, location, place, work, spanish, day, know'},
#  54: {'topic': 4,
#   'probability': 0.9294999837875366,
#   'terms': 'good, amazing, food, ice, order, cream, service, wrong, come, quick, correct, get, taste, late, fast, mcdonald, great, door, right, line'},
#  55: {'topic': 4,
#   'probability': 0.9107999801635742,
#   'terms': 'good, amazing, food, ice, order, cream, service, wrong, come, quick, correct, get, taste, late, fast, mcdonald, great, door, right, line'},
#  56: {'topic': 4,
#   'probability': 0.9142000079154968,
#   'terms': 'good, amazing, food, ice, order, cream, service, wrong, come, quick, correct, get, taste, late, fast, mcdonald, great, door, right, line'},
#  57: {'topic': 5,
#   'probability': 0.9157000184059143,
#   'terms': 'food, time, letter, order, love, well, fry, customer, difference, raw, give, get, meal, experience, mess, take, extra, call, cold, minute'},
#  58: {'topic': 4,
#   'probability': 0.9337000250816345,
#   'terms': 'good, amazing, food, ice, order, cream, service, wrong, come, quick, correct, get, taste, late, fast, mcdonald, great, door, right, line'},
#  59: {'topic': 1,
#   'probability': 0.9327999949455261,
#   'terms': 'rude, nice, hour, people, manager, exist, issue, order, enjoy, try, say, coffee, point, mcdonald, location, place, work, spanish, day, know'},
#  60: {'topic': 4,
#   'probability': 0.9135000109672546,
#   'terms': 'good, amazing, food, ice, order, cream, service, wrong, come, quick, correct, get, taste, late, fast, mcdonald, great, door, right, line'},
#  61: {'topic': 1,
#   'probability': 0.9293000102043152,
#   'terms': 'rude, nice, hour, people, manager, exist, issue, order, enjoy, try, say, coffee, point, mcdonald, location, place, work, spanish, day, know'},
#  62: {'topic': 1,
#   'probability': 0.9294000267982483,
#   'terms': 'rude, nice, hour, people, manager, exist, issue, order, enjoy, try, say, coffee, point, mcdonald, location, place, work, spanish, day, know'},
#  63: {'topic': 1,
#   'probability': 0.9352999925613403,
#   'terms': 'rude, nice, hour, people, manager, exist, issue, order, enjoy, try, say, coffee, point, mcdonald, location, place, work, spanish, day, know'},
#  64: {'topic': 2,
#   'probability': 0.9277999997138977,
#   'terms': 'drink, large, thru, menu, take, order, job, staff, drive, last, employee, student, line, make, sauce, sit, get, store, change, sandwich'},
#  65: {'topic': 4,
#   'probability': 0.9354000091552734,
#   'terms': 'good, amazing, food, ice, order, cream, service, wrong, come, quick, correct, get, taste, late, fast, mcdonald, great, door, right, line'},
#  66: {'topic': 1,
#   'probability': 0.9347000122070312,
#   'terms': 'rude, nice, hour, people, manager, exist, issue, order, enjoy, try, say, coffee, point, mcdonald, location, place, work, spanish, day, know'},
#  67: {'topic': 4,
#   'probability': 0.8892999887466431,
#   'terms': 'good, amazing, food, ice, order, cream, service, wrong, come, quick, correct, get, taste, late, fast, mcdonald, great, door, right, line'},
#  68: {'topic': 2,
#   'probability': 0.8984000086784363,
#   'terms': 'drink, large, thru, menu, take, order, job, staff, drive, last, employee, student, line, make, sauce, sit, get, store, change, sandwich'},
#  69: {'topic': 1,
#   'probability': 0.9290000200271606,
#   'terms': 'rude, nice, hour, people, manager, exist, issue, order, enjoy, try, say, coffee, point, mcdonald, location, place, work, spanish, day, know'},
#  70: {'topic': 2,
#   'probability': 0.9311000108718872,
#   'terms': 'drink, large, thru, menu, take, order, job, staff, drive, last, employee, student, line, make, sauce, sit, get, store, change, sandwich'},
#  71: {'topic': 1,
#   'probability': 0.9271000027656555,
#   'terms': 'rude, nice, hour, people, manager, exist, issue, order, enjoy, try, say, coffee, point, mcdonald, location, place, work, spanish, day, know'},
#  72: {'topic': 1,
#   'probability': 0.932699978351593,
#   'terms': 'rude, nice, hour, people, manager, exist, issue, order, enjoy, try, say, coffee, point, mcdonald, location, place, work, spanish, day, know'},
#  73: {'topic': 1,
#   'probability': 0.9333000183105469,
#   'terms': 'rude, nice, hour, people, manager, exist, issue, order, enjoy, try, say, coffee, point, mcdonald, location, place, work, spanish, day, know'},
#  74: {'topic': 3,
#   'probability': 0.9244999885559082,
#   'terms': 'staff, wait, make, manager, great, smoothie, miss, customer, correct, boy, meal, confuse, unhappy, clean, fresh, leave, upgrade, period, fresher, attitude'},
#  75: {'topic': 2,
#   'probability': 0.9323999881744385,
#   'terms': 'drink, large, thru, menu, take, order, job, staff, drive, last, employee, student, line, make, sauce, sit, get, store, change, sandwich'},
#  76: {'topic': 5,
#   'probability': 0.919700026512146,
#   'terms': 'food, time, letter, order, love, well, fry, customer, difference, raw, give, get, meal, experience, mess, take, extra, call, cold, minute'},
#  77: {'topic': 4,
#   'probability': 0.9336000084877014,
#   'terms': 'good, amazing, food, ice, order, cream, service, wrong, come, quick, correct, get, taste, late, fast, mcdonald, great, door, right, line'},
#  78: {'topic': 1,
#   'probability': 0.9138000011444092,
#   'terms': 'rude, nice, hour, people, manager, exist, issue, order, enjoy, try, say, coffee, point, mcdonald, location, place, work, spanish, day, know'},
#  79: {'topic': 3,
#   'probability': 0.9229999780654907,
#   'terms': 'staff, wait, make, manager, great, smoothie, miss, customer, correct, boy, meal, confuse, unhappy, clean, fresh, leave, upgrade, period, fresher, attitude'},
#  80: {'topic': 4,
#   'probability': 0.9122999906539917,
#   'terms': 'good, amazing, food, ice, order, cream, service, wrong, come, quick, correct, get, taste, late, fast, mcdonald, great, door, right, line'},
#  81: {'topic': 1,
#   'probability': 0.9391999840736389,
#   'terms': 'rude, nice, hour, people, manager, exist, issue, order, enjoy, try, say, coffee, point, mcdonald, location, place, work, spanish, day, know'},
#  82: {'topic': 2,
#   'probability': 0.9297000169754028,
#   'terms': 'drink, large, thru, menu, take, order, job, staff, drive, last, employee, student, line, make, sauce, sit, get, store, change, sandwich'},
#  83: {'topic': 3,
#   'probability': 0.927299976348877,
#   'terms': 'staff, wait, make, manager, great, smoothie, miss, customer, correct, boy, meal, confuse, unhappy, clean, fresh, leave, upgrade, period, fresher, attitude'},
#  84: {'topic': 3,
#   'probability': 0.9211999773979187,
#   'terms': 'staff, wait, make, manager, great, smoothie, miss, customer, correct, boy, meal, confuse, unhappy, clean, fresh, leave, upgrade, period, fresher, attitude'},
#  85: {'topic': 1,
#   'probability': 0.9261000156402588,
#   'terms': 'rude, nice, hour, people, manager, exist, issue, order, enjoy, try, say, coffee, point, mcdonald, location, place, work, spanish, day, know'},
#  86: {'topic': 1,
#   'probability': 0.9232000112533569,
#   'terms': 'rude, nice, hour, people, manager, exist, issue, order, enjoy, try, say, coffee, point, mcdonald, location, place, work, spanish, day, know'},
#  87: {'topic': 4,
#   'probability': 0.9200000166893005,
#   'terms': 'good, amazing, food, ice, order, cream, service, wrong, come, quick, correct, get, taste, late, fast, mcdonald, great, door, right, line'},
#  88: {'topic': 4,
#   'probability': 0.9269000291824341,
#   'terms': 'good, amazing, food, ice, order, cream, service, wrong, come, quick, correct, get, taste, late, fast, mcdonald, great, door, right, line'},
#  89: {'topic': 4,
#   'probability': 0.9452999830245972,
#   'terms': 'good, amazing, food, ice, order, cream, service, wrong, come, quick, correct, get, taste, late, fast, mcdonald, great, door, right, line'},
#  90: {'topic': 5,
#   'probability': 0.9162999987602234,
#   'terms': 'food, time, letter, order, love, well, fry, customer, difference, raw, give, get, meal, experience, mess, take, extra, call, cold, minute'},
#  91: {'topic': 2,
#   'probability': 0.9312999844551086,
#   'terms': 'drink, large, thru, menu, take, order, job, staff, drive, last, employee, student, line, make, sauce, sit, get, store, change, sandwich'},
#  92: {'topic': 1,
#   'probability': 0.9244999885559082,
#   'terms': 'rude, nice, hour, people, manager, exist, issue, order, enjoy, try, say, coffee, point, mcdonald, location, place, work, spanish, day, know'},
#  93: {'topic': 1,
#   'probability': 0.9284999966621399,
#   'terms': 'rude, nice, hour, people, manager, exist, issue, order, enjoy, try, say, coffee, point, mcdonald, location, place, work, spanish, day, know'},
#  94: {'topic': 2,
#   'probability': 0.9282000064849854,
#   'terms': 'drink, large, thru, menu, take, order, job, staff, drive, last, employee, student, line, make, sauce, sit, get, store, change, sandwich'},
#  95: {'topic': 5,
#   'probability': 0.909600019454956,
#   'terms': 'food, time, letter, order, love, well, fry, customer, difference, raw, give, get, meal, experience, mess, take, extra, call, cold, minute'},
#  96: {'topic': 3,
#   'probability': 0.9372000098228455,
#   'terms': 'staff, wait, make, manager, great, smoothie, miss, customer, correct, boy, meal, confuse, unhappy, clean, fresh, leave, upgrade, period, fresher, attitude'},
#  97: {'topic': 5,
#   'probability': 0.9136000275611877,
#   'terms': 'food, time, letter, order, love, well, fry, customer, difference, raw, give, get, meal, experience, mess, take, extra, call, cold, minute'},
#  98: {'topic': 1,
#   'probability': 0.9142000079154968,
#   'terms': 'rude, nice, hour, people, manager, exist, issue, order, enjoy, try, say, coffee, point, mcdonald, location, place, work, spanish, day, know'},
#  99: {'topic': 4,
#   'probability': 0.9117000102996826,
#   'terms': 'good, amazing, food, ice, order, cream, service, wrong, come, quick, correct, get, taste, late, fast, mcdonald, great, door, right, line'},
#  100: {'topic': 1,
#   'probability': 0.927299976348877,
#   'terms': 'rude, nice, hour, people, manager, exist, issue, order, enjoy, try, say, coffee, point, mcdonald, location, place, work, spanish, day, know'}}

# %%
df['topic'] = df['reviewer_id'].apply(lambda x: corpus_topic_json[x])

df.head()
# Out:
#    reviewer_id review_time  rating  \
# 0            1  2024-09-04       1
# 1            2  2024-11-29       4
# 2            3  2024-11-29       1
# 3            4  2024-11-04       5
# 4            5  2024-10-04       1
#
#                                     review_processed  \
# 0  I had a normal transaction, everyone was calm ...
# 1  The staff at McDonald's are friendly, accommod...
# 2  I made a mobile order got to the speaker and c...
# 3  Crispy chicken sandwich was delicious, and cus...
# 4  I repeat my order three times in the drive thr...
#
#                                     aspect_sentiment sentiment  \
# 0  [{'term': 'food', 'class': 'negative', 'probab...  negative
# 1  [{'term': 'fast food', 'class': 'postive', 'pr...  positive
# 2  [{'term': 'speaker', 'class': 'neutral', 'prob...  negative
# 3  [{'term': 'sandwich', 'class': 'postive', 'pro...  positive
# 4  [{'term': 'fries', 'class': 'negative', 'proba...  negative
#
#                                                topic
# 0  {'topic': 4, 'probability': 0.9312000274658203...
# 1  {'topic': 5, 'probability': 0.9164999723434448...
# 2  {'topic': 3, 'probability': 0.9259999990463257...
# 3  {'topic': 4, 'probability': 0.9243999719619751...
# 4  {'topic': 2, 'probability': 0.9345999956130981...

# %%
result = df.to_dict('index')
result
# Out:
# {'0': {'reviewer_id': 1,
#   'review_time': '2024-09-04',
#   'rating': 1,
#   'review_processed': "I had a normal transaction, everyone was calm and polite, but now I don't want to eat this. I'm trying not to think about what this milky white/clear substance is all over my food, and I'm sure I'm not coming back.",
#   'aspect_sentiment': [{'term': 'food',
#     'class': 'negative',
#     'probability': [0.9815933108329773,
#      0.015454968437552452,
#      0.002951699076220393],
#     'context': ["I'm trying not to think about what this milky white/clear substance is all over my food, and I'm sure I'm not coming back."]},
#    {'term': 'substance',
#     'class': 'negative',
#     'probability': [0.5997273921966553,
#      0.004296493716537952,
#      0.39597612619400024],
#     'context': ["I'm trying not to think about what this milky white/clear substance is all over my food, and I'm sure I'm not coming back."]}],
#   'sentiment': 'negative',
#   'topic': {'topic': 4,
#    'probability': 0.9312000274658203,
#    'terms': 'good, amazing, food, ice, order, cream, service, wrong, come, quick, correct, get, taste, late, fast, mcdonald, great, door, right, line'}},
#  '1': {'reviewer_id': 2,
#   'review_time': '2024-11-29',
#   'rating': 4,
#   'review_processed': "The staff at McDonald's are friendly, accommodating and always smiling. It is what it is as far as the food and atmosphere go; it's what it's always been. It makes for a more pleasant experience than many other fast food places in the area.",
#   'aspect_sentiment': [{'term': 'fast food',
#     'class': 'postive',
#     'probability': [0.006815647706389427,
#      0.03166038542985916,
#      0.9615239500999451],
#     'context': ['It makes for a more pleasant experience than many other fast food places in the area.']},
#    {'term': 'atmosphere',
#     'class': 'postive',
#     'probability': [0.0012359353713691235,
#      0.0019914235454052687,
#      0.9967727065086365],
#     'context': ["It is what it is as far as the food and atmosphere go; it's what it's always been."]},
#    {'term': 'food',
#     'class': 'postive',
#     'probability': [0.002793692983686924,
#      0.004679643549025059,
#      0.992526650428772],
#     'context': ["It is what it is as far as the food and atmosphere go; it's what it's always been.",
#      'It makes for a more pleasant experience than many other fast food places in the area.']},
#    {'term': 'staff',
#     'class': 'postive',
#     'probability': [0.00021674683375749737,
#      0.0003625940880738199,
#      0.9994207620620728],
#     'context': ["The staff at McDonald's are friendly, accommodating and always smiling."]}],
#   'sentiment': 'positive',
#   'topic': {'topic': 5,
#    'probability': 0.9164999723434448,
#    'terms': 'food, time, letter, order, love, well, fry, customer, difference, raw, give, get, meal, experience, mess, take, extra, call, cold, minute'}},
#  '2': {'reviewer_id': 3,
#   'review_time': '2024-11-29',
#   'rating': 1,
#   'review_processed': 'I made a mobile order got to the speaker and checked it in, but the line was not moving, so I had to leave. I never got the refund in the app. I called them and they said I could only get my money back in person because it was stuck in the system.',
#   'aspect_sentiment': [{'term': 'speaker',
#     'class': 'neutral',
#     'probability': [0.33699119091033936,
#      0.65718674659729,
#      0.005822065286338329],
#     'context': ['I made a mobile order got to the speaker and checked it in, but the line was not moving, so I had to leave.']}],
#   'sentiment': 'negative',
#   'topic': {'topic': 3,
#    'probability': 0.9259999990463257,
#    'terms': 'staff, wait, make, manager, great, smoothie, miss, customer, correct, boy, meal, confuse, unhappy, clean, fresh, leave, upgrade, period, fresher, attitude'}},
#  '3': {'reviewer_id': 4,
#   'review_time': '2024-11-04',
#   'rating': 5,
#   'review_processed': "Crispy chicken sandwich was delicious, and customer service was quick and efficient. My mc. was correct: My sandwich was crisp, but the service was fast and friendly. 'My mc. is correct': My sandwich is delicious, but my customer service is fast, friendly, and professional.",
#   'aspect_sentiment': [{'term': 'sandwich',
#     'class': 'postive',
#     'probability': [0.11512675136327744,
#      0.007394721265882254,
#      0.8774785399436951],
#     'context': ['Crispy chicken sandwich was delicious, and customer service was quick and efficient.',
#      'was correct: My sandwich was crisp, but the service was fast and friendly.',
#      "is correct': My sandwich is delicious, but my customer service is fast, friendly, and professional."]},
#    {'term': 'service',
#     'class': 'postive',
#     'probability': [0.06365323811769485,
#      0.0026424317620694637,
#      0.9337043166160583],
#     'context': ['Crispy chicken sandwich was delicious, and customer service was quick and efficient.',
#      'was correct: My sandwich was crisp, but the service was fast and friendly.',
#      "is correct': My sandwich is delicious, but my customer service is fast, friendly, and professional."]},
#    {'term': 'customer',
#     'class': 'postive',
#     'probability': [0.0929778441786766,
#      0.00539865018799901,
#      0.901623547077179],
#     'context': ['Crispy chicken sandwich was delicious, and customer service was quick and efficient.',
#      "is correct': My sandwich is delicious, but my customer service is fast, friendly, and professional."]},
#    {'term': 'crispy chicken sandwich',
#     'class': 'postive',
#     'probability': [0.04437816143035889,
#      0.002110624685883522,
#      0.9535112977027893],
#     'context': ['Crispy chicken sandwich was delicious, and customer service was quick and efficient.']}],
#   'sentiment': 'positive',
#   'topic': {'topic': 4,
#    'probability': 0.9243999719619751,
#    'terms': 'good, amazing, food, ice, order, cream, service, wrong, come, quick, correct, get, taste, late, fast, mcdonald, great, door, right, line'}},
#  '4': {'reviewer_id': 5,
#   'review_time': '2024-10-04',
#   'rating': 1,
#   'review_processed': 'I repeat my order three times in the drive thru, and she still manages to mess it up. It was suppose to be a large meal double filet of fish with large fries, but it was all wrong. They either need to pay close attention to the order being made, or they need not to work at a drive thru.',
#   'aspect_sentiment': [{'term': 'fries',
#     'class': 'negative',
#     'probability': [0.8274237513542175,
#      0.03699015825986862,
#      0.13558609783649445],
#     'context': ['It was suppose to be a large meal double filet of fish with large fries, but it was all wrong.']},
#    {'term': 'filet of fish',
#     'class': 'neutral',
#     'probability': [0.3450517952442169,
#      0.6001273989677429,
#      0.05482081323862076],
#     'context': ['It was suppose to be a large meal double filet of fish with large fries, but it was all wrong.']},
#    {'term': 'meal',
#     'class': 'negative',
#     'probability': [0.5714789628982544,
#      0.3977477252483368,
#      0.03077329508960247],
#     'context': ['It was suppose to be a large meal double filet of fish with large fries, but it was all wrong.']}],
#   'sentiment': 'negative',
#   'topic': {'topic': 2,
#    'probability': 0.9345999956130981,
#    'terms': 'drink, large, thru, menu, take, order, job, staff, drive, last, employee, student, line, make, sauce, sit, get, store, change, sandwich'}},
#  '5': {'reviewer_id': 6,
#   'review_time': '2024-12-01',
#   'rating': 1,
#   'review_processed': "I work for door dash and they locked us all out to wait in a long line for no reason at 10. I tried to beg them to open it because I'm door dash, but they refused. Covid is over; I'm getting a new job.",
#   'aspect_sentiment': [{'term': 'wait',
#     'class': 'negative',
#     'probability': [0.9932532906532288,
#      0.006253655068576336,
#      0.0004929883871227503],
#     'context': ['I work for door dash and they locked us all out to wait in a long line for no reason at 10.']},
#    {'term': 'door',
#     'class': 'negative',
#     'probability': [0.9924323558807373,
#      0.0022597189527004957,
#      0.005308002699166536],
#     'context': ['I work for door dash and they locked us all out to wait in a long line for no reason at 10.',
#      "I tried to beg them to open it because I'm door dash, but they refused."]}],
#   'sentiment': 'negative',
#   'topic': {'topic': 4,
#    'probability': 0.9276000261306763,
#    'terms': 'good, amazing, food, ice, order, cream, service, wrong, come, quick, correct, get, taste, late, fast, mcdonald, great, door, right, line'}},
#  '6': {'reviewer_id': 7,
#   'review_time': '2024-09-04',
#   'rating': 1,
#   'review_processed': "If I could give this location a zero on customer service, I would. It's a horrible experience every time as you can see by other reviews. After getting home, I had no regular hamburg but had cookies. Don't even bother going to this location again.",
#   'aspect_sentiment': [{'term': 'cookies',
#     'class': 'postive',
#     'probability': [0.15484055876731873,
#      0.015986056998372078,
#      0.8291733860969543],
#     'context': ['After getting home, I had no regular hamburg but had cookies.']},
#    {'term': 'hamburg',
#     'class': 'negative',
#     'probability': [0.998023509979248,
#      0.0009887544438242912,
#      0.0009877586271613836],
#     'context': ['After getting home, I had no regular hamburg but had cookies.']},
#    {'term': 'customer service',
#     'class': 'negative',
#     'probability': [0.9984126091003418,
#      0.0005393950268626213,
#      0.0010479566408321261],
#     'context': ['If I could give this location a zero on customer service, I would.']}],
#   'sentiment': 'negative',
#   'topic': {'topic': 5,
#    'probability': 0.9178000092506409,
#    'terms': 'food, time, letter, order, love, well, fry, customer, difference, raw, give, get, meal, experience, mess, take, extra, call, cold, minute'}},
#  '7': {'reviewer_id': 8,
#   'review_time': '2023-12-04',
#   'rating': 1,
#   'review_processed': 'I asked the employee if they could give me a Large coffee w/no ice and she said no. I always get a large sweet tea with no ice and it always tastes good. They handed me a cup that was less than half way full. I was willing to pay more to get a full cup.',
#   'aspect_sentiment': [{'term': 'cup',
#     'class': 'postive',
#     'probability': [0.14494062960147858,
#      0.2756275236606598,
#      0.5794318318367004],
#     'context': ['They handed me a cup that was less than half way full.',
#      'I was willing to pay more to get a full cup.']},
#    {'term': 'tea',
#     'class': 'postive',
#     'probability': [0.16581080853939056,
#      0.07779897004365921,
#      0.7563902735710144],
#     'context': ['I always get a large sweet tea with no ice and it always tastes good.']},
#    {'term': 'sweet',
#     'class': 'postive',
#     'probability': [0.16649764776229858,
#      0.22194929420948029,
#      0.6115531325340271],
#     'context': ['I always get a large sweet tea with no ice and it always tastes good.']},
#    {'term': 'coffee',
#     'class': 'postive',
#     'probability': [0.1834869384765625,
#      0.08739488571882248,
#      0.7291181087493896],
#     'context': ['I asked the employee if they could give me a Large coffee w/no ice and she said no.']}],
#   'sentiment': 'positive',
#   'topic': {'topic': 4,
#    'probability': 0.9366999864578247,
#    'terms': 'good, amazing, food, ice, order, cream, service, wrong, come, quick, correct, get, taste, late, fast, mcdonald, great, door, right, line'}},
#  '8': {'reviewer_id': 9,
#   'review_time': '2024-09-04',
#   'rating': 1,
#   'review_processed': 'My 10 pieces of chicken were missing. The restaurant gave me a hard time about extra sauce. I was very unhappy with the service at the restaurant. The manager was very unsympathetic to my request to get the chicken McNuggets back. The customer was also very unhappy.',
#   'aspect_sentiment': [{'term': 'chicken mcnuggets',
#     'class': 'postive',
#     'probability': [0.31099334359169006,
#      0.16668684780597687,
#      0.5223197937011719],
#     'context': ['The manager was very unsympathetic to my request to get the chicken McNuggets back.']},
#    {'term': 'manager',
#     'class': 'negative',
#     'probability': [0.9987077713012695,
#      0.0004580307868309319,
#      0.0008342147921212018],
#     'context': ['The manager was very unsympathetic to my request to get the chicken McNuggets back.']},
#    {'term': 'service',
#     'class': 'negative',
#     'probability': [0.9980725049972534,
#      0.0016530909342691302,
#      0.0002743771765381098],
#     'context': ['I was very unhappy with the service at the restaurant.']},
#    {'term': 'sauce',
#     'class': 'negative',
#     'probability': [0.9985558390617371,
#      0.0011071250773966312,
#      0.00033698396873660386],
#     'context': ['The restaurant gave me a hard time about extra sauce.']},
#    {'term': 'chicken',
#     'class': 'negative',
#     'probability': [0.9976153373718262,
#      0.002048772294074297,
#      0.0003359100373927504],
#     'context': ['My 10 pieces of chicken were missing.',
#      'The manager was very unsympathetic to my request to get the chicken McNuggets back.']}],
#   'sentiment': 'negative',
#   'topic': {'topic': 3,
#    'probability': 0.9207000136375427,
#    'terms': 'staff, wait, make, manager, great, smoothie, miss, customer, correct, boy, meal, confuse, unhappy, clean, fresh, leave, upgrade, period, fresher, attitude'}},
#  '9': {'reviewer_id': 10,
#   'review_time': '2024-09-04',
#   'rating': 4,
#   'review_processed': "I'm not a huge fan of fast food, but I have two teenage daughters who enjoy McD's. The staff here is always friendly and always get their orders correct. I always enjoy and appreciate quality service from quality people, and you'll definitely find it here.",
#   'aspect_sentiment': [{'term': 'service',
#     'class': 'postive',
#     'probability': [0.001063541043549776,
#      0.00024696311447769403,
#      0.998689591884613],
#     'context': ["I always enjoy and appreciate quality service from quality people, and you'll definitely find it here."]},
#    {'term': 'staff',
#     'class': 'postive',
#     'probability': [0.0011739794863387942,
#      0.00024848702014423907,
#      0.9985775947570801],
#     'context': ['The staff here is always friendly and always get their orders correct.']},
#    {'term': 'fast food',
#     'class': 'postive',
#     'probability': [0.34771257638931274,
#      0.014774005860090256,
#      0.6375134587287903],
#     'context': ["I'm not a huge fan of fast food, but I have two teenage daughters who enjoy McD's."]}],
#   'sentiment': 'positive',
#   'topic': {'topic': 1,
#    'probability': 0.921999990940094,
#    'terms': 'rude, nice, hour, people, manager, exist, issue, order, enjoy, try, say, coffee, point, mcdonald, location, place, work, spanish, day, know'}},
#  '10': {'reviewer_id': 11,
#   'review_time': '2024-09-04',
#   'rating': 1,
#   'review_processed': "The best McDonald's is the worst McDonald's, says the chain's owner. It's the only McDonald's in the U.S.; it's the worst in the world. It is the world's only fast food chain, and it's a terrible one.",
#   'aspect_sentiment': [{'term': 'fast food',
#     'class': 'negative',
#     'probability': [0.9725459814071655,
#      0.006914272904396057,
#      0.020539719611406326],
#     'context': ["It is the world's only fast food chain, and it's a terrible one."]}],
#   'sentiment': 'negative',
#   'topic': {'topic': 1,
#    'probability': 0.9070000052452087,
#    'terms': 'rude, nice, hour, people, manager, exist, issue, order, enjoy, try, say, coffee, point, mcdonald, location, place, work, spanish, day, know'}},
#  '11': {'reviewer_id': 12,
#   'review_time': '2024-06-04',
#   'rating': 2,
#   'review_processed': 'Our order was supposed to have 3 food items and 2 drinks, but they missed a food item. The lady ignored me when I told her. My husband went to get it, she finished her task then handed it to him without a word or a smile or anything.',
#   'aspect_sentiment': [{'term': 'food',
#     'class': 'neutral',
#     'probability': [0.03177140653133392,
#      0.9670061469078064,
#      0.0012224643724039197],
#     'context': ['Our order was supposed to have 3 food items and 2 drinks, but they missed a food item.']},
#    {'term': 'drinks',
#     'class': 'neutral',
#     'probability': [0.006546773482114077,
#      0.9927389025688171,
#      0.0007143780821934342],
#     'context': ['Our order was supposed to have 3 food items and 2 drinks, but they missed a food item.']},
#    {'term': 'food items',
#     'class': 'neutral',
#     'probability': [0.014800053089857101,
#      0.9838448166847229,
#      0.0013551837764680386],
#     'context': ['Our order was supposed to have 3 food items and 2 drinks, but they missed a food item.']}],
#   'sentiment': 'negative',
#   'topic': {'topic': 3,
#    'probability': 0.9218999743461609,
#    'terms': 'staff, wait, make, manager, great, smoothie, miss, customer, correct, boy, meal, confuse, unhappy, clean, fresh, leave, upgrade, period, fresher, attitude'}},
#  '12': {'reviewer_id': 13,
#   'review_time': '2024-06-04',
#   'rating': 1,
#   'review_processed': "The morning crew seems fast and efficient, but the night crew is a whole different experience. The staff is so rude you leave wanting to crash your car through the building. Don't forget they will mistake your order almost every single time as well and serve it to you cold.",
#   'aspect_sentiment': [{'term': 'staff',
#     'class': 'negative',
#     'probability': [0.9865595102310181,
#      0.0008878746884875,
#      0.012552599422633648],
#     'context': ['The staff is so rude you leave wanting to crash your car through the building.']},
#    {'term': 'night crew',
#     'class': 'postive',
#     'probability': [0.1201997622847557,
#      0.0037240320816636086,
#      0.8760762810707092],
#     'context': ['The morning crew seems fast and efficient, but the night crew is a whole different experience.']},
#    {'term': 'morning crew',
#     'class': 'postive',
#     'probability': [0.04071913659572601,
#      0.0013627063017338514,
#      0.9579181671142578],
#     'context': ['The morning crew seems fast and efficient, but the night crew is a whole different experience.']}],
#   'sentiment': 'negative',
#   'topic': {'topic': 4,
#    'probability': 0.9416999816894531,
#    'terms': 'good, amazing, food, ice, order, cream, service, wrong, come, quick, correct, get, taste, late, fast, mcdonald, great, door, right, line'}},
#  '13': {'reviewer_id': 14,
#   'review_time': '2023-12-04',
#   'rating': 3,
#   'review_processed': 'I was disappointed that the restaurant did not get me my full order, meaning I did not receive my condiments for my big breakfast with hot cakes. No butter, no syrup, and no utensils. Oh, and the egg was half the size of the sausage.',
#   'aspect_sentiment': [{'term': 'sausage',
#     'class': 'negative',
#     'probability': [0.9789081811904907,
#      0.019984861835837364,
#      0.0011069513857364655],
#     'context': ['Oh, and the egg was half the size of the sausage.']},
#    {'term': 'egg',
#     'class': 'negative',
#     'probability': [0.9930011034011841,
#      0.002290455624461174,
#      0.00470846937969327],
#     'context': ['Oh, and the egg was half the size of the sausage.']},
#    {'term': '##ensils',
#     'class': 'negative',
#     'probability': [0.8582509160041809,
#      0.07489224523305893,
#      0.06685690581798553],
#     'context': []},
#    {'term': 'ut',
#     'class': 'negative',
#     'probability': [0.9965523481369019,
#      0.002759113209322095,
#      0.0006885712500661612],
#     'context': []},
#    {'term': 'syrup',
#     'class': 'negative',
#     'probability': [0.9983137845993042,
#      0.0005611283122561872,
#      0.0011251039104536176],
#     'context': ['No butter, no syrup, and no utensils.']},
#    {'term': 'butter',
#     'class': 'negative',
#     'probability': [0.9982079267501831,
#      0.0008565931930206716,
#      0.0009354839567095041],
#     'context': ['No butter, no syrup, and no utensils.']},
#    {'term': 'breakfast with hot cakes',
#     'class': 'neutral',
#     'probability': [0.10337114334106445,
#      0.8078848719596863,
#      0.08874398469924927],
#     'context': ['I was disappointed that the restaurant did not get me my full order, meaning I did not receive my condiments for my big breakfast with hot cakes.']},
#    {'term': '##diments',
#     'class': 'negative',
#     'probability': [0.89311683177948,
#      0.05806119740009308,
#      0.04882201552391052],
#     'context': []},
#    {'term': 'con',
#     'class': 'negative',
#     'probability': [0.9474828839302063,
#      0.04992890730500221,
#      0.0025881922338157892],
#     'context': []}],
#   'sentiment': 'negative',
#   'topic': {'topic': 4,
#    'probability': 0.9359999895095825,
#    'terms': 'good, amazing, food, ice, order, cream, service, wrong, come, quick, correct, get, taste, late, fast, mcdonald, great, door, right, line'}},
#  '14': {'reviewer_id': 15,
#   'review_time': '2024-07-04',
#   'rating': 1,
#   'review_processed': 'Ordered food wrong and left out part of the order also. One of the drink cups were not filled; poor service girl handed the order at the window on January 7, 2023 at 1 p.m. correct: Ordered food burger wrong, left out some of the orders also.',
#   'aspect_sentiment': [{'term': 'food burger',
#     'class': 'negative',
#     'probability': [0.9960941672325134,
#      0.003144483547657728,
#      0.0007613926427438855],
#     'context': ['One of the drink cups were not filled; poor service girl handed the order at the window on January 7, 2023 at 1 p.m. correct: Ordered food burger wrong, left out some of the orders also.']},
#    {'term': 'drink cups',
#     'class': 'negative',
#     'probability': [0.9877892732620239,
#      0.011494306847453117,
#      0.0007163902628235519],
#     'context': ['One of the drink cups were not filled; poor service girl handed the order at the window on January 7, 2023 at 1 p.m. correct: Ordered food burger wrong, left out some of the orders also.']},
#    {'term': 'food',
#     'class': 'negative',
#     'probability': [0.994797945022583,
#      0.004450373817235231,
#      0.0007516511250287294],
#     'context': ['Ordered food wrong and left out part of the order also.',
#      'One of the drink cups were not filled; poor service girl handed the order at the window on January 7, 2023 at 1 p.m. correct: Ordered food burger wrong, left out some of the orders also.']}],
#   'sentiment': 'negative',
#   'topic': {'topic': 4,
#    'probability': 0.9345999956130981,
#    'terms': 'good, amazing, food, ice, order, cream, service, wrong, come, quick, correct, get, taste, late, fast, mcdonald, great, door, right, line'}},
#  '15': {'reviewer_id': 16,
#   'review_time': '2024-10-04',
#   'rating': 2,
#   'review_processed': "This was a dine in experience. The tables were all dirty, and we did not get our food after waiting 35 minutes. Chicken sandwich was burnt; tables were dirty and we didn't receive our food until after 35 minutes had passed; and the food was uneaten.",
#   'aspect_sentiment': [{'term': 'chicken sandwich',
#     'class': 'negative',
#     'probability': [0.9991394281387329,
#      0.00037128617987036705,
#      0.0004893332370556891],
#     'context': ["Chicken sandwich was burnt; tables were dirty and we didn't receive our food until after 35 minutes had passed; and the food was uneaten."]},
#    {'term': 'food',
#     'class': 'negative',
#     'probability': [0.9963996410369873,
#      0.003311085281893611,
#      0.00028918657335452735],
#     'context': ['The tables were all dirty, and we did not get our food after waiting 35 minutes.',
#      "Chicken sandwich was burnt; tables were dirty and we didn't receive our food until after 35 minutes had passed; and the food was uneaten."]},
#    {'term': 'tables',
#     'class': 'negative',
#     'probability': [0.9990373849868774,
#      0.0005781945656053722,
#      0.0003844642487820238],
#     'context': ['The tables were all dirty, and we did not get our food after waiting 35 minutes.',
#      "Chicken sandwich was burnt; tables were dirty and we didn't receive our food until after 35 minutes had passed; and the food was uneaten."]}],
#   'sentiment': 'negative',
#   'topic': {'topic': 4,
#    'probability': 0.9232000112533569,
#    'terms': 'good, amazing, food, ice, order, cream, service, wrong, come, quick, correct, get, taste, late, fast, mcdonald, great, door, right, line'}},
#  '16': {'reviewer_id': 17,
#   'review_time': '2023-12-04',
#   'rating': 4,
#   'review_processed': 'The line was extremely big and was moving very slowly, plus they were out of apples and strawberries, but they gave me a substitute cookie. The staff were very apologetic for being slow, but it was the middle of the night and they were extremely under-staffed.',
#   'aspect_sentiment': [{'term': 'staff',
#     'class': 'negative',
#     'probability': [0.9847680926322937,
#      0.0013101707445457578,
#      0.013921706937253475],
#     'context': ['The staff were very apologetic for being slow, but it was the middle of the night and they were extremely under-staffed.']},
#    {'term': 'cookie',
#     'class': 'negative',
#     'probability': [0.9897438883781433,
#      0.0049213538877666,
#      0.00533474562689662],
#     'context': ['The line was extremely big and was moving very slowly, plus they were out of apples and strawberries, but they gave me a substitute cookie.']},
#    {'term': 'apples strawberries',
#     'class': 'neutral',
#     'probability': [0.07545929402112961,
#      0.9139658808708191,
#      0.0105748837813735],
#     'context': []}],
#   'sentiment': 'negative',
#   'topic': {'topic': 2,
#    'probability': 0.9230999946594238,
#    'terms': 'drink, large, thru, menu, take, order, job, staff, drive, last, employee, student, line, make, sauce, sit, get, store, change, sandwich'}},
#  '17': {'reviewer_id': 18,
#   'review_time': '2024-10-04',
#   'rating': 1,
#   'review_processed': "The boy who attended me made me wait, and when he saw that the drink was wrong he threw the bag of food at me with a grimace. He was so disappointed, he was so angry! The boy was making me wait; he didn't want me to wait.",
#   'aspect_sentiment': [{'term': 'bag of food',
#     'class': 'neutral',
#     'probability': [0.11328613013029099,
#      0.8842231035232544,
#      0.002490766579285264],
#     'context': ['The boy who attended me made me wait, and when he saw that the drink was wrong he threw the bag of food at me with a grimace.']},
#    {'term': 'drink',
#     'class': 'negative',
#     'probability': [0.7699991464614868,
#      0.2245049625635147,
#      0.005495852790772915],
#     'context': ['The boy who attended me made me wait, and when he saw that the drink was wrong he threw the bag of food at me with a grimace.']}],
#   'sentiment': 'negative',
#   'topic': {'topic': 3,
#    'probability': 0.9146000146865845,
#    'terms': 'staff, wait, make, manager, great, smoothie, miss, customer, correct, boy, meal, confuse, unhappy, clean, fresh, leave, upgrade, period, fresher, attitude'}},
#  '18': {'reviewer_id': 19,
#   'review_time': '2024-05-04',
#   'rating': 1,
#   'review_processed': 'I went and bought 4 Strawberry Banana smoothies and and 2 hash browns and my smoothies tasted like straight ice and water. I am very disappointed in there service. My smoothie should never taste like that, especially the fact I bought it for not only me but my kids.',
#   'aspect_sentiment': [{'term': 'smoothie',
#     'class': 'negative',
#     'probability': [0.5565332174301147,
#      0.05360134318470955,
#      0.3898654580116272],
#     'context': ['My smoothie should never taste like that, especially the fact I bought it for not only me but my kids.']},
#    {'term': 'service',
#     'class': 'negative',
#     'probability': [0.9974496960639954,
#      0.0014037463115528226,
#      0.00114648905582726],
#     'context': ['I am very disappointed in there service.']},
#    {'term': 'water',
#     'class': 'postive',
#     'probability': [0.08196575194597244,
#      0.034085072576999664,
#      0.8839491009712219],
#     'context': ['I went and bought 4 Strawberry Banana smoothies and and 2 hash browns and my smoothies tasted like straight ice and water.']},
#    {'term': 'hash brownsies',
#     'class': 'postive',
#     'probability': [0.04074759781360626,
#      0.006972364149987698,
#      0.9522801041603088],
#     'context': []},
#    {'term': 'strawberry banana smoothies',
#     'class': 'postive',
#     'probability': [0.27268412709236145,
#      0.0066567654721438885,
#      0.7206591367721558],
#     'context': ['I went and bought 4 Strawberry Banana smoothies and and 2 hash browns and my smoothies tasted like straight ice and water.']}],
#   'sentiment': 'negative',
#   'topic': {'topic': 3,
#    'probability': 0.911899983882904,
#    'terms': 'staff, wait, make, manager, great, smoothie, miss, customer, correct, boy, meal, confuse, unhappy, clean, fresh, leave, upgrade, period, fresher, attitude'}},
#  '19': {'reviewer_id': 20,
#   'review_time': '2024-05-04',
#   'rating': 4,
#   'review_processed': 'The staff seems to always be different, which makes ordering sometimes a little difficult because they are in a state of perpetual learning. The lobby is always clean as well as the bathrooms, but the wait is always longer due to their constant changes in appearance. The staff are always different, making ordering difficult.',
#   'aspect_sentiment': [{'term': 'appearance',
#     'class': 'negative',
#     'probability': [0.9731659889221191,
#      0.024411581456661224,
#      0.0024223667569458485],
#     'context': ['The lobby is always clean as well as the bathrooms, but the wait is always longer due to their constant changes in appearance.']},
#    {'term': 'wait',
#     'class': 'negative',
#     'probability': [0.9962146878242493,
#      0.0017749888356775045,
#      0.0020102967973798513],
#     'context': ['The lobby is always clean as well as the bathrooms, but the wait is always longer due to their constant changes in appearance.']},
#    {'term': 'bathrooms',
#     'class': 'neutral',
#     'probability': [0.07573594897985458,
#      0.6802747249603271,
#      0.24398933351039886],
#     'context': ['The lobby is always clean as well as the bathrooms, but the wait is always longer due to their constant changes in appearance.']},
#    {'term': 'lobby',
#     'class': 'postive',
#     'probability': [0.16022616624832153,
#      0.0077795060351490974,
#      0.831994354724884],
#     'context': ['The lobby is always clean as well as the bathrooms, but the wait is always longer due to their constant changes in appearance.']},
#    {'term': 'staff',
#     'class': 'negative',
#     'probability': [0.7863964438438416,
#      0.013776720501482487,
#      0.19982686638832092],
#     'context': ['The staff seems to always be different, which makes ordering sometimes a little difficult because they are in a state of perpetual learning.',
#      'The staff are always different, making ordering difficult.']}],
#   'sentiment': 'negative',
#   'topic': {'topic': 2,
#    'probability': 0.9291999936103821,
#    'terms': 'drink, large, thru, menu, take, order, job, staff, drive, last, employee, student, line, make, sauce, sit, get, store, change, sandwich'}},
#  '20': {'reviewer_id': 21,
#   'review_time': '2024-02-04',
#   'rating': 1,
#   'review_processed': "Can't believe experience with order taker. Went from drive thru and employee directly asked what do you want. He keeps rushing while taking order with no other cars placing order. We wanted to add one more item and asked for a minute. When I said we are ready - no response.",
#   'aspect_sentiment': [{'term': 'order taker',
#     'class': 'negative',
#     'probability': [0.9969251751899719,
#      0.0028428477235138416,
#      0.0002319530030945316],
#     'context': ["Can't believe experience with order taker."]}],
#   'sentiment': 'negative',
#   'topic': {'topic': 4,
#    'probability': 0.9391999840736389,
#    'terms': 'good, amazing, food, ice, order, cream, service, wrong, come, quick, correct, get, taste, late, fast, mcdonald, great, door, right, line'}},
#  '21': {'reviewer_id': 22,
#   'review_time': '2020-12-04',
#   'rating': 1,
#   'review_processed': 'I only go here when they are not busy, in hope that my order is correct when I go to leave. When I finally get the correct order, it is generally tasty. The evening staff is pleasant, but the morning staff leaves a lot to be desired. The morning staff thinks they can talk negatively about people in Spanish out in the open.',
#   'aspect_sentiment': [{'term': 'morning staff',
#     'class': 'postive',
#     'probability': [0.29298898577690125,
#      0.004363544750958681,
#      0.7026475071907043],
#     'context': ['The evening staff is pleasant, but the morning staff leaves a lot to be desired.',
#      'The morning staff thinks they can talk negatively about people in Spanish out in the open.']},
#    {'term': 'evening staff',
#     'class': 'postive',
#     'probability': [0.18166635930538177,
#      0.0032298490405082703,
#      0.8151037693023682],
#     'context': ['The evening staff is pleasant, but the morning staff leaves a lot to be desired.']}],
#   'sentiment': 'negative',
#   'topic': {'topic': 3,
#    'probability': 0.9262999892234802,
#    'terms': 'staff, wait, make, manager, great, smoothie, miss, customer, correct, boy, meal, confuse, unhappy, clean, fresh, leave, upgrade, period, fresher, attitude'}},
#  '22': {'reviewer_id': 23,
#   'review_time': '2024-11-04',
#   'rating': 2,
#   'review_processed': "The staff at the drive thru just shoved the drink in my hands. It's not very professional. I just needed caffeine; I'm not a big fan of fast food. The food was good, but the service was unappetiteful and unprofessional.",
#   'aspect_sentiment': [{'term': 'service',
#     'class': 'negative',
#     'probability': [0.9968095421791077,
#      0.0007321911980397999,
#      0.0024582671467214823],
#     'context': ['The food was good, but the service was unappetiteful and unprofessional.']},
#    {'term': 'food',
#     'class': 'neutral',
#     'probability': [0.07116822898387909,
#      0.6706492304801941,
#      0.25818249583244324],
#     'context': ["I just needed caffeine; I'm not a big fan of fast food.",
#      'The food was good, but the service was unappetiteful and unprofessional.']},
#    {'term': 'fast food',
#     'class': 'neutral',
#     'probability': [0.102867990732193, 0.4722709655761719, 0.4248610734939575],
#     'context': ["I just needed caffeine; I'm not a big fan of fast food."]},
#    {'term': '##feine',
#     'class': 'negative',
#     'probability': [0.8221876621246338,
#      0.008761527948081493,
#      0.16905087232589722],
#     'context': []},
#    {'term': 'caf',
#     'class': 'neutral',
#     'probability': [0.033860109746456146,
#      0.9015904664993286,
#      0.06454944610595703],
#     'context': []},
#    {'term': 'drink',
#     'class': 'neutral',
#     'probability': [0.01874767430126667,
#      0.9803789854049683,
#      0.0008733723079785705],
#     'context': ['The staff at the drive thru just shoved the drink in my hands.']},
#    {'term': 'staff',
#     'class': 'negative',
#     'probability': [0.9944396018981934,
#      0.000629544083494693,
#      0.004930817522108555],
#     'context': ['The staff at the drive thru just shoved the drink in my hands.']}],
#   'sentiment': 'negative',
#   'topic': {'topic': 2,
#    'probability': 0.9282000064849854,
#    'terms': 'drink, large, thru, menu, take, order, job, staff, drive, last, employee, student, line, make, sauce, sit, get, store, change, sandwich'}},
#  '23': {'reviewer_id': 24,
#   'review_time': '2024-04-04',
#   'rating': 1,
#   'review_processed': "Microwaved nuggets, cold fries and a 30 minute wait? What more can you ask for? Don't go there ever! You're better off going hungry or giving the meal you paid for to the homeless by the donation box behind the drive thru.",
#   'aspect_sentiment': [{'term': 'meal',
#     'class': 'negative',
#     'probability': [0.9807120561599731,
#      0.004715777467936277,
#      0.014572146348655224],
#     'context': ["You're better off going hungry or giving the meal you paid for to the homeless by the donation box behind the drive thru."]},
#    {'term': 'wait',
#     'class': 'negative',
#     'probability': [0.9969077706336975,
#      0.0026386796962469816,
#      0.0004534372710622847],
#     'context': ['Microwaved nuggets, cold fries and a 30 minute wait?']},
#    {'term': 'fries',
#     'class': 'postive',
#     'probability': [0.02401219867169857,
#      0.2507196068763733,
#      0.7252681851387024],
#     'context': ['Microwaved nuggets, cold fries and a 30 minute wait?']}],
#   'sentiment': 'negative',
#   'topic': {'topic': 5,
#    'probability': 0.9223999977111816,
#    'terms': 'food, time, letter, order, love, well, fry, customer, difference, raw, give, get, meal, experience, mess, take, extra, call, cold, minute'}},
#  '24': {'reviewer_id': 25,
#   'review_time': '2024-08-04',
#   'rating': 1,
#   'review_processed': "Didn't take a card. But didn't have any money on her. It's not true. No, it wasn't true. It wasn't there. It didn't exist. It doesn't exist at all. It never existed at all; it never existed.",
#   'aspect_sentiment': [{'term': 'money',
#     'class': 'negative',
#     'probability': [0.9988659620285034,
#      0.0006195291643962264,
#      0.0005145296454429626],
#     'context': ["But didn't have any money on her."]},
#    {'term': 'card',
#     'class': 'negative',
#     'probability': [0.9989323019981384,
#      0.0006905178306624293,
#      0.0003770860203076154],
#     'context': ["Didn't take a card."]}],
#   'sentiment': 'negative',
#   'topic': {'topic': 1,
#    'probability': 0.8562999963760376,
#    'terms': 'rude, nice, hour, people, manager, exist, issue, order, enjoy, try, say, coffee, point, mcdonald, location, place, work, spanish, day, know'}},
#  '25': {'reviewer_id': 26,
#   'review_time': '2024-06-04',
#   'rating': 1,
#   'review_processed': "McDonald's is proud to own the most broken ice cream machines on the planet. When I asked at the drive through if they had ice cream, the lady replied that they didn't have any ice cream at all. It's a shame, because they have some of the best ice cream in the world.",
#   'aspect_sentiment': [{'term': 'ice cream',
#     'class': 'negative',
#     'probability': [0.8867460489273071,
#      0.07630795985460281,
#      0.036946043372154236],
#     'context': ["McDonald's is proud to own the most broken ice cream machines on the planet.",
#      "When I asked at the drive through if they had ice cream, the lady replied that they didn't have any ice cream at all.",
#      "It's a shame, because they have some of the best ice cream in the world."]}],
#   'sentiment': 'negative',
#   'topic': {'topic': 4,
#    'probability': 0.9164000153541565,
#    'terms': 'good, amazing, food, ice, order, cream, service, wrong, come, quick, correct, get, taste, late, fast, mcdonald, great, door, right, line'}},
#  '26': {'reviewer_id': 27,
#   'review_time': '2024-11-04',
#   'rating': 4,
#   'review_processed': 'With all the new upgrades, everything looks great and is clean and neat. The staff are great and have a great staff. correct: With all the upgrades, the staff are very clean and well-mannered. incorrect: The staff is very friendly and friendly.',
#   'aspect_sentiment': [{'term': 'staff',
#     'class': 'postive',
#     'probability': [0.00019963973318226635,
#      0.00026557687669992447,
#      0.9995348453521729],
#     'context': ['The staff are great and have a great staff.',
#      'correct: With all the upgrades, the staff are very clean and well-mannered.',
#      'incorrect: The staff is very friendly and friendly.']}],
#   'sentiment': 'positive',
#   'topic': {'topic': 3,
#    'probability': 0.9075000286102295,
#    'terms': 'staff, wait, make, manager, great, smoothie, miss, customer, correct, boy, meal, confuse, unhappy, clean, fresh, leave, upgrade, period, fresher, attitude'}},
#  '27': {'reviewer_id': 28,
#   'review_time': '2024-11-04',
#   'rating': 2,
#   'review_processed': 'This article has been updated since it was published in the spring of 2012. It is the first published version of this article to feature a corrected spelling of the word \'taste\' The error occurred due to misbelief that the word "taste" referred to the food.',
#   'aspect_sentiment': [{'term': 'food',
#     'class': 'neutral',
#     'probability': [0.25921422243118286,
#      0.7359218001365662,
#      0.004863974172621965],
#     'context': ['It is the first published version of this article to feature a corrected spelling of the word \'taste\' The error occurred due to misbelief that the word "taste" referred to the food.']},
#    {'term': '"',
#     'class': 'neutral',
#     'probability': [0.4206438362598419,
#      0.5757195353507996,
#      0.0036366696003824472],
#     'context': []},
#    {'term': 'taste',
#     'class': 'negative',
#     'probability': [0.8525221347808838,
#      0.14425751566886902,
#      0.0032203206792473793],
#     'context': ['It is the first published version of this article to feature a corrected spelling of the word \'taste\' The error occurred due to misbelief that the word "taste" referred to the food.']},
#    {'term': "'",
#     'class': 'neutral',
#     'probability': [0.40049421787261963,
#      0.5950559377670288,
#      0.004449840169399977],
#     'context': []}],
#   'sentiment': 'negative',
#   'topic': {'topic': 4,
#    'probability': 0.9301999807357788,
#    'terms': 'good, amazing, food, ice, order, cream, service, wrong, come, quick, correct, get, taste, late, fast, mcdonald, great, door, right, line'}},
#  '28': {'reviewer_id': 29,
#   'review_time': '2024-09-04',
#   'rating': 1,
#   'review_processed': "A McDonald's with horrible service and lazy employees. I mean, do they intentionally hire unqualified people? It's yet another McDonald's where the service is horrible and the employees are unqualified. It's ridiculous! It's like a movie! It doesn't get any worse.",
#   'aspect_sentiment': [{'term': 'employees',
#     'class': 'negative',
#     'probability': [0.9987545013427734,
#      0.0008405973203480244,
#      0.0004048882401548326],
#     'context': ["A McDonald's with horrible service and lazy employees.",
#      "It's yet another McDonald's where the service is horrible and the employees are unqualified."]},
#    {'term': 'service',
#     'class': 'negative',
#     'probability': [0.9988682270050049,
#      0.000763076706789434,
#      0.00036880504922010005],
#     'context': ["A McDonald's with horrible service and lazy employees.",
#      "It's yet another McDonald's where the service is horrible and the employees are unqualified."]}],
#   'sentiment': 'negative',
#   'topic': {'topic': 2,
#    'probability': 0.9153000116348267,
#    'terms': 'drink, large, thru, menu, take, order, job, staff, drive, last, employee, student, line, make, sauce, sit, get, store, change, sandwich'}},
#  '29': {'reviewer_id': 30,
#   'review_time': '2021-12-04',
#   'rating': 1,
#   'review_processed': "First and last time I went to this location. Look at my receipt and what I got. That's a plain sausage biscuit and a double quarter pounder. I didn't go there before; it's the first and last place I've ever been.",
#   'aspect_sentiment': [{'term': 'pounder',
#     'class': 'postive',
#     'probability': [0.006075546611100435,
#      0.005678566638380289,
#      0.9882458448410034],
#     'context': ["That's a plain sausage biscuit and a double quarter pounder."]},
#    {'term': 'quarter',
#     'class': 'postive',
#     'probability': [0.007255909498780966,
#      0.02992238849401474,
#      0.9628216624259949],
#     'context': ["That's a plain sausage biscuit and a double quarter pounder."]},
#    {'term': 'double',
#     'class': 'postive',
#     'probability': [0.006429081317037344,
#      0.006671649869531393,
#      0.9868992567062378],
#     'context': ["That's a plain sausage biscuit and a double quarter pounder."]},
#    {'term': 'sausage biscuit',
#     'class': 'postive',
#     'probability': [0.012622660025954247,
#      0.004381369799375534,
#      0.9829960465431213],
#     'context': ["That's a plain sausage biscuit and a double quarter pounder."]}],
#   'sentiment': 'negative',
#   'topic': {'topic': 2,
#    'probability': 0.9205999970436096,
#    'terms': 'drink, large, thru, menu, take, order, job, staff, drive, last, employee, student, line, make, sauce, sit, get, store, change, sandwich'}},
#  '30': {'reviewer_id': 31,
#   'review_time': '2022-12-04',
#   'rating': 1,
#   'review_processed': "A 20 minute wait in the drive through for a room temperature caramel mocha that was less than 2/3 full. This was exactly what I ordered! It's what I had ordered, and it's exactly where I ordered it to be. It's perfect!",
#   'aspect_sentiment': [{'term': 'caramel mocha',
#     'class': 'postive',
#     'probability': [0.031187569722533226,
#      0.004736708477139473,
#      0.9640757441520691],
#     'context': ['A 20 minute wait in the drive through for a room temperature caramel mocha that was less than 2/3 full.']},
#    {'term': 'wait',
#     'class': 'negative',
#     'probability': [0.9422491788864136,
#      0.01572427712380886,
#      0.042026620358228683],
#     'context': ['A 20 minute wait in the drive through for a room temperature caramel mocha that was less than 2/3 full.']}],
#   'sentiment': 'positive',
#   'topic': {'topic': 5,
#    'probability': 0.9070000052452087,
#    'terms': 'food, time, letter, order, love, well, fry, customer, difference, raw, give, get, meal, experience, mess, take, extra, call, cold, minute'}},
#  '31': {'reviewer_id': 32,
#   'review_time': '2024-03-04',
#   'rating': 2,
#   'review_processed': "They will literally stop taking orders and make people sit in the parking lot for 12 minutes until 3 a.m. so that they don't get to order dinner. We have gone multiple times right after leaving the pinball arcade just to wait in the drive-thru line while they do nothing but wait for the order menu to change.",
#   'aspect_sentiment': [{'term': 'order menu',
#     'class': 'negative',
#     'probability': [0.9835450053215027,
#      0.015292356722056866,
#      0.0011626201448962092],
#     'context': ['We have gone multiple times right after leaving the pinball arcade just to wait in the drive-thru line while they do nothing but wait for the order menu to change.']},
#    {'term': 'thru line',
#     'class': 'negative',
#     'probability': [0.9862879514694214,
#      0.004368256777524948,
#      0.009343740530312061],
#     'context': ['We have gone multiple times right after leaving the pinball arcade just to wait in the drive-thru line while they do nothing but wait for the order menu to change.']},
#    {'term': '-',
#     'class': 'neutral',
#     'probability': [0.37977904081344604,
#      0.6033185720443726,
#      0.016902383416891098],
#     'context': ['We have gone multiple times right after leaving the pinball arcade just to wait in the drive-thru line while they do nothing but wait for the order menu to change.']},
#    {'term': 'drive',
#     'class': 'neutral',
#     'probability': [0.09000447392463684,
#      0.9051740169525146,
#      0.00482152309268713],
#     'context': ['We have gone multiple times right after leaving the pinball arcade just to wait in the drive-thru line while they do nothing but wait for the order menu to change.']},
#    {'term': 'pinball arcade',
#     'class': 'neutral',
#     'probability': [0.06662467122077942,
#      0.9219281077384949,
#      0.011447218246757984],
#     'context': ['We have gone multiple times right after leaving the pinball arcade just to wait in the drive-thru line while they do nothing but wait for the order menu to change.']},
#    {'term': 'dinner',
#     'class': 'neutral',
#     'probability': [0.02694079652428627,
#      0.9721358418464661,
#      0.0009233492310158908],
#     'context': ["They will literally stop taking orders and make people sit in the parking lot for 12 minutes until 3 a.m. so that they don't get to order dinner."]},
#    {'term': 'orders',
#     'class': 'negative',
#     'probability': [0.99802565574646,
#      0.0013995227636769414,
#      0.0005749202100560069],
#     'context': ["They will literally stop taking orders and make people sit in the parking lot for 12 minutes until 3 a.m. so that they don't get to order dinner."]}],
#   'sentiment': 'negative',
#   'topic': {'topic': 2,
#    'probability': 0.9372000098228455,
#    'terms': 'drink, large, thru, menu, take, order, job, staff, drive, last, employee, student, line, make, sauce, sit, get, store, change, sandwich'}},
#  '32': {'reviewer_id': 33,
#   'review_time': '2023-12-04',
#   'rating': 1,
#   'review_processed': "They did not honor there advertised price. This is extra pickles; they did not pay the advertised price for them. They did not have any leftovers from the previous batch of food. It's not their fault; they didn't pay the price they were promised.",
#   'aspect_sentiment': [{'term': 'food',
#     'class': 'negative',
#     'probability': [0.982486367225647,
# ...
#     'context': ['When are robots going to replace the kitchen staff who hate their jobs?']},
#    {'term': 'fast food',
#     'class': 'negative',
#     'probability': [0.6209200620651245,
#      0.37634900212287903,
#      0.002730959327891469],
#     'context': ["McDonald's is not a fast food company anymore."]}],
#   'sentiment': 'negative',
#   'topic': {'topic': 4,
#    'probability': 0.9269000291824341,
#    'terms': 'good, amazing, food, ice, order, cream, service, wrong, come, quick, correct, get, taste, late, fast, mcdonald, great, door, right, line'}},
#  '88': {'reviewer_id': 89,
#   'review_time': '2021-12-04',
#   'rating': 1,
#   'review_processed': "This McDonald's constantly gets orders wrong. We have ordered at the window and over the phone and every time we don't get a complete order. Today we went back to get our fries and the manager gave us a new one, but the girl at the front window shoved the bag in our hands and when I asked her to stop, she made a rude face and turned away.",
#   'aspect_sentiment': [{'term': 'manager',
#     'class': 'negative',
#     'probability': [0.9913186430931091,
#      0.0016886949306353927,
#      0.006992637179791927],
#     'context': ['Today we went back to get our fries and the manager gave us a new one, but the girl at the front window shoved the bag in our hands and when I asked her to stop, she made a rude face and turned away.']},
#    {'term': 'fries',
#     'class': 'postive',
#     'probability': [0.20578721165657043,
#      0.34283310174942017,
#      0.4513796865940094],
#     'context': ['Today we went back to get our fries and the manager gave us a new one, but the girl at the front window shoved the bag in our hands and when I asked her to stop, she made a rude face and turned away.']}],
#   'sentiment': 'negative',
#   'topic': {'topic': 4,
#    'probability': 0.9452999830245972,
#    'terms': 'good, amazing, food, ice, order, cream, service, wrong, come, quick, correct, get, taste, late, fast, mcdonald, great, door, right, line'}},
#  '89': {'reviewer_id': 90,
#   'review_time': '2023-12-04',
#   'rating': 1,
#   'review_processed': "I ordered a meal with an extra fry, but when I got to the food window, was only given the fry with the meal. I offered to pay the difference for the extra fry but was told I needed to drive back around and order again. Seriously? That's the response? Will not be returning.",
#   'aspect_sentiment': [{'term': 'food window',
#     'class': 'neutral',
#     'probability': [0.038910411298274994,
#      0.9590328931808472,
#      0.002056698314845562],
#     'context': ['I ordered a meal with an extra fry, but when I got to the food window, was only given the fry with the meal.']},
#    {'term': 'fry',
#     'class': 'neutral',
#     'probability': [0.13860642910003662,
#      0.8576528429985046,
#      0.003740777028724551],
#     'context': ['I ordered a meal with an extra fry, but when I got to the food window, was only given the fry with the meal.',
#      'I offered to pay the difference for the extra fry but was told I needed to drive back around and order again.']},
#    {'term': 'meal',
#     'class': 'neutral',
#     'probability': [0.0832051932811737,
#      0.914055585861206,
#      0.002739212941378355],
#     'context': ['I ordered a meal with an extra fry, but when I got to the food window, was only given the fry with the meal.']}],
#   'sentiment': 'negative',
#   'topic': {'topic': 5,
#    'probability': 0.9162999987602234,
#    'terms': 'food, time, letter, order, love, well, fry, customer, difference, raw, give, get, meal, experience, mess, take, extra, call, cold, minute'}},
#  '90': {'reviewer_id': 91,
#   'review_time': '2019-12-04',
#   'rating': 1,
#   'review_processed': "This is the 3rd time in a row that we've been burned going through the drive thru. You'd think by now that I would have learned my lesson, but I thought this would be quick and easy. This location sucks. I tried calling the number in the receipt but no one answers.",
#   'aspect_sentiment': [],
#   'sentiment': 'negative',
#   'topic': {'topic': 2,
#    'probability': 0.9312999844551086,
#    'terms': 'drink, large, thru, menu, take, order, job, staff, drive, last, employee, student, line, make, sauce, sit, get, store, change, sandwich'}},
#  '91': {'reviewer_id': 92,
#   'review_time': '2021-12-04',
#   'rating': 1,
#   'review_processed': 'All I asked for was a regular size coffee. Coffee was full of coffee grounds to the point I was spitting them out. Also asked for 3 splendas and 4 creamers on the side and received 3 regular sugars and 2 creamers. And as a little plus there was a piece of plastic! Never again!',
#   'aspect_sentiment': [{'term': 'sugars',
#     'class': 'negative',
#     'probability': [0.9795821905136108,
#      0.015034454874694347,
#      0.005383349489420652],
#     'context': ['Also asked for 3 splendas and 4 creamers on the side and received 3 regular sugars and 2 creamers.']},
#    {'term': 'creamers',
#     'class': 'negative',
#     'probability': [0.9829748272895813,
#      0.013136506080627441,
#      0.0038886505644768476],
#     'context': ['Also asked for 3 splendas and 4 creamers on the side and received 3 regular sugars and 2 creamers.']},
#    {'term': '##lendas',
#     'class': 'negative',
#     'probability': [0.9824161529541016,
#      0.014306364580988884,
#      0.003277549287304282],
#     'context': []},
#    {'term': 'sp',
#     'class': 'neutral',
#     'probability': [0.3061542809009552,
#      0.6778585314750671,
#      0.01598716713488102],
#     'context': []},
#    {'term': 'coffee grounds',
#     'class': 'negative',
#     'probability': [0.7095144391059875,
#      0.27448341250419617,
#      0.016002189368009567],
#     'context': ['Coffee was full of coffee grounds to the point I was spitting them out.']},
#    {'term': 'coffee',
#     'class': 'negative',
#     'probability': [0.8361466526985168,
#      0.1547451764345169,
#      0.009108172729611397],
#     'context': ['All I asked for was a regular size coffee.',
#      'Coffee was full of coffee grounds to the point I was spitting them out.']}],
#   'sentiment': 'negative',
#   'topic': {'topic': 1,
#    'probability': 0.9244999885559082,
#    'terms': 'rude, nice, hour, people, manager, exist, issue, order, enjoy, try, say, coffee, point, mcdonald, location, place, work, spanish, day, know'}},
#  '92': {'reviewer_id': 93,
#   'review_time': '2019-12-04',
#   'rating': 1,
#   'review_processed': "I tried to go through the drive thru at 430 a. It said it was 24 hours, but no one seemed to be taking orders. I drove around twice just in case and tried again but still no answer. I saw one employee in the kitchen but couldn't get his attention. It's very bad business.",
#   'aspect_sentiment': [{'term': 'kitchen',
#     'class': 'negative',
#     'probability': [0.5457109212875366,
#      0.45042192935943604,
#      0.003867190098389983],
#     'context': ["I saw one employee in the kitchen but couldn't get his attention."]}],
#   'sentiment': 'negative',
#   'topic': {'topic': 1,
#    'probability': 0.9284999966621399,
#    'terms': 'rude, nice, hour, people, manager, exist, issue, order, enjoy, try, say, coffee, point, mcdonald, location, place, work, spanish, day, know'}},
#  '93': {'reviewer_id': 94,
#   'review_time': '2020-12-04',
#   'rating': 3,
#   'review_processed': "I ordered a frozen lemonade, paid for it, then sat down. I was there for a bit before someone came and told me they were out. It was too much trouble to get a refund for the difference. I'm not sure I like this new way.",
#   'aspect_sentiment': [{'term': 'frozen lemonade',
#     'class': 'negative',
#     'probability': [0.4706272482872009,
#      0.38040411472320557,
#      0.14896859228610992],
#     'context': ['I ordered a frozen lemonade, paid for it, then sat down.']}],
#   'sentiment': 'negative',
#   'topic': {'topic': 2,
#    'probability': 0.9282000064849854,
#    'terms': 'drink, large, thru, menu, take, order, job, staff, drive, last, employee, student, line, make, sauce, sit, get, store, change, sandwich'}},
#  '94': {'reviewer_id': 95,
#   'review_time': '2021-12-04',
#   'rating': 1,
#   'review_processed': 'My burger was completely raw in the middle, and when I took it back in to get it remade, the lady behind the counter treated me like I was some stuck up brat for not wanting to eat a raw burger. I will never eat there again.',
#   'aspect_sentiment': [{'term': 'lady',
#     'class': 'negative',
#     'probability': [0.9987659454345703,
#      0.00045107313781045377,
#      0.0007829025271348655],
#     'context': ['My burger was completely raw in the middle, and when I took it back in to get it remade, the lady behind the counter treated me like I was some stuck up brat for not wanting to eat a raw burger.']},
#    {'term': 'burger',
#     'class': 'negative',
#     'probability': [0.9936532974243164,
#      0.005539106670767069,
#      0.000807653705123812],
#     'context': ['My burger was completely raw in the middle, and when I took it back in to get it remade, the lady behind the counter treated me like I was some stuck up brat for not wanting to eat a raw burger.']}],
#   'sentiment': 'negative',
#   'topic': {'topic': 5,
#    'probability': 0.909600019454956,
#    'terms': 'food, time, letter, order, love, well, fry, customer, difference, raw, give, get, meal, experience, mess, take, extra, call, cold, minute'}},
#  '95': {'reviewer_id': 96,
#   'review_time': '2020-12-04',
#   'rating': 1,
#   'review_processed': 'Every single time I go they f up my order! Then give attitude when they need to correct their mistakes. The staff is horrible. Corporate needs to send all their staff over to a week of training at chic-fil-A college to learn about work ethic, time management, teamwork and basic manors.',
#   'aspect_sentiment': [{'term': 'manors',
#     'class': 'negative',
#     'probability': [0.9981818199157715,
#      0.0011882988037541509,
#      0.000629953108727932],
#     'context': ['Corporate needs to send all their staff over to a week of training at chic-fil-A college to learn about work ethic, time management, teamwork and basic manors.']},
#    {'term': 'teamwork',
#     'class': 'negative',
#     'probability': [0.9969677329063416,
#      0.001958282431587577,
#      0.0010740001453086734],
#     'context': ['Corporate needs to send all their staff over to a week of training at chic-fil-A college to learn about work ethic, time management, teamwork and basic manors.']},
#    {'term': 'time management',
#     'class': 'negative',
#     'probability': [0.9895713329315186,
#      0.009903143160045147,
#      0.0005255448049865663],
#     'context': ['Corporate needs to send all their staff over to a week of training at chic-fil-A college to learn about work ethic, time management, teamwork and basic manors.']},
#    {'term': 'work',
#     'class': 'negative',
#     'probability': [0.959642767906189,
#      0.0379057452082634,
#      0.0024514507967978716],
#     'context': ['Corporate needs to send all their staff over to a week of training at chic-fil-A college to learn about work ethic, time management, teamwork and basic manors.']},
#    {'term': 'staff',
#     'class': 'negative',
#     'probability': [0.9991330504417419,
#      0.000503927527461201,
#      0.0003630200808402151],
#     'context': ['The staff is horrible.',
#      'Corporate needs to send all their staff over to a week of training at chic-fil-A college to learn about work ethic, time management, teamwork and basic manors.']}],
#   'sentiment': 'negative',
#   'topic': {'topic': 3,
#    'probability': 0.9372000098228455,
#    'terms': 'staff, wait, make, manager, great, smoothie, miss, customer, correct, boy, meal, confuse, unhappy, clean, fresh, leave, upgrade, period, fresher, attitude'}},
#  '96': {'reviewer_id': 97,
#   'review_time': '2022-12-04',
#   'rating': 1,
#   'review_processed': 'When ordering food, the employees forgot to turn off their microphones and were talking messily about all the food we had ordered. This is very unprofessional and honestly uncalled for. When I asked for a receipt, they said it was in the bad and it was not in there.',
#   'aspect_sentiment': [{'term': 'employees',
#     'class': 'negative',
#     'probability': [0.9987253546714783,
#      0.0005044877761974931,
#      0.000770182756241411],
#     'context': ['When ordering food, the employees forgot to turn off their microphones and were talking messily about all the food we had ordered.']},
#    {'term': 'food',
#     'class': 'negative',
#     'probability': [0.9288522005081177,
#      0.06959313899278641,
#      0.0015547084622085094],
#     'context': ['When ordering food, the employees forgot to turn off their microphones and were talking messily about all the food we had ordered.']}],
#   'sentiment': 'negative',
#   'topic': {'topic': 5,
#    'probability': 0.9136000275611877,
#    'terms': 'food, time, letter, order, love, well, fry, customer, difference, raw, give, get, meal, experience, mess, take, extra, call, cold, minute'}},
#  '97': {'reviewer_id': 98,
#   'review_time': '2021-12-04',
#   'rating': 1,
#   'review_processed': "I don't usually review places, but this location has ridiculously rude service and consistently gets the orders wrong. Even when not busy, they are rude. If I were rude, I wouldn't be able to enjoy the experience at this location. It's ridiculous.",
#   'aspect_sentiment': [{'term': 'orders',
#     'class': 'negative',
#     'probability': [0.9989007711410522,
#      0.0005099655245430768,
#      0.0005892295157536864],
#     'context': ["I don't usually review places, but this location has ridiculously rude service and consistently gets the orders wrong."]},
#    {'term': 'service',
#     'class': 'negative',
#     'probability': [0.9983295798301697,
#      0.0003267021384090185,
#      0.0013437323505058885],
#     'context': ["I don't usually review places, but this location has ridiculously rude service and consistently gets the orders wrong."]}],
#   'sentiment': 'negative',
#   'topic': {'topic': 1,
#    'probability': 0.9142000079154968,
#    'terms': 'rude, nice, hour, people, manager, exist, issue, order, enjoy, try, say, coffee, point, mcdonald, location, place, work, spanish, day, know'}},
#  '98': {'reviewer_id': 99,
#   'review_time': '2024-06-04',
#   'rating': 5,
#   'review_processed': "Allways has the best fries and ice cream in the world; it's the best in the whole world! correct: It has the world's best fries, and the best ice cream anywhere! It's very tasty. It's amazing. It is the best!",
#   'aspect_sentiment': [{'term': 'ice cream',
#     'class': 'postive',
#     'probability': [0.0001824156061047688,
#      0.0002252057456644252,
#      0.9995923638343811],
#     'context': ["Allways has the best fries and ice cream in the world; it's the best in the whole world!",
#      "correct: It has the world's best fries, and the best ice cream anywhere!"]},
#    {'term': 'fries',
#     'class': 'postive',
#     'probability': [0.00017211318481713533,
#      0.00021300360094755888,
#      0.999614953994751],
#     'context': ["Allways has the best fries and ice cream in the world; it's the best in the whole world!",
#      "correct: It has the world's best fries, and the best ice cream anywhere!"]}],
#   'sentiment': 'positive',
#   'topic': {'topic': 4,
#    'probability': 0.9117000102996826,
#    'terms': 'good, amazing, food, ice, order, cream, service, wrong, come, quick, correct, get, taste, late, fast, mcdonald, great, door, right, line'}},
#  '99': {'reviewer_id': 100,
#   'review_time': '2023-12-04',
#   'rating': 4,
#   'review_processed': "McDonald's is great, but they need to hire people who understand both English and Spanish. The people are really nice, but be smarter about who you put in the drive thru and lobby to take orders. The staff are all Spanish speakers trying to take English orders.",
#   'aspect_sentiment': [{'term': 'staff',
#     'class': 'postive',
#     'probability': [0.02162514440715313,
#      0.06668327003717422,
#      0.9116915464401245],
#     'context': ['The staff are all Spanish speakers trying to take English orders.']}],
#   'sentiment': 'positive',
#   'topic': {'topic': 1,
#    'probability': 0.927299976348877,
#    'terms': 'rude, nice, hour, people, manager, exist, issue, order, enjoy, try, say, coffee, point, mcdonald, location, place, work, spanish, day, know'}}}

# %% [markdown]
# # Save Result

# %%
with open("meta-data.json", "w") as file:
    json.dump(result, file, indent=4)

# %%
with open("map-topic.json",  "w") as file:
    json.dump(topic_json, file, indent=4)
