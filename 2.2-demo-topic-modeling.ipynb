# %%
# Utility: Preparation text

from contractions import CONTRACTION_MAP

##========== PREPARATION TEXT ===========##

# Contraction
def expand_contractions(sentence, contraction_mapping=CONTRACTION_MAP):
    """
    Expand the contractions in a sentence. For example don't => do not.
    
    Paramters:
    sentence (str): The input sentence to clean.
    contraction_mapping (dict): A dictionary for mapping contractions.
    
    
    Returns:
    str: The expanded contraction sentence.
    """
    
    contractions_pattern = re.compile('({})'.format('|'.join(contraction_mapping.keys())),
                                      flags=re.IGNORECASE|re.DOTALL)
    
    def expanded_match(contraction):
        """
        Filter for expanding the matched contraction.
        
        Parameters:
        contraction (str): The input of contraction
        
        Returns:
        str: The expanded contraction.
        """
        match = contraction.group(0)
        first_char = match[0]
        expanded_contraction = contraction_mapping.get(match) if contraction_mapping.get(match) else contraction_mapping.get(match.lower())
        
        expanded_contraction = first_char + expanded_contraction[1:]
        return expanded_contraction
    
    expanded_sentence = contractions_pattern.sub(expanded_match, sentence)
    return expanded_sentence


def remove_extra_spaces(sentence):
    # Use regex to replace multiple spaces with a single space
    return re.sub(r'\s+', ' ', sentence).strip()


def remove_non_ascii(text):
    """
    Remove all non-ASCII characters from the text.

    Parameters:
    text (str): The input text to clean.

    Returns:
    str: The cleaned text with only ASCII characters.
    
    """
    
    return ''.join([char for char in text if ord(char) < 128])

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import json
import copy
import re

from tqdm import tqdm

from nltk.corpus import stopwords

import spacy
import gensim
from pattern.en import sentiment

# %%
pd.set_option('display.max_colwidth', 2000)

# %%
# Load nlp model
nlp = spacy.load('en_core_web_sm')

# %%
# Load JSON data from a file
with open('data-2.json', 'r') as json_file:
    data = json.load(json_file)

data
# Out:
# {'0': {'id': 1,
#   'review': 'The staff were incredibly helpful and patient, helping me find the perfect phone!',
#   'date': '2024-11-01',
#   'aspect': {'staff': {'ADJ': [[['helpful'], 'staff were helpful.', 'Neutral'],
#      [['patient'], 'staff were patient.', 'Neutral']],
#     'VERB': [],
#     'OTHER': []}},
#   'sentiment': 'Neutral'},
#  '1': {'id': 2,
#   'review': 'I had a great experience purchasing my phone here, the process was smooth and quick.',
#   'date': '2024-11-01',
#   'aspect': {'process': {'ADJ': [[['quick'], 'process was quick.', 'Positive'],
#      [['smooth'], 'process was smooth.', 'Positive']],
#     'VERB': [],
#     'OTHER': []}},
#   'sentiment': 'Positive'},
#  '2': {'id': 3,
#   'review': 'Their selection of phones is amazing, and the prices are very competitive!',
#   'date': '2024-11-01',
#   'aspect': {'selection': {'ADJ': [[['amazing'],
#       'selection is amazing.',
#       'Positive']],
#     'VERB': [],
#     'OTHER': []},
#    'price': {'ADJ': [[['competitive'], 'price are competitive.', 'Neutral']],
#     'VERB': [],
#     'OTHER': []}},
#   'sentiment': 'Neutral'},
#  '3': {'id': 4,
#   'review': 'I appreciate how the staff walked me through setting up my new device.',
#   'date': '2024-11-01',
#   'aspect': {'staff': {'ADJ': [],
#     'VERB': [[['appreciate', 'walk'], 'I appreciate walked me.', 'Neutral'],
#      [['appreciate', 'walk'],
#       'I appreciate walked through setting new device.',
#       'Positive']],
#     'OTHER': []}},
#   'sentiment': 'Positive'},
#  '4': {'id': 5,
#   'review': 'Great customer service, I left with the phone I wanted and all my questions answered.',
#   'date': '2024-11-01',
#   'aspect': {'question': {'ADJ': [],
#     'VERB': [[['answer'], 'question answered.', 'Neutral']],
#     'OTHER': []}},
#   'sentiment': 'Neutral'},
#  '5': {'id': 6,
#   'review': 'They offer amazing deals on phones, I couldn’t resist upgrading.',
#   'date': '2024-11-01',
#   'aspect': {'staff': {'ADJ': [],
#     'VERB': [[['resist', 'offer'],
#       'I could not resist offer amazing deals on phones.',
#       'Positive'],
#      [['resist'], 'I could not resist upgrading.', 'Neutral']],
#     'OTHER': []}},
#   'sentiment': 'Positive'},
#  '6': {'id': 7,
#   'review': 'The technician fixed my phone’s issue faster than I expected. Highly recommend!',
#   'date': '2024-11-01',
#   'aspect': {'technician': {'ADJ': [],
#     'VERB': [[['fix'], 'technician fixed faster.', 'Positive'],
#      [['fix'], 'technician fixed phones issue.', 'Positive']],
#     'OTHER': []},
#    'phones issue': {'ADJ': [],
#     'VERB': [[['fix'], 'technician fixed phones issue.', 'Positive']],
#     'OTHER': []}},
#   'sentiment': 'Positive'},
#  '7': {'id': 8,
#   'review': 'Fantastic experience, the staff really know their stuff!',
#   'date': '2024-11-01',
#   'aspect': {'experience': {'ADJ': [],
#     'VERB': [[['know'], 'experience really know stuff.', 'Positive']],
#     'OTHER': []}},
#   'sentiment': 'Positive'},
#  '8': {'id': 9,
#   'review': 'I found the perfect phone case here, and the variety was impressive.',
#   'date': '2024-11-01',
#   'aspect': {'variety': {'ADJ': [[['impressive'],
#       'variety was impressive.',
#       'Positive']],
#     'VERB': [],
#     'OTHER': []}},
#   'sentiment': 'Positive'},
#  '9': {'id': 10,
#   'review': 'Upgrading my phone was a breeze thanks to their professional service.',
#   'date': '2024-11-01',
#   'aspect': {},
#   'sentiment': 'Positive'},
#  '10': {'id': 11,
#   'review': 'Staff was knowledgeable and made sure I knew everything about my new phone.',
#   'date': '2024-11-01',
#   'aspect': {'staff': {'ADJ': [[['knowledgeable'],
#       'staff was knowledgeable.',
#       'Neutral']],
#     'VERB': [],
#     'OTHER': []}},
#   'sentiment': 'Neutral'},
#  '11': {'id': 12,
#   'review': 'Prices were reasonable and the staff very courteous!',
#   'date': '2024-11-01',
#   'aspect': {'price': {'ADJ': [[['reasonable'],
#       'price were reasonable.',
#       'Positive']],
#     'VERB': [],
#     'OTHER': []}},
#   'sentiment': 'Positive'},
#  '12': {'id': 13,
#   'review': 'Very happy with my purchase, the staff really went the extra mile.',
#   'date': '2024-11-01',
#   'aspect': {'staff': {'ADJ': [],
#     'VERB': [[['go'], 'staff really went mile.', 'Positive']],
#     'OTHER': []}},
#   'sentiment': 'Positive'},
#  '13': {'id': 14,
#   'review': 'Excellent service! They helped me find exactly what I was looking for.',
#   'date': '2024-11-01',
#   'aspect': {'service': {'ADJ': [[['excellent'],
#       'service be excellent.',
#       'Positive']],
#     'VERB': [],
#     'OTHER': []}},
#   'sentiment': 'Positive'},
#  '14': {'id': 15,
#   'review': 'Great deals on accessories, and the staff was super friendly!',
#   'date': '2024-11-01',
#   'aspect': {'deal': {'ADJ': [[['friendly'],
#       'deal was friendly.',
#       'Positive']],
#     'VERB': [],
#     'OTHER': []},
#    'staff': {'ADJ': [[['friendly'], 'staff was friendly.', 'Positive']],
#     'VERB': [],
#     'OTHER': []}},
#   'sentiment': 'Positive'},
#  '15': {'id': 16,
#   'review': 'I love this store! Always a smooth experience buying or fixing my phone.',
#   'date': '2024-11-02',
#   'aspect': {'buying': {'ADJ': [],
#     'VERB': [],
#     'OTHER': [[['experience'], 'buying be experience.', 'Neutral']]},
#    'fixing': {'ADJ': [],
#     'VERB': [],
#     'OTHER': [[['experience'], 'fixing be experience.', 'Neutral']]}},
#   'sentiment': 'Neutral'},
#  '16': {'id': 17,
#   'review': 'I got a really good trade-in deal on my old phone.',
#   'date': '2024-11-02',
#   'aspect': {'staff': {'ADJ': [],
#     'VERB': [[['get'], 'I got good deal on old phone.', 'Positive']],
#     'OTHER': []}},
#   'sentiment': 'Positive'},
#  '17': {'id': 18,
#   'review': 'Their repair services are quick and reliable.',
#   'date': '2024-11-02',
#   'aspect': {'service': {'ADJ': [[['quick'], 'service are quick.', 'Positive'],
#      [['reliable'], 'service are reliable.', 'Neutral']],
#     'VERB': [],
#     'OTHER': []}},
#   'sentiment': 'Neutral'},
#  '18': {'id': 19,
#   'review': 'The staff was extremely helpful in setting up my phone and transferring all my data.',
#   'date': '2024-11-02',
#   'aspect': {'phone': {'ADJ': [[['helpful'],
#       'staff was helpful in setting phone.',
#       'Neutral']],
#     'VERB': [],
#     'OTHER': []},
#    'staff': {'ADJ': [[['helpful'],
#       'staff was helpful in setting phone.',
#       'Neutral']],
#     'VERB': [],
#     'OTHER': []}},
#   'sentiment': 'Neutral'},
#  '19': {'id': 20,
#   'review': 'Very professional and friendly service, I’m super satisfied!',
#   'date': '2024-11-02',
#   'aspect': {'staff': {'ADJ': [],
#     'VERB': [[['m'], 'I m satisfied.', 'Positive']],
#     'OTHER': []}},
#   'sentiment': 'Positive'},
#  '20': {'id': 21,
#   'review': 'Great variety of phones, and the staff was very patient with my questions.',
#   'date': '2024-11-03',
#   'aspect': {'staff': {'ADJ': [[['patient'],
#       'staff was patient with questions.',
#       'Neutral']],
#     'VERB': [],
#     'OTHER': []},
#    'variety': {'ADJ': [[['patient'],
#       'variety was patient with questions.',
#       'Neutral']],
#     'VERB': [],
#     'OTHER': []}},
#   'sentiment': 'Neutral'},
#  '21': {'id': 22,
#   'review': 'The process was super simple, and I’m thrilled with my new phone.',
#   'date': '2024-11-03',
#   'aspect': {'process': {'ADJ': [[['simple'],
#       'process was simple.',
#       'Neutral']],
#     'VERB': [],
#     'OTHER': []}},
#   'sentiment': 'Neutral'},
#  '22': {'id': 23,
#   'review': 'They helped me choose a phone within my budget, which I really appreciated.',
#   'date': '2024-11-03',
#   'aspect': {'store': {'ADJ': [],
#     'VERB': [[['help', 'choose'],
#       'they helped choose within budget.',
#       'Neutral'],
#      [['help', 'choose'], 'they helped choose phone.', 'Neutral']],
#     'OTHER': []}},
#   'sentiment': 'Neutral'},
#  '23': {'id': 24,
#   'review': 'My phone was fixed in less than 30 minutes, such fast service!',
#   'date': '2024-11-03',
#   'aspect': {'phone': {'ADJ': [],
#     'VERB': [[['fix'], 'phone was fixed in minutes.', 'Positive']],
#     'OTHER': []}},
#   'sentiment': 'Positive'},
#  '24': {'id': 25,
#   'review': 'I’m a loyal customer because their customer service is always outstanding.',
#   'date': '2024-11-03',
#   'aspect': {'service': {'ADJ': [[['outstanding'],
#       'service is outstanding.',
#       'Positive']],
#     'VERB': [],
#     'OTHER': []}},
#   'sentiment': 'Positive'},
#  '25': {'id': 26,
#   'review': 'Best phone store in town, hands down!',
#   'date': '2024-11-04',
#   'aspect': {'store': {'ADJ': [],
#     'VERB': [[['hand'], 'store hands.', 'Neutral']],
#     'OTHER': []}},
#   'sentiment': 'Neutral'},
#  '26': {'id': 27,
#   'review': 'The staff made sure I was completely comfortable with my purchase.',
#   'date': '2024-11-04',
#   'aspect': {'staff': {'ADJ': [],
#     'VERB': [[['make'], 'staff made.', 'Neutral']],
#     'OTHER': []}},
#   'sentiment': 'Neutral'},
#  '27': {'id': 28,
#   'review': 'I found exactly what I needed, and they helped me get a great deal.',
#   'date': '2024-11-04',
#   'aspect': {'staff': {'ADJ': [],
#     'VERB': [[['find', 'need'], 'I found needed what.', 'Neutral']],
#     'OTHER': []},
#    'store': {'ADJ': [],
#     'VERB': [[['help', 'get'], 'they helped get great deal.', 'Positive']],
#     'OTHER': []}},
#   'sentiment': 'Positive'},
#  '28': {'id': 29,
#   'review': 'This store has a fantastic warranty service!',
#   'date': '2024-11-04',
#   'aspect': {'warranty service': {'ADJ': [],
#     'VERB': [[['have'], 'store has fantastic warranty service.', 'Positive']],
#     'OTHER': []},
#    'store': {'ADJ': [],
#     'VERB': [[['have'], 'store has fantastic warranty service.', 'Positive']],
#     'OTHER': []}},
#   'sentiment': 'Positive'},
#  '29': {'id': 30,
#   'review': 'The staff was very informative, I learned a lot about phone features I didn’t know about.',
#   'date': '2024-11-04',
#   'aspect': {'staff': {'ADJ': [[['informative'],
#       'staff was informative.',
#       'Neutral']],
#     'VERB': [],
#     'OTHER': []}},
#   'sentiment': 'Neutral'},
#  '30': {'id': 31,
#   'review': 'Excellent store for buying phone accessories, so much variety!',
#   'date': '2024-11-04',
#   'aspect': {'variety': {'ADJ': [[['excellent'],
#       'variety be excellent.',
#       'Positive']],
#     'VERB': [],
#     'OTHER': []},
#    'store': {'ADJ': [[['excellent'], 'store be excellent.', 'Positive']],
#     'VERB': [],
#     'OTHER': []}},
#   'sentiment': 'Positive'},
#  '31': {'id': 32,
#   'review': 'The phone I bought here is working perfectly, couldn’t be happier.',
#   'date': '2024-11-04',
#   'aspect': {},
#   'sentiment': 'Positive'},
#  '32': {'id': 33,
#   'review': 'They were super quick in setting up my phone, I was out of there in no time.',
#   'date': '2024-11-04',
#   'aspect': {'store': {'ADJ': [[['quick'],
#       'they were quick in setting phone.',
#       'Positive']],
#     'VERB': [],
#     'OTHER': []}},
#   'sentiment': 'Positive'},
#  '33': {'id': 34,
#   'review': 'Always come here for upgrades, they never disappoint!',
#   'date': '2024-11-04',
#   'aspect': {},
#   'sentiment': 'Positive'},
#  '34': {'id': 35,
#   'review': 'The store layout is easy to navigate and staff are always ready to help.',
#   'date': '2024-11-05',
#   'aspect': {'layout': {'ADJ': [[['easy'], 'layout is easy.', 'Positive']],
#     'VERB': [],
#     'OTHER': []},
#    'staff': {'ADJ': [[['ready'], 'staff are ready.', 'Positive']],
#     'VERB': [],
#     'OTHER': []}},
#   'sentiment': 'Positive'},
#  '35': {'id': 36,
#   'review': 'Best pricing for phone plans, they helped me save a lot!',
#   'date': '2024-11-05',
#   'aspect': {'store': {'ADJ': [],
#     'VERB': [[['help', 'save'], 'they helped save lot.', 'Neutral']],
#     'OTHER': []}},
#   'sentiment': 'Neutral'},
#  '36': {'id': 37,
#   'review': 'I’ve been to many phone stores, but this one by far provides the best service.',
#   'date': '2024-11-05',
#   'aspect': {'service': {'ADJ': [],
#     'VERB': [[['provide'], 'one provides best service.', 'Positive']],
#     'OTHER': []},
#    'one': {'ADJ': [],
#     'VERB': [[['provide'], 'one provides best service.', 'Positive']],
#     'OTHER': []}},
#   'sentiment': 'Positive'},
#  '37': {'id': 38,
#   'review': 'Customer service here is top-notch, they always resolve my issues quickly.',
#   'date': '2024-11-05',
#   'aspect': {'service': {'ADJ': [[['notch'], 'service is notch.', 'Neutral']],
#     'VERB': [],
#     'OTHER': [[['notch'], 'service is notch.', 'Neutral']]}},
#   'sentiment': 'Neutral'},
#  '38': {'id': 39,
#   'review': 'I always recommend this store to friends and family, they never fail to impress.',
#   'date': '2024-11-06',
#   'aspect': {'store': {'ADJ': [],
#     'VERB': [[['fail', 'recommend'],
#       'they not fail recommend to family.',
#       'Positive'],
#      [['fail', 'recommend'], 'they not fail recommend store.', 'Positive'],
#      [['fail', 'recommend'],
#       'they not fail recommend to friends.',
#       'Positive']],
#     'OTHER': []}},
#   'sentiment': 'Positive'},
#  '39': {'id': 40,
#   'review': 'The staff took the time to show me all my options, no pressure sales.',
#   'date': '2024-11-06',
#   'aspect': {'time': {'ADJ': [],
#     'VERB': [[['take'], 'staff took time.', 'Neutral']],
#     'OTHER': []},
#    'staff': {'ADJ': [],
#     'VERB': [[['take'], 'staff took time.', 'Neutral']],
#     'OTHER': []}},
#   'sentiment': 'Neutral'},
#  '40': {'id': 41,
#   'review': 'Amazing place to buy the latest phones at great prices!',
#   'date': '2024-11-06',
#   'aspect': {'place': {'ADJ': [[['amazing'], 'place be amazing.', 'Positive']],
#     'VERB': [],
#     'OTHER': []}},
#   'sentiment': 'Positive'},
#  '41': {'id': 42,
#   'review': 'Their warranty plan is worth every penny, such a relief!',
#   'date': '2024-11-06',
#   'aspect': {'plan': {'ADJ': [[['worth'], 'plan is worth.', 'Positive']],
#     'VERB': [],
#     'OTHER': []}},
#   'sentiment': 'Positive'},
#  '42': {'id': 43,
#   'review': 'I appreciate how they were able to fix my phone on the same day.',
#   'date': '2024-11-06',
#   'aspect': {'store': {'ADJ': [[['able'], 'they were able.', 'Positive']],
#     'VERB': [],
#     'OTHER': []},
#    'staff': {'ADJ': [],
#     'VERB': [[['appreciate', 'be'], 'I appreciate were able.', 'Positive']],
#     'OTHER': []}},
#   'sentiment': 'Positive'},
#  '43': {'id': 44,
#   'review': 'Got a great deal on my new phone and an awesome case as well!',
#   'date': '2024-11-07',
#   'aspect': {},
#   'sentiment': 'Positive'},
#  '44': {'id': 45,
#   'review': 'The staff was very accommodating when I had questions about phone features.',
#   'date': '2024-11-07',
#   'aspect': {'staff': {'ADJ': [[['accommodating'],
#       'staff was accommodating.',
#       'Neutral']],
#     'VERB': [],
#     'OTHER': []}},
#   'sentiment': 'Neutral'},
#  '45': {'id': 46,
#   'review': 'I had a great experience with their trade-in program.',
#   'date': '2024-11-07',
#   'aspect': {'staff': {'ADJ': [],
#     'VERB': [[['have'], 'I had great experience with program.', 'Positive']],
#     'OTHER': []}},
#   'sentiment': 'Positive'},
#  '46': {'id': 47,
#   'review': 'Service was quick and efficient, I was in and out within 15 minutes!',
#   'date': '2024-11-07',
#   'aspect': {'service': {'ADJ': [[['quick'], 'service was quick.', 'Positive'],
#      [['efficient'], 'service was efficient.', 'Neutral']],
#     'VERB': [],
#     'OTHER': []}},
#   'sentiment': 'Neutral'},
#  '47': {'id': 48,
#   'review': 'They even helped me transfer all my contacts and data without extra charge.',
#   'date': '2024-11-08',
#   'aspect': {'store': {'ADJ': [],
#     'VERB': [[['help', 'transfer'],
#       'they even helped transfer contacts.',
#       'Neutral'],
#      [['help', 'transfer'],
#       'they even helped transfer without extra charge.',
#       'Neutral'],
#      [['help', 'transfer'], 'they even helped transfer data.', 'Neutral']],
#     'OTHER': []}},
#   'sentiment': 'Neutral'},
#  '48': {'id': 49,
#   'review': 'My phone has been working flawlessly since I bought it from here.',
#   'date': '2024-11-08',
#   'aspect': {'phone': {'ADJ': [],
#     'VERB': [[['work'], 'phone has working flawlessly.', 'Positive']],
#     'OTHER': []}},
#   'sentiment': 'Positive'},
#  '49': {'id': 50,
#   'review': 'They fixed my screen perfectly and even gave me a discount on the repair.',
#   'date': '2024-11-08',
#   'aspect': {'store': {'ADJ': [],
#     'VERB': [[['give'], 'they even gave discount on repair.', 'Neutral'],
#      [['fix'], 'they fixed perfectly.', 'Positive'],
#      [['fix'], 'they fixed screen.', 'Positive']],
#     'OTHER': []}},
#   'sentiment': 'Positive'},
#  '50': {'id': 51,
#   'review': 'This is my go-to store for any phone issues, always reliable.',
#   'date': '2024-11-08',
#   'aspect': {'staff': {'ADJ': [[['reliable'], 'this is reliable.', 'Neutral']],
#     'VERB': [],
#     'OTHER': []}},
#   'sentiment': 'Neutral'},
#  '51': {'id': 52,
#   'review': 'They offer fantastic promotions and discounts!',
#   'date': '2024-11-09',
#   'aspect': {'store': {'ADJ': [],
#     'VERB': [[['offer'], 'they offer fantastic promotions.', 'Positive'],
#      [['offer'], 'they offer discounts.', 'Neutral']],
#     'OTHER': []}},
#   'sentiment': 'Positive'},
#  '52': {'id': 53,
#   'review': 'Great phone selection and even better customer service.',
#   'date': '2024-11-09',
#   'aspect': {'selection': {'ADJ': [[['great'],
#       'selection be great.',
#       'Positive']],
#     'VERB': [],
#     'OTHER': [[['phone'], 'selection be phone.', 'Neutral']]},
#    'service': {'ADJ': [[['great'], 'service be great.', 'Positive']],
#     'VERB': [],
#     'OTHER': [[['phone'], 'service be phone.', 'Neutral']]}},
#   'sentiment': 'Neutral'},
#  '53': {'id': 54,
#   'review': 'They resolved my issue very quickly and professionally.',
#   'date': '2024-11-10',
#   'aspect': {'store': {'ADJ': [],
#     'VERB': [[['resolve'], 'they resolved professionally.', 'Positive'],
#      [['resolve'], 'they resolved very quickly.', 'Positive'],
#      [['resolve'], 'they resolved issue.', 'Neutral']],
#     'OTHER': []}},
#   'sentiment': 'Positive'},
#  '54': {'id': 55,
#   'review': 'I love how organized the store is and how fast they attend to customers.',
#   'date': '2024-11-10',
#   'aspect': {'store': {'ADJ': [[['organize'],
#       'store is organized.',
#       'Neutral']],
#     'VERB': [],
#     'OTHER': []}},
#   'sentiment': 'Neutral'},
#  '55': {'id': 56,
#   'review': 'Highly recommend this store if you’re looking for good deals on phones!',
#   'date': '2024-11-10',
#   'aspect': {'store': {'ADJ': [],
#     'VERB': [[['look'], 'you re looking for good deals.', 'Positive']],
#     'OTHER': []}},
#   'sentiment': 'Positive'},
#  '56': {'id': 57,
#   'review': 'I always leave this store feeling like I made the right purchase.',
#   'date': '2024-11-10',
#   'aspect': {'staff': {'ADJ': [],
#     'VERB': [[['leave'], 'I always leave store.', 'Neutral'],
#      [['make'], 'I made right purchase.', 'Positive']],
#     'OTHER': []}},
#   'sentiment': 'Positive'},
#  '57': {'id': 58,
#   'review': 'I received excellent advice from the sales team, they really know their products.',
#   'date': '2024-11-10',
#   'aspect': {'store': {'ADJ': [],
#     'VERB': [[['know', 'receive'],
#       'they really know received excellent advice from sales team.',
#       'Positive'],
#      [['know'], 'they really know products.', 'Positive']],
#     'OTHER': []}},
#   'sentiment': 'Positive'},
#  '58': {'id': 59,
#   'review': 'Very happy with the repair service here, my phone looks brand new!',
#   'date': '2024-11-10',
#   'aspect': {'phone': {'ADJ': [],
#     'VERB': [[['look'], 'phone looks new.', 'Positive']],
#     'OTHER': []}},
#   'sentiment': 'Positive'},
#  '59': {'id': 60,
#   'review': 'I had to wait over an hour to be helped, and the staff wasn’t apologetic at all.',
#   'date': '2024-11-10',
#   'aspect': {'staff': {'ADJ': [[['apologetic'],
#       'staff was not apologetic.',
#       'Neutral']],
#     'VERB': [],
#     'OTHER': []}},
#   'sentiment': 'Neutral'},
#  '60': {'id': 61,
#   'review': 'Bought a phone here that stopped working within a week, very disappointing.',
#   'date': '2024-11-10',
#   'aspect': {},
#   'sentiment': 'Neutral'},
#  '61': {'id': 62,
#   'review': 'Their prices are too high, and the selection is limited.',
#   'date': '2024-11-11',
#   'aspect': {'price': {'ADJ': [[['high'], 'price are high.', 'Positive']],
#     'VERB': [],
#     'OTHER': []},
#    'selection': {'ADJ': [[['limited'], 'selection is limited.', 'Negative']],
#     'VERB': [],
#     'OTHER': []}},
#   'sentiment': 'Negative'},
#  '62': {'id': 63,
#   'review': 'Customer service is poor, no one seemed interested in helping me.',
#   'date': '2024-11-11',
#   'aspect': {'one': {'ADJ': [],
#     'VERB': [[['seem', 'be'], 'one seemed is poor.', 'Negative']],
#     'OTHER': []},
#    'service': {'ADJ': [[['poor'], 'service is poor.', 'Negative']],
#     'VERB': [],
#     'OTHER': []}},
#   'sentiment': 'Negative'},
#  '63': {'id': 64,
#   'review': 'I had a terrible experience, the phone they sold me was defective.',
#   'date': '2024-11-11',
#   'aspect': {'phone': {'ADJ': [[['defective'],
#       'phone was defective.',
#       'Neutral']],
#     'VERB': [],
#     'OTHER': []}},
#   'sentiment': 'Neutral'},
#  '64': {'id': 65,
#   'review': 'The staff was rude and unhelpful, I’m never coming back.',
#   'date': '2024-11-11',
#   'aspect': {'staff': {'ADJ': [[['rude'], 'staff was rude.', 'Negative'],
#      [['unhelpful'], 'staff was unhelpful.', 'Neutral']],
#     'VERB': [],
#     'OTHER': []}},
#   'sentiment': 'Neutral'},
#  '65': {'id': 66,
#   'review': 'They charged me extra for services I didn’t need, felt like a scam.',
#   'date': '2024-11-11',
#   'aspect': {'store': {'ADJ': [],
#     'VERB': [[['charge'], 'they charged me.', 'Neutral'],
#      [['feel'], 'they felt like scam.', 'Neutral'],
#      [['charge'], 'they charged extra for services.', 'Neutral']],
#     'OTHER': []}},
#   'sentiment': 'Neutral'},
#  '66': {'id': 67,
#   'review': 'Phone repairs took way too long, I had to come back multiple times.',
#   'date': '2024-11-12',
#   'aspect': {'staff': {'ADJ': [],
#     'VERB': [[['have', 'take'], 'I had took too long.', 'Negative'],
#      [['have', 'take'], 'I had took way.', 'Neutral']],
#     'OTHER': []}},
#   'sentiment': 'Neutral'},
#  '67': {'id': 68,
#   'review': 'I bought a phone, but they didn’t inform me of all the hidden fees.',
#   'date': '2024-11-12',
#   'aspect': {'store': {'ADJ': [],
#     'VERB': [[['inform'], 'they did not inform me.', 'Neutral'],
#      [['inform'], 'they did not inform of hidden fees.', 'Negative']],
#     'OTHER': []},
#    'staff': {'ADJ': [],
#     'VERB': [[['buy'], 'I bought phone.', 'Neutral']],
#     'OTHER': []}},
#   'sentiment': 'Neutral'},
#  '68': {'id': 69,
#   'review': 'Staff seemed untrained and gave me incorrect information about the phone plan.',
#   'date': '2024-11-12',
#   'aspect': {'staff': {'ADJ': [],
#     'VERB': [[['seem'], 'staff seemed.', 'Neutral'],
#      [['give'],
#       'staff gave incorrect information about phone plan.',
#       'Neutral']],
#     'OTHER': []},
#    'phone plan': {'ADJ': [],
#     'VERB': [[['give'],
#       'staff gave incorrect information about phone plan.',
#       'Neutral']],
#     'OTHER': []}},
#   'sentiment': 'Neutral'},
#  '69': {'id': 70,
#   'review': 'Their warranty is useless, they refused to fix my phone under it.',
#   'date': '2024-11-12',
#   'aspect': {'warranty': {'ADJ': [[['useless'],
#       'warranty is useless.',
#       'Negative']],
#     'VERB': [],
#     'OTHER': []}},
#   'sentiment': 'Negative'},
#  '70': {'id': 71,
#   'review': 'I had to return a faulty phone twice before they finally gave me a refund.',
#   'date': '2024-11-13',
#   'aspect': {'store': {'ADJ': [],
#     'VERB': [[['give'], 'they twice gave refund.', 'Neutral']],
#     'OTHER': []},
#    'staff': {'ADJ': [],
#     'VERB': [[['have', 'return'], 'I had to return faulty phone.', 'Neutral']],
#     'OTHER': []}},
#   'sentiment': 'Neutral'},
#  '71': {'id': 72,
#   'review': 'Very disorganized, I waited forever just to get a simple issue resolved.',
#   'date': '2024-11-13',
#   'aspect': {'staff': {'ADJ': [],
#     'VERB': [[['wait'], 'I very disorganized waited forever.', 'Positive']],
#     'OTHER': []}},
#   'sentiment': 'Positive'},
#  '72': {'id': 73,
#   'review': 'The phone I purchased here was overpriced compared to other stores.',
#   'date': '2024-11-13',
#   'aspect': {},
#   'sentiment': 'Positive'},
#  '73': {'id': 74,
#   'review': 'They refused to honor the promotion I came in for, very misleading.',
#   'date': '2024-11-13',
#   'aspect': {'store': {'ADJ': [],
#     'VERB': [[['refuse', 'honor'],
#       'they refused to honor promotion.',
#       'Neutral']],
#     'OTHER': []}},
#   'sentiment': 'Neutral'},
#  '74': {'id': 75,
#   'review': 'I felt pressured to buy accessories I didn’t need.',
#   'date': '2024-11-13',
#   'aspect': {'staff': {'ADJ': [],
#     'VERB': [[['feel'], 'I felt pressured.', 'Neutral']],
#     'OTHER': []}},
#   'sentiment': 'Neutral'},
#  '75': {'id': 76,
#   'review': 'The repair was done poorly, and my phone broke again within a week.',
#   'date': '2024-11-13',
#   'aspect': {'repair': {'ADJ': [],
#     'VERB': [[['do'], 'repair was done poorly.', 'Negative']],
#     'OTHER': []},
#    'phone': {'ADJ': [],
#     'VERB': [[['break'], 'phone broke again.', 'Neutral'],
#      [['break'], 'phone broke within week.', 'Neutral']],
#     'OTHER': []}},
#   'sentiment': 'Neutral'},
#  '76': {'id': 77,
#   'review': 'Customer service was extremely slow, they need to hire more staff.',
#   'date': '2024-11-13',
#   'aspect': {'service': {'ADJ': [[['slow'], 'service was slow.', 'Negative']],
#     'VERB': [],
#     'OTHER': []}},
#   'sentiment': 'Negative'},
#  '77': {'id': 78,
#   'review': 'They didn’t even check if my phone was working after the repair.',
#   'date': '2024-11-13',
#   'aspect': {'phone': {'ADJ': [],
#     'VERB': [[['work'], 'phone was working after repair.', 'Neutral']],
#     'OTHER': []}},
#   'sentiment': 'Neutral'},
#  '78': {'id': 79,
#   'review': "Terrible experience, my phone still has the same issue after getting it 'fixed'.",
#   'date': '2024-11-14',
#   'aspect': {'same issue': {'ADJ': [],
#     'VERB': [[['have'],
#       'phone still has same issue after getting.',
#       'Neutral']],
#     'OTHER': []},
#    'phone': {'ADJ': [],
#     'VERB': [[['have'],
#       'phone still has same issue after getting.',
#       'Neutral']],
#     'OTHER': []}},
#   'sentiment': 'Neutral'},
#  '79': {'id': 80,
#   'review': 'They upsold me on a phone plan I didn’t need, very deceptive.',
#   'date': '2024-11-14',
#   'aspect': {'store': {'ADJ': [],
#     'VERB': [[['upsold'], 'they upsold on phone plan.', 'Neutral'],
#      [['upsold'], 'they upsold me.', 'Neutral']],
#     'OTHER': []}},
#   'sentiment': 'Neutral'},
#  '80': {'id': 81,
#   'review': 'The staff was unprofessional and seemed like they didn’t want to be there.',
#   'date': '2024-11-14',
#   'aspect': {'staff': {'ADJ': [[['unprofessional'],
#       'staff was unprofessional.',
#       'Neutral']],
#     'VERB': [],
#     'OTHER': []}},
#   'sentiment': 'Neutral'},
#  '81': {'id': 82,
#   'review': 'Their return policy is awful, I couldn’t exchange my phone despite its defects.',
#   'date': '2024-11-14',
#   'aspect': {'policy': {'ADJ': [[['awful'], 'policy is awful.', 'Negative']],
#     'VERB': [],
#     'OTHER': []}},
#   'sentiment': 'Negative'},
#  '82': {'id': 83,
#   'review': 'They didn’t apply the discount I was promised.',
#   'date': '2024-11-14',
#   'aspect': {'store': {'ADJ': [],
#     'VERB': [[['apply'], 'they did not apply discount.', 'Neutral']],
#     'OTHER': []}},
#   'sentiment': 'Neutral'},
#  '83': {'id': 84,
#   'review': 'The store was messy and understaffed.',
#   'date': '2024-11-14',
#   'aspect': {'store': {'ADJ': [[['understaffed'],
#       'store was understaffed.',
#       'Neutral'],
#      [['messy'], 'store was messy.', 'Negative']],
#     'VERB': [],
#     'OTHER': []}},
#   'sentiment': 'Negative'},
#  '84': {'id': 85,
#   'review': 'My phone broke down just after the warranty expired, very frustrating.',
#   'date': '2024-11-14',
#   'aspect': {'warranty': {'ADJ': [],
#     'VERB': [[['expire'], 'warranty just expired.', 'Neutral']],
#     'OTHER': []},
#    'phone': {'ADJ': [],
#     'VERB': [[['break'], 'phone broke.', 'Neutral']],
#     'OTHER': []}},
#   'sentiment': 'Neutral'},
#  '85': {'id': 86,
#   'review': 'They kept trying to sell me more expensive phones when I clearly stated my budget.',
#   'date': '2024-11-14',
#   'aspect': {'store': {'ADJ': [],
#     'VERB': [[['keep', 'try'], 'they kept trying.', 'Neutral']],
#     'OTHER': []}},
#   'sentiment': 'Neutral'},
#  '86': {'id': 87,
#   'review': 'The repair job was incomplete, and they refused to refund me.',
#   'date': '2024-11-15',
#   'aspect': {'job': {'ADJ': [[['incomplete'],
#       'job was incomplete.',
#       'Neutral']],
#     'VERB': [],
#     'OTHER': []}},
#   'sentiment': 'Neutral'},
#  '87': {'id': 88,
#   'review': 'Their customer service representatives were extremely rude on the phone.',
#   'date': '2024-11-15',
#   'aspect': {'representative': {'ADJ': [[['rude'],
#       'representative were rude on phone.',
#       'Negative']],
#     'VERB': [],
#     'OTHER': []}},
#   'sentiment': 'Negative'},
#  '88': {'id': 89,
#   'review': 'I had to call multiple times just to get a response, very unprofessional.',
#   'date': '2024-11-15',
#   'aspect': {'staff': {'ADJ': [],
#     'VERB': [[['have', 'call'], 'I had to call multiple times.', 'Neutral']],
#     'OTHER': []}},
#   'sentiment': 'Neutral'},
#  '89': {'id': 90,
#   'review': 'They didn’t explain anything clearly and rushed me through the purchase.',
#   'date': '2024-11-15',
#   'aspect': {'store': {'ADJ': [],
#     'VERB': [[['explain'], 'they did not explain anything.', 'Neutral'],
#      [['rush'], 'they rushed me.', 'Neutral'],
#      [['rush'], 'they rushed through purchase.', 'Neutral'],
#      [['explain'], 'they did not explain clearly.', 'Positive']],
#     'OTHER': []}},
#   'sentiment': 'Positive'},
#  '90': {'id': 91,
#   'review': 'I regret buying from here, their post-purchase support is non-existent.',
#   'date': '2024-11-15',
#   'aspect': {'support': {'ADJ': [[['non'], 'support is non.', 'Neutral']],
#     'VERB': [],
#     'OTHER': []}},
#   'sentiment': 'Neutral'},
#  '91': {'id': 92,
#   'review': 'Phone stopped working just outside the return window, terrible quality.',
#   'date': '2024-11-16',
#   'aspect': {'return window': {'ADJ': [],
#     'VERB': [[['stop', 'work'],
#       'phone stopped working outside return window.',
#       'Neutral']],
#     'OTHER': []},
#    'phone': {'ADJ': [],
#     'VERB': [[['stop', 'work'],
#       'phone stopped working outside return window.',
#       'Neutral'],
#      [['stop'], 'phone stopped quality.', 'Neutral']],
#     'OTHER': []}},
#   'sentiment': 'Neutral'},
#  '92': {'id': 93,
#   'review': 'The store was chaotic, with long lines and unhelpful staff.',
#   'date': '2024-11-16',
#   'aspect': {'store': {'ADJ': [[['chaotic'], 'store was chaotic.', 'Neutral']],
#     'VERB': [],
#     'OTHER': [[['staff'], 'store was with unhelpful staff.', 'Neutral'],
#      [['lines'], 'store was with long lines.', 'Negative']]},
#    'staff': {'ADJ': [],
#     'VERB': [],
#     'OTHER': [[['staff'], 'store was with unhelpful staff.', 'Neutral']]},
#    'long lines': {'ADJ': [],
#     'VERB': [],
#     'OTHER': [[['lines'], 'store was with long lines.', 'Negative']]}},
#   'sentiment': 'Negative'},
#  '93': {'id': 94,
#   'review': 'They didn’t even have the phone I wanted in stock after promising me it was available.',
#   'date': '2024-11-16',
#   'aspect': {'store': {'ADJ': [],
#     'VERB': [[['have'],
#       'they did not even have after promising me.',
#       'Positive'],
#      [['have'], 'they did not even have phone.', 'Neutral']],
#     'OTHER': []}},
#   'sentiment': 'Positive'},
#  '94': {'id': 95,
#   'review': 'Terrible follow-up, they lost my repair order, and I had to start over.',
#   'date': '2024-11-17',
#   'aspect': {'store': {'ADJ': [],
#     'VERB': [[['lose'], 'they lost repair order.', 'Neutral']],
#     'OTHER': []}},
#   'sentiment': 'Neutral'},
#  '95': {'id': 96,
#   'review': 'I felt overcharged for a simple screen repair.',
#   'date': '2024-11-17',
#   'aspect': {'staff': {'ADJ': [],
#     'VERB': [[['feel'], 'I felt overcharged.', 'Neutral']],
#     'OTHER': []}},
#   'sentiment': 'Neutral'},
#  '96': {'id': 97,
#   'review': 'Bought a refurbished phone that had several issues they didn’t disclose.',
#   'date': '2024-11-17',
#   'aspect': {},
#   'sentiment': 'Neutral'},
#  '97': {'id': 98,
#   'review': 'The technician damaged my phone during the repair, and they didn’t take responsibility.',
#   'date': '2024-11-17',
#   'aspect': {'technician': {'ADJ': [],
#     'VERB': [[['damage'], 'technician damaged during repair.', 'Neutral'],
#      [['damage'], 'technician damaged phone.', 'Neutral']],
#     'OTHER': []}},
#   'sentiment': 'Neutral'},
#  '98': {'id': 99,
#   'review': 'I’m extremely disappointed, will not be coming back here again.',
#   'date': '2024-11-17',
#   'aspect': {},
#   'sentiment': 'Neutral'}}

# %%
def get_corpus(input_):
    corpus = []
    # Get dictionary level 1
    for i, dict_1 in input_.items():
        document = ''
        # Get dictionary level 2
        for aspect, dict_2 in dict_1['aspect'].items():
            # Get text from labels
            for label, data_ in dict_2.items():
                for d in data_:
                    document += d[1] + ' '
        corpus.append(document)

    return corpus

get_corpus(data)
# Out:
# ['staff were helpful. staff were patient. ',
#  'process was quick. process was smooth. ',
#  'selection is amazing. price are competitive. ',
#  'I appreciate walked me. I appreciate walked through setting new device. ',
#  'question answered. ',
#  'I could not resist offer amazing deals on phones. I could not resist upgrading. ',
#  'technician fixed faster. technician fixed phones issue. technician fixed phones issue. ',
#  'experience really know stuff. ',
#  'variety was impressive. ',
#  '',
#  'staff was knowledgeable. ',
#  'price were reasonable. ',
#  'staff really went mile. ',
#  'service be excellent. ',
#  'deal was friendly. staff was friendly. ',
#  'buying be experience. fixing be experience. ',
#  'I got good deal on old phone. ',
#  'service are quick. service are reliable. ',
#  'staff was helpful in setting phone. staff was helpful in setting phone. ',
#  'I m satisfied. ',
#  'staff was patient with questions. variety was patient with questions. ',
#  'process was simple. ',
#  'they helped choose within budget. they helped choose phone. ',
#  'phone was fixed in minutes. ',
#  'service is outstanding. ',
#  'store hands. ',
#  'staff made. ',
#  'I found needed what. they helped get great deal. ',
#  'store has fantastic warranty service. store has fantastic warranty service. ',
#  'staff was informative. ',
#  'variety be excellent. store be excellent. ',
#  '',
#  'they were quick in setting phone. ',
#  '',
#  'layout is easy. staff are ready. ',
#  'they helped save lot. ',
#  'one provides best service. one provides best service. ',
#  'service is notch. service is notch. ',
#  'they not fail recommend to family. they not fail recommend store. they not fail recommend to friends. ',
#  'staff took time. staff took time. ',
#  'place be amazing. ',
#  'plan is worth. ',
#  'they were able. I appreciate were able. ',
#  '',
#  'staff was accommodating. ',
#  'I had great experience with program. ',
#  'service was quick. service was efficient. ',
#  'they even helped transfer contacts. they even helped transfer without extra charge. they even helped transfer data. ',
#  'phone has working flawlessly. ',
#  'they even gave discount on repair. they fixed perfectly. they fixed screen. ',
#  'this is reliable. ',
#  'they offer fantastic promotions. they offer discounts. ',
#  'selection be great. selection be phone. service be great. service be phone. ',
#  'they resolved professionally. they resolved very quickly. they resolved issue. ',
#  'store is organized. ',
#  'you re looking for good deals. ',
#  'I always leave store. I made right purchase. ',
#  'they really know received excellent advice from sales team. they really know products. ',
#  'phone looks new. ',
#  'staff was not apologetic. ',
#  '',
#  'price are high. selection is limited. ',
#  'one seemed is poor. service is poor. ',
#  'phone was defective. ',
#  'staff was rude. staff was unhelpful. ',
#  'they charged me. they felt like scam. they charged extra for services. ',
#  'I had took too long. I had took way. ',
#  'they did not inform me. they did not inform of hidden fees. I bought phone. ',
#  'staff seemed. staff gave incorrect information about phone plan. staff gave incorrect information about phone plan. ',
#  'warranty is useless. ',
#  'they twice gave refund. I had to return faulty phone. ',
#  'I very disorganized waited forever. ',
#  '',
#  'they refused to honor promotion. ',
#  'I felt pressured. ',
#  'repair was done poorly. phone broke again. phone broke within week. ',
#  'service was slow. ',
#  'phone was working after repair. ',
#  'phone still has same issue after getting. phone still has same issue after getting. ',
#  'they upsold on phone plan. they upsold me. ',
#  'staff was unprofessional. ',
#  'policy is awful. ',
#  'they did not apply discount. ',
#  'store was understaffed. store was messy. ',
#  'warranty just expired. phone broke. ',
#  'they kept trying. ',
#  'job was incomplete. ',
#  'representative were rude on phone. ',
#  'I had to call multiple times. ',
#  'they did not explain anything. they rushed me. they rushed through purchase. they did not explain clearly. ',
#  'support is non. ',
#  'phone stopped working outside return window. phone stopped working outside return window. phone stopped quality. ',
#  'store was chaotic. store was with unhelpful staff. store was with long lines. store was with unhelpful staff. store was with long lines. ',
#  'they did not even have after promising me. they did not even have phone. ',
#  'they lost repair order. ',
#  'I felt overcharged. ',
#  '',
#  'technician damaged during repair. technician damaged phone. ',
#  '']

# %%
corpus = get_corpus(data)

# Define the list of stopwords
stop_words = set(stopwords.words('english'))
    
# Preprocessing text
def preprocessing(text):
    text = remove_extra_spaces(text)
    text = expand_contractions(text)
    text = remove_non_ascii(text)

    # Get token of words
    doc = nlp(text)
    result = []
    for token in doc:
        t = token.lemma_.lower()

        if re.match(r'^[0-9\W]+$', t) or len(t) < 3 or t in stop_words:
            continue
        # If the token is adjective, noun, propn, or verb
        if token.pos_ in ['NOUN', 'PROPN']:
            result.append(t)
        elif token.pos_ in ['ADJ', 'VERB']:
            result.append(t)
        else:
            continue
    return result

# Create texts
texts = [preprocessing(document) for document in corpus]

# Create dictionary
dictionary = gensim.corpora.Dictionary(texts)


# Convert documents into Bag-of-words format
corpus_bow = [dictionary.doc2bow(text) for text in texts]

# Train the TF-IDF model
tfidf_model = gensim.models.TfidfModel(corpus_bow)

# Get corpus tfidf 
corpus_tfidf = tfidf_model[corpus_bow]

# %%
def topic_model_coherence_generator(corpus, texts, dictionary,
                                    start_topic_count=2, end_topic_count=10,
                                    step=1, cpus=1):
    models = []
    coherence_scores = []
    for topic_nums in tqdm(range(start_topic_count, end_topic_count+1, step)):
        lda_model = gensim.models.LdaModel(corpus=corpus, id2word=dictionary,
                                           chunksize=1740, alpha='auto',
                                           eta='auto', random_state=42,
                                           iterations=500, num_topics=topic_nums,
                                           passes=20, eval_every=None)

        cv_coherence_model_lda = gensim.models.CoherenceModel(model=lda_model,
                                                                     corpus=corpus,
                                                                     texts=texts,
                                                                     dictionary=dictionary,
                                                                     coherence='c_v')
        coherence_score = cv_coherence_model_lda.get_coherence()
        coherence_scores.append(coherence_score)
        models.append(lda_model)


    return models, coherence_scores

models, coherence_scores = topic_model_coherence_generator(corpus=corpus_tfidf,
                                                           texts=texts,
                                                           dictionary=dictionary)
opt_model = models[np.argmax(coherence_scores)]
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████| 9/9 [00:55<00:00,  6.18s/it]

# %%
# Calculate overall mean coherence score
topics_coherences = opt_model.top_topics(corpus_tfidf, topn=20)

# %%
coherence_scores
# Out:
# [0.6850983927558234,
#  0.7225553258293611,
#  0.7219723474786128,
#  0.6984040893433792,
#  0.6874730577326793,
#  0.6994897914640068,
#  0.6819452616365094,
#  0.6789185895745116,
#  0.6635181678605453]

# %% [markdown]
# # Interpretation Result

# %%
# Visualize result: Topic with weights

topics_with_wts = [item[0] for item in topics_coherences]
print("LDA Topics with Weights")
print('='*50)
for idx, topic in enumerate(topics_with_wts):
  print(f'Topic {idx + 1}:')
  print([(term, round(wt, 3)) for wt, term in topic])
  print()
# Out:
# LDA Topics with Weights
# ==================================================
# Topic 1:
# [('phone', 0.043), ('fix', 0.022), ('work', 0.021), ('repair', 0.02), ('experience', 0.019), ('get', 0.017), ('great', 0.017), ('selection', 0.017), ('process', 0.016), ('break', 0.015), ('technician', 0.015), ('amazing', 0.015), ('issue', 0.015), ('helpful', 0.014), ('price', 0.013), ('staff', 0.013), ('time', 0.012), ('discount', 0.012), ('defective', 0.012), ('promise', 0.012)]
#
# Topic 2:
# [('staff', 0.037), ('service', 0.036), ('excellent', 0.019), ('quick', 0.019), ('take', 0.016), ('store', 0.016), ('good', 0.015), ('set', 0.015), ('make', 0.015), ('look', 0.014), ('help', 0.014), ('variety', 0.014), ('warranty', 0.013), ('give', 0.012), ('deal', 0.012), ('wait', 0.012), ('offer', 0.011), ('new', 0.011), ('appreciate', 0.011), ('friendly', 0.011)]
#
# Topic 3:
# [('store', 0.026), ('reliable', 0.023), ('feel', 0.021), ('question', 0.02), ('satisfied', 0.016), ('resolve', 0.015), ('plan', 0.015), ('upsold', 0.015), ('unprofessional', 0.015), ('apologetic', 0.015), ('slow', 0.015), ('outstanding', 0.015), ('hand', 0.014), ('pressured', 0.014), ('overcharge', 0.014), ('worth', 0.014), ('reasonable', 0.013), ('answer', 0.013), ('inform', 0.013), ('choose', 0.013)]

# %% [markdown]
# Explanation:
# - Topic 1: Service Quality and Conflict Resolution.
# > This topic likely centers around the overall quality of service and how customer issues are handled, particularly in resolving conflicts, complaints, or misunderstandings.
# - Topic 2: Product Experience and Sales Interactions.
# > This topic emphasizes product experiences and interactions with sales staff, with a particular focus on phones.
# - Topic 3: Service Effectiveness and Customer Satisfaction.
# > This topic likely reflects customer evaluations of service effectiveness.
# - Topic 4: In-Store Experience and Helpfulness.
# > This topic highlights in-store experiences, focusing on staff helpfulness, product selection, pricing, and store organization.

# %%
topics = [[(term, round(wt, 3))
              for term, wt in opt_model.show_topic(n, topn=20)]
          for n in range(0, opt_model.num_topics)
          ]

topic_df = pd.DataFrame([', '.join([term for term, wt in topic]) for topic in topics],
                       columns=['Term per Topic'],
                       index=[str(t) for t in range(1, opt_model.num_topics+1)])
topic_df
# Out:
#                                                                                                                                                                              Term per Topic
# 1  store, reliable, feel, question, satisfied, resolve, plan, upsold, unprofessional, apologetic, slow, outstanding, hand, pressured, overcharge, worth, reasonable, answer, inform, choose
# 2                                         staff, service, excellent, quick, take, store, good, set, make, look, help, variety, warranty, give, deal, wait, offer, new, appreciate, friendly
# 3                        phone, fix, work, repair, experience, get, great, selection, process, break, technician, amazing, issue, helpful, price, staff, time, discount, defective, promise

# %%
topic_json = topic_df.reset_index().rename({'index': 'topic', 'Term per Topic': 'term'}, axis=1).to_dict('records')

topic_json
# Out:
# [{'topic': '1',
#   'term': 'store, reliable, feel, question, satisfied, resolve, plan, upsold, unprofessional, apologetic, slow, outstanding, hand, pressured, overcharge, worth, reasonable, answer, inform, choose'},
#  {'topic': '2',
#   'term': 'staff, service, excellent, quick, take, store, good, set, make, look, help, variety, warranty, give, deal, wait, offer, new, appreciate, friendly'},
#  {'topic': '3',
#   'term': 'phone, fix, work, repair, experience, get, great, selection, process, break, technician, amazing, issue, helpful, price, staff, time, discount, defective, promise'}]

# %%
# Interpreting result
tm_results = opt_model[corpus_tfidf]

# Corpus Topics
corpus_topics = [sorted(topics, key=lambda record: -record[1])[0]
                 for topics in tm_results]

corpus_topics[:5]
# Out:
# [(2, 0.6150381),
#  (2, 0.6102596),
#  (2, 0.74554163),
#  (1, 0.7650772),
#  (0, 0.6253251)]

# %%
corpus_topic_df = pd.DataFrame()
corpus_topic_df['topic_dominant'] = [item[0]+1 for item in corpus_topics]
corpus_topic_df['topic_contribution'] = [round(item[1], 4) for item in corpus_topics]
corpus_topic_df['term'] = [topic_df.iloc[t[0]]['Term per Topic'] for t in corpus_topics]
corpus_topic_df['review'] = corpus

corpus_topic_df.head()
# Out:
#    topic_dominant  topic_contribution  \
# 0               3              0.6150
# 1               3              0.6103
# 2               3              0.7455
# 3               2              0.7651
# 4               1              0.6253
#
#                                                                                                                                                                                        term  \
# 0                        phone, fix, work, repair, experience, get, great, selection, process, break, technician, amazing, issue, helpful, price, staff, time, discount, defective, promise
# 1                        phone, fix, work, repair, experience, get, great, selection, process, break, technician, amazing, issue, helpful, price, staff, time, discount, defective, promise
# 2                        phone, fix, work, repair, experience, get, great, selection, process, break, technician, amazing, issue, helpful, price, staff, time, discount, defective, promise
# 3                                         staff, service, excellent, quick, take, store, good, set, make, look, help, variety, warranty, give, deal, wait, offer, new, appreciate, friendly
# 4  store, reliable, feel, question, satisfied, resolve, plan, upsold, unprofessional, apologetic, slow, outstanding, hand, pressured, overcharge, worth, reasonable, answer, inform, choose
#
#                                                                      review
# 0                                  staff were helpful. staff were patient.
# 1                                   process was quick. process was smooth.
# 2                             selection is amazing. price are competitive.
# 3  I appreciate walked me. I appreciate walked through setting new device.
# 4                                                       question answered.

# %% [markdown]
# # Save result

# %%
# Update meta data
new_data = corpus_topic_df.drop('review', axis=1).to_dict('index')

def update_data(data_, new_data_):
    updated_data = copy.deepcopy(data_)

    for i, new in new_data_.items():
        updated_data[str(i)].update({'topic': new})

    return updated_data

save_data = update_data(data, new_data)

# %%
# Save dictionary to a JSON file
with open('data-3.json', 'w') as json_file:
    json.dump(save_data, json_file, indent=4)  # 'indent=4' makes the JSON pretty-printed


with open('data-topic.json', 'w') as json_file:
    json.dump(topic_json, json_file, indent=4)

# %%
# Save model
