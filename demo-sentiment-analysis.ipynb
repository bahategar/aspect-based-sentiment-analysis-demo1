# %%
# Utility: Preparation text

from contractions import CONTRACTION_MAP

##========== PREPARATION TEXT ===========##

# Contraction
def expand_contractions(sentence, contraction_mapping=CONTRACTION_MAP):
    """
    Expand the contractions in a sentence. For example don't => do not.
    
    Paramters:
    sentence (str): The input sentence to clean.
    contraction_mapping (dict): A dictionary for mapping contractions.
    
    
    Returns:
    str: The expanded contraction sentence.
    """
    
    contractions_pattern = re.compile('({})'.format('|'.join(contraction_mapping.keys())),
                                      flags=re.IGNORECASE|re.DOTALL)
    
    def expanded_match(contraction):
        """
        Filter for expanding the matched contraction.
        
        Parameters:
        contraction (str): The input of contraction
        
        Returns:
        str: The expanded contraction.
        """
        match = contraction.group(0)
        first_char = match[0]
        expanded_contraction = contraction_mapping.get(match) if contraction_mapping.get(match) else contraction_mapping.get(match.lower())
        
        expanded_contraction = first_char + expanded_contraction[1:]
        return expanded_contraction
    
    expanded_sentence = contractions_pattern.sub(expanded_match, sentence)
    return expanded_sentence


def remove_extra_spaces(sentence):
    # Use regex to replace multiple spaces with a single space
    return re.sub(r'\s+', ' ', sentence).strip()


def remove_non_ascii(text):
    """
    Remove all non-ASCII characters from the text.

    Parameters:
    text (str): The input text to clean.

    Returns:
    str: The cleaned text with only ASCII characters.
    
    """
    
    return ''.join([char for char in text if ord(char) < 128])

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import spacy

import re
import os
import json

import ast

from tqdm import tqdm

from nltk.corpus import stopwords
import gensim

# %%
from pattern.en import sentiment

# %%
# Load nlp model
nlp = spacy.load('en_core_web_lg')

# %%
df = pd.read_csv('example.csv')

# Convert the string columns to dictionaries
df['ability'] = df['ability'].apply(ast.literal_eval)
df['aspects'] = df['aspects'].apply(ast.literal_eval)


print(df.info())
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 91 entries, 0 to 90
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   index    91 non-null     int64
#  1   review   91 non-null     object
#  2   ability  91 non-null     object
#  3   aspects  91 non-null     object
# dtypes: int64(1), object(3)
# memory usage: 3.0+ KB
# None
#    index                                             review  \
# 0      0  The staff were incredibly helpful and patient,...
# 1      1  I had a great experience purchasing my phone h...
# 2      2  Their selection of phones is amazing, and the ...
# 3      3  I appreciate how the staff walked me through s...
# 4      4  Great customer service, I left with the phone ...
#
#                                              ability  \
# 0  {0: [('staff', 'were patient'), ('staff', 'wer...
# 1  {0: [('process', 'was smooth'), ('process', 'w...
# 2  {0: [('price', 'are competitive'), ('selection...
# 3  {0: [('I', 'appreciate walked me'), ('I', 'app...
# 4  {0: [('I', 'left with phone'), ('question', 'a...
#
#                                              aspects
# 0  {'staff': ['staff were patient.', 'staff were ...
# 1  {'process': ['process was smooth.', 'process w...
# 2  {'price': ['price are competitive.'], 'selecti...
# 3  {'new device': ['I appreciate walked through s...
# 4               {'question': ['question answered.']}

# %%
# Load JSON data from a file
with open('data-1.json', 'r') as json_file:
    data = json.load(json_file)

data
# Out:
# {'0': {'staff': {'ADJ': [[['helpful'], 'staff were helpful.'],
#     [['patient'], 'staff were patient.']],
#    'VERB': [],
#    'OTHER': []}},
#  '1': {'process': {'ADJ': [[['smooth'], 'process was smooth.'],
#     [['quick'], 'process was quick.']],
#    'VERB': [],
#    'OTHER': []}},
#  '2': {'selection': {'ADJ': [[['amazing'], 'selection is amazing.']],
#    'VERB': [],
#    'OTHER': []},
#   'price': {'ADJ': [[['competitive'], 'price are competitive.']],
#    'VERB': [],
#    'OTHER': []}},
#  '3': {'staff': {'ADJ': [],
#    'VERB': [[['appreciate', 'walk'], 'I appreciate walked me.'],
#     [['appreciate', 'walk'],
#      'I appreciate walked through setting new device.']],
#    'OTHER': []}},
#  '4': {'question': {'ADJ': [],
#    'VERB': [[['answer'], 'question answered.']],
#    'OTHER': []}},
#  '5': {'staff': {'ADJ': [],
#    'VERB': [[['resist'], 'I could not resist upgrading.'],
#     [['resist', 'offer'],
#      'I could not resist offer amazing deals on phones.']],
#    'OTHER': []}},
#  '6': {'phones issue': {'ADJ': [],
#    'VERB': [[['fix'], 'technician fixed phones issue.']],
#    'OTHER': []},
#   'technician': {'ADJ': [],
#    'VERB': [[['fix'], 'technician fixed phones issue.'],
#     [['fix'], 'technician fixed faster.']],
#    'OTHER': []}},
#  '7': {'experience': {'ADJ': [],
#    'VERB': [[['know'], 'experience really know stuff.']],
#    'OTHER': []}},
#  '8': {'variety': {'ADJ': [[['impressive'], 'variety was impressive.']],
#    'VERB': [],
#    'OTHER': []}},
#  '9': {},
#  '10': {'staff': {'ADJ': [[['knowledgeable'], 'staff was knowledgeable.']],
#    'VERB': [],
#    'OTHER': []}},
#  '11': {'price': {'ADJ': [[['reasonable'], 'price were reasonable.']],
#    'VERB': [],
#    'OTHER': []}},
#  '12': {'staff': {'ADJ': [],
#    'VERB': [[['go'], 'staff really went mile.']],
#    'OTHER': []}},
#  '13': {'service': {'ADJ': [[['excellent'], 'service be excellent.']],
#    'VERB': [],
#    'OTHER': []}},
#  '14': {'deal': {'ADJ': [[['friendly'], 'deal was friendly.']],
#    'VERB': [],
#    'OTHER': []},
#   'staff': {'ADJ': [[['friendly'], 'staff was friendly.']],
#    'VERB': [],
#    'OTHER': []}},
#  '15': {'buying': {'ADJ': [],
#    'VERB': [],
#    'OTHER': [[['experience'], 'buying be experience.']]},
#   'fixing': {'ADJ': [],
#    'VERB': [],
#    'OTHER': [[['experience'], 'fixing be experience.']]}},
#  '16': {'staff': {'ADJ': [],
#    'VERB': [[['get'], 'I got good deal on old phone.']],
#    'OTHER': []}},
#  '17': {'service': {'ADJ': [[['quick'], 'service are quick.'],
#     [['reliable'], 'service are reliable.']],
#    'VERB': [],
#    'OTHER': []}},
#  '18': {'phone': {'ADJ': [[['helpful'],
#      'staff was helpful in setting phone.']],
#    'VERB': [],
#    'OTHER': []},
#   'staff': {'ADJ': [[['helpful'], 'staff was helpful in setting phone.']],
#    'VERB': [],
#    'OTHER': []}},
#  '19': {'staff': {'ADJ': [],
#    'VERB': [[['m'], 'I m satisfied.']],
#    'OTHER': []}},
#  '20': {'staff': {'ADJ': [[['patient'], 'staff was patient with questions.']],
#    'VERB': [],
#    'OTHER': []},
#   'variety': {'ADJ': [[['patient'], 'variety was patient with questions.']],
#    'VERB': [],
#    'OTHER': []}},
#  '21': {'process': {'ADJ': [[['simple'], 'process was simple.']],
#    'VERB': [],
#    'OTHER': []}},
#  '22': {'store': {'ADJ': [],
#    'VERB': [[['help', 'choose'], 'they helped choose within budget.'],
#     [['help', 'choose'], 'they helped choose phone.']],
#    'OTHER': []}},
#  '23': {'phone': {'ADJ': [],
#    'VERB': [[['fix'], 'phone was fixed in minutes.']],
#    'OTHER': []}},
#  '24': {'service': {'ADJ': [[['outstanding'], 'service is outstanding.']],
#    'VERB': [],
#    'OTHER': []}},
#  '25': {'store': {'ADJ': [],
#    'VERB': [[['hand'], 'store hands.']],
#    'OTHER': []}},
#  '26': {'staff': {'ADJ': [],
#    'VERB': [[['make'], 'staff made.']],
#    'OTHER': []}},
#  '27': {'staff': {'ADJ': [],
#    'VERB': [[['find', 'need'], 'I found needed what.']],
#    'OTHER': []},
#   'store': {'ADJ': [],
#    'VERB': [[['help', 'get'], 'they helped get great deal.']],
#    'OTHER': []}},
#  '28': {'warranty service': {'ADJ': [],
#    'VERB': [[['have'], 'store has fantastic warranty service.']],
#    'OTHER': []},
#   'store': {'ADJ': [],
#    'VERB': [[['have'], 'store has fantastic warranty service.']],
#    'OTHER': []}},
#  '29': {'staff': {'ADJ': [[['informative'], 'staff was informative.']],
#    'VERB': [],
#    'OTHER': []}},
#  '30': {'variety': {'ADJ': [[['excellent'], 'variety be excellent.']],
#    'VERB': [],
#    'OTHER': []},
#   'store': {'ADJ': [[['excellent'], 'store be excellent.']],
#    'VERB': [],
#    'OTHER': []}},
#  '31': {},
#  '32': {'store': {'ADJ': [[['quick'], 'they were quick in setting phone.']],
#    'VERB': [],
#    'OTHER': []}},
#  '33': {},
#  '34': {'layout': {'ADJ': [[['easy'], 'layout is easy.']],
#    'VERB': [],
#    'OTHER': []},
#   'staff': {'ADJ': [[['ready'], 'staff are ready.']],
#    'VERB': [],
#    'OTHER': []}},
#  '35': {'store': {'ADJ': [],
#    'VERB': [[['help', 'save'], 'they helped save lot.']],
#    'OTHER': []}},
#  '36': {'service': {'ADJ': [],
#    'VERB': [[['provide'], 'one provides best service.']],
#    'OTHER': []},
#   'one': {'ADJ': [],
#    'VERB': [[['provide'], 'one provides best service.']],
#    'OTHER': []}},
#  '37': {'service': {'ADJ': [[['notch'], 'service is notch.']],
#    'VERB': [],
#    'OTHER': [[['notch'], 'service is notch.']]}},
#  '38': {'store': {'ADJ': [],
#    'VERB': [[['fail', 'recommend'], 'they not fail recommend to friends.'],
#     [['fail', 'recommend'], 'they not fail recommend store.'],
#     [['fail', 'recommend'], 'they not fail recommend to family.']],
#    'OTHER': []}},
#  '39': {'time': {'ADJ': [],
#    'VERB': [[['take'], 'staff took time.']],
#    'OTHER': []},
#   'staff': {'ADJ': [], 'VERB': [[['take'], 'staff took time.']], 'OTHER': []}},
#  '40': {'place': {'ADJ': [[['amazing'], 'place be amazing.']],
#    'VERB': [],
#    'OTHER': []}},
#  '41': {'plan': {'ADJ': [[['worth'], 'plan is worth.']],
#    'VERB': [],
#    'OTHER': []}},
#  '42': {'staff': {'ADJ': [],
#    'VERB': [[['appreciate', 'be'], 'I appreciate were able.']],
#    'OTHER': []},
#   'store': {'ADJ': [[['able'], 'they were able.']], 'VERB': [], 'OTHER': []}},
#  '43': {},
#  '44': {'staff': {'ADJ': [[['accommodating'], 'staff was accommodating.']],
#    'VERB': [],
#    'OTHER': []}},
#  '45': {'staff': {'ADJ': [],
#    'VERB': [[['have'], 'I had great experience with program.']],
#    'OTHER': []}},
#  '46': {'service': {'ADJ': [[['quick'], 'service was quick.'],
#     [['efficient'], 'service was efficient.']],
#    'VERB': [],
#    'OTHER': []}},
#  '47': {'store': {'ADJ': [],
#    'VERB': [[['help', 'transfer'],
#      'they even helped transfer without extra charge.'],
#     [['help', 'transfer'], 'they even helped transfer data.'],
#     [['help', 'transfer'], 'they even helped transfer contacts.']],
#    'OTHER': []}},
#  '48': {'phone': {'ADJ': [],
#    'VERB': [[['work'], 'phone has working flawlessly.']],
#    'OTHER': []}},
#  '49': {'store': {'ADJ': [],
#    'VERB': [[['fix'], 'they fixed perfectly.'],
#     [['fix'], 'they fixed screen.'],
#     [['give'], 'they even gave discount on repair.']],
#    'OTHER': []}},
#  '50': {'staff': {'ADJ': [[['reliable'], 'this is reliable.']],
#    'VERB': [],
#    'OTHER': []}},
#  '51': {'store': {'ADJ': [],
#    'VERB': [[['offer'], 'they offer discounts.'],
#     [['offer'], 'they offer fantastic promotions.']],
#    'OTHER': []}},
#  '52': {'service': {'ADJ': [[['great'], 'service be great.']],
#    'VERB': [],
#    'OTHER': [[['phone'], 'service be phone.']]},
#   'selection': {'ADJ': [[['great'], 'selection be great.']],
#    'VERB': [],
#    'OTHER': [[['phone'], 'selection be phone.']]}},
#  '53': {'store': {'ADJ': [],
#    'VERB': [[['resolve'], 'they resolved professionally.'],
#     [['resolve'], 'they resolved very quickly.'],
#     [['resolve'], 'they resolved issue.']],
#    'OTHER': []}},
#  '54': {'store': {'ADJ': [[['organize'], 'store is organized.']],
#    'VERB': [],
#    'OTHER': []}},
#  '55': {'store': {'ADJ': [],
#    'VERB': [[['look'], 'you re looking for good deals.']],
#    'OTHER': []}},
#  '56': {'staff': {'ADJ': [],
#    'VERB': [[['make'], 'I made right purchase.'],
#     [['leave'], 'I always leave store.']],
#    'OTHER': []}},
#  '57': {'store': {'ADJ': [],
#    'VERB': [[['know', 'receive'],
#      'they really know received excellent advice from sales team.'],
#     [['know'], 'they really know products.']],
#    'OTHER': []}},
#  '58': {'phone': {'ADJ': [],
#    'VERB': [[['look'], 'phone looks new.']],
#    'OTHER': []}},
#  '59': {'staff': {'ADJ': [[['apologetic'], 'staff was not apologetic.']],
#    'VERB': [],
#    'OTHER': []}},
#  '60': {},
#  '61': {'selection': {'ADJ': [[['limited'], 'selection is limited.']],
#    'VERB': [],
#    'OTHER': []},
#   'price': {'ADJ': [[['high'], 'price are high.']], 'VERB': [], 'OTHER': []}},
#  '62': {'one': {'ADJ': [],
#    'VERB': [[['seem', 'be'], 'one seemed is poor.']],
#    'OTHER': []},
#   'service': {'ADJ': [[['poor'], 'service is poor.']],
#    'VERB': [],
#    'OTHER': []}},
#  '63': {'phone': {'ADJ': [[['defective'], 'phone was defective.']],
#    'VERB': [],
#    'OTHER': []}},
#  '64': {'staff': {'ADJ': [[['rude'], 'staff was rude.'],
#     [['unhelpful'], 'staff was unhelpful.']],
#    'VERB': [],
#    'OTHER': []}},
#  '65': {'store': {'ADJ': [],
#    'VERB': [[['feel'], 'they felt like scam.'],
#     [['charge'], 'they charged me.'],
#     [['charge'], 'they charged extra for services.']],
#    'OTHER': []}},
#  '66': {'staff': {'ADJ': [],
#    'VERB': [[['have', 'take'], 'I had took too long.'],
#     [['have', 'take'], 'I had took way.']],
#    'OTHER': []}},
#  '67': {'store': {'ADJ': [],
#    'VERB': [[['inform'], 'they did not inform me.'],
#     [['inform'], 'they did not inform of hidden fees.']],
#    'OTHER': []},
#   'staff': {'ADJ': [], 'VERB': [[['buy'], 'I bought phone.']], 'OTHER': []}},
#  '68': {'staff': {'ADJ': [],
#    'VERB': [[['seem'], 'staff seemed.'],
#     [['give'], 'staff gave incorrect information about phone plan.']],
#    'OTHER': []},
#   'phone plan': {'ADJ': [],
#    'VERB': [[['give'], 'staff gave incorrect information about phone plan.']],
#    'OTHER': []}},
#  '69': {'warranty': {'ADJ': [[['useless'], 'warranty is useless.']],
#    'VERB': [],
#    'OTHER': []}},
#  '70': {'store': {'ADJ': [],
#    'VERB': [[['give'], 'they twice gave refund.']],
#    'OTHER': []},
#   'staff': {'ADJ': [],
#    'VERB': [[['have', 'return'], 'I had to return faulty phone.']],
#    'OTHER': []}},
#  '71': {'staff': {'ADJ': [],
#    'VERB': [[['wait'], 'I very disorganized waited forever.']],
#    'OTHER': []}},
#  '72': {},
#  '73': {'store': {'ADJ': [],
#    'VERB': [[['refuse', 'honor'], 'they refused to honor promotion.']],
#    'OTHER': []}},
#  '74': {'staff': {'ADJ': [],
#    'VERB': [[['feel'], 'I felt pressured.']],
#    'OTHER': []}},
#  '75': {'repair': {'ADJ': [],
#    'VERB': [[['do'], 'repair was done poorly.']],
#    'OTHER': []},
#   'phone': {'ADJ': [],
#    'VERB': [[['break'], 'phone broke within week.'],
#     [['break'], 'phone broke again.']],
#    'OTHER': []}},
#  '76': {'service': {'ADJ': [[['slow'], 'service was slow.']],
#    'VERB': [],
#    'OTHER': []}},
#  '77': {'phone': {'ADJ': [],
#    'VERB': [[['work'], 'phone was working after repair.']],
#    'OTHER': []}},
#  '78': {'same issue': {'ADJ': [],
#    'VERB': [[['have'], 'phone still has same issue after getting.']],
#    'OTHER': []},
#   'phone': {'ADJ': [],
#    'VERB': [[['have'], 'phone still has same issue after getting.']],
#    'OTHER': []}},
#  '79': {'store': {'ADJ': [],
#    'VERB': [[['upsold'], 'they upsold on phone plan.'],
#     [['upsold'], 'they upsold me.']],
#    'OTHER': []}},
#  '80': {'staff': {'ADJ': [[['unprofessional'], 'staff was unprofessional.']],
#    'VERB': [],
#    'OTHER': []}},
#  '81': {'policy': {'ADJ': [[['awful'], 'policy is awful.']],
#    'VERB': [],
#    'OTHER': []}},
#  '82': {'store': {'ADJ': [],
#    'VERB': [[['apply'], 'they did not apply discount.']],
#    'OTHER': []}},
#  '83': {'store': {'ADJ': [[['messy'], 'store was messy.'],
#     [['understaffed'], 'store was understaffed.']],
#    'VERB': [],
#    'OTHER': []}},
#  '84': {'warranty': {'ADJ': [],
#    'VERB': [[['expire'], 'warranty just expired.']],
#    'OTHER': []},
#   'phone': {'ADJ': [], 'VERB': [[['break'], 'phone broke.']], 'OTHER': []}},
#  '85': {'store': {'ADJ': [],
#    'VERB': [[['keep', 'try'], 'they kept trying.']],
#    'OTHER': []}},
#  '86': {'job': {'ADJ': [[['incomplete'], 'job was incomplete.']],
#    'VERB': [],
#    'OTHER': []}},
#  '87': {'representative': {'ADJ': [[['rude'],
#      'representative were rude on phone.']],
#    'VERB': [],
#    'OTHER': []}},
#  '88': {'staff': {'ADJ': [],
#    'VERB': [[['have', 'call'], 'I had to call multiple times.']],
#    'OTHER': []}},
#  '89': {'store': {'ADJ': [],
#    'VERB': [[['rush'], 'they rushed me.'],
#     [['explain'], 'they did not explain anything.'],
#     [['explain'], 'they did not explain clearly.'],
#     [['rush'], 'they rushed through purchase.']],
#    'OTHER': []}},
#  '90': {'support': {'ADJ': [[['non'], 'support is non.']],
#    'VERB': [],
#    'OTHER': []}},
#  '91': {'return window': {'ADJ': [],
#    'VERB': [[['stop', 'work'],
#      'phone stopped working outside return window.']],
#    'OTHER': []},
#   'phone': {'ADJ': [],
#    'VERB': [[['stop', 'work'], 'phone stopped working outside return window.'],
#     [['stop'], 'phone stopped quality.']],
#    'OTHER': []}},
#  '92': {'store': {'ADJ': [[['chaotic'], 'store was chaotic.']],
#    'VERB': [],
#    'OTHER': [[['staff'], 'store was with unhelpful staff.'],
#     [['lines'], 'store was with long lines.']]},
#   'staff': {'ADJ': [],
#    'VERB': [],
#    'OTHER': [[['staff'], 'store was with unhelpful staff.']]},
#   'long lines': {'ADJ': [],
#    'VERB': [],
#    'OTHER': [[['lines'], 'store was with long lines.']]}},
#  '93': {'store': {'ADJ': [],
#    'VERB': [[['have'], 'they did not even have after promising me.'],
#     [['have'], 'they did not even have phone.']],
#    'OTHER': []}},
#  '94': {'store': {'ADJ': [],
#    'VERB': [[['lose'], 'they lost repair order.']],
#    'OTHER': []}},
#  '95': {'staff': {'ADJ': [],
#    'VERB': [[['feel'], 'I felt overcharged.']],
#    'OTHER': []}},
#  '96': {},
#  '97': {'technician': {'ADJ': [],
#    'VERB': [[['damage'], 'technician damaged during repair.'],
#     [['damage'], 'technician damaged phone.']],
#    'OTHER': []}},
#  '98': {}}

# %%
# Function for Sentiment Analysis using Pattern
def pattern_sentiment_analysis(text):
    # Get the sentiment polarity and subjectivity
    polarity, subjectivity = sentiment(text)
    
    # Determine the sentiment based on polarity
    if polarity > 0:
        sentiment_label = "Positive"
    elif polarity < 0:
        sentiment_label = "Negative"
    else:
        sentiment_label = "Neutral"
    
    # Return the results
    return {
        "sentiment": sentiment_label,
        "polarity": polarity,
        "subjectivity": subjectivity
    }

# %%
pattern_sentiment_analysis("representative were rude on phone.")
pattern_sentiment_analysis('store was chaotic.')
# Out:
# {'sentiment': 'Neutral', 'polarity': 0.0, 'subjectivity': 0.0}

# %%
example = {'store': {'ADJ': [[['chaotic'], 'store was chaotic.']],
                     'VERB': [],
                     'OTHER': [[['staff'], 'store was with unhelpful staff.'],
                               [['lines'], 'store was with long lines.']]},
           'staff': {'ADJ': [],
                     'VERB': [],
                     'OTHER': [[['staff'], 'store was with unhelpful staff.']]},
           'long lines': {'ADJ': [],
                          'VERB': [],
                          'OTHER': [[['lines'], 'store was with long lines.']]}}

example
# Out:
# {'store': {'ADJ': [[['chaotic'], 'store was chaotic.']],
#   'VERB': [],
#   'OTHER': [[['staff'], 'store was with unhelpful staff.'],
#    [['lines'], 'store was with long lines.']]},
#  'staff': {'ADJ': [],
#   'VERB': [],
#   'OTHER': [[['staff'], 'store was with unhelpful staff.']]},
#  'long lines': {'ADJ': [],
#   'VERB': [],
#   'OTHER': [[['lines'], 'store was with long lines.']]}}

# %%
for aspect, item in example.items():

# %%
def fine_sentiment(input_):
    new_data = {}
    if len(input_) > 0:
        for aspect, item in input_.items():
            dict_label = {}
            for label, data in item.items():
                temp = []
                if len(data) > 0:
                    texts = []
                    for d in data:
                        text = d[-1]
                        texts.append(text)
                        # print(text)
                        result = pattern_sentiment_analysis(text)['sentiment']
                        temp.append([d[0], d[1], result])
                # Update data label
                dict_label[label] = temp
                
            texts = ' '.join(texts)
            result = pattern_sentiment_analysis(texts)['sentiment']
            
            new_data[aspect] = {'data': dict_label,
                                'sentiment': result}
    return new_data

test = [fine_sentiment(x) for x in data.values()]

test
# Out:
# [{'staff': {'data': {'ADJ': [[['helpful'], 'staff were helpful.', 'Neutral'],
#      [['patient'], 'staff were patient.', 'Neutral']],
#     'VERB': [],
#     'OTHER': []},
#    'sentiment': 'Neutral'}},
#  {'process': {'data': {'ADJ': [[['smooth'], 'process was smooth.', 'Positive'],
#      [['quick'], 'process was quick.', 'Positive']],
#     'VERB': [],
#     'OTHER': []},
#    'sentiment': 'Positive'}},
#  {'selection': {'data': {'ADJ': [[['amazing'],
#       'selection is amazing.',
#       'Positive']],
#     'VERB': [],
#     'OTHER': []},
#    'sentiment': 'Positive'},
#   'price': {'data': {'ADJ': [[['competitive'],
#       'price are competitive.',
#       'Neutral']],
#     'VERB': [],
#     'OTHER': []},
#    'sentiment': 'Neutral'}},
#  {'staff': {'data': {'ADJ': [],
#     'VERB': [[['appreciate', 'walk'], 'I appreciate walked me.', 'Neutral'],
#      [['appreciate', 'walk'],
#       'I appreciate walked through setting new device.',
#       'Positive']],
#     'OTHER': []},
#    'sentiment': 'Positive'}},
#  {'question': {'data': {'ADJ': [],
#     'VERB': [[['answer'], 'question answered.', 'Neutral']],
#     'OTHER': []},
#    'sentiment': 'Neutral'}},
#  {'staff': {'data': {'ADJ': [],
#     'VERB': [[['resist'], 'I could not resist upgrading.', 'Neutral'],
#      [['resist', 'offer'],
#       'I could not resist offer amazing deals on phones.',
#       'Positive']],
#     'OTHER': []},
#    'sentiment': 'Positive'}},
#  {'phones issue': {'data': {'ADJ': [],
#     'VERB': [[['fix'], 'technician fixed phones issue.', 'Positive']],
#     'OTHER': []},
#    'sentiment': 'Positive'},
#   'technician': {'data': {'ADJ': [],
#     'VERB': [[['fix'], 'technician fixed phones issue.', 'Positive'],
#      [['fix'], 'technician fixed faster.', 'Positive']],
#     'OTHER': []},
#    'sentiment': 'Positive'}},
#  {'experience': {'data': {'ADJ': [],
#     'VERB': [[['know'], 'experience really know stuff.', 'Positive']],
#     'OTHER': []},
#    'sentiment': 'Positive'}},
#  {'variety': {'data': {'ADJ': [[['impressive'],
#       'variety was impressive.',
#       'Positive']],
#     'VERB': [],
#     'OTHER': []},
#    'sentiment': 'Positive'}},
#  {},
#  {'staff': {'data': {'ADJ': [[['knowledgeable'],
#       'staff was knowledgeable.',
#       'Neutral']],
#     'VERB': [],
#     'OTHER': []},
#    'sentiment': 'Neutral'}},
#  {'price': {'data': {'ADJ': [[['reasonable'],
#       'price were reasonable.',
#       'Positive']],
#     'VERB': [],
#     'OTHER': []},
#    'sentiment': 'Positive'}},
#  {'staff': {'data': {'ADJ': [],
#     'VERB': [[['go'], 'staff really went mile.', 'Positive']],
#     'OTHER': []},
#    'sentiment': 'Positive'}},
#  {'service': {'data': {'ADJ': [[['excellent'],
#       'service be excellent.',
#       'Positive']],
#     'VERB': [],
#     'OTHER': []},
#    'sentiment': 'Positive'}},
#  {'deal': {'data': {'ADJ': [[['friendly'], 'deal was friendly.', 'Positive']],
#     'VERB': [],
#     'OTHER': []},
#    'sentiment': 'Positive'},
#   'staff': {'data': {'ADJ': [[['friendly'],
#       'staff was friendly.',
#       'Positive']],
#     'VERB': [],
#     'OTHER': []},
#    'sentiment': 'Positive'}},
#  {'buying': {'data': {'ADJ': [],
#     'VERB': [],
#     'OTHER': [[['experience'], 'buying be experience.', 'Neutral']]},
#    'sentiment': 'Neutral'},
#   'fixing': {'data': {'ADJ': [],
#     'VERB': [],
#     'OTHER': [[['experience'], 'fixing be experience.', 'Neutral']]},
#    'sentiment': 'Neutral'}},
#  {'staff': {'data': {'ADJ': [],
#     'VERB': [[['get'], 'I got good deal on old phone.', 'Positive']],
#     'OTHER': []},
#    'sentiment': 'Positive'}},
#  {'service': {'data': {'ADJ': [[['quick'], 'service are quick.', 'Positive'],
#      [['reliable'], 'service are reliable.', 'Neutral']],
#     'VERB': [],
#     'OTHER': []},
#    'sentiment': 'Positive'}},
#  {'phone': {'data': {'ADJ': [[['helpful'],
#       'staff was helpful in setting phone.',
#       'Neutral']],
#     'VERB': [],
#     'OTHER': []},
#    'sentiment': 'Neutral'},
#   'staff': {'data': {'ADJ': [[['helpful'],
#       'staff was helpful in setting phone.',
#       'Neutral']],
#     'VERB': [],
#     'OTHER': []},
#    'sentiment': 'Neutral'}},
#  {'staff': {'data': {'ADJ': [],
#     'VERB': [[['m'], 'I m satisfied.', 'Positive']],
#     'OTHER': []},
#    'sentiment': 'Positive'}},
#  {'staff': {'data': {'ADJ': [[['patient'],
#       'staff was patient with questions.',
#       'Neutral']],
#     'VERB': [],
#     'OTHER': []},
#    'sentiment': 'Neutral'},
#   'variety': {'data': {'ADJ': [[['patient'],
#       'variety was patient with questions.',
#       'Neutral']],
#     'VERB': [],
#     'OTHER': []},
#    'sentiment': 'Neutral'}},
#  {'process': {'data': {'ADJ': [[['simple'], 'process was simple.', 'Neutral']],
#     'VERB': [],
#     'OTHER': []},
#    'sentiment': 'Neutral'}},
#  {'store': {'data': {'ADJ': [],
#     'VERB': [[['help', 'choose'],
#       'they helped choose within budget.',
#       'Neutral'],
#      [['help', 'choose'], 'they helped choose phone.', 'Neutral']],
#     'OTHER': []},
#    'sentiment': 'Neutral'}},
#  {'phone': {'data': {'ADJ': [],
#     'VERB': [[['fix'], 'phone was fixed in minutes.', 'Positive']],
#     'OTHER': []},
#    'sentiment': 'Positive'}},
#  {'service': {'data': {'ADJ': [[['outstanding'],
#       'service is outstanding.',
#       'Positive']],
#     'VERB': [],
#     'OTHER': []},
#    'sentiment': 'Positive'}},
#  {'store': {'data': {'ADJ': [],
#     'VERB': [[['hand'], 'store hands.', 'Neutral']],
#     'OTHER': []},
#    'sentiment': 'Neutral'}},
#  {'staff': {'data': {'ADJ': [],
#     'VERB': [[['make'], 'staff made.', 'Neutral']],
#     'OTHER': []},
#    'sentiment': 'Neutral'}},
#  {'staff': {'data': {'ADJ': [],
#     'VERB': [[['find', 'need'], 'I found needed what.', 'Neutral']],
#     'OTHER': []},
#    'sentiment': 'Neutral'},
#   'store': {'data': {'ADJ': [],
#     'VERB': [[['help', 'get'], 'they helped get great deal.', 'Positive']],
#     'OTHER': []},
#    'sentiment': 'Positive'}},
#  {'warranty service': {'data': {'ADJ': [],
#     'VERB': [[['have'], 'store has fantastic warranty service.', 'Positive']],
#     'OTHER': []},
#    'sentiment': 'Positive'},
#   'store': {'data': {'ADJ': [],
#     'VERB': [[['have'], 'store has fantastic warranty service.', 'Positive']],
#     'OTHER': []},
#    'sentiment': 'Positive'}},
#  {'staff': {'data': {'ADJ': [[['informative'],
#       'staff was informative.',
#       'Neutral']],
#     'VERB': [],
#     'OTHER': []},
#    'sentiment': 'Neutral'}},
#  {'variety': {'data': {'ADJ': [[['excellent'],
#       'variety be excellent.',
#       'Positive']],
#     'VERB': [],
#     'OTHER': []},
#    'sentiment': 'Positive'},
#   'store': {'data': {'ADJ': [[['excellent'],
#       'store be excellent.',
#       'Positive']],
#     'VERB': [],
#     'OTHER': []},
#    'sentiment': 'Positive'}},
#  {},
#  {'store': {'data': {'ADJ': [[['quick'],
#       'they were quick in setting phone.',
#       'Positive']],
#     'VERB': [],
#     'OTHER': []},
#    'sentiment': 'Positive'}},
#  {},
#  {'layout': {'data': {'ADJ': [[['easy'], 'layout is easy.', 'Positive']],
#     'VERB': [],
#     'OTHER': []},
#    'sentiment': 'Positive'},
#   'staff': {'data': {'ADJ': [[['ready'], 'staff are ready.', 'Positive']],
#     'VERB': [],
#     'OTHER': []},
#    'sentiment': 'Positive'}},
#  {'store': {'data': {'ADJ': [],
#     'VERB': [[['help', 'save'], 'they helped save lot.', 'Neutral']],
#     'OTHER': []},
#    'sentiment': 'Neutral'}},
#  {'service': {'data': {'ADJ': [],
#     'VERB': [[['provide'], 'one provides best service.', 'Positive']],
#     'OTHER': []},
#    'sentiment': 'Positive'},
#   'one': {'data': {'ADJ': [],
#     'VERB': [[['provide'], 'one provides best service.', 'Positive']],
#     'OTHER': []},
#    'sentiment': 'Positive'}},
#  {'service': {'data': {'ADJ': [[['notch'], 'service is notch.', 'Neutral']],
#     'VERB': [],
#     'OTHER': [[['notch'], 'service is notch.', 'Neutral']]},
#    'sentiment': 'Neutral'}},
#  {'store': {'data': {'ADJ': [],
#     'VERB': [[['fail', 'recommend'],
#       'they not fail recommend to friends.',
#       'Positive'],
#      [['fail', 'recommend'], 'they not fail recommend store.', 'Positive'],
#      [['fail', 'recommend'],
#       'they not fail recommend to family.',
#       'Positive']],
#     'OTHER': []},
#    'sentiment': 'Positive'}},
#  {'time': {'data': {'ADJ': [],
#     'VERB': [[['take'], 'staff took time.', 'Neutral']],
#     'OTHER': []},
#    'sentiment': 'Neutral'},
#   'staff': {'data': {'ADJ': [],
#     'VERB': [[['take'], 'staff took time.', 'Neutral']],
#     'OTHER': []},
#    'sentiment': 'Neutral'}},
#  {'place': {'data': {'ADJ': [[['amazing'], 'place be amazing.', 'Positive']],
#     'VERB': [],
#     'OTHER': []},
#    'sentiment': 'Positive'}},
#  {'plan': {'data': {'ADJ': [[['worth'], 'plan is worth.', 'Positive']],
#     'VERB': [],
#     'OTHER': []},
#    'sentiment': 'Positive'}},
#  {'staff': {'data': {'ADJ': [],
#     'VERB': [[['appreciate', 'be'], 'I appreciate were able.', 'Positive']],
#     'OTHER': []},
#    'sentiment': 'Positive'},
#   'store': {'data': {'ADJ': [[['able'], 'they were able.', 'Positive']],
#     'VERB': [],
#     'OTHER': []},
#    'sentiment': 'Positive'}},
#  {},
#  {'staff': {'data': {'ADJ': [[['accommodating'],
#       'staff was accommodating.',
#       'Neutral']],
#     'VERB': [],
#     'OTHER': []},
#    'sentiment': 'Neutral'}},
#  {'staff': {'data': {'ADJ': [],
#     'VERB': [[['have'], 'I had great experience with program.', 'Positive']],
#     'OTHER': []},
#    'sentiment': 'Positive'}},
#  {'service': {'data': {'ADJ': [[['quick'], 'service was quick.', 'Positive'],
#      [['efficient'], 'service was efficient.', 'Neutral']],
#     'VERB': [],
#     'OTHER': []},
#    'sentiment': 'Positive'}},
#  {'store': {'data': {'ADJ': [],
#     'VERB': [[['help', 'transfer'],
#       'they even helped transfer without extra charge.',
#       'Neutral'],
#      [['help', 'transfer'], 'they even helped transfer data.', 'Neutral'],
#      [['help', 'transfer'], 'they even helped transfer contacts.', 'Neutral']],
#     'OTHER': []},
#    'sentiment': 'Neutral'}},
#  {'phone': {'data': {'ADJ': [],
#     'VERB': [[['work'], 'phone has working flawlessly.', 'Positive']],
#     'OTHER': []},
#    'sentiment': 'Positive'}},
#  {'store': {'data': {'ADJ': [],
#     'VERB': [[['fix'], 'they fixed perfectly.', 'Positive'],
#      [['fix'], 'they fixed screen.', 'Positive'],
#      [['give'], 'they even gave discount on repair.', 'Neutral']],
#     'OTHER': []},
#    'sentiment': 'Positive'}},
#  {'staff': {'data': {'ADJ': [[['reliable'], 'this is reliable.', 'Neutral']],
#     'VERB': [],
#     'OTHER': []},
#    'sentiment': 'Neutral'}},
#  {'store': {'data': {'ADJ': [],
#     'VERB': [[['offer'], 'they offer discounts.', 'Neutral'],
#      [['offer'], 'they offer fantastic promotions.', 'Positive']],
#     'OTHER': []},
#    'sentiment': 'Positive'}},
#  {'service': {'data': {'ADJ': [[['great'], 'service be great.', 'Positive']],
#     'VERB': [],
#     'OTHER': [[['phone'], 'service be phone.', 'Neutral']]},
#    'sentiment': 'Neutral'},
#   'selection': {'data': {'ADJ': [[['great'],
#       'selection be great.',
#       'Positive']],
#     'VERB': [],
#     'OTHER': [[['phone'], 'selection be phone.', 'Neutral']]},
#    'sentiment': 'Neutral'}},
#  {'store': {'data': {'ADJ': [],
#     'VERB': [[['resolve'], 'they resolved professionally.', 'Positive'],
#      [['resolve'], 'they resolved very quickly.', 'Positive'],
#      [['resolve'], 'they resolved issue.', 'Neutral']],
#     'OTHER': []},
#    'sentiment': 'Positive'}},
#  {'store': {'data': {'ADJ': [[['organize'], 'store is organized.', 'Neutral']],
#     'VERB': [],
#     'OTHER': []},
#    'sentiment': 'Neutral'}},
#  {'store': {'data': {'ADJ': [],
#     'VERB': [[['look'], 'you re looking for good deals.', 'Positive']],
#     'OTHER': []},
#    'sentiment': 'Positive'}},
#  {'staff': {'data': {'ADJ': [],
#     'VERB': [[['make'], 'I made right purchase.', 'Positive'],
#      [['leave'], 'I always leave store.', 'Neutral']],
#     'OTHER': []},
#    'sentiment': 'Positive'}},
#  {'store': {'data': {'ADJ': [],
#     'VERB': [[['know', 'receive'],
#       'they really know received excellent advice from sales team.',
#       'Positive'],
#      [['know'], 'they really know products.', 'Positive']],
#     'OTHER': []},
#    'sentiment': 'Positive'}},
#  {'phone': {'data': {'ADJ': [],
#     'VERB': [[['look'], 'phone looks new.', 'Positive']],
#     'OTHER': []},
#    'sentiment': 'Positive'}},
#  {'staff': {'data': {'ADJ': [[['apologetic'],
#       'staff was not apologetic.',
#       'Neutral']],
#     'VERB': [],
#     'OTHER': []},
#    'sentiment': 'Neutral'}},
#  {},
#  {'selection': {'data': {'ADJ': [[['limited'],
#       'selection is limited.',
#       'Negative']],
#     'VERB': [],
#     'OTHER': []},
#    'sentiment': 'Negative'},
#   'price': {'data': {'ADJ': [[['high'], 'price are high.', 'Positive']],
#     'VERB': [],
#     'OTHER': []},
#    'sentiment': 'Positive'}},
#  {'one': {'data': {'ADJ': [],
#     'VERB': [[['seem', 'be'], 'one seemed is poor.', 'Negative']],
#     'OTHER': []},
#    'sentiment': 'Negative'},
#   'service': {'data': {'ADJ': [[['poor'], 'service is poor.', 'Negative']],
#     'VERB': [],
#     'OTHER': []},
#    'sentiment': 'Negative'}},
#  {'phone': {'data': {'ADJ': [[['defective'],
#       'phone was defective.',
#       'Neutral']],
#     'VERB': [],
#     'OTHER': []},
#    'sentiment': 'Neutral'}},
#  {'staff': {'data': {'ADJ': [[['rude'], 'staff was rude.', 'Negative'],
#      [['unhelpful'], 'staff was unhelpful.', 'Neutral']],
#     'VERB': [],
#     'OTHER': []},
#    'sentiment': 'Negative'}},
#  {'store': {'data': {'ADJ': [],
#     'VERB': [[['feel'], 'they felt like scam.', 'Neutral'],
#      [['charge'], 'they charged me.', 'Neutral'],
#      [['charge'], 'they charged extra for services.', 'Neutral']],
#     'OTHER': []},
#    'sentiment': 'Neutral'}},
#  {'staff': {'data': {'ADJ': [],
#     'VERB': [[['have', 'take'], 'I had took too long.', 'Negative'],
#      [['have', 'take'], 'I had took way.', 'Neutral']],
#     'OTHER': []},
#    'sentiment': 'Negative'}},
#  {'store': {'data': {'ADJ': [],
#     'VERB': [[['inform'], 'they did not inform me.', 'Neutral'],
#      [['inform'], 'they did not inform of hidden fees.', 'Negative']],
#     'OTHER': []},
#    'sentiment': 'Negative'},
#   'staff': {'data': {'ADJ': [],
#     'VERB': [[['buy'], 'I bought phone.', 'Neutral']],
#     'OTHER': []},
#    'sentiment': 'Neutral'}},
#  {'staff': {'data': {'ADJ': [],
#     'VERB': [[['seem'], 'staff seemed.', 'Neutral'],
#      [['give'],
#       'staff gave incorrect information about phone plan.',
#       'Neutral']],
#     'OTHER': []},
#    'sentiment': 'Neutral'},
#   'phone plan': {'data': {'ADJ': [],
#     'VERB': [[['give'],
#       'staff gave incorrect information about phone plan.',
#       'Neutral']],
#     'OTHER': []},
#    'sentiment': 'Neutral'}},
#  {'warranty': {'data': {'ADJ': [[['useless'],
#       'warranty is useless.',
#       'Negative']],
#     'VERB': [],
#     'OTHER': []},
#    'sentiment': 'Negative'}},
#  {'store': {'data': {'ADJ': [],
#     'VERB': [[['give'], 'they twice gave refund.', 'Neutral']],
#     'OTHER': []},
#    'sentiment': 'Neutral'},
#   'staff': {'data': {'ADJ': [],
#     'VERB': [[['have', 'return'], 'I had to return faulty phone.', 'Neutral']],
#     'OTHER': []},
#    'sentiment': 'Neutral'}},
#  {'staff': {'data': {'ADJ': [],
#     'VERB': [[['wait'], 'I very disorganized waited forever.', 'Positive']],
#     'OTHER': []},
#    'sentiment': 'Positive'}},
#  {},
#  {'store': {'data': {'ADJ': [],
#     'VERB': [[['refuse', 'honor'],
#       'they refused to honor promotion.',
#       'Neutral']],
#     'OTHER': []},
#    'sentiment': 'Neutral'}},
#  {'staff': {'data': {'ADJ': [],
#     'VERB': [[['feel'], 'I felt pressured.', 'Neutral']],
#     'OTHER': []},
#    'sentiment': 'Neutral'}},
#  {'repair': {'data': {'ADJ': [],
#     'VERB': [[['do'], 'repair was done poorly.', 'Negative']],
#     'OTHER': []},
#    'sentiment': 'Negative'},
#   'phone': {'data': {'ADJ': [],
#     'VERB': [[['break'], 'phone broke within week.', 'Neutral'],
#      [['break'], 'phone broke again.', 'Neutral']],
#     'OTHER': []},
#    'sentiment': 'Neutral'}},
#  {'service': {'data': {'ADJ': [[['slow'], 'service was slow.', 'Negative']],
#     'VERB': [],
#     'OTHER': []},
#    'sentiment': 'Negative'}},
#  {'phone': {'data': {'ADJ': [],
#     'VERB': [[['work'], 'phone was working after repair.', 'Neutral']],
#     'OTHER': []},
#    'sentiment': 'Neutral'}},
#  {'same issue': {'data': {'ADJ': [],
#     'VERB': [[['have'],
#       'phone still has same issue after getting.',
#       'Neutral']],
#     'OTHER': []},
#    'sentiment': 'Neutral'},
#   'phone': {'data': {'ADJ': [],
#     'VERB': [[['have'],
#       'phone still has same issue after getting.',
#       'Neutral']],
#     'OTHER': []},
#    'sentiment': 'Neutral'}},
#  {'store': {'data': {'ADJ': [],
#     'VERB': [[['upsold'], 'they upsold on phone plan.', 'Neutral'],
#      [['upsold'], 'they upsold me.', 'Neutral']],
#     'OTHER': []},
#    'sentiment': 'Neutral'}},
#  {'staff': {'data': {'ADJ': [[['unprofessional'],
#       'staff was unprofessional.',
#       'Neutral']],
#     'VERB': [],
#     'OTHER': []},
#    'sentiment': 'Neutral'}},
#  {'policy': {'data': {'ADJ': [[['awful'], 'policy is awful.', 'Negative']],
#     'VERB': [],
#     'OTHER': []},
#    'sentiment': 'Negative'}},
#  {'store': {'data': {'ADJ': [],
#     'VERB': [[['apply'], 'they did not apply discount.', 'Neutral']],
#     'OTHER': []},
#    'sentiment': 'Neutral'}},
#  {'store': {'data': {'ADJ': [[['messy'], 'store was messy.', 'Negative'],
#      [['understaffed'], 'store was understaffed.', 'Neutral']],
#     'VERB': [],
#     'OTHER': []},
#    'sentiment': 'Negative'}},
#  {'warranty': {'data': {'ADJ': [],
#     'VERB': [[['expire'], 'warranty just expired.', 'Neutral']],
#     'OTHER': []},
#    'sentiment': 'Neutral'},
#   'phone': {'data': {'ADJ': [],
#     'VERB': [[['break'], 'phone broke.', 'Neutral']],
#     'OTHER': []},
#    'sentiment': 'Neutral'}},
#  {'store': {'data': {'ADJ': [],
#     'VERB': [[['keep', 'try'], 'they kept trying.', 'Neutral']],
#     'OTHER': []},
#    'sentiment': 'Neutral'}},
#  {'job': {'data': {'ADJ': [[['incomplete'], 'job was incomplete.', 'Neutral']],
#     'VERB': [],
#     'OTHER': []},
#    'sentiment': 'Neutral'}},
#  {'representative': {'data': {'ADJ': [[['rude'],
#       'representative were rude on phone.',
#       'Negative']],
#     'VERB': [],
#     'OTHER': []},
#    'sentiment': 'Negative'}},
#  {'staff': {'data': {'ADJ': [],
#     'VERB': [[['have', 'call'], 'I had to call multiple times.', 'Neutral']],
#     'OTHER': []},
#    'sentiment': 'Neutral'}},
#  {'store': {'data': {'ADJ': [],
#     'VERB': [[['rush'], 'they rushed me.', 'Neutral'],
#      [['explain'], 'they did not explain anything.', 'Neutral'],
#      [['explain'], 'they did not explain clearly.', 'Positive'],
#      [['rush'], 'they rushed through purchase.', 'Neutral']],
#     'OTHER': []},
#    'sentiment': 'Positive'}},
#  {'support': {'data': {'ADJ': [[['non'], 'support is non.', 'Neutral']],
#     'VERB': [],
#     'OTHER': []},
#    'sentiment': 'Neutral'}},
#  {'return window': {'data': {'ADJ': [],
#     'VERB': [[['stop', 'work'],
#       'phone stopped working outside return window.',
#       'Neutral']],
#     'OTHER': []},
#    'sentiment': 'Neutral'},
#   'phone': {'data': {'ADJ': [],
#     'VERB': [[['stop', 'work'],
#       'phone stopped working outside return window.',
#       'Neutral'],
#      [['stop'], 'phone stopped quality.', 'Neutral']],
#     'OTHER': []},
#    'sentiment': 'Neutral'}},
#  {'store': {'data': {'ADJ': [[['chaotic'], 'store was chaotic.', 'Neutral']],
#     'VERB': [],
#     'OTHER': [[['staff'], 'store was with unhelpful staff.', 'Neutral'],
#      [['lines'], 'store was with long lines.', 'Negative']]},
#    'sentiment': 'Negative'},
#   'staff': {'data': {'ADJ': [],
#     'VERB': [],
#     'OTHER': [[['staff'], 'store was with unhelpful staff.', 'Neutral']]},
#    'sentiment': 'Neutral'},
#   'long lines': {'data': {'ADJ': [],
#     'VERB': [],
#     'OTHER': [[['lines'], 'store was with long lines.', 'Negative']]},
#    'sentiment': 'Negative'}},
#  {'store': {'data': {'ADJ': [],
#     'VERB': [[['have'],
#       'they did not even have after promising me.',
#       'Positive'],
#      [['have'], 'they did not even have phone.', 'Neutral']],
#     'OTHER': []},
#    'sentiment': 'Positive'}},
#  {'store': {'data': {'ADJ': [],
#     'VERB': [[['lose'], 'they lost repair order.', 'Neutral']],
#     'OTHER': []},
#    'sentiment': 'Neutral'}},
#  {'staff': {'data': {'ADJ': [],
#     'VERB': [[['feel'], 'I felt overcharged.', 'Neutral']],
#     'OTHER': []},
#    'sentiment': 'Neutral'}},
#  {},
#  {'technician': {'data': {'ADJ': [],
#     'VERB': [[['damage'], 'technician damaged during repair.', 'Neutral'],
#      [['damage'], 'technician damaged phone.', 'Neutral']],
#     'OTHER': []},
#    'sentiment': 'Neutral'}},
#  {}]

# %%
testing = pd.DataFrame({'before': data.values(),
                        'after': test})

testing.to_excel('fail.xlsx', index=False)

# %%
import re

# Function to check if a specific word exists in text
def word_exists(word, text):
    # Create the regex pattern with word boundaries
    pattern = r'\b' + re.escape(word) + r'\b'
    
    # Search for the word in the text
    if re.search(pattern, text, re.IGNORECASE):
        return True
    else:
        return False

# %%
word_exists("representative", "representative were rude on phone.")
# Out:
# True

# %%
store = ["phone", "apple", "rude"]

store = [s for s in store if word_exists(s, "representative were rude on phone.")]


store
# Out:
# ['phone', 'rude']

# %%
def sentiment_analysis(data):
    text, aspects = data
    doc = nlp(text)

    storage = {}
    for sentence in doc.sents:
        sentiment = pattern_sentiment_analysis(sentence.text)

        # Get aspect of sentiment
        temp_aspects = [a for a in aspects if word_exists(a, sentence.text)]
        # If there is no aspect extracted, custom aspect might appear.
        if len(temp_aspects) == 0:
            # Condition from custom aspect
            temp_aspects = [a for a in aspects if a in ['staff', 'store']]

        for a in temp_aspects:
            store = storage.get(a)
            if not store or store.lower() != 'Negative':
                storage[a] = sentiment['sentiment']
    return storage

# %%
example = ('price are competitive. selection is amazing.', ['selection', 'price'])

sentiment_analysis(example)
# Out:
# {'price': 'Neutral', 'selection': 'Positive'}

# %%
sentiments = [pattern_sentiment_analysis(text)['sentiment'] for text in corpus]
sentiments
# Out:
# ['Neutral',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Neutral',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Neutral',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Positive',
#  'Positive',
#  'Neutral',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Neutral',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Neutral',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Neutral',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Neutral',
#  'Positive',
#  'Positive',
#  'Neutral',
#  'Positive',
#  'Positive',
#  'Neutral',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Neutral',
#  'Positive',
#  'Negative',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Negative',
#  'Negative',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral']

# %%
aspect_based_sentiment = [sentiment_analysis(data) for data in zip(corpus, df['aspects'].values)]
aspect_based_sentiment
# Out:
# [{'staff': 'Neutral'},
#  {'process': 'Positive'},
#  {'selection': 'Positive', 'price': 'Neutral'},
#  {'new device': 'Neutral'},
#  {'question': 'Neutral'},
#  {'upgrading': 'Neutral', 'deals': 'Positive'},
#  {'technician': 'Positive'},
#  {'experience': 'Positive', 'stuff': 'Positive'},
#  {'variety': 'Positive', 'case': 'Positive'},
#  {'staff': 'Neutral'},
#  {'price': 'Positive'},
#  {'staff': 'Positive'},
#  {'service': 'Neutral'},
#  {'deal': 'Positive', 'staff': 'Positive'},
#  {'store': 'Positive', 'buying': 'Neutral'},
#  {'old phone': 'Positive', 'deal': 'Positive'},
#  {'service': 'Neutral'},
#  {'staff': 'Neutral', 'phone': 'Neutral'},
#  {'store': 'Positive'},
#  {'staff': 'Neutral', 'variety': 'Neutral'},
#  {'process': 'Neutral'},
#  {'phone': 'Neutral'},
#  {'phone': 'Positive'},
#  {'service': 'Neutral'},
#  {'store hands': 'Neutral'},
#  {'staff': 'Positive'},
#  {'deal': 'Neutral'},
#  {'store': 'Positive', 'service': 'Positive'},
#  {'staff': 'Neutral', 'lot': 'Neutral'},
#  {'store': 'Positive'},
#  {'phone': 'Positive'},
#  {'layout': 'Positive', 'staff': 'Positive'},
#  {'lot': 'Neutral'},
#  {'service': 'Positive', 'many stores': 'Positive'},
#  {'notch': 'Neutral', 'service': 'Neutral', 'issues': 'Neutral'},
#  {'store': 'Positive'},
#  {'time': 'Neutral', 'staff': 'Neutral'},
#  {'place': 'Positive'},
#  {'plan': 'Positive'},
#  {'staff': 'Positive'},
#  {'staff': 'Neutral'},
#  {'experience': 'Positive'},
#  {'service': 'Positive'},
#  {'data': 'Neutral', 'extra charge': 'Neutral', 'contacts': 'Neutral'},
#  {'phone': 'Neutral'},
#  {'discount': 'Positive', 'screen': 'Positive'},
#  {'store': 'Neutral'},
#  {'discounts': 'Neutral', 'promotions': 'Positive'},
#  {'selection': 'Neutral'},
#  {'issue': 'Positive'},
#  {'store': 'Positive'},
#  {'deals': 'Positive'},
#  {'store': 'Neutral', 'purchase': 'Positive'},
#  {'advice': 'Positive', 'products': 'Positive'},
#  {'phone': 'Positive'},
#  {'staff': 'Neutral'},
#  {'selection': 'Negative', 'price': 'Positive'},
#  {'service': 'Neutral'},
#  {'phone': 'Neutral'},
#  {'staff': 'Neutral'},
#  {'services': 'Neutral', 'scam': 'Neutral', 'staff': 'Neutral'},
#  {'way': 'Negative'},
#  {'phone': 'Neutral'},
#  {'staff': 'Neutral', 'information': 'Neutral'},
#  {'warranty': 'Neutral'},
#  {'refund': 'Neutral', 'phone': 'Neutral'},
#  {'store': 'Positive'},
#  {'promotion': 'Neutral'},
#  {'store': 'Neutral'},
#  {'phone': 'Neutral', 'repair': 'Negative'},
#  {'service': 'Neutral'},
#  {'phone': 'Neutral'},
#  {'phone': 'Neutral', 'same issue': 'Neutral'},
#  {'plan': 'Neutral', 'staff': 'Neutral'},
#  {'staff': 'Neutral'},
#  {'phone': 'Neutral', 'policy': 'Negative'},
#  {'discount': 'Neutral'},
#  {'store': 'Neutral'},
#  {'warranty': 'Neutral'},
#  {'staff': 'Neutral'},
#  {'job': 'Neutral'},
#  {'representative': 'Negative'},
#  {'multiple times': 'Neutral'},
#  {'purchase': 'Neutral', 'staff': 'Neutral'},
#  {'support': 'Neutral'},
#  {'phone': 'Neutral', 'quality': 'Neutral'},
#  {'long lines': 'Negative', 'store': 'Neutral', 'staff': 'Neutral'},
#  {'phone': 'Neutral'},
#  {'order': 'Neutral'},
#  {'store': 'Neutral'},
#  {'technician': 'Neutral', 'responsibility': 'Neutral'}]

# %%
df['aspect_sentiment'] = aspect_based_sentiment
df['sentiment'] = sentiments

# %%
df.to_excel('demo-sentiment.xlsx', index=False)
