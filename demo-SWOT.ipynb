# %%
# Similarity sentences helper function

def similarity_sentences(s1, s2):
    # Filter only noun, adj, and verb as keywords to compare
    # Handling sentence 1
    new_s1 = []
    for sent in nlp(s1).sents:
        for i, token in enumerate(sent):
            if i == 0:
                continue
            if token.pos_ in ['VERB', 'ADJ', 'NOUN', 'PROPN']:
                new_s1.append(token.lemma_)

    new_s1 = ' '.join(new_s1)

    # Handling sentence 2
    new_s2 = []
    for sent in nlp(s2).sents:
        for i, token in enumerate(sent):
            if i == 0:
                continue
            if token.pos_ in ['VERB', 'ADJ', 'NOUN', 'PROPN']:
                new_s2.append(token.lemma_)
            
    new_s2 = ' '.join(new_s2)

    # Similarity process
    doc1 = nlp(new_s1)
    doc2 = nlp(new_s2)

    similarity = doc1.similarity(doc2)
    # print(doc1, "<->", doc2, similarity)

    return similarity

# %%
def doc_based_similarity(corpus):
    rows = []
    for row in range(len(corpus)):
        columns = []
        for column in range(len(corpus)):
            result = similarity_sentences(corpus[row], corpus[column])
            columns.append(result)
        rows.append(columns)

    return np.array(rows)

# %%
def text_rank(input_, factor):
    # Create similarity graph object
    similarity_graph = networkx.from_numpy_array(input_)

    # Calculate pagerank algorithm
    scores = networkx.pagerank(similarity_graph)
    ranked_sentences = sorted(
                            ((score, index) for index, score in scores.items()),
                            reverse=True)

    # Filtering out based of threshold
    scores = [s[0] for s in ranked_sentences]
    thres = factor * np.max(scores)

    top_sentence_indices = []
    for item in ranked_sentences:
        if item[0] >= thres:
            top_sentence_indices.append(item[-1])

    return top_sentence_indices

# %%
def summarization(corpus, factor=0.5, as_string=False):
    # Create document based similarity matrix
    matrix = doc_based_similarity(corpus)
    # Get top sentence indices
    indices = text_rank(matrix, factor=factor)
    # Get result
    result = np.array(corpus)[indices]

    if as_string:
        return ''.join(['● ' + t + '\n' for t in result])
    return result

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import spacy
import networkx

import re
import os
import json

import ast

from tqdm import tqdm

# %%
# Load nlp model
nlp = spacy.load('en_core_web_lg')

# %%
# Load JSON data from a file
with open('data-2.json', 'r') as json_file:
    data = json.load(json_file)

data
# Out:
# {'0': {'staff': {'data': {'ADJ': [[['helpful'],
#       'staff were helpful.',
#       'Neutral'],
#      [['patient'], 'staff were patient.', 'Neutral']],
#     'VERB': [],
#     'OTHER': []},
#    'sentiment': 'Neutral'}},
#  '1': {'process': {'data': {'ADJ': [[['smooth'],
#       'process was smooth.',
#       'Positive'],
#      [['quick'], 'process was quick.', 'Positive']],
#     'VERB': [],
#     'OTHER': []},
#    'sentiment': 'Positive'}},
#  '2': {'selection': {'data': {'ADJ': [[['amazing'],
#       'selection is amazing.',
#       'Positive']],
#     'VERB': [],
#     'OTHER': []},
#    'sentiment': 'Positive'},
#   'price': {'data': {'ADJ': [[['competitive'],
#       'price are competitive.',
#       'Neutral']],
#     'VERB': [],
#     'OTHER': []},
#    'sentiment': 'Neutral'}},
#  '3': {'staff': {'data': {'ADJ': [],
#     'VERB': [[['appreciate', 'walk'], 'I appreciate walked me.', 'Neutral'],
#      [['appreciate', 'walk'],
#       'I appreciate walked through setting new device.',
#       'Positive']],
#     'OTHER': []},
#    'sentiment': 'Positive'}},
#  '4': {'question': {'data': {'ADJ': [],
#     'VERB': [[['answer'], 'question answered.', 'Neutral']],
#     'OTHER': []},
#    'sentiment': 'Neutral'}},
#  '5': {'staff': {'data': {'ADJ': [],
#     'VERB': [[['resist'], 'I could not resist upgrading.', 'Neutral'],
#      [['resist', 'offer'],
#       'I could not resist offer amazing deals on phones.',
#       'Positive']],
#     'OTHER': []},
#    'sentiment': 'Positive'}},
#  '6': {'phones issue': {'data': {'ADJ': [],
#     'VERB': [[['fix'], 'technician fixed phones issue.', 'Positive']],
#     'OTHER': []},
#    'sentiment': 'Positive'},
#   'technician': {'data': {'ADJ': [],
#     'VERB': [[['fix'], 'technician fixed phones issue.', 'Positive'],
#      [['fix'], 'technician fixed faster.', 'Positive']],
#     'OTHER': []},
#    'sentiment': 'Positive'}},
#  '7': {'experience': {'data': {'ADJ': [],
#     'VERB': [[['know'], 'experience really know stuff.', 'Positive']],
#     'OTHER': []},
#    'sentiment': 'Positive'}},
#  '8': {'variety': {'data': {'ADJ': [[['impressive'],
#       'variety was impressive.',
#       'Positive']],
#     'VERB': [],
#     'OTHER': []},
#    'sentiment': 'Positive'}},
#  '9': {},
#  '10': {'staff': {'data': {'ADJ': [[['knowledgeable'],
#       'staff was knowledgeable.',
#       'Neutral']],
#     'VERB': [],
#     'OTHER': []},
#    'sentiment': 'Neutral'}},
#  '11': {'price': {'data': {'ADJ': [[['reasonable'],
#       'price were reasonable.',
#       'Positive']],
#     'VERB': [],
#     'OTHER': []},
#    'sentiment': 'Positive'}},
#  '12': {'staff': {'data': {'ADJ': [],
#     'VERB': [[['go'], 'staff really went mile.', 'Positive']],
#     'OTHER': []},
#    'sentiment': 'Positive'}},
#  '13': {'service': {'data': {'ADJ': [[['excellent'],
#       'service be excellent.',
#       'Positive']],
#     'VERB': [],
#     'OTHER': []},
#    'sentiment': 'Positive'}},
#  '14': {'deal': {'data': {'ADJ': [[['friendly'],
#       'deal was friendly.',
#       'Positive']],
#     'VERB': [],
#     'OTHER': []},
#    'sentiment': 'Positive'},
#   'staff': {'data': {'ADJ': [[['friendly'],
#       'staff was friendly.',
#       'Positive']],
#     'VERB': [],
#     'OTHER': []},
#    'sentiment': 'Positive'}},
#  '15': {'buying': {'data': {'ADJ': [],
#     'VERB': [],
#     'OTHER': [[['experience'], 'buying be experience.', 'Neutral']]},
#    'sentiment': 'Neutral'},
#   'fixing': {'data': {'ADJ': [],
#     'VERB': [],
#     'OTHER': [[['experience'], 'fixing be experience.', 'Neutral']]},
#    'sentiment': 'Neutral'}},
#  '16': {'staff': {'data': {'ADJ': [],
#     'VERB': [[['get'], 'I got good deal on old phone.', 'Positive']],
#     'OTHER': []},
#    'sentiment': 'Positive'}},
#  '17': {'service': {'data': {'ADJ': [[['quick'],
#       'service are quick.',
#       'Positive'],
#      [['reliable'], 'service are reliable.', 'Neutral']],
#     'VERB': [],
#     'OTHER': []},
#    'sentiment': 'Positive'}},
#  '18': {'phone': {'data': {'ADJ': [[['helpful'],
#       'staff was helpful in setting phone.',
#       'Neutral']],
#     'VERB': [],
#     'OTHER': []},
#    'sentiment': 'Neutral'},
#   'staff': {'data': {'ADJ': [[['helpful'],
#       'staff was helpful in setting phone.',
#       'Neutral']],
#     'VERB': [],
#     'OTHER': []},
#    'sentiment': 'Neutral'}},
#  '19': {'staff': {'data': {'ADJ': [],
#     'VERB': [[['m'], 'I m satisfied.', 'Positive']],
#     'OTHER': []},
#    'sentiment': 'Positive'}},
#  '20': {'staff': {'data': {'ADJ': [[['patient'],
#       'staff was patient with questions.',
#       'Neutral']],
#     'VERB': [],
#     'OTHER': []},
#    'sentiment': 'Neutral'},
#   'variety': {'data': {'ADJ': [[['patient'],
#       'variety was patient with questions.',
#       'Neutral']],
#     'VERB': [],
#     'OTHER': []},
#    'sentiment': 'Neutral'}},
#  '21': {'process': {'data': {'ADJ': [[['simple'],
#       'process was simple.',
#       'Neutral']],
#     'VERB': [],
#     'OTHER': []},
#    'sentiment': 'Neutral'}},
#  '22': {'store': {'data': {'ADJ': [],
#     'VERB': [[['help', 'choose'],
#       'they helped choose within budget.',
#       'Neutral'],
#      [['help', 'choose'], 'they helped choose phone.', 'Neutral']],
#     'OTHER': []},
#    'sentiment': 'Neutral'}},
#  '23': {'phone': {'data': {'ADJ': [],
#     'VERB': [[['fix'], 'phone was fixed in minutes.', 'Positive']],
#     'OTHER': []},
#    'sentiment': 'Positive'}},
#  '24': {'service': {'data': {'ADJ': [[['outstanding'],
#       'service is outstanding.',
#       'Positive']],
#     'VERB': [],
#     'OTHER': []},
#    'sentiment': 'Positive'}},
#  '25': {'store': {'data': {'ADJ': [],
#     'VERB': [[['hand'], 'store hands.', 'Neutral']],
#     'OTHER': []},
#    'sentiment': 'Neutral'}},
#  '26': {'staff': {'data': {'ADJ': [],
#     'VERB': [[['make'], 'staff made.', 'Neutral']],
#     'OTHER': []},
#    'sentiment': 'Neutral'}},
#  '27': {'staff': {'data': {'ADJ': [],
#     'VERB': [[['find', 'need'], 'I found needed what.', 'Neutral']],
#     'OTHER': []},
#    'sentiment': 'Neutral'},
#   'store': {'data': {'ADJ': [],
#     'VERB': [[['help', 'get'], 'they helped get great deal.', 'Positive']],
#     'OTHER': []},
#    'sentiment': 'Positive'}},
#  '28': {'warranty service': {'data': {'ADJ': [],
#     'VERB': [[['have'], 'store has fantastic warranty service.', 'Positive']],
#     'OTHER': []},
#    'sentiment': 'Positive'},
#   'store': {'data': {'ADJ': [],
#     'VERB': [[['have'], 'store has fantastic warranty service.', 'Positive']],
#     'OTHER': []},
#    'sentiment': 'Positive'}},
#  '29': {'staff': {'data': {'ADJ': [[['informative'],
#       'staff was informative.',
#       'Neutral']],
#     'VERB': [],
#     'OTHER': []},
#    'sentiment': 'Neutral'}},
#  '30': {'variety': {'data': {'ADJ': [[['excellent'],
#       'variety be excellent.',
#       'Positive']],
#     'VERB': [],
#     'OTHER': []},
#    'sentiment': 'Positive'},
#   'store': {'data': {'ADJ': [[['excellent'],
#       'store be excellent.',
#       'Positive']],
#     'VERB': [],
#     'OTHER': []},
#    'sentiment': 'Positive'}},
#  '31': {},
#  '32': {'store': {'data': {'ADJ': [[['quick'],
#       'they were quick in setting phone.',
#       'Positive']],
#     'VERB': [],
#     'OTHER': []},
#    'sentiment': 'Positive'}},
#  '33': {},
#  '34': {'layout': {'data': {'ADJ': [[['easy'], 'layout is easy.', 'Positive']],
#     'VERB': [],
#     'OTHER': []},
#    'sentiment': 'Positive'},
#   'staff': {'data': {'ADJ': [[['ready'], 'staff are ready.', 'Positive']],
#     'VERB': [],
#     'OTHER': []},
#    'sentiment': 'Positive'}},
#  '35': {'store': {'data': {'ADJ': [],
#     'VERB': [[['help', 'save'], 'they helped save lot.', 'Neutral']],
#     'OTHER': []},
#    'sentiment': 'Neutral'}},
#  '36': {'service': {'data': {'ADJ': [],
#     'VERB': [[['provide'], 'one provides best service.', 'Positive']],
#     'OTHER': []},
#    'sentiment': 'Positive'},
#   'one': {'data': {'ADJ': [],
#     'VERB': [[['provide'], 'one provides best service.', 'Positive']],
#     'OTHER': []},
#    'sentiment': 'Positive'}},
#  '37': {'service': {'data': {'ADJ': [[['notch'],
#       'service is notch.',
#       'Neutral']],
#     'VERB': [],
#     'OTHER': [[['notch'], 'service is notch.', 'Neutral']]},
#    'sentiment': 'Neutral'}},
#  '38': {'store': {'data': {'ADJ': [],
#     'VERB': [[['fail', 'recommend'],
#       'they not fail recommend to friends.',
#       'Positive'],
#      [['fail', 'recommend'], 'they not fail recommend store.', 'Positive'],
#      [['fail', 'recommend'],
#       'they not fail recommend to family.',
#       'Positive']],
#     'OTHER': []},
#    'sentiment': 'Positive'}},
#  '39': {'time': {'data': {'ADJ': [],
#     'VERB': [[['take'], 'staff took time.', 'Neutral']],
#     'OTHER': []},
#    'sentiment': 'Neutral'},
#   'staff': {'data': {'ADJ': [],
#     'VERB': [[['take'], 'staff took time.', 'Neutral']],
#     'OTHER': []},
#    'sentiment': 'Neutral'}},
#  '40': {'place': {'data': {'ADJ': [[['amazing'],
#       'place be amazing.',
#       'Positive']],
#     'VERB': [],
#     'OTHER': []},
#    'sentiment': 'Positive'}},
#  '41': {'plan': {'data': {'ADJ': [[['worth'], 'plan is worth.', 'Positive']],
#     'VERB': [],
#     'OTHER': []},
#    'sentiment': 'Positive'}},
#  '42': {'staff': {'data': {'ADJ': [],
#     'VERB': [[['appreciate', 'be'], 'I appreciate were able.', 'Positive']],
#     'OTHER': []},
#    'sentiment': 'Positive'},
#   'store': {'data': {'ADJ': [[['able'], 'they were able.', 'Positive']],
#     'VERB': [],
#     'OTHER': []},
#    'sentiment': 'Positive'}},
#  '43': {},
#  '44': {'staff': {'data': {'ADJ': [[['accommodating'],
#       'staff was accommodating.',
#       'Neutral']],
#     'VERB': [],
#     'OTHER': []},
#    'sentiment': 'Neutral'}},
#  '45': {'staff': {'data': {'ADJ': [],
#     'VERB': [[['have'], 'I had great experience with program.', 'Positive']],
#     'OTHER': []},
#    'sentiment': 'Positive'}},
#  '46': {'service': {'data': {'ADJ': [[['quick'],
#       'service was quick.',
#       'Positive'],
#      [['efficient'], 'service was efficient.', 'Neutral']],
#     'VERB': [],
#     'OTHER': []},
#    'sentiment': 'Positive'}},
#  '47': {'store': {'data': {'ADJ': [],
#     'VERB': [[['help', 'transfer'],
#       'they even helped transfer without extra charge.',
#       'Neutral'],
#      [['help', 'transfer'], 'they even helped transfer data.', 'Neutral'],
#      [['help', 'transfer'], 'they even helped transfer contacts.', 'Neutral']],
#     'OTHER': []},
#    'sentiment': 'Neutral'}},
#  '48': {'phone': {'data': {'ADJ': [],
#     'VERB': [[['work'], 'phone has working flawlessly.', 'Positive']],
#     'OTHER': []},
#    'sentiment': 'Positive'}},
#  '49': {'store': {'data': {'ADJ': [],
#     'VERB': [[['fix'], 'they fixed perfectly.', 'Positive'],
#      [['fix'], 'they fixed screen.', 'Positive'],
#      [['give'], 'they even gave discount on repair.', 'Neutral']],
#     'OTHER': []},
#    'sentiment': 'Positive'}},
#  '50': {'staff': {'data': {'ADJ': [[['reliable'],
#       'this is reliable.',
#       'Neutral']],
#     'VERB': [],
#     'OTHER': []},
#    'sentiment': 'Neutral'}},
#  '51': {'store': {'data': {'ADJ': [],
#     'VERB': [[['offer'], 'they offer discounts.', 'Neutral'],
#      [['offer'], 'they offer fantastic promotions.', 'Positive']],
#     'OTHER': []},
#    'sentiment': 'Positive'}},
#  '52': {'service': {'data': {'ADJ': [[['great'],
#       'service be great.',
#       'Positive']],
#     'VERB': [],
#     'OTHER': [[['phone'], 'service be phone.', 'Neutral']]},
#    'sentiment': 'Positive'},
#   'selection': {'data': {'ADJ': [[['great'],
#       'selection be great.',
#       'Positive']],
#     'VERB': [],
#     'OTHER': [[['phone'], 'selection be phone.', 'Neutral']]},
#    'sentiment': 'Positive'}},
#  '53': {'store': {'data': {'ADJ': [],
#     'VERB': [[['resolve'], 'they resolved professionally.', 'Positive'],
#      [['resolve'], 'they resolved very quickly.', 'Positive'],
#      [['resolve'], 'they resolved issue.', 'Neutral']],
#     'OTHER': []},
#    'sentiment': 'Positive'}},
#  '54': {'store': {'data': {'ADJ': [[['organize'],
#       'store is organized.',
#       'Neutral']],
#     'VERB': [],
#     'OTHER': []},
#    'sentiment': 'Neutral'}},
#  '55': {'store': {'data': {'ADJ': [],
#     'VERB': [[['look'], 'you re looking for good deals.', 'Positive']],
#     'OTHER': []},
#    'sentiment': 'Positive'}},
#  '56': {'staff': {'data': {'ADJ': [],
#     'VERB': [[['make'], 'I made right purchase.', 'Positive'],
#      [['leave'], 'I always leave store.', 'Neutral']],
#     'OTHER': []},
#    'sentiment': 'Positive'}},
#  '57': {'store': {'data': {'ADJ': [],
#     'VERB': [[['know', 'receive'],
#       'they really know received excellent advice from sales team.',
#       'Positive'],
#      [['know'], 'they really know products.', 'Positive']],
#     'OTHER': []},
#    'sentiment': 'Positive'}},
#  '58': {'phone': {'data': {'ADJ': [],
#     'VERB': [[['look'], 'phone looks new.', 'Positive']],
#     'OTHER': []},
#    'sentiment': 'Positive'}},
#  '59': {'staff': {'data': {'ADJ': [[['apologetic'],
#       'staff was not apologetic.',
#       'Neutral']],
#     'VERB': [],
#     'OTHER': []},
#    'sentiment': 'Neutral'}},
#  '60': {},
#  '61': {'selection': {'data': {'ADJ': [[['limited'],
#       'selection is limited.',
#       'Negative']],
#     'VERB': [],
#     'OTHER': []},
#    'sentiment': 'Negative'},
#   'price': {'data': {'ADJ': [[['high'], 'price are high.', 'Positive']],
#     'VERB': [],
#     'OTHER': []},
#    'sentiment': 'Positive'}},
#  '62': {'one': {'data': {'ADJ': [],
#     'VERB': [[['seem', 'be'], 'one seemed is poor.', 'Negative']],
#     'OTHER': []},
#    'sentiment': 'Negative'},
#   'service': {'data': {'ADJ': [[['poor'], 'service is poor.', 'Negative']],
#     'VERB': [],
#     'OTHER': []},
#    'sentiment': 'Negative'}},
#  '63': {'phone': {'data': {'ADJ': [[['defective'],
#       'phone was defective.',
#       'Neutral']],
#     'VERB': [],
#     'OTHER': []},
#    'sentiment': 'Neutral'}},
#  '64': {'staff': {'data': {'ADJ': [[['rude'], 'staff was rude.', 'Negative'],
#      [['unhelpful'], 'staff was unhelpful.', 'Neutral']],
#     'VERB': [],
#     'OTHER': []},
#    'sentiment': 'Negative'}},
#  '65': {'store': {'data': {'ADJ': [],
#     'VERB': [[['feel'], 'they felt like scam.', 'Neutral'],
#      [['charge'], 'they charged me.', 'Neutral'],
#      [['charge'], 'they charged extra for services.', 'Neutral']],
#     'OTHER': []},
#    'sentiment': 'Neutral'}},
#  '66': {'staff': {'data': {'ADJ': [],
#     'VERB': [[['have', 'take'], 'I had took too long.', 'Negative'],
#      [['have', 'take'], 'I had took way.', 'Neutral']],
#     'OTHER': []},
#    'sentiment': 'Negative'}},
#  '67': {'store': {'data': {'ADJ': [],
#     'VERB': [[['inform'], 'they did not inform me.', 'Neutral'],
#      [['inform'], 'they did not inform of hidden fees.', 'Negative']],
#     'OTHER': []},
#    'sentiment': 'Negative'},
#   'staff': {'data': {'ADJ': [],
#     'VERB': [[['buy'], 'I bought phone.', 'Neutral']],
#     'OTHER': []},
#    'sentiment': 'Neutral'}},
#  '68': {'staff': {'data': {'ADJ': [],
#     'VERB': [[['seem'], 'staff seemed.', 'Neutral'],
#      [['give'],
#       'staff gave incorrect information about phone plan.',
#       'Neutral']],
#     'OTHER': []},
#    'sentiment': 'Neutral'},
#   'phone plan': {'data': {'ADJ': [],
#     'VERB': [[['give'],
#       'staff gave incorrect information about phone plan.',
#       'Neutral']],
#     'OTHER': []},
#    'sentiment': 'Neutral'}},
#  '69': {'warranty': {'data': {'ADJ': [[['useless'],
#       'warranty is useless.',
#       'Negative']],
#     'VERB': [],
#     'OTHER': []},
#    'sentiment': 'Negative'}},
#  '70': {'store': {'data': {'ADJ': [],
#     'VERB': [[['give'], 'they twice gave refund.', 'Neutral']],
#     'OTHER': []},
#    'sentiment': 'Neutral'},
#   'staff': {'data': {'ADJ': [],
#     'VERB': [[['have', 'return'], 'I had to return faulty phone.', 'Neutral']],
#     'OTHER': []},
#    'sentiment': 'Neutral'}},
#  '71': {'staff': {'data': {'ADJ': [],
#     'VERB': [[['wait'], 'I very disorganized waited forever.', 'Positive']],
#     'OTHER': []},
#    'sentiment': 'Positive'}},
#  '72': {},
#  '73': {'store': {'data': {'ADJ': [],
#     'VERB': [[['refuse', 'honor'],
#       'they refused to honor promotion.',
#       'Neutral']],
#     'OTHER': []},
#    'sentiment': 'Neutral'}},
#  '74': {'staff': {'data': {'ADJ': [],
#     'VERB': [[['feel'], 'I felt pressured.', 'Neutral']],
#     'OTHER': []},
#    'sentiment': 'Neutral'}},
#  '75': {'repair': {'data': {'ADJ': [],
#     'VERB': [[['do'], 'repair was done poorly.', 'Negative']],
#     'OTHER': []},
#    'sentiment': 'Negative'},
#   'phone': {'data': {'ADJ': [],
#     'VERB': [[['break'], 'phone broke within week.', 'Neutral'],
#      [['break'], 'phone broke again.', 'Neutral']],
#     'OTHER': []},
#    'sentiment': 'Neutral'}},
#  '76': {'service': {'data': {'ADJ': [[['slow'],
#       'service was slow.',
#       'Negative']],
#     'VERB': [],
#     'OTHER': []},
#    'sentiment': 'Negative'}},
#  '77': {'phone': {'data': {'ADJ': [],
#     'VERB': [[['work'], 'phone was working after repair.', 'Neutral']],
#     'OTHER': []},
#    'sentiment': 'Neutral'}},
#  '78': {'same issue': {'data': {'ADJ': [],
#     'VERB': [[['have'],
#       'phone still has same issue after getting.',
#       'Neutral']],
#     'OTHER': []},
#    'sentiment': 'Neutral'},
#   'phone': {'data': {'ADJ': [],
#     'VERB': [[['have'],
#       'phone still has same issue after getting.',
#       'Neutral']],
#     'OTHER': []},
#    'sentiment': 'Neutral'}},
#  '79': {'store': {'data': {'ADJ': [],
#     'VERB': [[['upsold'], 'they upsold on phone plan.', 'Neutral'],
#      [['upsold'], 'they upsold me.', 'Neutral']],
#     'OTHER': []},
#    'sentiment': 'Neutral'}},
#  '80': {'staff': {'data': {'ADJ': [[['unprofessional'],
#       'staff was unprofessional.',
#       'Neutral']],
#     'VERB': [],
#     'OTHER': []},
#    'sentiment': 'Neutral'}},
#  '81': {'policy': {'data': {'ADJ': [[['awful'],
#       'policy is awful.',
#       'Negative']],
#     'VERB': [],
#     'OTHER': []},
#    'sentiment': 'Negative'}},
#  '82': {'store': {'data': {'ADJ': [],
#     'VERB': [[['apply'], 'they did not apply discount.', 'Neutral']],
#     'OTHER': []},
#    'sentiment': 'Neutral'}},
#  '83': {'store': {'data': {'ADJ': [[['messy'], 'store was messy.', 'Negative'],
#      [['understaffed'], 'store was understaffed.', 'Neutral']],
#     'VERB': [],
#     'OTHER': []},
#    'sentiment': 'Negative'}},
#  '84': {'warranty': {'data': {'ADJ': [],
#     'VERB': [[['expire'], 'warranty just expired.', 'Neutral']],
#     'OTHER': []},
#    'sentiment': 'Neutral'},
#   'phone': {'data': {'ADJ': [],
#     'VERB': [[['break'], 'phone broke.', 'Neutral']],
#     'OTHER': []},
#    'sentiment': 'Neutral'}},
#  '85': {'store': {'data': {'ADJ': [],
#     'VERB': [[['keep', 'try'], 'they kept trying.', 'Neutral']],
#     'OTHER': []},
#    'sentiment': 'Neutral'}},
#  '86': {'job': {'data': {'ADJ': [[['incomplete'],
#       'job was incomplete.',
#       'Neutral']],
#     'VERB': [],
#     'OTHER': []},
#    'sentiment': 'Neutral'}},
#  '87': {'representative': {'data': {'ADJ': [[['rude'],
#       'representative were rude on phone.',
#       'Negative']],
#     'VERB': [],
#     'OTHER': []},
#    'sentiment': 'Negative'}},
#  '88': {'staff': {'data': {'ADJ': [],
#     'VERB': [[['have', 'call'], 'I had to call multiple times.', 'Neutral']],
#     'OTHER': []},
#    'sentiment': 'Neutral'}},
#  '89': {'store': {'data': {'ADJ': [],
#     'VERB': [[['rush'], 'they rushed me.', 'Neutral'],
#      [['explain'], 'they did not explain anything.', 'Neutral'],
#      [['explain'], 'they did not explain clearly.', 'Positive'],
#      [['rush'], 'they rushed through purchase.', 'Neutral']],
#     'OTHER': []},
#    'sentiment': 'Positive'}},
#  '90': {'support': {'data': {'ADJ': [[['non'], 'support is non.', 'Neutral']],
#     'VERB': [],
#     'OTHER': []},
#    'sentiment': 'Neutral'}},
#  '91': {'return window': {'data': {'ADJ': [],
#     'VERB': [[['stop', 'work'],
#       'phone stopped working outside return window.',
#       'Neutral']],
#     'OTHER': []},
#    'sentiment': 'Neutral'},
#   'phone': {'data': {'ADJ': [],
#     'VERB': [[['stop', 'work'],
#       'phone stopped working outside return window.',
#       'Neutral'],
#      [['stop'], 'phone stopped quality.', 'Neutral']],
#     'OTHER': []},
#    'sentiment': 'Neutral'}},
#  '92': {'store': {'data': {'ADJ': [[['chaotic'],
#       'store was chaotic.',
#       'Neutral']],
#     'VERB': [],
#     'OTHER': [[['staff'], 'store was with unhelpful staff.', 'Neutral'],
#      [['lines'], 'store was with long lines.', 'Negative']]},
#    'sentiment': 'Negative'},
#   'staff': {'data': {'ADJ': [],
#     'VERB': [],
#     'OTHER': [[['staff'], 'store was with unhelpful staff.', 'Neutral']]},
#    'sentiment': 'Neutral'},
#   'long lines': {'data': {'ADJ': [],
#     'VERB': [],
#     'OTHER': [[['lines'], 'store was with long lines.', 'Negative']]},
#    'sentiment': 'Negative'}},
#  '93': {'store': {'data': {'ADJ': [],
#     'VERB': [[['have'],
#       'they did not even have after promising me.',
#       'Positive'],
#      [['have'], 'they did not even have phone.', 'Neutral']],
#     'OTHER': []},
#    'sentiment': 'Positive'}},
#  '94': {'store': {'data': {'ADJ': [],
#     'VERB': [[['lose'], 'they lost repair order.', 'Neutral']],
#     'OTHER': []},
#    'sentiment': 'Neutral'}},
#  '95': {'staff': {'data': {'ADJ': [],
#     'VERB': [[['feel'], 'I felt overcharged.', 'Neutral']],
#     'OTHER': []},
#    'sentiment': 'Neutral'}},
#  '96': {},
#  '97': {'technician': {'data': {'ADJ': [],
#     'VERB': [[['damage'], 'technician damaged during repair.', 'Neutral'],
#      [['damage'], 'technician damaged phone.', 'Neutral']],
#     'OTHER': []},
#    'sentiment': 'Neutral'}},
#  '98': {}}

# %%
def get_data_aspect(input_, aspect):
    storage = {}
    # Preparation storage
    storage = {
            'positive': {
                    'ADJ': [],
                    'VERB': [],
                    'OTHER': [],
            },
            'negative': {
                    'ADJ': [],
                    'VERB': [],
                    'OTHER': [],
            },
            'neutral': {
                    'ADJ': [],
                    'VERB': [],
                    'OTHER': [],
            },
    }
    # Get dictionary level 1
    for i, dict_1 in input_.items():
        # If the dictionary level 1 is empty, data at current index is not updated
        if len(dict_1) == 0:
            continue
        # Get dictionary level 2
        for a, dict_2 in dict_1.items():
            # Get dictionary data at dictionary level 2
            if a != aspect:
                continue
            for l, data in dict_2['data'].items():
                if len(data) > 0:
                    # Get through all data
                    for d in data:
                        _, t, s = d
                        storage[s.lower()][l].append(t)
                        
    return storage

# %%
def summarize_swot(input_, aspect):
    storage = {
    'aspect': [aspect],
    'positive': [],
    'negative': [],
    'neutral': [],
    }
    # Get dictionary level 1
    for sentiment, dict_1 in input_.items():
        summ = ''
        for l, data in dict_1.items():
            if len(data) > 0:
                if l == 'VERB' or l == 'OTHER':
                    if len(data) < 3:
                        summ += ''.join(['● ' + t + '\n' for t in data])
                        # print(summ)
                    else:
                        summ += summarization(data, as_string=True)
                        # print(summ)
                if l == 'ADJ':
                    # summ += ''.join([t + '\n' for t in data])
                    adj = []
                    for d in data:
                        adj.append(' '.join(d.split()[2:]).replace('.',''))
                    summ += '● ' + aspect + ' is ' + ', '.join(adj) + '.\n'
        storage[sentiment] += [summ]
    return storage

# %%
def processing_swot(data, aspect):
    # Fetching data for specific aspect
    data = get_data_aspect(data, aspect)
    # Summarize swot
    result = summarize_swot(data, aspect)

    return result
# Out:
# {'aspect': ['price'],
#  'positive': ['● price is reasonable, high.\n'],
#  'negative': [''],
#  'neutral': ['● price is competitive.\n']}

# %%
def get_all_aspects(data):
    storage = []
    # Get level 1 dictionary
    for idx, dict_1 in data.items():
        # Get level 2 dictionary
        for a, _ in dict_1.items():
            if a not in storage:
                storage.append(a)
    return storage

aspects = get_all_aspects(data)

# %%
def processing_swot_all(data):
    storage = {
    'aspect': [],
    'positive': [],
    'negative': [],
    'neutral': [],
    }
    
    for a in aspects:
        temp = processing_swot(data, a)

        for k in temp.keys():
            storage[k] += (temp[k])
    return storage


result = processing_swot_all(data)
result
# Out:
# C:\Users\Baha Tegar\AppData\Local\Temp\ipykernel_6572\450853164.py:31: UserWarning: [W008] Evaluating Doc.similarity based on empty vectors.
#   similarity = doc1.similarity(doc2)
# {'aspect': ['staff',
#   'process',
#   'selection',
#   'price',
#   'question',
#   'phones issue',
#   'technician',
#   'experience',
#   'variety',
#   'service',
#   'deal',
#   'buying',
#   'fixing',
#   'phone',
#   'store',
#   'warranty service',
#   'layout',
#   'one',
#   'time',
#   'place',
#   'plan',
#   'phone plan',
#   'warranty',
#   'repair',
#   'same issue',
#   'policy',
#   'job',
#   'representative',
#   'support',
#   'return window',
#   'long lines'],
#  'positive': ['● staff is friendly, ready.\n● I could not resist offer amazing deals on phones.\n● I made right purchase.\n● I appreciate walked through setting new device.\n● I got good deal on old phone.\n● I appreciate were able.\n● I had great experience with program.\n● staff really went mile.\n● I very disorganized waited forever.\n● I m satisfied.\n',
#   '● process is smooth, quick.\n',
#   '● selection is amazing, great.\n',
#   '● price is reasonable, high.\n',
#   '',
#   '● technician fixed phones issue.\n',
#   '● technician fixed phones issue.\n● technician fixed faster.\n',
#   '● experience really know stuff.\n',
#   '● variety is impressive, excellent.\n',
#   '● service is excellent, quick, outstanding, quick, great.\n● one provides best service.\n',
#   '● deal is friendly.\n',
#   '',
#   '',
#   '● phone looks new.\n● phone has working flawlessly.\n● phone was fixed in minutes.\n',
#   '● store is excellent, quick in setting phone, able.\n● they helped get great deal.\n● they not fail recommend to friends.\n● they not fail recommend to family.\n● they not fail recommend store.\n● you re looking for good deals.\n● they really know products.\n● they did not even have after promising me.\n● store has fantastic warranty service.\n● they really know received excellent advice from sales team.\n● they resolved very quickly.\n● they resolved professionally.\n● they offer fantastic promotions.\n● they did not explain clearly.\n● they fixed screen.\n● they fixed perfectly.\n',
#   '● store has fantastic warranty service.\n',
#   '● layout is easy.\n',
#   '● one provides best service.\n',
#   '',
#   '● place is amazing.\n',
#   '● plan is worth.\n',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  'negative': ['● staff is rude.\n● I had took too long.\n',
#   '',
#   '● selection is limited.\n',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '● service is poor, slow.\n',
#   '',
#   '',
#   '',
#   '',
#   '● store is messy.\n● they did not inform of hidden fees.\n● store was with long lines.\n',
#   '',
#   '',
#   '● one seemed is poor.\n',
#   '',
#   '',
#   '',
#   '',
#   '● warranty is useless.\n',
#   '● repair was done poorly.\n',
#   '',
#   '● policy is awful.\n',
#   '',
#   '● representative is rude on phone.\n',
#   '',
#   '',
#   '● store was with long lines.\n'],
#  'neutral': ['● staff is helpful, patient, knowledgeable, helpful in setting phone, patient with questions, informative, accommodating, reliable, not apologetic, unhelpful, unprofessional.\n● I found needed what.\n● I had to call multiple times.\n● I had to return faulty phone.\n● staff took time.\n● I felt overcharged.\n● I had took way.\n● staff gave incorrect information about phone plan.\n● I felt pressured.\n● staff made.\n● I always leave store.\n● I appreciate walked me.\n● I could not resist upgrading.\n● I bought phone.\n● staff seemed.\n● store was with unhelpful staff.\n',
#   '● process is simple.\n',
#   '● selection be phone.\n',
#   '● price is competitive.\n',
#   '● question answered.\n',
#   '',
#   '● technician damaged during repair.\n● technician damaged phone.\n',
#   '',
#   '● variety is patient with questions.\n',
#   '● service is reliable, notch, efficient.\n● service is notch.\n● service be phone.\n',
#   '',
#   '● buying be experience.\n',
#   '● fixing be experience.\n',
#   '● phone is helpful in setting phone, defective.\n● phone stopped working outside return window.\n● phone broke.\n● phone broke again.\n● phone still has same issue after getting.\n● phone broke within week.\n● phone stopped quality.\n● phone was working after repair.\n',
#   '● store is organized, understaffed, chaotic.\n● they even helped transfer without extra charge.\n● they even gave discount on repair.\n● they even helped transfer contacts.\n● they helped choose phone.\n● they helped choose within budget.\n● they even helped transfer data.\n● they lost repair order.\n● they twice gave refund.\n● they did not apply discount.\n● they offer discounts.\n● they charged extra for services.\n● they helped save lot.\n● they did not inform me.\n● they upsold me.\n● they rushed through purchase.\n● they did not even have phone.\n● they kept trying.\n● they upsold on phone plan.\n● they resolved issue.\n● they charged me.\n● they did not explain anything.\n● they refused to honor promotion.\n● they felt like scam.\n● store hands.\n● store was with unhelpful staff.\n',
#   '',
#   '',
#   '',
#   '● staff took time.\n',
#   '',
#   '',
#   '● staff gave incorrect information about phone plan.\n',
#   '● warranty just expired.\n',
#   '',
#   '● phone still has same issue after getting.\n',
#   '',
#   '● job is incomplete.\n',
#   '',
#   '● support is non.\n',
#   '● phone stopped working outside return window.\n',
#   '']}

# %%
pd.DataFrame.from_dict(result)
# Out:
#               aspect                                           positive  \
# 0              staff  ● staff is friendly, ready.\n● I could not res...
# 1            process                      ● process is smooth, quick.\n
# 2          selection                   ● selection is amazing, great.\n
# 3              price                     ● price is reasonable, high.\n
# 4           question
# 5       phones issue                 ● technician fixed phones issue.\n
# 6         technician  ● technician fixed phones issue.\n● technician...
# 7         experience                  ● experience really know stuff.\n
# 8            variety              ● variety is impressive, excellent.\n
# 9            service  ● service is excellent, quick, outstanding, qu...
# 10              deal                              ● deal is friendly.\n
# 11            buying
# 12            fixing
# 13             phone  ● phone looks new.\n● phone has working flawle...
# 14             store  ● store is excellent, quick in setting phone, ...
# 15  warranty service          ● store has fantastic warranty service.\n
# 16            layout                                ● layout is easy.\n
# 17               one                     ● one provides best service.\n
# 18              time
# 19             place                              ● place is amazing.\n
# 20              plan                                 ● plan is worth.\n
# 21        phone plan
# 22          warranty
# 23            repair
# 24        same issue
# 25            policy
# 26               job
# 27    representative
# 28           support
# 29     return window
# 30        long lines
#
#                                              negative  \
# 0          ● staff is rude.\n● I had took too long.\n
# 1
# 2                           ● selection is limited.\n
# 3
# 4
# 5
# 6
# 7
# 8
# 9                          ● service is poor, slow.\n
# 10
# 11
# 12
# 13
# 14  ● store is messy.\n● they did not inform of hi...
# 15
# 16
# 17                            ● one seemed is poor.\n
# 18
# 19
# 20
# 21
# 22                           ● warranty is useless.\n
# 23                        ● repair was done poorly.\n
# 24
# 25                               ● policy is awful.\n
# 26
# 27               ● representative is rude on phone.\n
# 28
# 29
# 30                     ● store was with long lines.\n
#
#                                               neutral
# 0   ● staff is helpful, patient, knowledgeable, he...
# 1                              ● process is simple.\n
# 2                             ● selection be phone.\n
# 3                           ● price is competitive.\n
# 4                              ● question answered.\n
# 5
# 6   ● technician damaged during repair.\n● technic...
# 7
# 8              ● variety is patient with questions.\n
# 9   ● service is reliable, notch, efficient.\n● se...
# 10
# 11                          ● buying be experience.\n
# 12                          ● fixing be experience.\n
# 13  ● phone is helpful in setting phone, defective...
# 14  ● store is organized, understaffed, chaotic.\n...
# 15
# 16
# 17
# 18                               ● staff took time.\n
# 19
# 20
# 21  ● staff gave incorrect information about phone...
# 22                         ● warranty just expired.\n
# 23
# 24      ● phone still has same issue after getting.\n
# 25
# 26                             ● job is incomplete.\n
# 27
# 28                                ● support is non.\n
# 29   ● phone stopped working outside return window.\n
# 30

# %%
# pd.DataFrame.from_dict(result).to_excel('fail.xlsx', index=False)
